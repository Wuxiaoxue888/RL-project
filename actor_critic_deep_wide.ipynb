# %%
import gymnasium as gym
import mahjong_env
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from time import strftime
import csv
np.random.seed(42)
tf.random.set_seed(42)

# %%
class Logger:
    """Log rewards, models transitions"""
    def __init__(self):
        # Create a unique log directory
        self.log_dir = f"log_{strftime("%Y_%m_%d-%H_%M_%S")}"
        os.makedirs(self.log_dir, exist_ok=True)

        # Paths for logging files
        self.rewards_log_path = os.path.join(self.log_dir, "rewards.csv")
        self.transitions_log_path = os.path.join(self.log_dir, "transitions.csv")
        self.evaluation_log_path = os.path.join(self.log_dir, "evaluation_rewards.csv")
        self.policy_model_path = os.path.join(self.log_dir, "policy_model.keras")
        self.value_model_path = os.path.join(self.log_dir, "value_model.keras")

        # Initialize the CSV log files
        with open(self.rewards_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward sum", "last reward", "steps"])

        with open(self.transitions_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "state", "action", "next-state", "reward", "done", "truncated"])

        with open(self.evaluation_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward_sum", "last_reward", "steps"])

    def log_training_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])
            
    def log_eval_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])

    def log_transition(self, episode, state, action, next_state, reward, done, truncated):
        with open(self.transitions_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, state.tolist(), action, next_state.tolist(), reward, done, truncated])

    def save_policy_model(self, model):
        model.save(self.policy_model_path)
        
    def save_value_model(self, model):
        model.save(self.value_model_path)


class RewardNormalizer:
    def __init__(self):
        # Initialize variables for tracking mean, variance, and count of rewards
        self.mean = 0
        self.var = 0
        self.count = 0

    def normalize(self, reward):
        # Increment the count for normalization
        self.count += 1
        # Update the mean using an incremental formula
        old_mean = self.mean
        self.mean += (reward - self.mean) / self.count
        # Update variance using incremental formula
        self.var += (reward - old_mean) * (reward - self.mean)
        # Compute standard deviation and return normalized reward
        std = (self.var / self.count) ** 0.5
        return (reward - self.mean) / (std + 1e-8)


class ActorCritic:
    def __init__(self, env, policy_network, value_network, logger, gamma=0.99):
        # Initialize environment, networks, gamma, and optimizers
        self.env = env
        self.policy_network = policy_network
        self.value_network = value_network
        self.gamma = gamma
        self.learning_rate = 0.001
        self.policy_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.value_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        # Reward tracking for training and evaluation
        self.training_rewards_per_episode_sum = [] # including intermediate reward
        self.training_rewards_per_episode_last_one = [] # excluding intermediate reward
        self.eval_rewards_per_episode_sum = []
        self.eval_rewards_per_episode_last_one = []
        self.logger = logger  # Optional logging for rewards and models
        self.reward_normalizer = RewardNormalizer()  # Normalize rewards during training

    def take_action(self, state):
        # Select the best action (greedy) based on policy network's probabilities
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        # Mask invalid actions by setting their probabilities to -inf
        action_probs[(state[:27] == 0)] = -np.inf
        action = np.argmax(action_probs)  # Select action with highest probability
        return action

    def sample_action(self, state):
        # Select action probabilistically (exploration) while masking invalid actions
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        valid_actions = np.where(state[:27] != 0)[0]  # Identify valid actions
        invalid_actions = np.where(state[:27] == 0)[0]  # Identify invalid actions
        action_probs[invalid_actions] = 0.0  # Set invalid actions to 0 probability
        total_prob = np.sum(action_probs)
        if total_prob == 0.0:
            # Handle edge case where no valid actions exist
            print("No valid actions")
            return np.random.choice(valid_actions)
        # Normalize probabilities for valid actions
        normalized_probs = np.zeros_like(action_probs)
        normalized_probs[valid_actions] = action_probs[valid_actions] / total_prob
        # Sample action based on normalized probabilities
        action = np.random.choice(range(len(normalized_probs)), p=normalized_probs)
        return action

    def train_step(self, state, action, reward, next_state, done):
        # Update the value network using TD error
        with tf.GradientTape() as value_tape:
            # Compute predicted Q-value and target Q-value
            q_value = tf.squeeze(self.value_network(tf.expand_dims(state, axis=0)), axis=-1)
            target_q_value = reward + self.gamma * tf.squeeze(self.value_network(tf.expand_dims(next_state, axis=0)), axis=-1) * (1 - done)
            value_loss = tf.keras.losses.Huber()(target_q_value, q_value)  # Huber loss for stability

        # Update value network parameters
        value_grads = value_tape.gradient(value_loss, self.value_network.trainable_variables)
        self.value_optimizer.apply_gradients(zip(value_grads, self.value_network.trainable_variables))

        # Update the policy network using policy gradient
        td_error = target_q_value - q_value  # Temporal Difference error
        with tf.GradientTape() as policy_tape:
            action_probs = self.policy_network(tf.expand_dims(state, axis=0))
            mask = tf.constant(state[:27] != 0, dtype=tf.float32)  # Mask invalid actions
            masked_action_probs = action_probs * mask
            masked_action_probs /= (tf.reduce_sum(masked_action_probs) + 1e-8)  # Normalize probabilities
            selected_action_prob = tf.gather_nd(masked_action_probs, [[0, action]])
            selected_action_prob = tf.maximum(selected_action_prob, 1e-8)  # Avoid log(0)
            policy_loss = -tf.reduce_mean(tf.math.log(selected_action_prob) * tf.stop_gradient(td_error))  # Policy gradient loss

        # Update policy network parameters
        policy_grads = policy_tape.gradient(policy_loss, self.policy_network.trainable_variables)
        self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_network.trainable_variables))

    def process_state(self, state):
        # Normalize and preprocess state features for the neural networks
        normalized_hand = state['hand'] / 4.0
        normalized_visible_cards = state['visible cards'] / 4.0
        kangs_one_hot = tf.one_hot(state['kangs'], depth=4).numpy()
        kangs_one_hot_flat = kangs_one_hot.reshape(-1)  # Flatten one-hot encoding
        final_array = np.concatenate((
            normalized_hand,
            state['pongs'],
            kangs_one_hot_flat,
            normalized_visible_cards
        ))
        return final_array

    def run_episode(self):
        # Run a single episode and train at each step
        state, _ = self.env.reset()
        state = self.process_state(state)
        episode_reward = 0
        done = False
        steps = 0
        last_reward = 0
        while not done:
            action = self.sample_action(state)
            next_state, reward, done, truncated, _ = self.env.step(action)
            next_state = self.process_state(next_state)
            done = done or truncated
            normalized_reward = self.reward_normalizer.normalize(reward)  # Normalize reward
            self.train_step(state, action, normalized_reward, next_state, done)  # Train networks
            steps += 1
            episode_reward += reward
            if done:
                last_reward = reward
            state = next_state
        return episode_reward, last_reward, steps

    def evaluate(self, episodes):
        # Evaluate the agent over a specified number of episodes
        for episode in range(episodes):
            state, _ = self.env.reset()
            state = self.process_state(state)
            episode_reward = 0
            done = False
            steps = 0
            last_reward = 0
            while not done:
                action = self.take_action(state)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_state = self.process_state(next_state)
                done = done or truncated
                steps += 1
                episode_reward += reward
                if done:
                    last_reward = reward
                state = next_state
            self.eval_rewards_per_episode_sum.append(episode_reward)
            self.eval_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_eval_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")

    def train(self, episodes=1, save_freq=20):
        # Train the agent over multiple episodes
        for episode in range(episodes):
            episode_reward, last_reward, steps = self.run_episode()
            self.training_rewards_per_episode_sum.append(episode_reward)
            self.training_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_training_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")
            if (episode + 1) % save_freq == 0 and self.logger:
                self.logger.save_policy_model(self.policy_network)
                self.logger.save_value_model(self.value_network)


class PolicyNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(PolicyNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(256, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.dense3 = tf.keras.layers.Dense(num_actions, activation='softmax')

    def call(self, state):
        x = self.dense1(state)
        return self.dense3(self.dense2(x))


class ValueNetwork(tf.keras.Model):
    def __init__(self):
        super(ValueNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.dense3 = tf.keras.layers.Dense(1)

    def call(self, state):
        x = self.dense1(state)
        return self.dense3(self.dense2(x))


def plot_rewards(root_folder, rewards, title, save_fig=False):
    plt.figure(figsize=(12, 8))
    plt.plot(rewards, label='Total Reward per Episode')
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.title(title)
    plt.grid(True)
    if save_fig:
        plt.savefig(root_folder + "/" + title + '_' + strftime("%Y_%m_%d_%H_%M_%S") +'_' + '.png')
    plt.legend()
    plt.show()

# %%
# Environment setup
env = gym.make("Mahjong-v2")
policy = PolicyNetwork(num_actions=27)
value_network = ValueNetwork()
logger = Logger()
agent = ActorCritic(env, policy, value_network, logger)
agent.train(10000)
# Out:
# 2024-12-10 18:09:36.920728: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /home/adde/Downloads/ju/deep_venv/venv/lib/python3.12/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'policy_network', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Episode 1: Reward sum = -23.98, Last reward = -25.0, Steps = 15
# Episode 2: Reward sum = -32.98, Last reward = -35.0, Steps = 17
# Episode 3: Reward sum = -2.71, Last reward = -5.0, Steps = 16
# Episode 4: Reward sum = -9.26, Last reward = -11.0, Steps = 11
# Episode 5: Reward sum = -3.48, Last reward = -5.0, Steps = 13
# Episode 6: Reward sum = 0.43, Last reward = 0.0, Steps = 18
# Episode 7: Reward sum = -4.04, Last reward = -5.0, Steps = 6
# Episode 8: Reward sum = -56.74, Last reward = -58.0, Steps = 18
# Episode 9: Reward sum = -60.38, Last reward = -63.0, Steps = 19
# Episode 10: Reward sum = -3.89, Last reward = -5.0, Steps = 8
# Episode 11: Reward sum = -67.76, Last reward = -70.0, Steps = 17
# Episode 12: Reward sum = -4.82, Last reward = -5.0, Steps = 3
# Episode 13: Reward sum = -2.73, Last reward = -5.0, Steps = 17
# Episode 14: Reward sum = 30.89, Last reward = 30.0, Steps = 18
# Episode 15: Reward sum = -3.01, Last reward = -5.0, Steps = 19
# Episode 16: Reward sum = -19.27, Last reward = -20.0, Steps = 12
# Episode 17: Reward sum = -48.31, Last reward = -50.0, Steps = 18
# Episode 18: Reward sum = -7.60, Last reward = -8.0, Steps = 14
# Episode 19: Reward sum = -33.74, Last reward = -35.0, Steps = 18
# Episode 20: Reward sum = -3.80, Last reward = -5.0, Steps = 15
# Episode 21: Reward sum = -6.86, Last reward = -8.0, Steps = 15
# Episode 22: Reward sum = -12.58, Last reward = -15.0, Steps = 15
# Episode 23: Reward sum = -8.52, Last reward = -10.0, Steps = 15
# Episode 24: Reward sum = -39.32, Last reward = -40.0, Steps = 15
# Episode 25: Reward sum = -8.47, Last reward = -10.0, Steps = 17
# Episode 26: Reward sum = -17.52, Last reward = -20.0, Steps = 14
# Episode 27: Reward sum = -18.47, Last reward = -20.0, Steps = 13
# Episode 28: Reward sum = -3.17, Last reward = -5.0, Steps = 16
# Episode 29: Reward sum = -3.65, Last reward = -5.0, Steps = 12
# Episode 30: Reward sum = -54.12, Last reward = -55.0, Steps = 15
# Episode 31: Reward sum = -6.95, Last reward = -8.0, Steps = 10
# Episode 32: Reward sum = -4.59, Last reward = -5.0, Steps = 12
# Episode 33: Reward sum = -3.02, Last reward = -5.0, Steps = 11
# Episode 34: Reward sum = -17.65, Last reward = -20.0, Steps = 16
# Episode 35: Reward sum = -39.22, Last reward = -40.0, Steps = 17
# Episode 36: Reward sum = -4.05, Last reward = -5.0, Steps = 10
# Episode 37: Reward sum = -3.58, Last reward = -5.0, Steps = 11
# Episode 38: Reward sum = -6.59, Last reward = -8.0, Steps = 11
# Episode 39: Reward sum = -18.42, Last reward = -20.0, Steps = 12
# Episode 40: Reward sum = -43.27, Last reward = -46.0, Steps = 14
# Episode 41: Reward sum = -16.20, Last reward = -18.0, Steps = 18
# Episode 42: Reward sum = -3.25, Last reward = -5.0, Steps = 11
# Episode 43: Reward sum = -4.03, Last reward = -5.0, Steps = 7
# Episode 44: Reward sum = -38.67, Last reward = -40.0, Steps = 16
# Episode 45: Reward sum = -6.30, Last reward = -8.0, Steps = 9
# Episode 46: Reward sum = -7.98, Last reward = -10.0, Steps = 16
# Episode 47: Reward sum = -19.10, Last reward = -20.0, Steps = 9
# Episode 48: Reward sum = -9.04, Last reward = -10.0, Steps = 16
# Episode 49: Reward sum = -3.17, Last reward = -5.0, Steps = 12
# Episode 50: Reward sum = -3.19, Last reward = -5.0, Steps = 16
# Episode 51: Reward sum = -47.65, Last reward = -50.0, Steps = 17
# Episode 52: Reward sum = -4.55, Last reward = -5.0, Steps = 6
# Episode 53: Reward sum = -33.07, Last reward = -35.0, Steps = 16
# Episode 54: Reward sum = -3.49, Last reward = -5.0, Steps = 11
# Episode 55: Reward sum = -6.34, Last reward = -8.0, Steps = 8
# Episode 56: Reward sum = -3.60, Last reward = -5.0, Steps = 16
# Episode 57: Reward sum = -17.70, Last reward = -20.0, Steps = 13
# Episode 58: Reward sum = -4.25, Last reward = -5.0, Steps = 9
# Episode 59: Reward sum = -53.33, Last reward = -55.0, Steps = 15
# Episode 60: Reward sum = -18.24, Last reward = -20.0, Steps = 12
# Episode 61: Reward sum = -48.86, Last reward = -50.0, Steps = 16
# Episode 62: Reward sum = -36.75, Last reward = -40.0, Steps = 15
# Episode 63: Reward sum = -6.39, Last reward = -8.0, Steps = 15
# Episode 64: Reward sum = -3.48, Last reward = -5.0, Steps = 16
# Episode 65: Reward sum = -5.32, Last reward = -8.0, Steps = 16
# Episode 66: Reward sum = -51.87, Last reward = -55.0, Steps = 15
# Episode 67: Reward sum = -42.94, Last reward = -45.0, Steps = 16
# Episode 68: Reward sum = -4.24, Last reward = -5.0, Steps = 6
# Episode 69: Reward sum = -2.62, Last reward = -5.0, Steps = 12
# Episode 70: Reward sum = -24.92, Last reward = -26.0, Steps = 13
# Episode 71: Reward sum = -55.33, Last reward = -58.0, Steps = 15
# Episode 72: Reward sum = -26.59, Last reward = -28.0, Steps = 16
# Episode 73: Reward sum = -18.33, Last reward = -20.0, Steps = 15
# Episode 74: Reward sum = -60.38, Last reward = -63.0, Steps = 18
# Episode 75: Reward sum = -29.20, Last reward = -30.0, Steps = 12
# Episode 76: Reward sum = -4.20, Last reward = -5.0, Steps = 11
# Episode 77: Reward sum = -8.79, Last reward = -10.0, Steps = 16
# Episode 78: Reward sum = -3.84, Last reward = -5.0, Steps = 8
# Episode 79: Reward sum = -23.57, Last reward = -25.0, Steps = 15
# Episode 80: Reward sum = -3.23, Last reward = -5.0, Steps = 17
# Episode 81: Reward sum = -18.17, Last reward = -20.0, Steps = 7
# Episode 82: Reward sum = -7.90, Last reward = -10.0, Steps = 16
# Episode 83: Reward sum = -4.67, Last reward = -8.0, Steps = 17
# Episode 84: Reward sum = 4.28, Last reward = 2.0, Steps = 16
# Episode 85: Reward sum = -3.50, Last reward = -5.0, Steps = 9
# Episode 86: Reward sum = -38.13, Last reward = -40.0, Steps = 17
# Episode 87: Reward sum = -42.60, Last reward = -45.0, Steps = 16
# Episode 88: Reward sum = -19.27, Last reward = -20.0, Steps = 10
# Episode 89: Reward sum = 19.15, Last reward = 18.0, Steps = 8
# Episode 90: Reward sum = -2.84, Last reward = -5.0, Steps = 13
# Episode 91: Reward sum = -2.14, Last reward = -5.0, Steps = 16
# Episode 92: Reward sum = -3.15, Last reward = -5.0, Steps = 12
# Episode 93: Reward sum = -9.20, Last reward = -10.0, Steps = 18
# Episode 94: Reward sum = -2.72, Last reward = -5.0, Steps = 15
# Episode 95: Reward sum = 28.53, Last reward = 27.0, Steps = 19
# Episode 96: Reward sum = -21.95, Last reward = -25.0, Steps = 16
# Episode 97: Reward sum = -27.73, Last reward = -30.0, Steps = 14
# Episode 98: Reward sum = -3.45, Last reward = -5.0, Steps = 11
# Episode 99: Reward sum = -53.98, Last reward = -55.0, Steps = 16
# Episode 100: Reward sum = -17.88, Last reward = -20.0, Steps = 18
# Episode 101: Reward sum = -3.18, Last reward = -5.0, Steps = 14
# Episode 102: Reward sum = -2.46, Last reward = -5.0, Steps = 15
# Episode 103: Reward sum = -27.34, Last reward = -30.0, Steps = 16
# Episode 104: Reward sum = -56.56, Last reward = -58.0, Steps = 15
# Episode 105: Reward sum = 1.83, Last reward = 0.0, Steps = 16
# Episode 106: Reward sum = -0.82, Last reward = -3.0, Steps = 17
# Episode 107: Reward sum = -3.84, Last reward = -5.0, Steps = 15
# Episode 108: Reward sum = -43.03, Last reward = -45.0, Steps = 16
# Episode 109: Reward sum = -36.53, Last reward = -39.0, Steps = 16
# Episode 110: Reward sum = -65.15, Last reward = -68.0, Steps = 20
# Episode 111: Reward sum = -3.30, Last reward = -5.0, Steps = 9
# Episode 112: Reward sum = 35.14, Last reward = 33.0, Steps = 10
# Episode 113: Reward sum = -68.80, Last reward = -70.0, Steps = 18
# Episode 114: Reward sum = 11.10, Last reward = 10.0, Steps = 15
# Episode 115: Reward sum = 66.55, Last reward = 63.0, Steps = 16
# Episode 116: Reward sum = 1.58, Last reward = 0.0, Steps = 12
# Episode 117: Reward sum = -6.74, Last reward = -10.0, Steps = 16
# Episode 118: Reward sum = -6.97, Last reward = -8.0, Steps = 13
# Episode 119: Reward sum = -3.79, Last reward = -5.0, Steps = 12
# Episode 120: Reward sum = -3.21, Last reward = -5.0, Steps = 10
# Episode 121: Reward sum = 90.95, Last reward = 90.0, Steps = 18
# Episode 122: Reward sum = 32.76, Last reward = 30.0, Steps = 19
# Episode 123: Reward sum = -41.32, Last reward = -43.0, Steps = 18
# Episode 124: Reward sum = -18.46, Last reward = -20.0, Steps = 11
# Episode 125: Reward sum = 31.00, Last reward = 30.0, Steps = 16
# Episode 126: Reward sum = -23.16, Last reward = -25.0, Steps = 17
# Episode 127: Reward sum = -4.18, Last reward = -5.0, Steps = 10
# Episode 128: Reward sum = -6.41, Last reward = -8.0, Steps = 11
# Episode 129: Reward sum = 1.70, Last reward = 0.0, Steps = 18
# Episode 130: Reward sum = -1.52, Last reward = -5.0, Steps = 17
# Episode 131: Reward sum = -2.57, Last reward = -5.0, Steps = 16
# Episode 132: Reward sum = -6.24, Last reward = -8.0, Steps = 14
# Episode 133: Reward sum = -3.56, Last reward = -5.0, Steps = 11
# Episode 134: Reward sum = -3.50, Last reward = -5.0, Steps = 13
# Episode 135: Reward sum = -4.45, Last reward = -5.0, Steps = 15
# Episode 136: Reward sum = -2.58, Last reward = -5.0, Steps = 18
# Episode 137: Reward sum = -66.11, Last reward = -69.0, Steps = 18
# Episode 138: Reward sum = -3.10, Last reward = -5.0, Steps = 9
# Episode 139: Reward sum = -4.06, Last reward = -5.0, Steps = 10
# Episode 140: Reward sum = 0.81, Last reward = 0.0, Steps = 16
# Episode 141: Reward sum = -32.90, Last reward = -35.0, Steps = 18
# Episode 142: Reward sum = -2.97, Last reward = -5.0, Steps = 12
# Episode 143: Reward sum = -3.82, Last reward = -5.0, Steps = 7
# Episode 144: Reward sum = -3.75, Last reward = -5.0, Steps = 15
# Episode 145: Reward sum = -3.71, Last reward = -5.0, Steps = 11
# Episode 146: Reward sum = -4.06, Last reward = -5.0, Steps = 14
# Episode 147: Reward sum = -4.67, Last reward = -5.0, Steps = 5
# Episode 148: Reward sum = -3.92, Last reward = -5.0, Steps = 9
# Episode 149: Reward sum = -25.55, Last reward = -28.0, Steps = 16
# Episode 150: Reward sum = -2.65, Last reward = -5.0, Steps = 16
# Episode 151: Reward sum = -4.07, Last reward = -5.0, Steps = 7
# Episode 152: Reward sum = -40.86, Last reward = -43.0, Steps = 16
# Episode 153: Reward sum = 34.03, Last reward = 33.0, Steps = 18
# Episode 154: Reward sum = -39.25, Last reward = -40.0, Steps = 17
# Episode 155: Reward sum = -45.05, Last reward = -46.0, Steps = 17
# Episode 156: Reward sum = -40.86, Last reward = -43.0, Steps = 15
# Episode 157: Reward sum = -26.86, Last reward = -30.0, Steps = 16
# Episode 158: Reward sum = -23.01, Last reward = -25.0, Steps = 16
# Episode 159: Reward sum = -3.02, Last reward = -5.0, Steps = 11
# Episode 160: Reward sum = -8.45, Last reward = -10.0, Steps = 16
# Episode 161: Reward sum = -3.72, Last reward = -5.0, Steps = 15
# Episode 162: Reward sum = -9.99, Last reward = -11.0, Steps = 16
# Episode 163: Reward sum = -3.84, Last reward = -5.0, Steps = 15
# Episode 164: Reward sum = -19.43, Last reward = -20.0, Steps = 14
# Episode 165: Reward sum = -37.53, Last reward = -40.0, Steps = 16
# Episode 166: Reward sum = -3.55, Last reward = -5.0, Steps = 15
# Episode 167: Reward sum = -12.35, Last reward = -15.0, Steps = 16
# Episode 168: Reward sum = -32.34, Last reward = -35.0, Steps = 15
# Episode 169: Reward sum = -58.80, Last reward = -60.0, Steps = 15
# Episode 170: Reward sum = -12.61, Last reward = -15.0, Steps = 18
# Episode 171: Reward sum = -18.94, Last reward = -21.0, Steps = 15
# Episode 172: Reward sum = -33.25, Last reward = -35.0, Steps = 16
# Episode 173: Reward sum = -4.02, Last reward = -5.0, Steps = 7
# Episode 174: Reward sum = -7.95, Last reward = -10.0, Steps = 17
# Episode 175: Reward sum = -6.15, Last reward = -8.0, Steps = 17
# Episode 176: Reward sum = -28.91, Last reward = -31.0, Steps = 16
# Episode 177: Reward sum = -66.15, Last reward = -68.0, Steps = 17
# Episode 178: Reward sum = -31.22, Last reward = -33.0, Steps = 15
# Episode 179: Reward sum = -18.84, Last reward = -20.0, Steps = 9
# Episode 180: Reward sum = -29.50, Last reward = -30.0, Steps = 11
# Episode 181: Reward sum = 1.12, Last reward = 0.0, Steps = 17
# Episode 182: Reward sum = -3.74, Last reward = -5.0, Steps = 15
# Episode 183: Reward sum = 0.76, Last reward = 0.0, Steps = 8
# Episode 184: Reward sum = -23.78, Last reward = -25.0, Steps = 17
# Episode 185: Reward sum = -13.80, Last reward = -17.0, Steps = 17
# Episode 186: Reward sum = -2.77, Last reward = -5.0, Steps = 18
# Episode 187: Reward sum = -29.51, Last reward = -30.0, Steps = 16
# Episode 188: Reward sum = 1.43, Last reward = 0.0, Steps = 14
# Episode 189: Reward sum = -3.47, Last reward = -5.0, Steps = 15
# Episode 190: Reward sum = -33.01, Last reward = -35.0, Steps = 17
# Episode 191: Reward sum = -2.84, Last reward = -5.0, Steps = 14
# Episode 192: Reward sum = -37.35, Last reward = -38.0, Steps = 16
# Episode 193: Reward sum = -18.00, Last reward = -20.0, Steps = 12
# Episode 194: Reward sum = -18.52, Last reward = -20.0, Steps = 17
# Episode 195: Reward sum = -18.35, Last reward = -20.0, Steps = 11
# Episode 196: Reward sum = -28.21, Last reward = -30.0, Steps = 14
# Episode 197: Reward sum = -52.70, Last reward = -55.0, Steps = 17
# Episode 198: Reward sum = -18.50, Last reward = -20.0, Steps = 16
# Episode 199: Reward sum = -32.20, Last reward = -35.0, Steps = 13
# Episode 200: Reward sum = -18.25, Last reward = -20.0, Steps = 12
# Episode 201: Reward sum = -38.91, Last reward = -40.0, Steps = 17
# Episode 202: Reward sum = -3.25, Last reward = -5.0, Steps = 14
# Episode 203: Reward sum = -35.82, Last reward = -38.0, Steps = 15
# Episode 204: Reward sum = -4.54, Last reward = -5.0, Steps = 9
# Episode 205: Reward sum = -25.30, Last reward = -28.0, Steps = 16
# Episode 206: Reward sum = -9.66, Last reward = -11.0, Steps = 13
# Episode 207: Reward sum = -4.38, Last reward = -5.0, Steps = 5
# Episode 208: Reward sum = -4.25, Last reward = -5.0, Steps = 5
# Episode 209: Reward sum = -28.96, Last reward = -30.0, Steps = 16
# Episode 210: Reward sum = -4.34, Last reward = -5.0, Steps = 8
# Episode 211: Reward sum = -4.11, Last reward = -5.0, Steps = 11
# Episode 212: Reward sum = -4.36, Last reward = -5.0, Steps = 5
# Episode 213: Reward sum = -4.11, Last reward = -5.0, Steps = 12
# Episode 214: Reward sum = -25.42, Last reward = -26.0, Steps = 16
# Episode 215: Reward sum = -27.81, Last reward = -30.0, Steps = 16
# Episode 216: Reward sum = -6.10, Last reward = -8.0, Steps = 14
# Episode 217: Reward sum = -3.50, Last reward = -5.0, Steps = 13
# Episode 218: Reward sum = -33.54, Last reward = -35.0, Steps = 18
# Episode 219: Reward sum = -39.12, Last reward = -40.0, Steps = 15
# Episode 220: Reward sum = -65.94, Last reward = -68.0, Steps = 16
# Episode 221: Reward sum = -4.00, Last reward = -5.0, Steps = 7
# Episode 222: Reward sum = -28.52, Last reward = -30.0, Steps = 17
# Episode 223: Reward sum = -7.02, Last reward = -8.0, Steps = 15
# Episode 224: Reward sum = -3.25, Last reward = -5.0, Steps = 13
# Episode 225: Reward sum = -3.46, Last reward = -5.0, Steps = 9
# Episode 226: Reward sum = -3.07, Last reward = -5.0, Steps = 10
# Episode 227: Reward sum = -4.47, Last reward = -5.0, Steps = 9
# Episode 228: Reward sum = -19.12, Last reward = -20.0, Steps = 7
# Episode 229: Reward sum = -34.06, Last reward = -35.0, Steps = 13
# Episode 230: Reward sum = -18.66, Last reward = -20.0, Steps = 17
# Episode 231: Reward sum = -18.26, Last reward = -20.0, Steps = 14
# Episode 232: Reward sum = -66.10, Last reward = -68.0, Steps = 17
# Episode 233: Reward sum = -37.90, Last reward = -40.0, Steps = 17
# Episode 234: Reward sum = -24.15, Last reward = -25.0, Steps = 15
# Episode 235: Reward sum = -42.79, Last reward = -45.0, Steps = 16
# Episode 236: Reward sum = -32.90, Last reward = -35.0, Steps = 15
# Episode 237: Reward sum = -6.42, Last reward = -8.0, Steps = 15
# Episode 238: Reward sum = -35.87, Last reward = -38.0, Steps = 16
# Episode 239: Reward sum = -6.92, Last reward = -10.0, Steps = 17
# Episode 240: Reward sum = -4.48, Last reward = -5.0, Steps = 5
# Episode 241: Reward sum = -53.40, Last reward = -55.0, Steps = 18
# Episode 242: Reward sum = 21.79, Last reward = 20.0, Steps = 14
# Episode 243: Reward sum = -17.50, Last reward = -20.0, Steps = 16
# Episode 244: Reward sum = -4.19, Last reward = -5.0, Steps = 13
# Episode 245: Reward sum = -75.47, Last reward = -76.0, Steps = 18
# Episode 246: Reward sum = -3.36, Last reward = -5.0, Steps = 9
# Episode 247: Reward sum = -21.83, Last reward = -23.0, Steps = 12
# Episode 248: Reward sum = -3.11, Last reward = -5.0, Steps = 17
# Episode 249: Reward sum = -32.37, Last reward = -35.0, Steps = 17
# Episode 250: Reward sum = -29.57, Last reward = -30.0, Steps = 10
# Episode 251: Reward sum = -50.92, Last reward = -53.0, Steps = 16
# Episode 252: Reward sum = -35.33, Last reward = -38.0, Steps = 17
# Episode 253: Reward sum = -37.85, Last reward = -40.0, Steps = 17
# Episode 254: Reward sum = 7.25, Last reward = 0.0, Steps = 10
# Episode 255: Reward sum = -8.74, Last reward = -10.0, Steps = 17
# Episode 256: Reward sum = -3.31, Last reward = -5.0, Steps = 14
# Episode 257: Reward sum = -3.26, Last reward = -5.0, Steps = 14
# Episode 258: Reward sum = -18.40, Last reward = -20.0, Steps = 12
# Episode 259: Reward sum = -27.88, Last reward = -30.0, Steps = 16
# Episode 260: Reward sum = -8.30, Last reward = -10.0, Steps = 18
# Episode 261: Reward sum = -2.20, Last reward = -5.0, Steps = 14
# Episode 262: Reward sum = -37.78, Last reward = -40.0, Steps = 16
# Episode 263: Reward sum = -8.45, Last reward = -10.0, Steps = 16
# Episode 264: Reward sum = -7.79, Last reward = -10.0, Steps = 16
# Episode 265: Reward sum = 65.66, Last reward = 63.0, Steps = 18
# Episode 266: Reward sum = -3.29, Last reward = -5.0, Steps = 13
# Episode 267: Reward sum = -17.96, Last reward = -20.0, Steps = 15
# Episode 268: Reward sum = 1.55, Last reward = 0.0, Steps = 14
# Episode 269: Reward sum = -3.66, Last reward = -5.0, Steps = 10
# Episode 270: Reward sum = -18.18, Last reward = -20.0, Steps = 11
# Episode 271: Reward sum = -62.80, Last reward = -65.0, Steps = 17
# Episode 272: Reward sum = -5.88, Last reward = -8.0, Steps = 12
# Episode 273: Reward sum = 0.57, Last reward = 0.0, Steps = 14
# Episode 274: Reward sum = -2.38, Last reward = -5.0, Steps = 10
# Episode 275: Reward sum = -26.72, Last reward = -28.0, Steps = 15
# Episode 276: Reward sum = -17.15, Last reward = -20.0, Steps = 16
# Episode 277: Reward sum = -13.77, Last reward = -15.0, Steps = 16
# Episode 278: Reward sum = -38.82, Last reward = -40.0, Steps = 16
# Episode 279: Reward sum = -3.50, Last reward = -5.0, Steps = 13
# Episode 280: Reward sum = -24.12, Last reward = -25.0, Steps = 14
# Episode 281: Reward sum = -42.93, Last reward = -46.0, Steps = 15
# Episode 282: Reward sum = 28.20, Last reward = 27.0, Steps = 16
# Episode 283: Reward sum = -2.84, Last reward = -5.0, Steps = 13
# Episode 284: Reward sum = -4.66, Last reward = -5.0, Steps = 10
# Episode 285: Reward sum = -3.81, Last reward = -5.0, Steps = 10
# Episode 286: Reward sum = -2.12, Last reward = -5.0, Steps = 16
# Episode 287: Reward sum = -32.79, Last reward = -35.0, Steps = 16
# Episode 288: Reward sum = -3.05, Last reward = -5.0, Steps = 16
# Episode 289: Reward sum = -30.60, Last reward = -33.0, Steps = 16
# Episode 290: Reward sum = -31.26, Last reward = -33.0, Steps = 10
# Episode 291: Reward sum = -33.02, Last reward = -35.0, Steps = 18
# Episode 292: Reward sum = -42.66, Last reward = -45.0, Steps = 14
# Episode 293: Reward sum = -7.45, Last reward = -8.0, Steps = 11
# Episode 294: Reward sum = -3.66, Last reward = -5.0, Steps = 12
# Episode 295: Reward sum = -56.09, Last reward = -58.0, Steps = 15
# Episode 296: Reward sum = -50.22, Last reward = -53.0, Steps = 18
# Episode 297: Reward sum = 1.30, Last reward = 0.0, Steps = 17
# Episode 298: Reward sum = -18.22, Last reward = -20.0, Steps = 13
# Episode 299: Reward sum = -36.55, Last reward = -40.0, Steps = 18
# Episode 300: Reward sum = 1.93, Last reward = 0.0, Steps = 19
# Episode 301: Reward sum = -26.65, Last reward = -28.0, Steps = 16
# Episode 302: Reward sum = -50.38, Last reward = -53.0, Steps = 16
# Episode 303: Reward sum = -58.23, Last reward = -60.0, Steps = 15
# Episode 304: Reward sum = -25.70, Last reward = -28.0, Steps = 16
# Episode 305: Reward sum = 1.60, Last reward = 0.0, Steps = 18
# Episode 306: Reward sum = -10.85, Last reward = -13.0, Steps = 16
# Episode 307: Reward sum = -32.89, Last reward = -35.0, Steps = 15
# Episode 308: Reward sum = -3.09, Last reward = -5.0, Steps = 14
# Episode 309: Reward sum = -6.38, Last reward = -8.0, Steps = 15
# Episode 310: Reward sum = -12.57, Last reward = -15.0, Steps = 16
# Episode 311: Reward sum = -92.93, Last reward = -96.0, Steps = 18
# Episode 312: Reward sum = -9.09, Last reward = -10.0, Steps = 16
# Episode 313: Reward sum = -30.98, Last reward = -33.0, Steps = 15
# Episode 314: Reward sum = -21.73, Last reward = -25.0, Steps = 17
# Episode 315: Reward sum = 2.42, Last reward = 0.0, Steps = 13
# Episode 316: Reward sum = -5.77, Last reward = -8.0, Steps = 14
# Episode 317: Reward sum = -7.56, Last reward = -10.0, Steps = 18
# Episode 318: Reward sum = -1.73, Last reward = -5.0, Steps = 17
# Episode 319: Reward sum = 2.08, Last reward = 0.0, Steps = 17
# Episode 320: Reward sum = 68.62, Last reward = 66.0, Steps = 17
# Episode 321: Reward sum = -1.80, Last reward = -5.0, Steps = 16
# Episode 322: Reward sum = -26.44, Last reward = -28.0, Steps = 17
# Episode 323: Reward sum = -45.86, Last reward = -48.0, Steps = 15
# Episode 324: Reward sum = -18.09, Last reward = -20.0, Steps = 13
# Episode 325: Reward sum = -3.30, Last reward = -5.0, Steps = 14
# Episode 326: Reward sum = -23.93, Last reward = -25.0, Steps = 16
# Episode 327: Reward sum = -78.91, Last reward = -80.0, Steps = 16
# Episode 328: Reward sum = -53.47, Last reward = -55.0, Steps = 14
# Episode 329: Reward sum = -19.35, Last reward = -20.0, Steps = 12
# Episode 330: Reward sum = -18.61, Last reward = -20.0, Steps = 9
# Episode 331: Reward sum = -3.70, Last reward = -5.0, Steps = 11
# Episode 332: Reward sum = -38.92, Last reward = -40.0, Steps = 16
# Episode 333: Reward sum = -2.69, Last reward = -5.0, Steps = 14
# Episode 334: Reward sum = -23.13, Last reward = -25.0, Steps = 15
# Episode 335: Reward sum = -4.30, Last reward = -5.0, Steps = 6
# Episode 336: Reward sum = -60.86, Last reward = -63.0, Steps = 15
# Episode 337: Reward sum = -2.95, Last reward = -5.0, Steps = 16
# Episode 338: Reward sum = -8.72, Last reward = -10.0, Steps = 17
# Episode 339: Reward sum = -3.38, Last reward = -5.0, Steps = 14
# Episode 340: Reward sum = 0.68, Last reward = 0.0, Steps = 16
# Episode 341: Reward sum = -56.86, Last reward = -58.0, Steps = 16
# Episode 342: Reward sum = -23.93, Last reward = -25.0, Steps = 16
# Episode 343: Reward sum = -65.33, Last reward = -68.0, Steps = 17
# Episode 344: Reward sum = -4.64, Last reward = -5.0, Steps = 4
# Episode 345: Reward sum = -47.68, Last reward = -50.0, Steps = 16
# Episode 346: Reward sum = -5.00, Last reward = -8.0, Steps = 16
# Episode 347: Reward sum = -3.22, Last reward = -5.0, Steps = 7
# Episode 348: Reward sum = -52.31, Last reward = -55.0, Steps = 18
# Episode 349: Reward sum = -37.96, Last reward = -41.0, Steps = 17
# Episode 350: Reward sum = -30.20, Last reward = -33.0, Steps = 16
# Episode 351: Reward sum = -3.09, Last reward = -5.0, Steps = 13
# Episode 352: Reward sum = -22.38, Last reward = -25.0, Steps = 16
# Episode 353: Reward sum = -3.27, Last reward = -5.0, Steps = 9
# Episode 354: Reward sum = -96.45, Last reward = -98.0, Steps = 16
# Episode 355: Reward sum = -7.99, Last reward = -10.0, Steps = 16
# Episode 356: Reward sum = -26.48, Last reward = -30.0, Steps = 17
# Episode 357: Reward sum = -8.20, Last reward = -10.0, Steps = 17
# Episode 358: Reward sum = -4.17, Last reward = -5.0, Steps = 8
# Episode 359: Reward sum = -4.69, Last reward = -5.0, Steps = 3
# Episode 360: Reward sum = -3.99, Last reward = -5.0, Steps = 8
# Episode 361: Reward sum = -23.10, Last reward = -25.0, Steps = 18
# Episode 362: Reward sum = -13.53, Last reward = -15.0, Steps = 14
# Episode 363: Reward sum = -32.51, Last reward = -35.0, Steps = 16
# Episode 364: Reward sum = -7.22, Last reward = -10.0, Steps = 17
# Episode 365: Reward sum = -7.23, Last reward = -10.0, Steps = 15
# Episode 366: Reward sum = 93.73, Last reward = 93.0, Steps = 14
# Episode 367: Reward sum = -30.76, Last reward = -33.0, Steps = 17
# Episode 368: Reward sum = -3.36, Last reward = -5.0, Steps = 12
# Episode 369: Reward sum = -70.66, Last reward = -73.0, Steps = 16
# Episode 370: Reward sum = 61.45, Last reward = 60.0, Steps = 17
# Episode 371: Reward sum = -5.87, Last reward = -10.0, Steps = 18
# Episode 372: Reward sum = -3.40, Last reward = -5.0, Steps = 10
# Episode 373: Reward sum = -63.34, Last reward = -65.0, Steps = 16
# Episode 374: Reward sum = -4.09, Last reward = -5.0, Steps = 12
# Episode 375: Reward sum = 62.85, Last reward = 60.0, Steps = 16
# Episode 376: Reward sum = -12.75, Last reward = -15.0, Steps = 16
# Episode 377: Reward sum = -7.60, Last reward = -10.0, Steps = 17
# Episode 378: Reward sum = -3.58, Last reward = -5.0, Steps = 16
# Episode 379: Reward sum = -14.10, Last reward = -18.0, Steps = 16
# Episode 380: Reward sum = -3.44, Last reward = -5.0, Steps = 16
# Episode 381: Reward sum = 0.49, Last reward = 0.0, Steps = 4
# Episode 382: Reward sum = -2.85, Last reward = -5.0, Steps = 11
# Episode 383: Reward sum = -0.76, Last reward = -5.0, Steps = 16
# Episode 384: Reward sum = -27.94, Last reward = -30.0, Steps = 17
# Episode 385: Reward sum = -4.35, Last reward = -5.0, Steps = 8
# Episode 386: Reward sum = -3.96, Last reward = -5.0, Steps = 10
# Episode 387: Reward sum = -21.96, Last reward = -25.0, Steps = 17
# Episode 388: Reward sum = -4.82, Last reward = -5.0, Steps = 2
# Episode 389: Reward sum = 2.16, Last reward = 0.0, Steps = 13
# Episode 390: Reward sum = -3.92, Last reward = -5.0, Steps = 18
# Episode 391: Reward sum = -7.31, Last reward = -10.0, Steps = 17
# Episode 392: Reward sum = -19.39, Last reward = -20.0, Steps = 8
# Episode 393: Reward sum = -34.89, Last reward = -38.0, Steps = 18
# Episode 394: Reward sum = -6.18, Last reward = -8.0, Steps = 15
# Episode 395: Reward sum = -48.56, Last reward = -50.0, Steps = 14
# Episode 396: Reward sum = -61.24, Last reward = -63.0, Steps = 15
# Episode 397: Reward sum = -3.31, Last reward = -5.0, Steps = 9
# Episode 398: Reward sum = -3.41, Last reward = -5.0, Steps = 13
# Episode 399: Reward sum = -37.35, Last reward = -40.0, Steps = 17
# Episode 400: Reward sum = -55.48, Last reward = -58.0, Steps = 15
# Episode 401: Reward sum = -48.44, Last reward = -50.0, Steps = 15
# Episode 402: Reward sum = 1.77, Last reward = 0.0, Steps = 16
# Episode 403: Reward sum = -4.57, Last reward = -5.0, Steps = 5
# Episode 404: Reward sum = -28.80, Last reward = -30.0, Steps = 16
# Episode 405: Reward sum = -26.87, Last reward = -30.0, Steps = 17
# Episode 406: Reward sum = -28.50, Last reward = -30.0, Steps = 11
# Episode 407: Reward sum = -23.23, Last reward = -25.0, Steps = 16
# Episode 408: Reward sum = -4.21, Last reward = -5.0, Steps = 12
# Episode 409: Reward sum = 3.97, Last reward = 0.0, Steps = 17
# Episode 410: Reward sum = -3.46, Last reward = -5.0, Steps = 14
# Episode 411: Reward sum = -23.37, Last reward = -25.0, Steps = 17
# Episode 412: Reward sum = -28.50, Last reward = -30.0, Steps = 17
# Episode 413: Reward sum = -39.05, Last reward = -40.0, Steps = 16
# Episode 414: Reward sum = -3.33, Last reward = -5.0, Steps = 12
# Episode 415: Reward sum = -38.65, Last reward = -40.0, Steps = 16
# Episode 416: Reward sum = -18.18, Last reward = -20.0, Steps = 17
# Episode 417: Reward sum = -3.41, Last reward = -5.0, Steps = 9
# Episode 418: Reward sum = 2.50, Last reward = 0.0, Steps = 17
# Episode 419: Reward sum = -3.64, Last reward = -5.0, Steps = 9
# Episode 420: Reward sum = -2.68, Last reward = -5.0, Steps = 12
# Episode 421: Reward sum = 62.94, Last reward = 60.0, Steps = 17
# Episode 422: Reward sum = 2.66, Last reward = 0.0, Steps = 17
# Episode 423: Reward sum = -8.14, Last reward = -10.0, Steps = 16
# Episode 424: Reward sum = -3.85, Last reward = -5.0, Steps = 10
# Episode 425: Reward sum = -19.24, Last reward = -20.0, Steps = 9
# Episode 426: Reward sum = -4.85, Last reward = -5.0, Steps = 10
# Episode 427: Reward sum = -6.42, Last reward = -8.0, Steps = 16
# Episode 428: Reward sum = -32.96, Last reward = -35.0, Steps = 17
# Episode 429: Reward sum = -3.71, Last reward = -5.0, Steps = 14
# Episode 430: Reward sum = -7.50, Last reward = -8.0, Steps = 5
# Episode 431: Reward sum = -35.00, Last reward = -38.0, Steps = 17
# Episode 432: Reward sum = -25.48, Last reward = -30.0, Steps = 15
# Episode 433: Reward sum = -7.68, Last reward = -10.0, Steps = 18
# Episode 434: Reward sum = -62.21, Last reward = -65.0, Steps = 19
# Episode 435: Reward sum = 31.04, Last reward = 30.0, Steps = 18
# Episode 436: Reward sum = -6.40, Last reward = -8.0, Steps = 16
# Episode 437: Reward sum = -69.36, Last reward = -71.0, Steps = 15
# Episode 438: Reward sum = -29.31, Last reward = -30.0, Steps = 16
# Episode 439: Reward sum = -3.73, Last reward = -5.0, Steps = 14
# Episode 440: Reward sum = -3.19, Last reward = -5.0, Steps = 15
# Episode 441: Reward sum = -6.80, Last reward = -10.0, Steps = 17
# Episode 442: Reward sum = -18.42, Last reward = -20.0, Steps = 15
# Episode 443: Reward sum = -33.43, Last reward = -35.0, Steps = 15
# Episode 444: Reward sum = -7.89, Last reward = -10.0, Steps = 16
# Episode 445: Reward sum = -60.86, Last reward = -63.0, Steps = 17
# Episode 446: Reward sum = -28.44, Last reward = -30.0, Steps = 10
# Episode 447: Reward sum = -28.55, Last reward = -30.0, Steps = 16
# Episode 448: Reward sum = -63.11, Last reward = -65.0, Steps = 17
# Episode 449: Reward sum = -27.68, Last reward = -30.0, Steps = 15
# Episode 450: Reward sum = -3.40, Last reward = -5.0, Steps = 13
# Episode 451: Reward sum = -23.22, Last reward = -25.0, Steps = 14
# Episode 452: Reward sum = 91.41, Last reward = 90.0, Steps = 10
# Episode 453: Reward sum = -19.11, Last reward = -20.0, Steps = 7
# Episode 454: Reward sum = -15.38, Last reward = -18.0, Steps = 15
# Episode 455: Reward sum = -38.15, Last reward = -40.0, Steps = 16
# Episode 456: Reward sum = -66.47, Last reward = -68.0, Steps = 18
# Episode 457: Reward sum = -28.60, Last reward = -30.0, Steps = 17
# Episode 458: Reward sum = -3.87, Last reward = -5.0, Steps = 15
# Episode 459: Reward sum = -3.74, Last reward = -5.0, Steps = 8
# Episode 460: Reward sum = -18.85, Last reward = -20.0, Steps = 7
# Episode 461: Reward sum = -38.29, Last reward = -40.0, Steps = 13
# Episode 462: Reward sum = -4.20, Last reward = -5.0, Steps = 6
# Episode 463: Reward sum = 22.25, Last reward = 20.0, Steps = 17
# Episode 464: Reward sum = -17.46, Last reward = -20.0, Steps = 14
# Episode 465: Reward sum = -7.47, Last reward = -8.0, Steps = 13
# Episode 466: Reward sum = -4.54, Last reward = -5.0, Steps = 3
# Episode 467: Reward sum = 2.21, Last reward = 0.0, Steps = 17
# Episode 468: Reward sum = -30.39, Last reward = -33.0, Steps = 18
# Episode 469: Reward sum = -7.53, Last reward = -8.0, Steps = 15
# Episode 470: Reward sum = -18.27, Last reward = -20.0, Steps = 12
# Episode 471: Reward sum = -18.34, Last reward = -20.0, Steps = 15
# Episode 472: Reward sum = -5.07, Last reward = -8.0, Steps = 14
# Episode 473: Reward sum = -42.35, Last reward = -45.0, Steps = 16
# Episode 474: Reward sum = -19.07, Last reward = -20.0, Steps = 12
# Episode 475: Reward sum = -3.98, Last reward = -5.0, Steps = 7
# Episode 476: Reward sum = -38.05, Last reward = -40.0, Steps = 16
# Episode 477: Reward sum = -3.24, Last reward = -5.0, Steps = 15
# Episode 478: Reward sum = -29.14, Last reward = -30.0, Steps = 12
# Episode 479: Reward sum = -27.83, Last reward = -30.0, Steps = 15
# Episode 480: Reward sum = -6.52, Last reward = -8.0, Steps = 12
# Episode 481: Reward sum = -3.39, Last reward = -5.0, Steps = 16
# Episode 482: Reward sum = -3.57, Last reward = -5.0, Steps = 16
# Episode 483: Reward sum = -28.59, Last reward = -30.0, Steps = 12
# Episode 484: Reward sum = -27.91, Last reward = -30.0, Steps = 16
# Episode 485: Reward sum = -3.95, Last reward = -5.0, Steps = 7
# Episode 486: Reward sum = -28.50, Last reward = -30.0, Steps = 16
# Episode 487: Reward sum = -3.41, Last reward = -5.0, Steps = 9
# Episode 488: Reward sum = -22.52, Last reward = -23.0, Steps = 15
# Episode 489: Reward sum = 1.50, Last reward = 0.0, Steps = 11
# Episode 490: Reward sum = -5.89, Last reward = -8.0, Steps = 14
# Episode 491: Reward sum = -30.95, Last reward = -33.0, Steps = 11
# Episode 492: Reward sum = -7.70, Last reward = -10.0, Steps = 16
# Episode 493: Reward sum = 2.09, Last reward = 0.0, Steps = 18
# Episode 494: Reward sum = -4.47, Last reward = -5.0, Steps = 16
# Episode 495: Reward sum = -38.37, Last reward = -40.0, Steps = 19
# Episode 496: Reward sum = -18.26, Last reward = -20.0, Steps = 14
# Episode 497: Reward sum = -45.87, Last reward = -48.0, Steps = 18
# Episode 498: Reward sum = -3.36, Last reward = -5.0, Steps = 15
# Episode 499: Reward sum = -32.58, Last reward = -35.0, Steps = 15
# Episode 500: Reward sum = 2.31, Last reward = 0.0, Steps = 19
# Episode 501: Reward sum = -4.55, Last reward = -5.0, Steps = 4
# Episode 502: Reward sum = -35.07, Last reward = -38.0, Steps = 17
# Episode 503: Reward sum = 15.99, Last reward = 15.0, Steps = 12
# Episode 504: Reward sum = -6.43, Last reward = -8.0, Steps = 15
# Episode 505: Reward sum = -43.37, Last reward = -45.0, Steps = 16
# Episode 506: Reward sum = -18.29, Last reward = -20.0, Steps = 15
# Episode 507: Reward sum = -6.94, Last reward = -8.0, Steps = 11
# Episode 508: Reward sum = -27.17, Last reward = -28.0, Steps = 16
# Episode 509: Reward sum = -33.70, Last reward = -35.0, Steps = 17
# Episode 510: Reward sum = -3.40, Last reward = -5.0, Steps = 13
# Episode 511: Reward sum = -47.73, Last reward = -50.0, Steps = 16
# Episode 512: Reward sum = -33.93, Last reward = -35.0, Steps = 16
# Episode 513: Reward sum = -30.33, Last reward = -33.0, Steps = 15
# Episode 514: Reward sum = -18.71, Last reward = -20.0, Steps = 14
# Episode 515: Reward sum = 64.16, Last reward = 63.0, Steps = 13
# Episode 516: Reward sum = -3.14, Last reward = -5.0, Steps = 13
# Episode 517: Reward sum = -7.11, Last reward = -10.0, Steps = 15
# Episode 518: Reward sum = -3.80, Last reward = -5.0, Steps = 11
# Episode 519: Reward sum = -22.64, Last reward = -25.0, Steps = 17
# Episode 520: Reward sum = -38.30, Last reward = -40.0, Steps = 17
# Episode 521: Reward sum = -63.39, Last reward = -65.0, Steps = 14
# Episode 522: Reward sum = -6.90, Last reward = -10.0, Steps = 16
# Episode 523: Reward sum = -48.97, Last reward = -51.0, Steps = 16
# Episode 524: Reward sum = -58.34, Last reward = -60.0, Steps = 16
# Episode 525: Reward sum = 90.68, Last reward = 90.0, Steps = 15
# Episode 526: Reward sum = -3.36, Last reward = -5.0, Steps = 13
# Episode 527: Reward sum = -6.28, Last reward = -8.0, Steps = 12
# Episode 528: Reward sum = -6.64, Last reward = -8.0, Steps = 10
# Episode 529: Reward sum = -28.70, Last reward = -30.0, Steps = 16
# Episode 530: Reward sum = -8.37, Last reward = -10.0, Steps = 16
# Episode 531: Reward sum = -22.36, Last reward = -25.0, Steps = 16
# Episode 532: Reward sum = -13.36, Last reward = -15.0, Steps = 15
# Episode 533: Reward sum = -15.95, Last reward = -18.0, Steps = 16
# Episode 534: Reward sum = -5.92, Last reward = -8.0, Steps = 15
# Episode 535: Reward sum = -3.93, Last reward = -5.0, Steps = 8
# Episode 536: Reward sum = -25.58, Last reward = -28.0, Steps = 16
# Episode 537: Reward sum = -12.07, Last reward = -15.0, Steps = 17
# Episode 538: Reward sum = -7.78, Last reward = -10.0, Steps = 16
# Episode 539: Reward sum = -53.01, Last reward = -55.0, Steps = 15
# Episode 540: Reward sum = -6.48, Last reward = -8.0, Steps = 18
# Episode 541: Reward sum = -18.11, Last reward = -20.0, Steps = 9
# Episode 542: Reward sum = -51.87, Last reward = -55.0, Steps = 17
# Episode 543: Reward sum = -35.94, Last reward = -38.0, Steps = 15
# Episode 544: Reward sum = -22.20, Last reward = -23.0, Steps = 8
# Episode 545: Reward sum = -5.90, Last reward = -8.0, Steps = 11
# Episode 546: Reward sum = -97.73, Last reward = -99.0, Steps = 17
# Episode 547: Reward sum = -53.42, Last reward = -55.0, Steps = 15
# Episode 548: Reward sum = -3.02, Last reward = -5.0, Steps = 13
# Episode 549: Reward sum = -8.27, Last reward = -10.0, Steps = 16
# Episode 550: Reward sum = -3.01, Last reward = -5.0, Steps = 13
# Episode 551: Reward sum = -43.39, Last reward = -45.0, Steps = 16
# Episode 552: Reward sum = -48.88, Last reward = -50.0, Steps = 16
# Episode 553: Reward sum = -15.93, Last reward = -18.0, Steps = 15
# Episode 554: Reward sum = -38.35, Last reward = -40.0, Steps = 19
# Episode 555: Reward sum = -4.14, Last reward = -5.0, Steps = 6
# Episode 556: Reward sum = -28.76, Last reward = -30.0, Steps = 16
# Episode 557: Reward sum = -4.38, Last reward = -5.0, Steps = 5
# Episode 558: Reward sum = -3.56, Last reward = -5.0, Steps = 8
# Episode 559: Reward sum = -35.38, Last reward = -38.0, Steps = 16
# Episode 560: Reward sum = -3.27, Last reward = -5.0, Steps = 13
# Episode 561: Reward sum = 1.64, Last reward = 0.0, Steps = 17
# Episode 562: Reward sum = -28.96, Last reward = -30.0, Steps = 13
# Episode 563: Reward sum = -4.58, Last reward = -5.0, Steps = 8
# Episode 564: Reward sum = -6.56, Last reward = -8.0, Steps = 15
# Episode 565: Reward sum = -41.14, Last reward = -43.0, Steps = 18
# Episode 566: Reward sum = -2.73, Last reward = -5.0, Steps = 15
# Episode 567: Reward sum = -21.57, Last reward = -23.0, Steps = 17
# Episode 568: Reward sum = -6.85, Last reward = -8.0, Steps = 12
# Episode 569: Reward sum = -3.96, Last reward = -5.0, Steps = 7
# Episode 570: Reward sum = -28.41, Last reward = -30.0, Steps = 14
# Episode 571: Reward sum = -3.96, Last reward = -5.0, Steps = 10
# Episode 572: Reward sum = -7.86, Last reward = -10.0, Steps = 16
# Episode 573: Reward sum = -66.88, Last reward = -68.0, Steps = 17
# Episode 574: Reward sum = -33.70, Last reward = -35.0, Steps = 15
# Episode 575: Reward sum = -4.65, Last reward = -5.0, Steps = 4
# Episode 576: Reward sum = -23.20, Last reward = -25.0, Steps = 13
# Episode 577: Reward sum = -52.43, Last reward = -55.0, Steps = 15
# Episode 578: Reward sum = -27.16, Last reward = -30.0, Steps = 17
# Episode 579: Reward sum = -6.31, Last reward = -8.0, Steps = 14
# Episode 580: Reward sum = -3.07, Last reward = -5.0, Steps = 15
# Episode 581: Reward sum = -26.78, Last reward = -28.0, Steps = 14
# Episode 582: Reward sum = -48.58, Last reward = -50.0, Steps = 16
# Episode 583: Reward sum = -4.29, Last reward = -5.0, Steps = 14
# Episode 584: Reward sum = -48.55, Last reward = -50.0, Steps = 16
# Episode 585: Reward sum = -38.44, Last reward = -40.0, Steps = 16
# Episode 586: Reward sum = -53.00, Last reward = -55.0, Steps = 17
# Episode 587: Reward sum = -13.86, Last reward = -16.0, Steps = 17
# Episode 588: Reward sum = -4.05, Last reward = -5.0, Steps = 9
# Episode 589: Reward sum = -8.29, Last reward = -10.0, Steps = 17
# Episode 590: Reward sum = -8.91, Last reward = -10.0, Steps = 18
# Episode 591: Reward sum = -32.68, Last reward = -35.0, Steps = 18
# Episode 592: Reward sum = -8.10, Last reward = -10.0, Steps = 14
# Episode 593: Reward sum = -54.27, Last reward = -55.0, Steps = 17
# Episode 594: Reward sum = 94.05, Last reward = 93.0, Steps = 17
# Episode 595: Reward sum = 31.66, Last reward = 30.0, Steps = 18
# Episode 596: Reward sum = -43.87, Last reward = -45.0, Steps = 16
# Episode 597: Reward sum = -36.89, Last reward = -40.0, Steps = 16
# Episode 598: Reward sum = -4.90, Last reward = -5.0, Steps = 7
# Episode 599: Reward sum = -4.14, Last reward = -5.0, Steps = 15
# Episode 600: Reward sum = -30.24, Last reward = -33.0, Steps = 16
# Episode 601: Reward sum = -3.34, Last reward = -5.0, Steps = 10
# Episode 602: Reward sum = -39.06, Last reward = -40.0, Steps = 15
# Episode 603: Reward sum = 24.79, Last reward = 23.0, Steps = 16
# Episode 604: Reward sum = -4.74, Last reward = -5.0, Steps = 3
# Episode 605: Reward sum = -32.87, Last reward = -35.0, Steps = 18
# Episode 606: Reward sum = -31.66, Last reward = -33.0, Steps = 15
# Episode 607: Reward sum = -29.15, Last reward = -30.0, Steps = 13
# Episode 608: Reward sum = -23.59, Last reward = -25.0, Steps = 17
# Episode 609: Reward sum = -18.66, Last reward = -20.0, Steps = 15
# Episode 610: Reward sum = -9.52, Last reward = -10.0, Steps = 18
# Episode 611: Reward sum = -3.90, Last reward = -5.0, Steps = 15
# Episode 612: Reward sum = -4.01, Last reward = -5.0, Steps = 11
# Episode 613: Reward sum = -4.30, Last reward = -5.0, Steps = 8
# Episode 614: Reward sum = -18.86, Last reward = -20.0, Steps = 16
# Episode 615: Reward sum = -64.27, Last reward = -65.0, Steps = 16
# Episode 616: Reward sum = -8.34, Last reward = -10.0, Steps = 17
# Episode 617: Reward sum = -2.99, Last reward = -5.0, Steps = 15
# Episode 618: Reward sum = -3.01, Last reward = -5.0, Steps = 16
# Episode 619: Reward sum = -23.90, Last reward = -25.0, Steps = 17
# Episode 620: Reward sum = -3.02, Last reward = -5.0, Steps = 12
# Episode 621: Reward sum = 23.31, Last reward = 20.0, Steps = 15
# Episode 622: Reward sum = -2.56, Last reward = -5.0, Steps = 14
# Episode 623: Reward sum = -3.46, Last reward = -5.0, Steps = 11
# Episode 624: Reward sum = -14.50, Last reward = -15.0, Steps = 14
# Episode 625: Reward sum = -3.94, Last reward = -5.0, Steps = 9
# Episode 626: Reward sum = -3.87, Last reward = -5.0, Steps = 8
# Episode 627: Reward sum = -3.62, Last reward = -5.0, Steps = 8
# Episode 628: Reward sum = -4.08, Last reward = -5.0, Steps = 7
# Episode 629: Reward sum = -48.25, Last reward = -50.0, Steps = 16
# Episode 630: Reward sum = -3.75, Last reward = -5.0, Steps = 14
# Episode 631: Reward sum = -22.53, Last reward = -25.0, Steps = 16
# Episode 632: Reward sum = -8.46, Last reward = -10.0, Steps = 18
# Episode 633: Reward sum = -4.54, Last reward = -5.0, Steps = 7
# Episode 634: Reward sum = -30.72, Last reward = -33.0, Steps = 15
# Episode 635: Reward sum = -30.90, Last reward = -33.0, Steps = 17
# Episode 636: Reward sum = -3.23, Last reward = -5.0, Steps = 17
# Episode 637: Reward sum = -4.35, Last reward = -5.0, Steps = 12
# Episode 638: Reward sum = -18.04, Last reward = -20.0, Steps = 17
# Episode 639: Reward sum = -8.18, Last reward = -11.0, Steps = 14
# Episode 640: Reward sum = -4.40, Last reward = -5.0, Steps = 16
# Episode 641: Reward sum = 1.63, Last reward = 0.0, Steps = 17
# Episode 642: Reward sum = -3.06, Last reward = -5.0, Steps = 9
# Episode 643: Reward sum = -9.15, Last reward = -10.0, Steps = 16
# Episode 644: Reward sum = -51.87, Last reward = -55.0, Steps = 16
# Episode 645: Reward sum = -3.69, Last reward = -5.0, Steps = 15
# Episode 646: Reward sum = -62.15, Last reward = -65.0, Steps = 18
# Episode 647: Reward sum = -3.64, Last reward = -5.0, Steps = 8
# Episode 648: Reward sum = -4.08, Last reward = -5.0, Steps = 17
# Episode 649: Reward sum = -4.06, Last reward = -5.0, Steps = 13
# Episode 650: Reward sum = 1.29, Last reward = 0.0, Steps = 10
# Episode 651: Reward sum = -3.38, Last reward = -5.0, Steps = 14
# Episode 652: Reward sum = -13.08, Last reward = -15.0, Steps = 16
# Episode 653: Reward sum = -6.27, Last reward = -8.0, Steps = 11
# Episode 654: Reward sum = -33.51, Last reward = -35.0, Steps = 18
# Episode 655: Reward sum = -40.42, Last reward = -43.0, Steps = 17
# Episode 656: Reward sum = -18.41, Last reward = -20.0, Steps = 16
# Episode 657: Reward sum = -31.01, Last reward = -33.0, Steps = 14
# Episode 658: Reward sum = -3.96, Last reward = -5.0, Steps = 17
# Episode 659: Reward sum = -41.77, Last reward = -43.0, Steps = 18
# Episode 660: Reward sum = -63.33, Last reward = -65.0, Steps = 18
# Episode 661: Reward sum = -58.38, Last reward = -60.0, Steps = 17
# Episode 662: Reward sum = -4.21, Last reward = -5.0, Steps = 14
# Episode 663: Reward sum = -8.23, Last reward = -10.0, Steps = 15
# Episode 664: Reward sum = -18.71, Last reward = -20.0, Steps = 14
# Episode 665: Reward sum = -4.59, Last reward = -5.0, Steps = 7
# Episode 666: Reward sum = -81.78, Last reward = -83.0, Steps = 18
# Episode 667: Reward sum = -7.66, Last reward = -10.0, Steps = 16
# Episode 668: Reward sum = -38.61, Last reward = -40.0, Steps = 18
# Episode 669: Reward sum = -18.38, Last reward = -20.0, Steps = 17
# Episode 670: Reward sum = -18.77, Last reward = -20.0, Steps = 12
# Episode 671: Reward sum = -32.95, Last reward = -35.0, Steps = 16
# Episode 672: Reward sum = -2.33, Last reward = -5.0, Steps = 16
# Episode 673: Reward sum = -3.00, Last reward = -5.0, Steps = 15
# Episode 674: Reward sum = -4.03, Last reward = -5.0, Steps = 7
# Episode 675: Reward sum = -33.01, Last reward = -35.0, Steps = 16
# Episode 676: Reward sum = -6.95, Last reward = -8.0, Steps = 15
# Episode 677: Reward sum = -57.51, Last reward = -58.0, Steps = 17
# Episode 678: Reward sum = 2.58, Last reward = 0.0, Steps = 17
# Episode 679: Reward sum = -28.88, Last reward = -30.0, Steps = 12
# Episode 680: Reward sum = -6.78, Last reward = -8.0, Steps = 10
# Episode 681: Reward sum = 64.54, Last reward = 63.0, Steps = 11
# Episode 682: Reward sum = -22.60, Last reward = -23.0, Steps = 11
# Episode 683: Reward sum = 34.80, Last reward = 33.0, Steps = 19
# Episode 684: Reward sum = -41.01, Last reward = -43.0, Steps = 17
# Episode 685: Reward sum = -33.23, Last reward = -35.0, Steps = 16
# Episode 686: Reward sum = -12.60, Last reward = -15.0, Steps = 16
# Episode 687: Reward sum = -18.44, Last reward = -20.0, Steps = 18
# Episode 688: Reward sum = -6.57, Last reward = -8.0, Steps = 14
# Episode 689: Reward sum = -17.67, Last reward = -20.0, Steps = 14
# Episode 690: Reward sum = -28.80, Last reward = -30.0, Steps = 17
# Episode 691: Reward sum = -8.07, Last reward = -10.0, Steps = 17
# Episode 692: Reward sum = -50.94, Last reward = -53.0, Steps = 17
# Episode 693: Reward sum = -29.09, Last reward = -30.0, Steps = 9
# Episode 694: Reward sum = -22.70, Last reward = -25.0, Steps = 17
# Episode 695: Reward sum = -3.83, Last reward = -5.0, Steps = 10
# Episode 696: Reward sum = -25.99, Last reward = -27.0, Steps = 14
# Episode 697: Reward sum = -3.99, Last reward = -5.0, Steps = 10
# Episode 698: Reward sum = -4.49, Last reward = -5.0, Steps = 10
# Episode 699: Reward sum = -3.55, Last reward = -5.0, Steps = 15
# Episode 700: Reward sum = -38.07, Last reward = -40.0, Steps = 18
# Episode 701: Reward sum = -38.09, Last reward = -40.0, Steps = 16
# Episode 702: Reward sum = -3.38, Last reward = -5.0, Steps = 15
# Episode 703: Reward sum = -7.87, Last reward = -10.0, Steps = 17
# Episode 704: Reward sum = -4.10, Last reward = -5.0, Steps = 11
# Episode 705: Reward sum = -7.84, Last reward = -10.0, Steps = 15
# Episode 706: Reward sum = -53.51, Last reward = -55.0, Steps = 19
# Episode 707: Reward sum = 22.14, Last reward = 20.0, Steps = 18
# Episode 708: Reward sum = -3.27, Last reward = -5.0, Steps = 14
# Episode 709: Reward sum = -30.97, Last reward = -33.0, Steps = 16
# Episode 710: Reward sum = -6.28, Last reward = -8.0, Steps = 17
# Episode 711: Reward sum = -30.95, Last reward = -33.0, Steps = 12
# Episode 712: Reward sum = -55.99, Last reward = -58.0, Steps = 16
# Episode 713: Reward sum = -3.59, Last reward = -5.0, Steps = 12
# Episode 714: Reward sum = -6.10, Last reward = -8.0, Steps = 13
# Episode 715: Reward sum = -6.17, Last reward = -8.0, Steps = 17
# Episode 716: Reward sum = -22.56, Last reward = -25.0, Steps = 17
# Episode 717: Reward sum = -6.77, Last reward = -8.0, Steps = 12
# Episode 718: Reward sum = -21.37, Last reward = -25.0, Steps = 16
# Episode 719: Reward sum = -3.74, Last reward = -5.0, Steps = 16
# Episode 720: Reward sum = -19.06, Last reward = -20.0, Steps = 14
# Episode 721: Reward sum = -3.77, Last reward = -5.0, Steps = 12
# Episode 722: Reward sum = -7.63, Last reward = -10.0, Steps = 16
# Episode 723: Reward sum = 2.62, Last reward = 0.0, Steps = 16
# Episode 724: Reward sum = -4.12, Last reward = -5.0, Steps = 17
# Episode 725: Reward sum = -53.27, Last reward = -55.0, Steps = 18
# Episode 726: Reward sum = -8.50, Last reward = -10.0, Steps = 15
# Episode 727: Reward sum = -68.49, Last reward = -70.0, Steps = 14
# Episode 728: Reward sum = -20.19, Last reward = -23.0, Steps = 14
# Episode 729: Reward sum = -6.40, Last reward = -10.0, Steps = 16
# Episode 730: Reward sum = -28.97, Last reward = -30.0, Steps = 15
# Episode 731: Reward sum = 32.30, Last reward = 30.0, Steps = 19
# ...
# Episode 9758: Reward sum = -3.51, Last reward = -5.0, Steps = 16
# Episode 9759: Reward sum = -7.62, Last reward = -10.0, Steps = 18
# Episode 9760: Reward sum = -3.63, Last reward = -5.0, Steps = 14
# Episode 9761: Reward sum = -28.56, Last reward = -30.0, Steps = 17
# Episode 9762: Reward sum = -4.01, Last reward = -5.0, Steps = 9
# Episode 9763: Reward sum = -3.34, Last reward = -5.0, Steps = 13
# Episode 9764: Reward sum = 2.62, Last reward = 0.0, Steps = 18
# Episode 9765: Reward sum = -5.27, Last reward = -8.0, Steps = 18
# Episode 9766: Reward sum = -4.35, Last reward = -5.0, Steps = 6
# Episode 9767: Reward sum = 2.49, Last reward = 0.0, Steps = 16
# Episode 9768: Reward sum = -4.54, Last reward = -5.0, Steps = 9
# Episode 9769: Reward sum = -8.63, Last reward = -10.0, Steps = 16
# Episode 9770: Reward sum = -2.89, Last reward = -5.0, Steps = 16
# Episode 9771: Reward sum = -7.42, Last reward = -8.0, Steps = 15
# Episode 9772: Reward sum = -12.14, Last reward = -15.0, Steps = 15
# Episode 9773: Reward sum = 25.71, Last reward = 23.0, Steps = 18
# Episode 9774: Reward sum = 3.24, Last reward = 0.0, Steps = 16
# Episode 9775: Reward sum = -47.02, Last reward = -50.0, Steps = 17
# Episode 9776: Reward sum = -37.78, Last reward = -40.0, Steps = 17
# Episode 9777: Reward sum = -13.00, Last reward = -15.0, Steps = 16
# Episode 9778: Reward sum = -2.43, Last reward = -5.0, Steps = 16
# Episode 9779: Reward sum = -6.46, Last reward = -8.0, Steps = 14
# Episode 9780: Reward sum = -25.63, Last reward = -28.0, Steps = 15
# Episode 9781: Reward sum = -21.92, Last reward = -23.0, Steps = 14
# Episode 9782: Reward sum = -2.35, Last reward = -5.0, Steps = 13
# Episode 9783: Reward sum = -79.02, Last reward = -80.0, Steps = 14
# Episode 9784: Reward sum = -3.75, Last reward = -5.0, Steps = 8
# Episode 9785: Reward sum = -26.69, Last reward = -28.0, Steps = 15
# Episode 9786: Reward sum = -7.83, Last reward = -10.0, Steps = 16
# Episode 9787: Reward sum = -1.74, Last reward = -5.0, Steps = 18
# Episode 9788: Reward sum = 16.20, Last reward = 15.0, Steps = 9
# Episode 9789: Reward sum = -4.35, Last reward = -5.0, Steps = 6
# Episode 9790: Reward sum = -32.10, Last reward = -33.0, Steps = 10
# Episode 9791: Reward sum = -28.60, Last reward = -30.0, Steps = 17
# Episode 9792: Reward sum = -3.82, Last reward = -5.0, Steps = 8
# Episode 9793: Reward sum = -23.66, Last reward = -25.0, Steps = 16
# Episode 9794: Reward sum = -52.95, Last reward = -55.0, Steps = 17
# Episode 9795: Reward sum = -63.57, Last reward = -65.0, Steps = 18
# Episode 9796: Reward sum = -3.64, Last reward = -5.0, Steps = 15
# Episode 9797: Reward sum = -32.01, Last reward = -33.0, Steps = 19
# Episode 9798: Reward sum = -58.68, Last reward = -60.0, Steps = 17
# Episode 9799: Reward sum = -23.08, Last reward = -25.0, Steps = 15
# Episode 9800: Reward sum = -2.95, Last reward = -5.0, Steps = 14
# Episode 9801: Reward sum = -29.62, Last reward = -30.0, Steps = 10
# Episode 9802: Reward sum = -8.19, Last reward = -10.0, Steps = 16
# Episode 9803: Reward sum = -3.87, Last reward = -5.0, Steps = 11
# Episode 9804: Reward sum = -31.64, Last reward = -33.0, Steps = 16
# Episode 9805: Reward sum = -8.85, Last reward = -10.0, Steps = 15
# Episode 9806: Reward sum = -41.35, Last reward = -43.0, Steps = 15
# Episode 9807: Reward sum = -14.14, Last reward = -18.0, Steps = 16
# Episode 9808: Reward sum = -4.12, Last reward = -5.0, Steps = 9
# Episode 9809: Reward sum = -9.00, Last reward = -10.0, Steps = 17
# Episode 9810: Reward sum = -19.51, Last reward = -20.0, Steps = 18
# Episode 9811: Reward sum = -3.50, Last reward = -5.0, Steps = 15
# Episode 9812: Reward sum = -18.75, Last reward = -20.0, Steps = 11
# Episode 9813: Reward sum = -27.67, Last reward = -30.0, Steps = 12
# Episode 9814: Reward sum = 2.91, Last reward = 0.0, Steps = 18
# Episode 9815: Reward sum = -33.90, Last reward = -35.0, Steps = 17
# Episode 9816: Reward sum = -3.17, Last reward = -5.0, Steps = 14
# Episode 9817: Reward sum = 0.06, Last reward = -2.0, Steps = 16
# Episode 9818: Reward sum = -3.00, Last reward = -5.0, Steps = 17
# Episode 9819: Reward sum = -18.33, Last reward = -20.0, Steps = 14
# Episode 9820: Reward sum = 2.19, Last reward = 0.0, Steps = 15
# Episode 9821: Reward sum = 34.24, Last reward = 33.0, Steps = 18
# Episode 9822: Reward sum = -3.09, Last reward = -5.0, Steps = 16
# Episode 9823: Reward sum = -32.44, Last reward = -35.0, Steps = 14
# Episode 9824: Reward sum = -3.08, Last reward = -5.0, Steps = 11
# Episode 9825: Reward sum = -3.00, Last reward = -5.0, Steps = 18
# Episode 9826: Reward sum = -2.63, Last reward = -5.0, Steps = 12
# Episode 9827: Reward sum = -7.75, Last reward = -8.0, Steps = 16
# Episode 9828: Reward sum = -3.33, Last reward = -5.0, Steps = 15
# Episode 9829: Reward sum = -40.04, Last reward = -43.0, Steps = 15
# Episode 9830: Reward sum = -3.40, Last reward = -5.0, Steps = 11
# Episode 9831: Reward sum = -14.81, Last reward = -16.0, Steps = 17
# Episode 9832: Reward sum = -90.84, Last reward = -93.0, Steps = 17
# Episode 9833: Reward sum = -4.45, Last reward = -5.0, Steps = 12
# Episode 9834: Reward sum = -57.19, Last reward = -60.0, Steps = 16
# Episode 9835: Reward sum = -48.14, Last reward = -50.0, Steps = 18
# Episode 9836: Reward sum = -3.55, Last reward = -5.0, Steps = 17
# Episode 9837: Reward sum = -27.37, Last reward = -30.0, Steps = 16
# Episode 9838: Reward sum = -3.44, Last reward = -5.0, Steps = 14
# Episode 9839: Reward sum = -48.26, Last reward = -50.0, Steps = 17
# Episode 9840: Reward sum = -38.06, Last reward = -40.0, Steps = 15
# Episode 9841: Reward sum = -3.17, Last reward = -5.0, Steps = 12
# Episode 9842: Reward sum = -4.75, Last reward = -5.0, Steps = 5
# Episode 9843: Reward sum = -4.06, Last reward = -5.0, Steps = 9
# Episode 9844: Reward sum = -7.32, Last reward = -8.0, Steps = 5
# Episode 9845: Reward sum = -3.19, Last reward = -5.0, Steps = 15
# Episode 9846: Reward sum = -62.65, Last reward = -65.0, Steps = 16
# Episode 9847: Reward sum = -4.01, Last reward = -5.0, Steps = 9
# Episode 9848: Reward sum = 45.97, Last reward = 43.0, Steps = 16
# Episode 9849: Reward sum = -19.41, Last reward = -20.0, Steps = 8
# Episode 9850: Reward sum = -3.92, Last reward = -5.0, Steps = 7
# Episode 9851: Reward sum = -26.16, Last reward = -28.0, Steps = 15
# Episode 9852: Reward sum = 11.62, Last reward = 10.0, Steps = 16
# Episode 9853: Reward sum = -2.75, Last reward = -5.0, Steps = 11
# Episode 9854: Reward sum = -18.13, Last reward = -20.0, Steps = 15
# Episode 9855: Reward sum = -17.50, Last reward = -20.0, Steps = 17
# Episode 9856: Reward sum = 2.13, Last reward = 0.0, Steps = 11
# Episode 9857: Reward sum = -25.83, Last reward = -28.0, Steps = 15
# Episode 9858: Reward sum = -53.11, Last reward = -55.0, Steps = 17
# Episode 9859: Reward sum = -37.08, Last reward = -40.0, Steps = 15
# Episode 9860: Reward sum = -4.09, Last reward = -5.0, Steps = 8
# Episode 9861: Reward sum = -28.78, Last reward = -30.0, Steps = 16
# Episode 9862: Reward sum = 11.13, Last reward = 10.0, Steps = 16
# Episode 9863: Reward sum = -2.68, Last reward = -5.0, Steps = 18
# Episode 9864: Reward sum = 94.35, Last reward = 93.0, Steps = 16
# Episode 9865: Reward sum = -48.15, Last reward = -50.0, Steps = 17
# Episode 9866: Reward sum = -3.74, Last reward = -5.0, Steps = 15
# Episode 9867: Reward sum = -52.42, Last reward = -55.0, Steps = 18
# Episode 9868: Reward sum = 15.19, Last reward = 13.0, Steps = 16
# Episode 9869: Reward sum = 14.18, Last reward = 12.0, Steps = 16
# Episode 9870: Reward sum = -8.41, Last reward = -10.0, Steps = 16
# Episode 9871: Reward sum = -6.76, Last reward = -8.0, Steps = 12
# Episode 9872: Reward sum = -3.12, Last reward = -5.0, Steps = 9
# Episode 9873: Reward sum = -6.74, Last reward = -8.0, Steps = 14
# Episode 9874: Reward sum = -38.33, Last reward = -40.0, Steps = 15
# Episode 9875: Reward sum = -28.91, Last reward = -30.0, Steps = 17
# Episode 9876: Reward sum = -4.35, Last reward = -5.0, Steps = 14
# Episode 9877: Reward sum = 2.04, Last reward = 0.0, Steps = 18
# Episode 9878: Reward sum = 2.43, Last reward = 0.0, Steps = 18
# Episode 9879: Reward sum = -29.21, Last reward = -30.0, Steps = 16
# Episode 9880: Reward sum = -32.19, Last reward = -33.0, Steps = 17
# Episode 9881: Reward sum = -4.05, Last reward = -5.0, Steps = 6
# Episode 9882: Reward sum = -53.25, Last reward = -55.0, Steps = 18
# Episode 9883: Reward sum = -21.75, Last reward = -23.0, Steps = 10
# Episode 9884: Reward sum = -24.69, Last reward = -25.0, Steps = 15
# Episode 9885: Reward sum = -29.47, Last reward = -30.0, Steps = 7
# Episode 9886: Reward sum = 1.43, Last reward = 0.0, Steps = 14
# Episode 9887: Reward sum = -9.22, Last reward = -10.0, Steps = 15
# Episode 9888: Reward sum = 4.25, Last reward = 2.0, Steps = 18
# Episode 9889: Reward sum = -3.23, Last reward = -5.0, Steps = 13
# Episode 9890: Reward sum = -4.46, Last reward = -5.0, Steps = 15
# Episode 9891: Reward sum = -47.73, Last reward = -50.0, Steps = 18
# Episode 9892: Reward sum = -81.78, Last reward = -83.0, Steps = 17
# Episode 9893: Reward sum = -28.59, Last reward = -30.0, Steps = 15
# Episode 9894: Reward sum = -66.05, Last reward = -68.0, Steps = 17
# Episode 9895: Reward sum = -3.64, Last reward = -5.0, Steps = 15
# Episode 9896: Reward sum = -52.30, Last reward = -55.0, Steps = 15
# Episode 9897: Reward sum = -57.25, Last reward = -60.0, Steps = 15
# Episode 9898: Reward sum = -2.99, Last reward = -5.0, Steps = 13
# Episode 9899: Reward sum = -2.76, Last reward = -5.0, Steps = 15
# Episode 9900: Reward sum = -3.21, Last reward = -5.0, Steps = 9
# Episode 9901: Reward sum = -4.39, Last reward = -5.0, Steps = 5
# Episode 9902: Reward sum = -2.96, Last reward = -5.0, Steps = 12
# Episode 9903: Reward sum = -49.99, Last reward = -53.0, Steps = 17
# Episode 9904: Reward sum = -14.35, Last reward = -15.0, Steps = 17
# Episode 9905: Reward sum = -7.65, Last reward = -10.0, Steps = 16
# Episode 9906: Reward sum = -2.69, Last reward = -5.0, Steps = 15
# Episode 9907: Reward sum = 1.13, Last reward = 0.0, Steps = 19
# Episode 9908: Reward sum = -39.60, Last reward = -40.0, Steps = 15
# Episode 9909: Reward sum = -38.16, Last reward = -41.0, Steps = 18
# Episode 9910: Reward sum = -23.36, Last reward = -25.0, Steps = 15
# Episode 9911: Reward sum = -37.74, Last reward = -41.0, Steps = 17
# Episode 9912: Reward sum = -40.53, Last reward = -43.0, Steps = 16
# Episode 9913: Reward sum = -21.23, Last reward = -23.0, Steps = 14
# Episode 9914: Reward sum = -45.38, Last reward = -48.0, Steps = 15
# Episode 9915: Reward sum = -3.97, Last reward = -5.0, Steps = 16
# Episode 9916: Reward sum = -3.31, Last reward = -5.0, Steps = 16
# Episode 9917: Reward sum = -8.54, Last reward = -10.0, Steps = 16
# Episode 9918: Reward sum = -7.86, Last reward = -10.0, Steps = 15
# Episode 9919: Reward sum = -78.42, Last reward = -80.0, Steps = 16
# Episode 9920: Reward sum = -27.77, Last reward = -30.0, Steps = 16
# Episode 9921: Reward sum = -6.46, Last reward = -8.0, Steps = 15
# Episode 9922: Reward sum = -26.74, Last reward = -28.0, Steps = 15
# Episode 9923: Reward sum = -4.10, Last reward = -5.0, Steps = 12
# Episode 9924: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 9925: Reward sum = -58.05, Last reward = -60.0, Steps = 17
# Episode 9926: Reward sum = -4.40, Last reward = -5.0, Steps = 11
# Episode 9927: Reward sum = -3.59, Last reward = -5.0, Steps = 17
# Episode 9928: Reward sum = -30.96, Last reward = -33.0, Steps = 19
# Episode 9929: Reward sum = -18.69, Last reward = -20.0, Steps = 14
# Episode 9930: Reward sum = -3.94, Last reward = -5.0, Steps = 11
# Episode 9931: Reward sum = -33.60, Last reward = -35.0, Steps = 17
# Episode 9932: Reward sum = -37.01, Last reward = -40.0, Steps = 15
# Episode 9933: Reward sum = -3.55, Last reward = -5.0, Steps = 12
# Episode 9934: Reward sum = -47.88, Last reward = -50.0, Steps = 16
# Episode 9935: Reward sum = -4.31, Last reward = -5.0, Steps = 4
# Episode 9936: Reward sum = -33.40, Last reward = -35.0, Steps = 18
# Episode 9937: Reward sum = -33.19, Last reward = -35.0, Steps = 17
# Episode 9938: Reward sum = -3.84, Last reward = -5.0, Steps = 8
# Episode 9939: Reward sum = -3.92, Last reward = -5.0, Steps = 8
# Episode 9940: Reward sum = -53.47, Last reward = -55.0, Steps = 15
# Episode 9941: Reward sum = -19.20, Last reward = -20.0, Steps = 6
# Episode 9942: Reward sum = -3.54, Last reward = -5.0, Steps = 15
# Episode 9943: Reward sum = -48.48, Last reward = -50.0, Steps = 16
# Episode 9944: Reward sum = -10.80, Last reward = -13.0, Steps = 16
# Episode 9945: Reward sum = -23.68, Last reward = -25.0, Steps = 16
# Episode 9946: Reward sum = -2.59, Last reward = -5.0, Steps = 12
# Episode 9947: Reward sum = -3.51, Last reward = -5.0, Steps = 11
# Episode 9948: Reward sum = -3.71, Last reward = -5.0, Steps = 9
# Episode 9949: Reward sum = -3.78, Last reward = -5.0, Steps = 9
# Episode 9950: Reward sum = -40.54, Last reward = -43.0, Steps = 18
# Episode 9951: Reward sum = -8.69, Last reward = -10.0, Steps = 17
# Episode 9952: Reward sum = -3.79, Last reward = -5.0, Steps = 8
# Episode 9953: Reward sum = 1.83, Last reward = 0.0, Steps = 16
# Episode 9954: Reward sum = -3.62, Last reward = -5.0, Steps = 15
# Episode 9955: Reward sum = -29.10, Last reward = -30.0, Steps = 16
# Episode 9956: Reward sum = -32.53, Last reward = -35.0, Steps = 17
# Episode 9957: Reward sum = -43.33, Last reward = -45.0, Steps = 17
# Episode 9958: Reward sum = -2.77, Last reward = -5.0, Steps = 12
# Episode 9959: Reward sum = -18.66, Last reward = -20.0, Steps = 14
# Episode 9960: Reward sum = -6.32, Last reward = -8.0, Steps = 9
# Episode 9961: Reward sum = -12.75, Last reward = -14.0, Steps = 16
# Episode 9962: Reward sum = -83.85, Last reward = -85.0, Steps = 17
# Episode 9963: Reward sum = -6.50, Last reward = -8.0, Steps = 15
# Episode 9964: Reward sum = -11.78, Last reward = -15.0, Steps = 15
# Episode 9965: Reward sum = -27.42, Last reward = -30.0, Steps = 13
# Episode 9966: Reward sum = 1.45, Last reward = 0.0, Steps = 15
# Episode 9967: Reward sum = -18.67, Last reward = -20.0, Steps = 9
# Episode 9968: Reward sum = -3.58, Last reward = -5.0, Steps = 14
# Episode 9969: Reward sum = -18.55, Last reward = -20.0, Steps = 16
# Episode 9970: Reward sum = 31.35, Last reward = 30.0, Steps = 17
# Episode 9971: Reward sum = -4.18, Last reward = -5.0, Steps = 9
# Episode 9972: Reward sum = -4.82, Last reward = -5.0, Steps = 2
# Episode 9973: Reward sum = -31.42, Last reward = -33.0, Steps = 15
# Episode 9974: Reward sum = 61.00, Last reward = 60.0, Steps = 18
# Episode 9975: Reward sum = 15.87, Last reward = 15.0, Steps = 15
# Episode 9976: Reward sum = -2.38, Last reward = -5.0, Steps = 15
# Episode 9977: Reward sum = -5.61, Last reward = -8.0, Steps = 13
# Episode 9978: Reward sum = 1.90, Last reward = 0.0, Steps = 17
# Episode 9979: Reward sum = -31.30, Last reward = -33.0, Steps = 18
# Episode 9980: Reward sum = -3.92, Last reward = -5.0, Steps = 16
# Episode 9981: Reward sum = -3.37, Last reward = -5.0, Steps = 10
# Episode 9982: Reward sum = -3.19, Last reward = -5.0, Steps = 14
# Episode 9983: Reward sum = -41.34, Last reward = -43.0, Steps = 16
# Episode 9984: Reward sum = -63.85, Last reward = -65.0, Steps = 16
# Episode 9985: Reward sum = -40.95, Last reward = -43.0, Steps = 17
# Episode 9986: Reward sum = -38.81, Last reward = -40.0, Steps = 15
# Episode 9987: Reward sum = -37.81, Last reward = -40.0, Steps = 17
# Episode 9988: Reward sum = -3.65, Last reward = -5.0, Steps = 14
# Episode 9989: Reward sum = -29.79, Last reward = -30.0, Steps = 14
# Episode 9990: Reward sum = -58.93, Last reward = -61.0, Steps = 17
# Episode 9991: Reward sum = -34.99, Last reward = -36.0, Steps = 15
# Episode 9992: Reward sum = -2.95, Last reward = -5.0, Steps = 16
# Episode 9993: Reward sum = -3.91, Last reward = -5.0, Steps = 13
# Episode 9994: Reward sum = -7.53, Last reward = -8.0, Steps = 5
# Episode 9995: Reward sum = -17.64, Last reward = -20.0, Steps = 13
# Episode 9996: Reward sum = 1.38, Last reward = 0.0, Steps = 17
# Episode 9997: Reward sum = -51.85, Last reward = -53.0, Steps = 15
# Episode 9998: Reward sum = -1.35, Last reward = -3.0, Steps = 14
# Episode 9999: Reward sum = -18.83, Last reward = -20.0, Steps = 12
# Episode 10000: Reward sum = -18.93, Last reward = -20.0, Steps = 10

# %%
plot_rewards(logger.log_dir, agent.training_rewards_per_episode_last_one, title="Training Rewards", save_fig=True)
print("Mean = ", np.mean(agent.training_rewards_per_episode_last_one))
# Out:
# Mean =  -19.3585

# %%
agent_eval = ActorCritic(env, policy, value_network, logger)
agent_eval.evaluate(1000)
# Out:
# Episode 1: Reward sum = -34.40, Last reward = -35.0, Steps = 17
# Episode 2: Reward sum = 1.97, Last reward = 0.0, Steps = 18
# Episode 3: Reward sum = -28.21, Last reward = -30.0, Steps = 17
# Episode 4: Reward sum = -27.41, Last reward = -30.0, Steps = 16
# Episode 5: Reward sum = -19.02, Last reward = -20.0, Steps = 12
# Episode 6: Reward sum = -18.93, Last reward = -20.0, Steps = 15
# Episode 7: Reward sum = -3.71, Last reward = -5.0, Steps = 9
# Episode 8: Reward sum = 30.95, Last reward = 30.0, Steps = 17
# Episode 9: Reward sum = -2.95, Last reward = -5.0, Steps = 12
# Episode 10: Reward sum = -7.76, Last reward = -8.0, Steps = 4
# Episode 11: Reward sum = -4.15, Last reward = -5.0, Steps = 7
# Episode 12: Reward sum = -3.35, Last reward = -5.0, Steps = 12
# Episode 13: Reward sum = 2.83, Last reward = 0.0, Steps = 17
# Episode 14: Reward sum = -37.98, Last reward = -40.0, Steps = 16
# Episode 15: Reward sum = -3.17, Last reward = -5.0, Steps = 16
# Episode 16: Reward sum = -21.79, Last reward = -25.0, Steps = 16
# Episode 17: Reward sum = -7.59, Last reward = -10.0, Steps = 15
# Episode 18: Reward sum = -7.31, Last reward = -8.0, Steps = 9
# Episode 19: Reward sum = -4.47, Last reward = -5.0, Steps = 16
# Episode 20: Reward sum = -22.68, Last reward = -25.0, Steps = 15
# Episode 21: Reward sum = -31.49, Last reward = -33.0, Steps = 16
# Episode 22: Reward sum = -36.82, Last reward = -40.0, Steps = 16
# Episode 23: Reward sum = -33.78, Last reward = -35.0, Steps = 17
# Episode 24: Reward sum = -40.89, Last reward = -43.0, Steps = 16
# Episode 25: Reward sum = -22.79, Last reward = -25.0, Steps = 16
# Episode 26: Reward sum = -2.67, Last reward = -5.0, Steps = 12
# Episode 27: Reward sum = -4.01, Last reward = -5.0, Steps = 14
# Episode 28: Reward sum = -37.18, Last reward = -38.0, Steps = 16
# Episode 29: Reward sum = -18.90, Last reward = -20.0, Steps = 11
# Episode 30: Reward sum = -3.08, Last reward = -5.0, Steps = 15
# Episode 31: Reward sum = -6.04, Last reward = -8.0, Steps = 12
# Episode 32: Reward sum = 28.20, Last reward = 27.0, Steps = 17
# Episode 33: Reward sum = 12.20, Last reward = 10.0, Steps = 18
# Episode 34: Reward sum = 60.60, Last reward = 60.0, Steps = 17
# Episode 35: Reward sum = -13.00, Last reward = -15.0, Steps = 15
# Episode 36: Reward sum = -38.43, Last reward = -40.0, Steps = 17
# Episode 37: Reward sum = -57.31, Last reward = -60.0, Steps = 15
# Episode 38: Reward sum = -8.59, Last reward = -10.0, Steps = 15
# Episode 39: Reward sum = -2.71, Last reward = -5.0, Steps = 15
# Episode 40: Reward sum = -3.17, Last reward = -5.0, Steps = 12
# Episode 41: Reward sum = -3.23, Last reward = -5.0, Steps = 13
# Episode 42: Reward sum = 1.41, Last reward = 0.0, Steps = 17
# Episode 43: Reward sum = -2.90, Last reward = -5.0, Steps = 13
# Episode 44: Reward sum = 58.27, Last reward = 57.0, Steps = 15
# Episode 45: Reward sum = -2.80, Last reward = -5.0, Steps = 16
# Episode 46: Reward sum = -31.62, Last reward = -33.0, Steps = 17
# Episode 47: Reward sum = -37.94, Last reward = -40.0, Steps = 16
# Episode 48: Reward sum = -53.32, Last reward = -55.0, Steps = 14
# Episode 49: Reward sum = -3.16, Last reward = -5.0, Steps = 14
# Episode 50: Reward sum = -22.94, Last reward = -25.0, Steps = 16
# Episode 51: Reward sum = -3.48, Last reward = -5.0, Steps = 11
# Episode 52: Reward sum = -32.77, Last reward = -35.0, Steps = 17
# Episode 53: Reward sum = -3.95, Last reward = -5.0, Steps = 11
# Episode 54: Reward sum = -21.53, Last reward = -23.0, Steps = 15
# Episode 55: Reward sum = -18.95, Last reward = -20.0, Steps = 12
# Episode 56: Reward sum = 1.32, Last reward = 0.0, Steps = 16
# Episode 57: Reward sum = -4.03, Last reward = -5.0, Steps = 5
# Episode 58: Reward sum = -4.04, Last reward = -5.0, Steps = 9
# Episode 59: Reward sum = -4.33, Last reward = -5.0, Steps = 5
# Episode 60: Reward sum = -11.25, Last reward = -13.0, Steps = 16
# Episode 61: Reward sum = -55.88, Last reward = -58.0, Steps = 15
# Episode 62: Reward sum = -5.41, Last reward = -8.0, Steps = 15
# Episode 63: Reward sum = -19.04, Last reward = -20.0, Steps = 12
# Episode 64: Reward sum = -59.29, Last reward = -61.0, Steps = 17
# Episode 65: Reward sum = 42.27, Last reward = 40.0, Steps = 16
# Episode 66: Reward sum = -68.00, Last reward = -70.0, Steps = 13
# Episode 67: Reward sum = -2.75, Last reward = -5.0, Steps = 17
# Episode 68: Reward sum = 2.23, Last reward = 0.0, Steps = 17
# Episode 69: Reward sum = -11.50, Last reward = -14.0, Steps = 15
# Episode 70: Reward sum = -32.17, Last reward = -35.0, Steps = 17
# Episode 71: Reward sum = -24.22, Last reward = -25.0, Steps = 17
# Episode 72: Reward sum = -7.42, Last reward = -8.0, Steps = 5
# Episode 73: Reward sum = -2.28, Last reward = -5.0, Steps = 16
# Episode 74: Reward sum = 6.76, Last reward = 5.0, Steps = 16
# Episode 75: Reward sum = -3.83, Last reward = -5.0, Steps = 16
# Episode 76: Reward sum = -4.28, Last reward = -5.0, Steps = 5
# Episode 77: Reward sum = -21.83, Last reward = -23.0, Steps = 18
# Episode 78: Reward sum = -6.87, Last reward = -8.0, Steps = 14
# Episode 79: Reward sum = -38.71, Last reward = -43.0, Steps = 17
# Episode 80: Reward sum = -28.48, Last reward = -30.0, Steps = 16
# Episode 81: Reward sum = -17.29, Last reward = -20.0, Steps = 13
# Episode 82: Reward sum = -6.78, Last reward = -8.0, Steps = 10
# Episode 83: Reward sum = -4.79, Last reward = -5.0, Steps = 3
# Episode 84: Reward sum = -55.79, Last reward = -58.0, Steps = 17
# Episode 85: Reward sum = 3.56, Last reward = 0.0, Steps = 16
# Episode 86: Reward sum = -89.16, Last reward = -90.0, Steps = 19
# Episode 87: Reward sum = -38.03, Last reward = -41.0, Steps = 16
# Episode 88: Reward sum = -4.45, Last reward = -5.0, Steps = 6
# Episode 89: Reward sum = -48.22, Last reward = -50.0, Steps = 17
# Episode 90: Reward sum = -71.37, Last reward = -73.0, Steps = 16
# Episode 91: Reward sum = -3.52, Last reward = -5.0, Steps = 13
# Episode 92: Reward sum = -37.67, Last reward = -40.0, Steps = 17
# Episode 93: Reward sum = -19.44, Last reward = -20.0, Steps = 8
# Episode 94: Reward sum = -3.61, Last reward = -5.0, Steps = 15
# Episode 95: Reward sum = -69.05, Last reward = -71.0, Steps = 17
# Episode 96: Reward sum = -17.93, Last reward = -20.0, Steps = 15
# Episode 97: Reward sum = -4.29, Last reward = -5.0, Steps = 12
# Episode 98: Reward sum = -53.33, Last reward = -55.0, Steps = 17
# Episode 99: Reward sum = -3.20, Last reward = -5.0, Steps = 14
# Episode 100: Reward sum = -10.58, Last reward = -13.0, Steps = 16
# Episode 101: Reward sum = -28.63, Last reward = -30.0, Steps = 16
# Episode 102: Reward sum = 31.15, Last reward = 30.0, Steps = 18
# Episode 103: Reward sum = -78.78, Last reward = -80.0, Steps = 15
# Episode 104: Reward sum = -0.34, Last reward = -2.0, Steps = 13
# Episode 105: Reward sum = -3.86, Last reward = -5.0, Steps = 10
# Episode 106: Reward sum = -8.57, Last reward = -10.0, Steps = 15
# Episode 107: Reward sum = -3.55, Last reward = -5.0, Steps = 12
# Episode 108: Reward sum = -4.13, Last reward = -5.0, Steps = 10
# Episode 109: Reward sum = -22.50, Last reward = -25.0, Steps = 17
# Episode 110: Reward sum = -2.98, Last reward = -5.0, Steps = 13
# Episode 111: Reward sum = -29.90, Last reward = -30.0, Steps = 7
# Episode 112: Reward sum = 11.68, Last reward = 10.0, Steps = 18
# Episode 113: Reward sum = -6.73, Last reward = -8.0, Steps = 10
# Episode 114: Reward sum = -8.23, Last reward = -10.0, Steps = 16
# Episode 115: Reward sum = -18.25, Last reward = -20.0, Steps = 12
# Episode 116: Reward sum = -3.68, Last reward = -5.0, Steps = 10
# Episode 117: Reward sum = -22.15, Last reward = -25.0, Steps = 16
# Episode 118: Reward sum = -4.40, Last reward = -5.0, Steps = 14
# Episode 119: Reward sum = -6.74, Last reward = -8.0, Steps = 9
# Episode 120: Reward sum = -4.40, Last reward = -5.0, Steps = 12
# Episode 121: Reward sum = -36.80, Last reward = -40.0, Steps = 19
# Episode 122: Reward sum = -90.44, Last reward = -93.0, Steps = 17
# Episode 123: Reward sum = -62.94, Last reward = -65.0, Steps = 15
# Episode 124: Reward sum = -2.48, Last reward = -5.0, Steps = 12
# Episode 125: Reward sum = -3.74, Last reward = -5.0, Steps = 15
# Episode 126: Reward sum = -52.74, Last reward = -55.0, Steps = 17
# Episode 127: Reward sum = 1.53, Last reward = 0.0, Steps = 19
# Episode 128: Reward sum = -10.59, Last reward = -13.0, Steps = 16
# Episode 129: Reward sum = -18.86, Last reward = -20.0, Steps = 11
# Episode 130: Reward sum = -26.69, Last reward = -28.0, Steps = 17
# Episode 131: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 132: Reward sum = -38.56, Last reward = -40.0, Steps = 18
# Episode 133: Reward sum = -28.14, Last reward = -30.0, Steps = 15
# Episode 134: Reward sum = -22.22, Last reward = -25.0, Steps = 16
# Episode 135: Reward sum = -16.25, Last reward = -18.0, Steps = 16
# Episode 136: Reward sum = -2.76, Last reward = -5.0, Steps = 16
# Episode 137: Reward sum = -18.37, Last reward = -20.0, Steps = 12
# Episode 138: Reward sum = -4.74, Last reward = -5.0, Steps = 3
# Episode 139: Reward sum = 31.40, Last reward = 30.0, Steps = 18
# Episode 140: Reward sum = 91.19, Last reward = 90.0, Steps = 18
# Episode 141: Reward sum = -3.75, Last reward = -5.0, Steps = 11
# Episode 142: Reward sum = -3.90, Last reward = -5.0, Steps = 11
# Episode 143: Reward sum = -4.12, Last reward = -5.0, Steps = 7
# Episode 144: Reward sum = -28.03, Last reward = -30.0, Steps = 15
# Episode 145: Reward sum = -39.21, Last reward = -40.0, Steps = 16
# Episode 146: Reward sum = -4.15, Last reward = -5.0, Steps = 7
# Episode 147: Reward sum = -23.26, Last reward = -25.0, Steps = 17
# Episode 148: Reward sum = -3.09, Last reward = -5.0, Steps = 13
# Episode 149: Reward sum = -23.04, Last reward = -25.0, Steps = 17
# Episode 150: Reward sum = -40.50, Last reward = -43.0, Steps = 16
# Episode 151: Reward sum = -38.39, Last reward = -40.0, Steps = 13
# Episode 152: Reward sum = -3.57, Last reward = -5.0, Steps = 11
# Episode 153: Reward sum = -4.39, Last reward = -5.0, Steps = 14
# Episode 154: Reward sum = -42.57, Last reward = -46.0, Steps = 16
# Episode 155: Reward sum = -17.79, Last reward = -20.0, Steps = 14
# Episode 156: Reward sum = -28.61, Last reward = -30.0, Steps = 16
# Episode 157: Reward sum = -18.94, Last reward = -20.0, Steps = 8
# Episode 158: Reward sum = -3.54, Last reward = -5.0, Steps = 11
# Episode 159: Reward sum = -2.34, Last reward = -5.0, Steps = 14
# Episode 160: Reward sum = -62.23, Last reward = -65.0, Steps = 19
# Episode 161: Reward sum = -3.59, Last reward = -5.0, Steps = 9
# Episode 162: Reward sum = -6.65, Last reward = -8.0, Steps = 15
# Episode 163: Reward sum = -12.49, Last reward = -15.0, Steps = 17
# Episode 164: Reward sum = -21.73, Last reward = -23.0, Steps = 12
# Episode 165: Reward sum = -13.47, Last reward = -15.0, Steps = 16
# Episode 166: Reward sum = -17.83, Last reward = -20.0, Steps = 16
# Episode 167: Reward sum = -53.38, Last reward = -55.0, Steps = 15
# Episode 168: Reward sum = -23.84, Last reward = -25.0, Steps = 16
# Episode 169: Reward sum = -3.71, Last reward = -5.0, Steps = 9
# Episode 170: Reward sum = -7.08, Last reward = -10.0, Steps = 17
# Episode 171: Reward sum = -3.79, Last reward = -5.0, Steps = 17
# Episode 172: Reward sum = -44.33, Last reward = -48.0, Steps = 15
# Episode 173: Reward sum = -7.14, Last reward = -8.0, Steps = 8
# Episode 174: Reward sum = -13.85, Last reward = -15.0, Steps = 16
# Episode 175: Reward sum = -6.71, Last reward = -8.0, Steps = 12
# Episode 176: Reward sum = -53.65, Last reward = -55.0, Steps = 16
# Episode 177: Reward sum = -4.11, Last reward = -5.0, Steps = 13
# Episode 178: Reward sum = -2.98, Last reward = -5.0, Steps = 11
# Episode 179: Reward sum = -57.26, Last reward = -58.0, Steps = 16
# Episode 180: Reward sum = -4.00, Last reward = -5.0, Steps = 7
# Episode 181: Reward sum = -6.30, Last reward = -8.0, Steps = 13
# Episode 182: Reward sum = -58.38, Last reward = -60.0, Steps = 15
# Episode 183: Reward sum = -3.36, Last reward = -5.0, Steps = 13
# Episode 184: Reward sum = -40.43, Last reward = -43.0, Steps = 15
# Episode 185: Reward sum = -18.63, Last reward = -20.0, Steps = 17
# Episode 186: Reward sum = -16.02, Last reward = -18.0, Steps = 15
# Episode 187: Reward sum = -4.36, Last reward = -5.0, Steps = 4
# Episode 188: Reward sum = -33.07, Last reward = -35.0, Steps = 16
# Episode 189: Reward sum = -17.77, Last reward = -20.0, Steps = 16
# Episode 190: Reward sum = -6.33, Last reward = -8.0, Steps = 10
# Episode 191: Reward sum = -32.84, Last reward = -35.0, Steps = 14
# Episode 192: Reward sum = -4.01, Last reward = -5.0, Steps = 11
# Episode 193: Reward sum = -4.24, Last reward = -5.0, Steps = 10
# Episode 194: Reward sum = -46.01, Last reward = -48.0, Steps = 14
# Episode 195: Reward sum = -4.01, Last reward = -5.0, Steps = 7
# Episode 196: Reward sum = -4.25, Last reward = -5.0, Steps = 5
# Episode 197: Reward sum = -27.37, Last reward = -30.0, Steps = 15
# Episode 198: Reward sum = -2.45, Last reward = -5.0, Steps = 16
# Episode 199: Reward sum = -66.61, Last reward = -68.0, Steps = 17
# Episode 200: Reward sum = -3.28, Last reward = -5.0, Steps = 15
# Episode 201: Reward sum = -26.09, Last reward = -28.0, Steps = 15
# Episode 202: Reward sum = -27.61, Last reward = -30.0, Steps = 16
# Episode 203: Reward sum = -6.97, Last reward = -8.0, Steps = 16
# Episode 204: Reward sum = -3.71, Last reward = -5.0, Steps = 9
# Episode 205: Reward sum = -28.53, Last reward = -31.0, Steps = 16
# Episode 206: Reward sum = -28.20, Last reward = -30.0, Steps = 13
# Episode 207: Reward sum = -7.85, Last reward = -10.0, Steps = 15
# Episode 208: Reward sum = -37.68, Last reward = -40.0, Steps = 15
# Episode 209: Reward sum = -21.67, Last reward = -23.0, Steps = 14
# Episode 210: Reward sum = -4.09, Last reward = -5.0, Steps = 9
# Episode 211: Reward sum = -22.49, Last reward = -23.0, Steps = 13
# Episode 212: Reward sum = -3.38, Last reward = -5.0, Steps = 12
# Episode 213: Reward sum = -6.98, Last reward = -8.0, Steps = 14
# Episode 214: Reward sum = -28.68, Last reward = -30.0, Steps = 16
# Episode 215: Reward sum = -3.29, Last reward = -5.0, Steps = 10
# Episode 216: Reward sum = 12.72, Last reward = 10.0, Steps = 15
# Episode 217: Reward sum = -65.33, Last reward = -68.0, Steps = 17
# Episode 218: Reward sum = 10.42, Last reward = 8.0, Steps = 16
# Episode 219: Reward sum = -28.80, Last reward = -30.0, Steps = 18
# Episode 220: Reward sum = -4.57, Last reward = -5.0, Steps = 8
# Episode 221: Reward sum = -3.48, Last reward = -5.0, Steps = 14
# Episode 222: Reward sum = -19.02, Last reward = -20.0, Steps = 12
# Episode 223: Reward sum = -3.07, Last reward = -5.0, Steps = 13
# Episode 224: Reward sum = 2.71, Last reward = 0.0, Steps = 18
# Episode 225: Reward sum = -33.76, Last reward = -35.0, Steps = 17
# Episode 226: Reward sum = -4.28, Last reward = -5.0, Steps = 7
# Episode 227: Reward sum = -18.37, Last reward = -20.0, Steps = 12
# Episode 228: Reward sum = 6.65, Last reward = 5.0, Steps = 15
# Episode 229: Reward sum = -28.02, Last reward = -30.0, Steps = 15
# Episode 230: Reward sum = -18.50, Last reward = -20.0, Steps = 11
# Episode 231: Reward sum = -0.87, Last reward = -5.0, Steps = 16
# Episode 232: Reward sum = -2.85, Last reward = -5.0, Steps = 16
# Episode 233: Reward sum = 16.05, Last reward = 13.0, Steps = 16
# Episode 234: Reward sum = -4.34, Last reward = -5.0, Steps = 14
# Episode 235: Reward sum = -34.15, Last reward = -35.0, Steps = 16
# Episode 236: Reward sum = -22.90, Last reward = -25.0, Steps = 16
# Episode 237: Reward sum = -18.11, Last reward = -20.0, Steps = 14
# Episode 238: Reward sum = -36.37, Last reward = -38.0, Steps = 14
# Episode 239: Reward sum = -3.49, Last reward = -5.0, Steps = 13
# Episode 240: Reward sum = -32.48, Last reward = -35.0, Steps = 15
# Episode 241: Reward sum = -38.02, Last reward = -40.0, Steps = 17
# Episode 242: Reward sum = -23.23, Last reward = -25.0, Steps = 15
# Episode 243: Reward sum = -37.12, Last reward = -40.0, Steps = 17
# Episode 244: Reward sum = -4.44, Last reward = -5.0, Steps = 10
# Episode 245: Reward sum = -8.48, Last reward = -10.0, Steps = 15
# Episode 246: Reward sum = -9.00, Last reward = -10.0, Steps = 17
# Episode 247: Reward sum = -69.81, Last reward = -71.0, Steps = 17
# Episode 248: Reward sum = -3.78, Last reward = -5.0, Steps = 9
# Episode 249: Reward sum = -20.91, Last reward = -23.0, Steps = 16
# Episode 250: Reward sum = -22.16, Last reward = -25.0, Steps = 15
# Episode 251: Reward sum = -4.56, Last reward = -5.0, Steps = 15
# Episode 252: Reward sum = -22.47, Last reward = -25.0, Steps = 18
# Episode 253: Reward sum = -37.78, Last reward = -40.0, Steps = 18
# Episode 254: Reward sum = -4.26, Last reward = -5.0, Steps = 14
# Episode 255: Reward sum = -4.45, Last reward = -8.0, Steps = 16
# Episode 256: Reward sum = -4.35, Last reward = -5.0, Steps = 6
# Episode 257: Reward sum = -18.80, Last reward = -20.0, Steps = 12
# Episode 258: Reward sum = -17.46, Last reward = -20.0, Steps = 14
# Episode 259: Reward sum = -31.52, Last reward = -35.0, Steps = 17
# Episode 260: Reward sum = -7.71, Last reward = -10.0, Steps = 15
# Episode 261: Reward sum = 31.71, Last reward = 30.0, Steps = 17
# Episode 262: Reward sum = -29.30, Last reward = -30.0, Steps = 18
# Episode 263: Reward sum = -3.00, Last reward = -5.0, Steps = 15
# Episode 264: Reward sum = -7.70, Last reward = -10.0, Steps = 15
# Episode 265: Reward sum = -18.73, Last reward = -20.0, Steps = 14
# Episode 266: Reward sum = -19.70, Last reward = -20.0, Steps = 6
# Episode 267: Reward sum = -3.93, Last reward = -5.0, Steps = 19
# Episode 268: Reward sum = -18.97, Last reward = -21.0, Steps = 16
# Episode 269: Reward sum = -3.50, Last reward = -5.0, Steps = 7
# Episode 270: Reward sum = -12.61, Last reward = -15.0, Steps = 14
# Episode 271: Reward sum = -8.03, Last reward = -10.0, Steps = 17
# Episode 272: Reward sum = -3.96, Last reward = -5.0, Steps = 16
# Episode 273: Reward sum = -4.11, Last reward = -5.0, Steps = 10
# Episode 274: Reward sum = -37.63, Last reward = -40.0, Steps = 17
# Episode 275: Reward sum = -4.08, Last reward = -5.0, Steps = 15
# Episode 276: Reward sum = 2.10, Last reward = 0.0, Steps = 16
# Episode 277: Reward sum = -22.94, Last reward = -25.0, Steps = 16
# Episode 278: Reward sum = -17.92, Last reward = -20.0, Steps = 12
# Episode 279: Reward sum = -6.01, Last reward = -8.0, Steps = 16
# Episode 280: Reward sum = -3.78, Last reward = -5.0, Steps = 12
# Episode 281: Reward sum = -7.20, Last reward = -10.0, Steps = 17
# Episode 282: Reward sum = -18.15, Last reward = -20.0, Steps = 14
# Episode 283: Reward sum = -17.74, Last reward = -20.0, Steps = 17
# Episode 284: Reward sum = -2.61, Last reward = -5.0, Steps = 17
# Episode 285: Reward sum = -3.81, Last reward = -5.0, Steps = 9
# Episode 286: Reward sum = -23.72, Last reward = -25.0, Steps = 16
# Episode 287: Reward sum = -4.26, Last reward = -5.0, Steps = 6
# Episode 288: Reward sum = -3.31, Last reward = -5.0, Steps = 17
# Episode 289: Reward sum = 1.90, Last reward = 0.0, Steps = 17
# Episode 290: Reward sum = -8.98, Last reward = -10.0, Steps = 16
# Episode 291: Reward sum = -6.69, Last reward = -8.0, Steps = 8
# Episode 292: Reward sum = -24.78, Last reward = -28.0, Steps = 16
# Episode 293: Reward sum = -23.34, Last reward = -25.0, Steps = 14
# Episode 294: Reward sum = -4.40, Last reward = -5.0, Steps = 12
# Episode 295: Reward sum = -3.93, Last reward = -5.0, Steps = 10
# Episode 296: Reward sum = -28.15, Last reward = -30.0, Steps = 11
# Episode 297: Reward sum = -78.57, Last reward = -80.0, Steps = 17
# Episode 298: Reward sum = -47.84, Last reward = -50.0, Steps = 17
# Episode 299: Reward sum = 2.00, Last reward = 0.0, Steps = 18
# Episode 300: Reward sum = -8.11, Last reward = -10.0, Steps = 14
# Episode 301: Reward sum = -6.51, Last reward = -8.0, Steps = 14
# Episode 302: Reward sum = -18.13, Last reward = -20.0, Steps = 16
# Episode 303: Reward sum = -55.63, Last reward = -58.0, Steps = 18
# Episode 304: Reward sum = -18.26, Last reward = -20.0, Steps = 11
# Episode 305: Reward sum = -51.54, Last reward = -55.0, Steps = 17
# Episode 306: Reward sum = -3.43, Last reward = -5.0, Steps = 15
# Episode 307: Reward sum = 1.39, Last reward = 0.0, Steps = 16
# Episode 308: Reward sum = -3.61, Last reward = -5.0, Steps = 11
# Episode 309: Reward sum = -12.21, Last reward = -15.0, Steps = 15
# Episode 310: Reward sum = 2.26, Last reward = 0.0, Steps = 16
# Episode 311: Reward sum = -2.13, Last reward = -5.0, Steps = 14
# Episode 312: Reward sum = -3.46, Last reward = -5.0, Steps = 14
# Episode 313: Reward sum = -31.28, Last reward = -33.0, Steps = 10
# Episode 314: Reward sum = -59.18, Last reward = -60.0, Steps = 16
# Episode 315: Reward sum = -53.69, Last reward = -55.0, Steps = 17
# Episode 316: Reward sum = -32.85, Last reward = -35.0, Steps = 15
# Episode 317: Reward sum = 0.15, Last reward = -2.0, Steps = 18
# Episode 318: Reward sum = -9.07, Last reward = -10.0, Steps = 15
# Episode 319: Reward sum = -3.28, Last reward = -5.0, Steps = 11
# Episode 320: Reward sum = -23.31, Last reward = -25.0, Steps = 15
# Episode 321: Reward sum = -18.62, Last reward = -20.0, Steps = 10
# Episode 322: Reward sum = -23.16, Last reward = -25.0, Steps = 15
# Episode 323: Reward sum = -17.12, Last reward = -20.0, Steps = 17
# Episode 324: Reward sum = -23.57, Last reward = -25.0, Steps = 18
# Episode 325: Reward sum = -7.22, Last reward = -8.0, Steps = 12
# Episode 326: Reward sum = -47.15, Last reward = -50.0, Steps = 16
# Episode 327: Reward sum = -32.90, Last reward = -35.0, Steps = 16
# Episode 328: Reward sum = -24.97, Last reward = -28.0, Steps = 16
# Episode 329: Reward sum = -1.86, Last reward = -5.0, Steps = 16
# Episode 330: Reward sum = -6.47, Last reward = -8.0, Steps = 15
# Episode 331: Reward sum = 1.78, Last reward = 0.0, Steps = 16
# Episode 332: Reward sum = 0.81, Last reward = 0.0, Steps = 15
# Episode 333: Reward sum = -3.85, Last reward = -5.0, Steps = 11
# Episode 334: Reward sum = -9.40, Last reward = -10.0, Steps = 16
# Episode 335: Reward sum = -3.88, Last reward = -5.0, Steps = 15
# Episode 336: Reward sum = -6.14, Last reward = -8.0, Steps = 15
# Episode 337: Reward sum = -28.54, Last reward = -30.0, Steps = 15
# Episode 338: Reward sum = -2.21, Last reward = -5.0, Steps = 17
# Episode 339: Reward sum = -3.97, Last reward = -5.0, Steps = 14
# Episode 340: Reward sum = -22.43, Last reward = -25.0, Steps = 17
# Episode 341: Reward sum = -18.06, Last reward = -20.0, Steps = 14
# Episode 342: Reward sum = -3.49, Last reward = -5.0, Steps = 13
# Episode 343: Reward sum = -34.53, Last reward = -35.0, Steps = 16
# Episode 344: Reward sum = -8.32, Last reward = -10.0, Steps = 16
# Episode 345: Reward sum = -30.89, Last reward = -33.0, Steps = 17
# Episode 346: Reward sum = 31.25, Last reward = 30.0, Steps = 16
# Episode 347: Reward sum = -7.64, Last reward = -10.0, Steps = 15
# Episode 348: Reward sum = -3.52, Last reward = -5.0, Steps = 15
# Episode 349: Reward sum = -2.79, Last reward = -5.0, Steps = 15
# Episode 350: Reward sum = -3.83, Last reward = -5.0, Steps = 14
# Episode 351: Reward sum = -3.89, Last reward = -5.0, Steps = 13
# Episode 352: Reward sum = 2.80, Last reward = 0.0, Steps = 16
# Episode 353: Reward sum = -34.20, Last reward = -35.0, Steps = 17
# Episode 354: Reward sum = -3.86, Last reward = -5.0, Steps = 10
# Episode 355: Reward sum = -17.98, Last reward = -20.0, Steps = 14
# Episode 356: Reward sum = -17.97, Last reward = -20.0, Steps = 11
# Episode 357: Reward sum = 35.38, Last reward = 33.0, Steps = 16
# Episode 358: Reward sum = -6.98, Last reward = -8.0, Steps = 9
# Episode 359: Reward sum = -4.40, Last reward = -5.0, Steps = 5
# Episode 360: Reward sum = -37.95, Last reward = -40.0, Steps = 18
# Episode 361: Reward sum = -25.92, Last reward = -28.0, Steps = 15
# Episode 362: Reward sum = 7.14, Last reward = 5.0, Steps = 14
# Episode 363: Reward sum = -18.88, Last reward = -20.0, Steps = 11
# Episode 364: Reward sum = -28.49, Last reward = -30.0, Steps = 13
# Episode 365: Reward sum = -32.65, Last reward = -35.0, Steps = 15
# Episode 366: Reward sum = 3.14, Last reward = 0.0, Steps = 18
# Episode 367: Reward sum = -6.33, Last reward = -8.0, Steps = 11
# Episode 368: Reward sum = -4.62, Last reward = -5.0, Steps = 4
# Episode 369: Reward sum = -7.37, Last reward = -8.0, Steps = 8
# Episode 370: Reward sum = -6.79, Last reward = -8.0, Steps = 15
# Episode 371: Reward sum = -3.33, Last reward = -5.0, Steps = 16
# Episode 372: Reward sum = -28.01, Last reward = -30.0, Steps = 17
# Episode 373: Reward sum = -29.72, Last reward = -30.0, Steps = 6
# Episode 374: Reward sum = 8.63, Last reward = 7.0, Steps = 16
# Episode 375: Reward sum = -3.47, Last reward = -5.0, Steps = 11
# Episode 376: Reward sum = -4.32, Last reward = -5.0, Steps = 11
# Episode 377: Reward sum = -4.19, Last reward = -5.0, Steps = 14
# Episode 378: Reward sum = -2.95, Last reward = -5.0, Steps = 11
# Episode 379: Reward sum = -4.56, Last reward = -5.0, Steps = 4
# Episode 380: Reward sum = -3.37, Last reward = -5.0, Steps = 12
# Episode 381: Reward sum = -2.28, Last reward = -5.0, Steps = 16
# Episode 382: Reward sum = -27.85, Last reward = -30.0, Steps = 16
# Episode 383: Reward sum = -3.62, Last reward = -5.0, Steps = 7
# Episode 384: Reward sum = -3.53, Last reward = -5.0, Steps = 10
# Episode 385: Reward sum = -7.75, Last reward = -10.0, Steps = 15
# Episode 386: Reward sum = -10.44, Last reward = -13.0, Steps = 15
# Episode 387: Reward sum = -2.38, Last reward = -5.0, Steps = 18
# Episode 388: Reward sum = 27.96, Last reward = 27.0, Steps = 20
# Episode 389: Reward sum = -31.14, Last reward = -33.0, Steps = 16
# Episode 390: Reward sum = -18.65, Last reward = -20.0, Steps = 15
# Episode 391: Reward sum = -19.22, Last reward = -20.0, Steps = 10
# Episode 392: Reward sum = -3.48, Last reward = -5.0, Steps = 10
# Episode 393: Reward sum = 7.15, Last reward = 5.0, Steps = 17
# Episode 394: Reward sum = -2.51, Last reward = -5.0, Steps = 16
# Episode 395: Reward sum = -2.77, Last reward = -5.0, Steps = 16
# Episode 396: Reward sum = -36.69, Last reward = -40.0, Steps = 18
# Episode 397: Reward sum = -53.18, Last reward = -55.0, Steps = 16
# Episode 398: Reward sum = -18.05, Last reward = -20.0, Steps = 16
# Episode 399: Reward sum = -3.27, Last reward = -5.0, Steps = 8
# Episode 400: Reward sum = -9.15, Last reward = -10.0, Steps = 14
# Episode 401: Reward sum = -0.84, Last reward = -2.0, Steps = 13
# Episode 402: Reward sum = -27.69, Last reward = -30.0, Steps = 14
# Episode 403: Reward sum = -2.65, Last reward = -5.0, Steps = 14
# Episode 404: Reward sum = -3.00, Last reward = -5.0, Steps = 14
# Episode 405: Reward sum = -3.62, Last reward = -5.0, Steps = 17
# Episode 406: Reward sum = -13.28, Last reward = -15.0, Steps = 15
# Episode 407: Reward sum = -38.27, Last reward = -40.0, Steps = 18
# Episode 408: Reward sum = -22.90, Last reward = -25.0, Steps = 18
# Episode 409: Reward sum = -4.69, Last reward = -5.0, Steps = 3
# Episode 410: Reward sum = -5.73, Last reward = -8.0, Steps = 15
# Episode 411: Reward sum = -2.84, Last reward = -5.0, Steps = 13
# Episode 412: Reward sum = -2.91, Last reward = -5.0, Steps = 15
# Episode 413: Reward sum = -53.85, Last reward = -55.0, Steps = 17
# Episode 414: Reward sum = -2.03, Last reward = -5.0, Steps = 15
# Episode 415: Reward sum = -76.64, Last reward = -80.0, Steps = 17
# Episode 416: Reward sum = -19.25, Last reward = -20.0, Steps = 11
# Episode 417: Reward sum = -15.98, Last reward = -18.0, Steps = 17
# Episode 418: Reward sum = -6.99, Last reward = -10.0, Steps = 15
# Episode 419: Reward sum = -12.53, Last reward = -15.0, Steps = 16
# Episode 420: Reward sum = 0.80, Last reward = 0.0, Steps = 10
# Episode 421: Reward sum = -21.42, Last reward = -23.0, Steps = 11
# Episode 422: Reward sum = -3.76, Last reward = -5.0, Steps = 12
# Episode 423: Reward sum = -83.43, Last reward = -86.0, Steps = 15
# Episode 424: Reward sum = -4.05, Last reward = -5.0, Steps = 15
# Episode 425: Reward sum = -28.12, Last reward = -30.0, Steps = 12
# Episode 426: Reward sum = -30.67, Last reward = -33.0, Steps = 14
# Episode 427: Reward sum = -32.93, Last reward = -35.0, Steps = 15
# Episode 428: Reward sum = -2.30, Last reward = -5.0, Steps = 16
# Episode 429: Reward sum = -3.20, Last reward = -5.0, Steps = 6
# Episode 430: Reward sum = -45.73, Last reward = -48.0, Steps = 16
# Episode 431: Reward sum = 1.33, Last reward = 0.0, Steps = 18
# Episode 432: Reward sum = 0.88, Last reward = 0.0, Steps = 6
# Episode 433: Reward sum = -33.01, Last reward = -35.0, Steps = 19
# Episode 434: Reward sum = -18.40, Last reward = -20.0, Steps = 16
# Episode 435: Reward sum = -49.42, Last reward = -51.0, Steps = 16
# Episode 436: Reward sum = -4.85, Last reward = -5.0, Steps = 14
# Episode 437: Reward sum = -3.72, Last reward = -5.0, Steps = 10
# Episode 438: Reward sum = -3.54, Last reward = -5.0, Steps = 13
# Episode 439: Reward sum = -4.04, Last reward = -5.0, Steps = 16
# Episode 440: Reward sum = -7.37, Last reward = -10.0, Steps = 17
# Episode 441: Reward sum = -8.01, Last reward = -10.0, Steps = 15
# Episode 442: Reward sum = -28.37, Last reward = -30.0, Steps = 15
# Episode 443: Reward sum = 25.02, Last reward = 23.0, Steps = 18
# Episode 444: Reward sum = -4.11, Last reward = -5.0, Steps = 14
# Episode 445: Reward sum = 31.63, Last reward = 30.0, Steps = 15
# Episode 446: Reward sum = 32.21, Last reward = 30.0, Steps = 19
# Episode 447: Reward sum = -6.59, Last reward = -8.0, Steps = 13
# Episode 448: Reward sum = 1.61, Last reward = 0.0, Steps = 15
# Episode 449: Reward sum = 1.61, Last reward = 0.0, Steps = 17
# Episode 450: Reward sum = -19.06, Last reward = -20.0, Steps = 16
# Episode 451: Reward sum = -4.47, Last reward = -5.0, Steps = 15
# Episode 452: Reward sum = 1.66, Last reward = 0.0, Steps = 16
# Episode 453: Reward sum = -6.49, Last reward = -8.0, Steps = 15
# Episode 454: Reward sum = -28.59, Last reward = -30.0, Steps = 16
# Episode 455: Reward sum = -76.65, Last reward = -80.0, Steps = 18
# Episode 456: Reward sum = -3.67, Last reward = -5.0, Steps = 12
# Episode 457: Reward sum = -48.82, Last reward = -50.0, Steps = 19
# Episode 458: Reward sum = -26.45, Last reward = -28.0, Steps = 16
# Episode 459: Reward sum = -17.62, Last reward = -20.0, Steps = 16
# Episode 460: Reward sum = -21.83, Last reward = -25.0, Steps = 15
# Episode 461: Reward sum = 91.50, Last reward = 90.0, Steps = 15
# Episode 462: Reward sum = -85.70, Last reward = -86.0, Steps = 19
# Episode 463: Reward sum = -16.25, Last reward = -18.0, Steps = 17
# Episode 464: Reward sum = -8.30, Last reward = -10.0, Steps = 14
# Episode 465: Reward sum = -32.73, Last reward = -35.0, Steps = 16
# Episode 466: Reward sum = -6.84, Last reward = -8.0, Steps = 11
# Episode 467: Reward sum = -12.80, Last reward = -15.0, Steps = 16
# Episode 468: Reward sum = -41.00, Last reward = -43.0, Steps = 16
# Episode 469: Reward sum = -42.14, Last reward = -43.0, Steps = 16
# Episode 470: Reward sum = -27.60, Last reward = -30.0, Steps = 17
# Episode 471: Reward sum = -3.75, Last reward = -5.0, Steps = 18
# Episode 472: Reward sum = -3.69, Last reward = -5.0, Steps = 14
# Episode 473: Reward sum = -49.00, Last reward = -50.0, Steps = 16
# Episode 474: Reward sum = -3.13, Last reward = -5.0, Steps = 15
# Episode 475: Reward sum = -2.45, Last reward = -5.0, Steps = 16
# Episode 476: Reward sum = -23.98, Last reward = -25.0, Steps = 15
# Episode 477: Reward sum = -33.03, Last reward = -35.0, Steps = 17
# Episode 478: Reward sum = -2.52, Last reward = -5.0, Steps = 12
# Episode 479: Reward sum = 18.45, Last reward = 14.0, Steps = 18
# Episode 480: Reward sum = 181.38, Last reward = 180.0, Steps = 14
# Episode 481: Reward sum = -19.05, Last reward = -20.0, Steps = 16
# Episode 482: Reward sum = -3.58, Last reward = -5.0, Steps = 15
# Episode 483: Reward sum = -9.94, Last reward = -11.0, Steps = 14
# Episode 484: Reward sum = -70.35, Last reward = -73.0, Steps = 17
# Episode 485: Reward sum = -7.87, Last reward = -10.0, Steps = 17
# Episode 486: Reward sum = -41.16, Last reward = -43.0, Steps = 18
# Episode 487: Reward sum = -4.18, Last reward = -5.0, Steps = 5
# Episode 488: Reward sum = -54.47, Last reward = -58.0, Steps = 17
# Episode 489: Reward sum = 7.88, Last reward = 5.0, Steps = 18
# Episode 490: Reward sum = -3.07, Last reward = -5.0, Steps = 16
# Episode 491: Reward sum = -4.67, Last reward = -5.0, Steps = 5
# Episode 492: Reward sum = 0.68, Last reward = 0.0, Steps = 11
# Episode 493: Reward sum = -4.36, Last reward = -5.0, Steps = 5
# Episode 494: Reward sum = -18.64, Last reward = -20.0, Steps = 16
# Episode 495: Reward sum = 1.76, Last reward = 0.0, Steps = 18
# Episode 496: Reward sum = -18.55, Last reward = -20.0, Steps = 14
# Episode 497: Reward sum = 10.33, Last reward = 8.0, Steps = 17
# Episode 498: Reward sum = -4.05, Last reward = -5.0, Steps = 6
# Episode 499: Reward sum = -3.38, Last reward = -5.0, Steps = 9
# Episode 500: Reward sum = -22.23, Last reward = -25.0, Steps = 16
# Episode 501: Reward sum = -28.06, Last reward = -30.0, Steps = 14
# Episode 502: Reward sum = -57.85, Last reward = -60.0, Steps = 16
# Episode 503: Reward sum = -61.60, Last reward = -64.0, Steps = 16
# Episode 504: Reward sum = -33.17, Last reward = -35.0, Steps = 17
# Episode 505: Reward sum = -4.02, Last reward = -5.0, Steps = 16
# Episode 506: Reward sum = 11.30, Last reward = 8.0, Steps = 16
# Episode 507: Reward sum = -2.92, Last reward = -5.0, Steps = 12
# Episode 508: Reward sum = 29.05, Last reward = 27.0, Steps = 19
# Episode 509: Reward sum = -23.89, Last reward = -25.0, Steps = 15
# Episode 510: Reward sum = -23.34, Last reward = -25.0, Steps = 17
# Episode 511: Reward sum = -56.40, Last reward = -58.0, Steps = 15
# Episode 512: Reward sum = -3.61, Last reward = -5.0, Steps = 8
# Episode 513: Reward sum = -92.61, Last reward = -94.0, Steps = 16
# Episode 514: Reward sum = -28.38, Last reward = -30.0, Steps = 15
# Episode 515: Reward sum = -68.76, Last reward = -70.0, Steps = 16
# Episode 516: Reward sum = -28.04, Last reward = -30.0, Steps = 16
# Episode 517: Reward sum = -62.69, Last reward = -65.0, Steps = 15
# Episode 518: Reward sum = -51.70, Last reward = -53.0, Steps = 15
# Episode 519: Reward sum = -19.24, Last reward = -20.0, Steps = 7
# Episode 520: Reward sum = -76.81, Last reward = -80.0, Steps = 19
# Episode 521: Reward sum = -21.84, Last reward = -23.0, Steps = 15
# Episode 522: Reward sum = -22.42, Last reward = -25.0, Steps = 14
# Episode 523: Reward sum = -3.54, Last reward = -5.0, Steps = 12
# Episode 524: Reward sum = -4.07, Last reward = -5.0, Steps = 9
# Episode 525: Reward sum = -3.40, Last reward = -5.0, Steps = 13
# Episode 526: Reward sum = -14.24, Last reward = -15.0, Steps = 16
# Episode 527: Reward sum = -22.82, Last reward = -25.0, Steps = 18
# Episode 528: Reward sum = -34.02, Last reward = -35.0, Steps = 14
# Episode 529: Reward sum = -3.80, Last reward = -5.0, Steps = 9
# Episode 530: Reward sum = -8.52, Last reward = -10.0, Steps = 16
# Episode 531: Reward sum = -32.84, Last reward = -35.0, Steps = 16
# Episode 532: Reward sum = -4.03, Last reward = -5.0, Steps = 8
# Episode 533: Reward sum = -17.17, Last reward = -20.0, Steps = 17
# Episode 534: Reward sum = -8.28, Last reward = -10.0, Steps = 16
# Episode 535: Reward sum = -3.44, Last reward = -5.0, Steps = 13
# Episode 536: Reward sum = -16.15, Last reward = -18.0, Steps = 17
# Episode 537: Reward sum = -69.01, Last reward = -70.0, Steps = 16
# Episode 538: Reward sum = -51.82, Last reward = -53.0, Steps = 17
# Episode 539: Reward sum = -62.25, Last reward = -63.0, Steps = 16
# Episode 540: Reward sum = -48.11, Last reward = -50.0, Steps = 18
# Episode 541: Reward sum = -18.05, Last reward = -20.0, Steps = 14
# Episode 542: Reward sum = -34.43, Last reward = -38.0, Steps = 20
# Episode 543: Reward sum = -26.35, Last reward = -28.0, Steps = 19
# Episode 544: Reward sum = -42.18, Last reward = -43.0, Steps = 16
# Episode 545: Reward sum = -2.95, Last reward = -5.0, Steps = 13
# Episode 546: Reward sum = 2.09, Last reward = 0.0, Steps = 14
# Episode 547: Reward sum = -18.06, Last reward = -20.0, Steps = 15
# Episode 548: Reward sum = -3.23, Last reward = -5.0, Steps = 13
# Episode 549: Reward sum = -53.96, Last reward = -55.0, Steps = 18
# Episode 550: Reward sum = -2.94, Last reward = -5.0, Steps = 15
# Episode 551: Reward sum = -8.28, Last reward = -10.0, Steps = 19
# Episode 552: Reward sum = 10.41, Last reward = 8.0, Steps = 16
# Episode 553: Reward sum = -27.30, Last reward = -30.0, Steps = 17
# Episode 554: Reward sum = -45.74, Last reward = -48.0, Steps = 17
# Episode 555: Reward sum = -3.90, Last reward = -5.0, Steps = 10
# Episode 556: Reward sum = -1.85, Last reward = -5.0, Steps = 16
# Episode 557: Reward sum = -3.74, Last reward = -5.0, Steps = 13
# Episode 558: Reward sum = 6.22, Last reward = 5.0, Steps = 18
# Episode 559: Reward sum = -17.79, Last reward = -20.0, Steps = 12
# Episode 560: Reward sum = 15.58, Last reward = 13.0, Steps = 17
# Episode 561: Reward sum = -6.90, Last reward = -8.0, Steps = 8
# Episode 562: Reward sum = -3.30, Last reward = -5.0, Steps = 11
# Episode 563: Reward sum = -7.77, Last reward = -10.0, Steps = 16
# Episode 564: Reward sum = -28.42, Last reward = -30.0, Steps = 16
# Episode 565: Reward sum = -2.30, Last reward = -5.0, Steps = 16
# Episode 566: Reward sum = -32.22, Last reward = -33.0, Steps = 16
# Episode 567: Reward sum = -63.49, Last reward = -65.0, Steps = 16
# Episode 568: Reward sum = -45.15, Last reward = -48.0, Steps = 17
# Episode 569: Reward sum = 90.86, Last reward = 90.0, Steps = 13
# Episode 570: Reward sum = -53.99, Last reward = -55.0, Steps = 16
# Episode 571: Reward sum = -3.03, Last reward = -5.0, Steps = 13
# Episode 572: Reward sum = -32.42, Last reward = -35.0, Steps = 17
# Episode 573: Reward sum = -4.85, Last reward = -5.0, Steps = 10
# Episode 574: Reward sum = 91.45, Last reward = 90.0, Steps = 15
# Episode 575: Reward sum = 8.06, Last reward = 5.0, Steps = 15
# Episode 576: Reward sum = -82.83, Last reward = -85.0, Steps = 15
# Episode 577: Reward sum = -28.10, Last reward = -30.0, Steps = 13
# Episode 578: Reward sum = -8.57, Last reward = -10.0, Steps = 15
# Episode 579: Reward sum = -93.61, Last reward = -96.0, Steps = 16
# Episode 580: Reward sum = -53.38, Last reward = -55.0, Steps = 14
# Episode 581: Reward sum = -3.57, Last reward = -5.0, Steps = 13
# Episode 582: Reward sum = -31.92, Last reward = -35.0, Steps = 16
# Episode 583: Reward sum = -38.58, Last reward = -40.0, Steps = 17
# Episode 584: Reward sum = 0.80, Last reward = 0.0, Steps = 17
# Episode 585: Reward sum = -106.99, Last reward = -110.0, Steps = 17
# Episode 586: Reward sum = 31.81, Last reward = 30.0, Steps = 17
# Episode 587: Reward sum = -3.23, Last reward = -5.0, Steps = 14
# Episode 588: Reward sum = -1.88, Last reward = -5.0, Steps = 13
# Episode 589: Reward sum = -3.19, Last reward = -5.0, Steps = 13
# Episode 590: Reward sum = -24.07, Last reward = -25.0, Steps = 16
# Episode 591: Reward sum = -53.19, Last reward = -55.0, Steps = 16
# Episode 592: Reward sum = -36.45, Last reward = -38.0, Steps = 15
# Episode 593: Reward sum = -89.49, Last reward = -90.0, Steps = 16
# Episode 594: Reward sum = 2.72, Last reward = 0.0, Steps = 17
# Episode 595: Reward sum = 1.95, Last reward = 0.0, Steps = 17
# Episode 596: Reward sum = -18.14, Last reward = -20.0, Steps = 13
# Episode 597: Reward sum = -23.95, Last reward = -25.0, Steps = 17
# Episode 598: Reward sum = -3.96, Last reward = -5.0, Steps = 10
# Episode 599: Reward sum = -43.63, Last reward = -45.0, Steps = 16
# Episode 600: Reward sum = -43.40, Last reward = -45.0, Steps = 16
# Episode 601: Reward sum = -48.85, Last reward = -50.0, Steps = 15
# Episode 602: Reward sum = -7.50, Last reward = -10.0, Steps = 16
# Episode 603: Reward sum = -22.62, Last reward = -23.0, Steps = 6
# Episode 604: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 605: Reward sum = -3.02, Last reward = -5.0, Steps = 12
# Episode 606: Reward sum = 10.46, Last reward = 8.0, Steps = 17
# Episode 607: Reward sum = -4.90, Last reward = -8.0, Steps = 16
# Episode 608: Reward sum = -18.38, Last reward = -20.0, Steps = 11
# Episode 609: Reward sum = -8.05, Last reward = -10.0, Steps = 16
# Episode 610: Reward sum = -33.46, Last reward = -35.0, Steps = 17
# Episode 611: Reward sum = -38.12, Last reward = -40.0, Steps = 16
# Episode 612: Reward sum = -19.11, Last reward = -20.0, Steps = 11
# Episode 613: Reward sum = -52.43, Last reward = -55.0, Steps = 15
# Episode 614: Reward sum = 30.56, Last reward = 30.0, Steps = 18
# Episode 615: Reward sum = -29.00, Last reward = -30.0, Steps = 15
# Episode 616: Reward sum = -89.83, Last reward = -91.0, Steps = 16
# Episode 617: Reward sum = -4.91, Last reward = -8.0, Steps = 15
# Episode 618: Reward sum = -38.27, Last reward = -40.0, Steps = 17
# Episode 619: Reward sum = -23.42, Last reward = -25.0, Steps = 15
# Episode 620: Reward sum = -26.80, Last reward = -28.0, Steps = 17
# Episode 621: Reward sum = -25.25, Last reward = -28.0, Steps = 16
# Episode 622: Reward sum = -22.64, Last reward = -25.0, Steps = 16
# Episode 623: Reward sum = -56.97, Last reward = -60.0, Steps = 16
# Episode 624: Reward sum = -2.93, Last reward = -5.0, Steps = 14
# Episode 625: Reward sum = -18.87, Last reward = -20.0, Steps = 10
# Episode 626: Reward sum = -5.45, Last reward = -8.0, Steps = 13
# Episode 627: Reward sum = -4.22, Last reward = -5.0, Steps = 5
# Episode 628: Reward sum = -23.18, Last reward = -25.0, Steps = 15
# Episode 629: Reward sum = -6.25, Last reward = -8.0, Steps = 13
# Episode 630: Reward sum = -26.24, Last reward = -28.0, Steps = 16
# Episode 631: Reward sum = -30.82, Last reward = -33.0, Steps = 16
# Episode 632: Reward sum = -6.72, Last reward = -8.0, Steps = 14
# Episode 633: Reward sum = -58.52, Last reward = -60.0, Steps = 16
# Episode 634: Reward sum = -38.15, Last reward = -40.0, Steps = 16
# Episode 635: Reward sum = -28.50, Last reward = -30.0, Steps = 16
# Episode 636: Reward sum = -68.20, Last reward = -70.0, Steps = 16
# Episode 637: Reward sum = -51.18, Last reward = -53.0, Steps = 17
# Episode 638: Reward sum = -39.25, Last reward = -40.0, Steps = 15
# Episode 639: Reward sum = -13.33, Last reward = -15.0, Steps = 14
# Episode 640: Reward sum = -20.50, Last reward = -23.0, Steps = 17
# Episode 641: Reward sum = -3.95, Last reward = -5.0, Steps = 10
# Episode 642: Reward sum = -3.70, Last reward = -5.0, Steps = 9
# Episode 643: Reward sum = 1.57, Last reward = 0.0, Steps = 17
# Episode 644: Reward sum = -6.52, Last reward = -8.0, Steps = 12
# Episode 645: Reward sum = -32.77, Last reward = -35.0, Steps = 17
# Episode 646: Reward sum = -3.89, Last reward = -5.0, Steps = 12
# Episode 647: Reward sum = -2.76, Last reward = -5.0, Steps = 14
# Episode 648: Reward sum = -23.09, Last reward = -25.0, Steps = 17
# Episode 649: Reward sum = -9.37, Last reward = -11.0, Steps = 17
# Episode 650: Reward sum = -4.95, Last reward = -5.0, Steps = 8
# Episode 651: Reward sum = -18.39, Last reward = -20.0, Steps = 16
# Episode 652: Reward sum = -3.44, Last reward = -5.0, Steps = 16
# Episode 653: Reward sum = -7.21, Last reward = -10.0, Steps = 15
# Episode 654: Reward sum = -1.73, Last reward = -5.0, Steps = 15
# Episode 655: Reward sum = -55.25, Last reward = -58.0, Steps = 17
# Episode 656: Reward sum = -3.79, Last reward = -5.0, Steps = 8
# Episode 657: Reward sum = -21.40, Last reward = -25.0, Steps = 16
# Episode 658: Reward sum = -18.75, Last reward = -20.0, Steps = 16
# Episode 659: Reward sum = -3.49, Last reward = -5.0, Steps = 11
# Episode 660: Reward sum = -41.31, Last reward = -43.0, Steps = 16
# Episode 661: Reward sum = -28.11, Last reward = -30.0, Steps = 16
# Episode 662: Reward sum = -46.47, Last reward = -48.0, Steps = 18
# Episode 663: Reward sum = -2.43, Last reward = -5.0, Steps = 15
# Episode 664: Reward sum = -11.86, Last reward = -13.0, Steps = 17
# Episode 665: Reward sum = -53.88, Last reward = -56.0, Steps = 16
# Episode 666: Reward sum = -23.26, Last reward = -25.0, Steps = 14
# Episode 667: Reward sum = -21.57, Last reward = -23.0, Steps = 12
# Episode 668: Reward sum = -30.92, Last reward = -33.0, Steps = 16
# Episode 669: Reward sum = -27.55, Last reward = -30.0, Steps = 15
# Episode 670: Reward sum = -23.66, Last reward = -25.0, Steps = 16
# Episode 671: Reward sum = -36.60, Last reward = -38.0, Steps = 16
# Episode 672: Reward sum = 16.64, Last reward = 15.0, Steps = 9
# Episode 673: Reward sum = -28.21, Last reward = -30.0, Steps = 17
# Episode 674: Reward sum = -18.70, Last reward = -20.0, Steps = 16
# Episode 675: Reward sum = -11.49, Last reward = -14.0, Steps = 16
# Episode 676: Reward sum = -5.88, Last reward = -8.0, Steps = 16
# Episode 677: Reward sum = -33.22, Last reward = -35.0, Steps = 19
# Episode 678: Reward sum = -4.90, Last reward = -5.0, Steps = 4
# Episode 679: Reward sum = -38.63, Last reward = -40.0, Steps = 15
# Episode 680: Reward sum = -3.23, Last reward = -5.0, Steps = 12
# Episode 681: Reward sum = -2.15, Last reward = -5.0, Steps = 16
# Episode 682: Reward sum = -9.60, Last reward = -10.0, Steps = 16
# Episode 683: Reward sum = -78.80, Last reward = -80.0, Steps = 18
# Episode 684: Reward sum = -15.95, Last reward = -18.0, Steps = 16
# Episode 685: Reward sum = -23.29, Last reward = -25.0, Steps = 15
# Episode 686: Reward sum = -79.10, Last reward = -80.0, Steps = 17
# Episode 687: Reward sum = -3.14, Last reward = -5.0, Steps = 13
# Episode 688: Reward sum = -3.21, Last reward = -5.0, Steps = 9
# Episode 689: Reward sum = -4.36, Last reward = -5.0, Steps = 14
# Episode 690: Reward sum = -6.89, Last reward = -8.0, Steps = 12
# Episode 691: Reward sum = -53.04, Last reward = -55.0, Steps = 15
# Episode 692: Reward sum = -63.68, Last reward = -65.0, Steps = 18
# Episode 693: Reward sum = -47.54, Last reward = -50.0, Steps = 17
# Episode 694: Reward sum = -2.42, Last reward = -5.0, Steps = 17
# Episode 695: Reward sum = -28.67, Last reward = -30.0, Steps = 15
# Episode 696: Reward sum = -46.70, Last reward = -48.0, Steps = 16
# Episode 697: Reward sum = -61.67, Last reward = -64.0, Steps = 16
# Episode 698: Reward sum = -9.44, Last reward = -10.0, Steps = 15
# Episode 699: Reward sum = -5.00, Last reward = -5.0, Steps = 2
# Episode 700: Reward sum = -58.73, Last reward = -61.0, Steps = 17
# Episode 701: Reward sum = -15.42, Last reward = -18.0, Steps = 13
# Episode 702: Reward sum = -35.97, Last reward = -38.0, Steps = 18
# Episode 703: Reward sum = -27.07, Last reward = -30.0, Steps = 15
# Episode 704: Reward sum = -29.24, Last reward = -30.0, Steps = 7
# Episode 705: Reward sum = -3.99, Last reward = -5.0, Steps = 12
# Episode 706: Reward sum = -54.14, Last reward = -55.0, Steps = 16
# Episode 707: Reward sum = -28.35, Last reward = -30.0, Steps = 16
# Episode 708: Reward sum = -8.51, Last reward = -11.0, Steps = 16
# Episode 709: Reward sum = -35.80, Last reward = -38.0, Steps = 17
# Episode 710: Reward sum = -4.31, Last reward = -5.0, Steps = 11
# Episode 711: Reward sum = -11.93, Last reward = -15.0, Steps = 16
# Episode 712: Reward sum = -24.25, Last reward = -25.0, Steps = 14
# Episode 713: Reward sum = -6.37, Last reward = -8.0, Steps = 15
# Episode 714: Reward sum = -31.33, Last reward = -33.0, Steps = 16
# Episode 715: Reward sum = 3.13, Last reward = 0.0, Steps = 18
# Episode 716: Reward sum = -0.03, Last reward = -2.0, Steps = 10
# Episode 717: Reward sum = -8.26, Last reward = -10.0, Steps = 16
# Episode 718: Reward sum = 61.02, Last reward = 60.0, Steps = 16
# Episode 719: Reward sum = -18.08, Last reward = -20.0, Steps = 15
# Episode 720: Reward sum = -21.23, Last reward = -23.0, Steps = 8
# Episode 721: Reward sum = 1.11, Last reward = 0.0, Steps = 12
# Episode 722: Reward sum = -9.24, Last reward = -10.0, Steps = 16
# Episode 723: Reward sum = -78.99, Last reward = -80.0, Steps = 15
# Episode 724: Reward sum = -27.56, Last reward = -30.0, Steps = 15
# Episode 725: Reward sum = 1.09, Last reward = 0.0, Steps = 9
# Episode 726: Reward sum = -3.92, Last reward = -5.0, Steps = 7
# Episode 727: Reward sum = -19.29, Last reward = -20.0, Steps = 8
# Episode 728: Reward sum = -6.78, Last reward = -8.0, Steps = 14
# Episode 729: Reward sum = -43.45, Last reward = -45.0, Steps = 17
# Episode 730: Reward sum = -19.24, Last reward = -20.0, Steps = 11
# Episode 731: Reward sum = 29.70, Last reward = 26.0, Steps = 16
# Episode 732: Reward sum = -1.44, Last reward = -5.0, Steps = 15
# Episode 733: Reward sum = -3.35, Last reward = -5.0, Steps = 11
# Episode 734: Reward sum = -23.13, Last reward = -25.0, Steps = 15
# Episode 735: Reward sum = -3.90, Last reward = -5.0, Steps = 14
# Episode 736: Reward sum = -12.10, Last reward = -15.0, Steps = 16
# Episode 737: Reward sum = -15.30, Last reward = -18.0, Steps = 15
# Episode 738: Reward sum = -23.81, Last reward = -25.0, Steps = 17
# Episode 739: Reward sum = -9.82, Last reward = -15.0, Steps = 18
# Episode 740: Reward sum = -3.48, Last reward = -5.0, Steps = 9
# Episode 741: Reward sum = -28.15, Last reward = -30.0, Steps = 11
# Episode 742: Reward sum = -19.19, Last reward = -20.0, Steps = 12
# ...
# Episode 755: Reward sum = -39.05, Last reward = -40.0, Steps = 14
# Episode 756: Reward sum = 30.81, Last reward = 30.0, Steps = 19
# Episode 757: Reward sum = 29.00, Last reward = 20.0, Steps = 18
# Episode 758: Reward sum = -32.74, Last reward = -35.0, Steps = 17
# Episode 759: Reward sum = -16.64, Last reward = -17.0, Steps = 15
# Episode 760: Reward sum = -17.40, Last reward = -20.0, Steps = 16
# Episode 761: Reward sum = -24.91, Last reward = -27.0, Steps = 14
# Episode 762: Reward sum = -47.81, Last reward = -50.0, Steps = 16
# Episode 763: Reward sum = -10.43, Last reward = -13.0, Steps = 15
# Episode 764: Reward sum = -24.26, Last reward = -25.0, Steps = 16
# Episode 765: Reward sum = -6.55, Last reward = -8.0, Steps = 11
# Episode 766: Reward sum = -38.38, Last reward = -40.0, Steps = 17
# Episode 767: Reward sum = -27.21, Last reward = -30.0, Steps = 17
# Episode 768: Reward sum = -2.27, Last reward = -5.0, Steps = 14
# Episode 769: Reward sum = -15.36, Last reward = -18.0, Steps = 18
# Episode 770: Reward sum = -7.97, Last reward = -10.0, Steps = 18
# Episode 771: Reward sum = -22.56, Last reward = -25.0, Steps = 16
# Episode 772: Reward sum = -23.11, Last reward = -25.0, Steps = 14
# Episode 773: Reward sum = -21.23, Last reward = -23.0, Steps = 16
# Episode 774: Reward sum = -40.49, Last reward = -43.0, Steps = 16
# Episode 775: Reward sum = -3.82, Last reward = -5.0, Steps = 15
# Episode 776: Reward sum = -45.05, Last reward = -46.0, Steps = 15
# Episode 777: Reward sum = -41.86, Last reward = -43.0, Steps = 17
# Episode 778: Reward sum = 31.82, Last reward = 30.0, Steps = 19
# Episode 779: Reward sum = -3.15, Last reward = -5.0, Steps = 13
# Episode 780: Reward sum = -12.57, Last reward = -15.0, Steps = 16
# Episode 781: Reward sum = -3.39, Last reward = -5.0, Steps = 15
# Episode 782: Reward sum = -25.67, Last reward = -28.0, Steps = 16
# Episode 783: Reward sum = -62.06, Last reward = -65.0, Steps = 18
# Episode 784: Reward sum = -3.59, Last reward = -5.0, Steps = 13
# Episode 785: Reward sum = -28.46, Last reward = -30.0, Steps = 14
# Episode 786: Reward sum = -85.44, Last reward = -86.0, Steps = 14
# Episode 787: Reward sum = -6.13, Last reward = -8.0, Steps = 15
# Episode 788: Reward sum = -3.71, Last reward = -5.0, Steps = 9
# Episode 789: Reward sum = -38.35, Last reward = -40.0, Steps = 16
# Episode 790: Reward sum = 48.68, Last reward = 40.0, Steps = 18
# Episode 791: Reward sum = -53.28, Last reward = -55.0, Steps = 15
# Episode 792: Reward sum = -36.68, Last reward = -40.0, Steps = 16
# Episode 793: Reward sum = -2.87, Last reward = -5.0, Steps = 15
# Episode 794: Reward sum = -43.66, Last reward = -45.0, Steps = 16
# Episode 795: Reward sum = 35.09, Last reward = 33.0, Steps = 19
# Episode 796: Reward sum = -60.92, Last reward = -63.0, Steps = 15
# Episode 797: Reward sum = -2.81, Last reward = -5.0, Steps = 12
# Episode 798: Reward sum = -37.95, Last reward = -40.0, Steps = 16
# Episode 799: Reward sum = -4.21, Last reward = -5.0, Steps = 13
# Episode 800: Reward sum = -53.46, Last reward = -55.0, Steps = 15
# Episode 801: Reward sum = -3.35, Last reward = -5.0, Steps = 11
# Episode 802: Reward sum = -3.91, Last reward = -5.0, Steps = 14
# Episode 803: Reward sum = -3.44, Last reward = -5.0, Steps = 14
# Episode 804: Reward sum = -4.48, Last reward = -5.0, Steps = 7
# Episode 805: Reward sum = 7.28, Last reward = 5.0, Steps = 18
# Episode 806: Reward sum = -8.91, Last reward = -10.0, Steps = 15
# Episode 807: Reward sum = -3.97, Last reward = -5.0, Steps = 7
# Episode 808: Reward sum = -25.42, Last reward = -27.0, Steps = 14
# Episode 809: Reward sum = -18.35, Last reward = -20.0, Steps = 13
# Episode 810: Reward sum = -38.03, Last reward = -41.0, Steps = 16
# Episode 811: Reward sum = -23.08, Last reward = -25.0, Steps = 15
# Episode 812: Reward sum = -28.76, Last reward = -30.0, Steps = 19
# Episode 813: Reward sum = -10.69, Last reward = -13.0, Steps = 15
# Episode 814: Reward sum = -3.39, Last reward = -5.0, Steps = 15
# Episode 815: Reward sum = -55.93, Last reward = -58.0, Steps = 15
# Episode 816: Reward sum = -33.17, Last reward = -35.0, Steps = 17
# Episode 817: Reward sum = -3.24, Last reward = -5.0, Steps = 13
# Episode 818: Reward sum = -4.21, Last reward = -5.0, Steps = 8
# Episode 819: Reward sum = -19.15, Last reward = -20.0, Steps = 16
# Episode 820: Reward sum = -3.10, Last reward = -5.0, Steps = 16
# Episode 821: Reward sum = -2.50, Last reward = -5.0, Steps = 16
# Episode 822: Reward sum = -43.53, Last reward = -45.0, Steps = 15
# Episode 823: Reward sum = -25.82, Last reward = -28.0, Steps = 17
# Episode 824: Reward sum = -16.94, Last reward = -18.0, Steps = 16
# Episode 825: Reward sum = -6.56, Last reward = -8.0, Steps = 13
# Episode 826: Reward sum = -49.34, Last reward = -53.0, Steps = 16
# Episode 827: Reward sum = -4.42, Last reward = -5.0, Steps = 9
# Episode 828: Reward sum = -33.05, Last reward = -35.0, Steps = 17
# Episode 829: Reward sum = -3.66, Last reward = -5.0, Steps = 15
# Episode 830: Reward sum = -3.62, Last reward = -5.0, Steps = 15
# Episode 831: Reward sum = -3.45, Last reward = -5.0, Steps = 13
# Episode 832: Reward sum = -3.97, Last reward = -5.0, Steps = 16
# Episode 833: Reward sum = -8.37, Last reward = -10.0, Steps = 15
# Episode 834: Reward sum = -4.64, Last reward = -5.0, Steps = 3
# Episode 835: Reward sum = -7.54, Last reward = -10.0, Steps = 14
# Episode 836: Reward sum = -3.40, Last reward = -5.0, Steps = 9
# Episode 837: Reward sum = -3.88, Last reward = -5.0, Steps = 10
# Episode 838: Reward sum = -3.71, Last reward = -5.0, Steps = 12
# Episode 839: Reward sum = -34.02, Last reward = -35.0, Steps = 16
# Episode 840: Reward sum = -8.48, Last reward = -10.0, Steps = 15
# Episode 841: Reward sum = -3.25, Last reward = -5.0, Steps = 12
# Episode 842: Reward sum = -3.20, Last reward = -5.0, Steps = 15
# Episode 843: Reward sum = -3.73, Last reward = -5.0, Steps = 10
# Episode 844: Reward sum = -2.51, Last reward = -5.0, Steps = 16
# Episode 845: Reward sum = -3.83, Last reward = -5.0, Steps = 10
# Episode 846: Reward sum = -3.95, Last reward = -5.0, Steps = 12
# Episode 847: Reward sum = -34.68, Last reward = -38.0, Steps = 17
# Episode 848: Reward sum = -3.40, Last reward = -5.0, Steps = 13
# Episode 849: Reward sum = -24.93, Last reward = -28.0, Steps = 18
# Episode 850: Reward sum = -34.41, Last reward = -35.0, Steps = 18
# Episode 851: Reward sum = 0.96, Last reward = 0.0, Steps = 18
# Episode 852: Reward sum = -2.67, Last reward = -5.0, Steps = 13
# Episode 853: Reward sum = -7.68, Last reward = -10.0, Steps = 15
# Episode 854: Reward sum = -3.26, Last reward = -5.0, Steps = 11
# Episode 855: Reward sum = -71.50, Last reward = -73.0, Steps = 16
# Episode 856: Reward sum = -3.02, Last reward = -5.0, Steps = 12
# Episode 857: Reward sum = -24.90, Last reward = -28.0, Steps = 16
# Episode 858: Reward sum = 31.81, Last reward = 30.0, Steps = 19
# Episode 859: Reward sum = -17.99, Last reward = -20.0, Steps = 13
# Episode 860: Reward sum = -27.39, Last reward = -30.0, Steps = 16
# Episode 861: Reward sum = -58.46, Last reward = -61.0, Steps = 17
# Episode 862: Reward sum = 91.83, Last reward = 90.0, Steps = 14
# Episode 863: Reward sum = -3.87, Last reward = -5.0, Steps = 14
# Episode 864: Reward sum = -31.32, Last reward = -33.0, Steps = 8
# Episode 865: Reward sum = 0.83, Last reward = 0.0, Steps = 16
# Episode 866: Reward sum = 1.89, Last reward = 0.0, Steps = 18
# Episode 867: Reward sum = -4.35, Last reward = -5.0, Steps = 6
# Episode 868: Reward sum = -18.65, Last reward = -20.0, Steps = 12
# Episode 869: Reward sum = -94.07, Last reward = -95.0, Steps = 17
# Episode 870: Reward sum = -1.77, Last reward = -5.0, Steps = 15
# Episode 871: Reward sum = -13.24, Last reward = -15.0, Steps = 16
# Episode 872: Reward sum = -32.96, Last reward = -35.0, Steps = 16
# Episode 873: Reward sum = -33.79, Last reward = -35.0, Steps = 15
# Episode 874: Reward sum = -3.78, Last reward = -5.0, Steps = 7
# Episode 875: Reward sum = -26.32, Last reward = -28.0, Steps = 17
# Episode 876: Reward sum = 31.38, Last reward = 30.0, Steps = 16
# Episode 877: Reward sum = 2.10, Last reward = 0.0, Steps = 16
# Episode 878: Reward sum = -33.91, Last reward = -35.0, Steps = 16
# Episode 879: Reward sum = -27.89, Last reward = -30.0, Steps = 16
# Episode 880: Reward sum = 2.97, Last reward = 0.0, Steps = 15
# Episode 881: Reward sum = -36.59, Last reward = -38.0, Steps = 17
# Episode 882: Reward sum = -16.40, Last reward = -18.0, Steps = 16
# Episode 883: Reward sum = -18.88, Last reward = -20.0, Steps = 5
# Episode 884: Reward sum = -2.86, Last reward = -5.0, Steps = 10
# Episode 885: Reward sum = -1.80, Last reward = -5.0, Steps = 13
# Episode 886: Reward sum = -22.74, Last reward = -25.0, Steps = 15
# Episode 887: Reward sum = -3.49, Last reward = -5.0, Steps = 12
# Episode 888: Reward sum = -23.76, Last reward = -25.0, Steps = 17
# Episode 889: Reward sum = 1.28, Last reward = 0.0, Steps = 14
# Episode 890: Reward sum = -6.96, Last reward = -8.0, Steps = 9
# Episode 891: Reward sum = -38.39, Last reward = -40.0, Steps = 18
# Episode 892: Reward sum = -8.61, Last reward = -10.0, Steps = 16
# Episode 893: Reward sum = -7.82, Last reward = -10.0, Steps = 16
# Episode 894: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 895: Reward sum = -41.90, Last reward = -43.0, Steps = 18
# Episode 896: Reward sum = 16.76, Last reward = 15.0, Steps = 15
# Episode 897: Reward sum = -7.34, Last reward = -8.0, Steps = 16
# Episode 898: Reward sum = -33.87, Last reward = -35.0, Steps = 17
# Episode 899: Reward sum = -5.92, Last reward = -8.0, Steps = 12
# Episode 900: Reward sum = -4.60, Last reward = -5.0, Steps = 11
# Episode 901: Reward sum = 90.66, Last reward = 90.0, Steps = 12
# Episode 902: Reward sum = -6.69, Last reward = -8.0, Steps = 14
# Episode 903: Reward sum = -3.74, Last reward = -5.0, Steps = 8
# Episode 904: Reward sum = -6.29, Last reward = -8.0, Steps = 17
# Episode 905: Reward sum = -6.24, Last reward = -8.0, Steps = 13
# Episode 906: Reward sum = -2.84, Last reward = -5.0, Steps = 11
# Episode 907: Reward sum = -52.97, Last reward = -55.0, Steps = 18
# Episode 908: Reward sum = -32.90, Last reward = -35.0, Steps = 17
# Episode 909: Reward sum = -3.51, Last reward = -5.0, Steps = 13
# Episode 910: Reward sum = -4.15, Last reward = -5.0, Steps = 12
# Episode 911: Reward sum = -18.60, Last reward = -20.0, Steps = 14
# Episode 912: Reward sum = -6.28, Last reward = -8.0, Steps = 10
# Episode 913: Reward sum = -7.20, Last reward = -8.0, Steps = 10
# Episode 914: Reward sum = -21.03, Last reward = -23.0, Steps = 16
# Episode 915: Reward sum = -6.89, Last reward = -10.0, Steps = 16
# Episode 916: Reward sum = -22.90, Last reward = -25.0, Steps = 16
# Episode 917: Reward sum = -28.41, Last reward = -30.0, Steps = 14
# Episode 918: Reward sum = -57.20, Last reward = -58.0, Steps = 17
# Episode 919: Reward sum = -13.86, Last reward = -15.0, Steps = 16
# Episode 920: Reward sum = -4.10, Last reward = -5.0, Steps = 12
# Episode 921: Reward sum = -36.37, Last reward = -38.0, Steps = 17
# Episode 922: Reward sum = -3.79, Last reward = -5.0, Steps = 8
# Episode 923: Reward sum = -38.50, Last reward = -40.0, Steps = 17
# Episode 924: Reward sum = -4.18, Last reward = -5.0, Steps = 15
# Episode 925: Reward sum = -4.55, Last reward = -5.0, Steps = 6
# Episode 926: Reward sum = -21.85, Last reward = -25.0, Steps = 16
# Episode 927: Reward sum = -25.05, Last reward = -28.0, Steps = 16
# Episode 928: Reward sum = -3.34, Last reward = -5.0, Steps = 14
# Episode 929: Reward sum = -3.41, Last reward = -5.0, Steps = 15
# Episode 930: Reward sum = -17.31, Last reward = -20.0, Steps = 16
# Episode 931: Reward sum = -4.26, Last reward = -5.0, Steps = 9
# Episode 932: Reward sum = -4.55, Last reward = -5.0, Steps = 7
# Episode 933: Reward sum = -16.87, Last reward = -20.0, Steps = 16
# Episode 934: Reward sum = -3.72, Last reward = -5.0, Steps = 10
# Episode 935: Reward sum = -12.58, Last reward = -15.0, Steps = 17
# Episode 936: Reward sum = -4.60, Last reward = -5.0, Steps = 15
# Episode 937: Reward sum = 12.00, Last reward = 11.0, Steps = 17
# Episode 938: Reward sum = -2.22, Last reward = -5.0, Steps = 14
# Episode 939: Reward sum = -7.25, Last reward = -8.0, Steps = 10
# Episode 940: Reward sum = -27.42, Last reward = -30.0, Steps = 14
# Episode 941: Reward sum = -13.33, Last reward = -15.0, Steps = 18
# Episode 942: Reward sum = -19.15, Last reward = -20.0, Steps = 15
# Episode 943: Reward sum = -41.93, Last reward = -43.0, Steps = 16
# Episode 944: Reward sum = -18.44, Last reward = -20.0, Steps = 16
# Episode 945: Reward sum = -31.15, Last reward = -33.0, Steps = 15
# Episode 946: Reward sum = -2.83, Last reward = -5.0, Steps = 10
# Episode 947: Reward sum = -4.15, Last reward = -5.0, Steps = 8
# Episode 948: Reward sum = -53.75, Last reward = -55.0, Steps = 14
# Episode 949: Reward sum = -33.67, Last reward = -35.0, Steps = 17
# Episode 950: Reward sum = -4.11, Last reward = -5.0, Steps = 11
# Episode 951: Reward sum = -28.71, Last reward = -30.0, Steps = 11
# Episode 952: Reward sum = 16.77, Last reward = 15.0, Steps = 18
# Episode 953: Reward sum = 16.38, Last reward = 15.0, Steps = 15
# Episode 954: Reward sum = -3.95, Last reward = -5.0, Steps = 6
# Episode 955: Reward sum = -28.08, Last reward = -30.0, Steps = 15
# Episode 956: Reward sum = -4.47, Last reward = -5.0, Steps = 10
# Episode 957: Reward sum = -21.70, Last reward = -23.0, Steps = 14
# Episode 958: Reward sum = -21.73, Last reward = -23.0, Steps = 11
# Episode 959: Reward sum = -30.58, Last reward = -33.0, Steps = 15
# Episode 960: Reward sum = -17.72, Last reward = -18.0, Steps = 15
# Episode 961: Reward sum = -2.41, Last reward = -5.0, Steps = 15
# Episode 962: Reward sum = -18.14, Last reward = -20.0, Steps = 11
# Episode 963: Reward sum = -13.98, Last reward = -15.0, Steps = 14
# Episode 964: Reward sum = 3.05, Last reward = 0.0, Steps = 18
# Episode 965: Reward sum = -6.59, Last reward = -8.0, Steps = 9
# Episode 966: Reward sum = -39.36, Last reward = -40.0, Steps = 16
# Episode 967: Reward sum = -3.30, Last reward = -5.0, Steps = 10
# Episode 968: Reward sum = -25.90, Last reward = -28.0, Steps = 16
# Episode 969: Reward sum = -2.64, Last reward = -5.0, Steps = 9
# Episode 970: Reward sum = 6.82, Last reward = 5.0, Steps = 17
# Episode 971: Reward sum = 61.38, Last reward = 60.0, Steps = 15
# Episode 972: Reward sum = -19.70, Last reward = -20.0, Steps = 17
# Episode 973: Reward sum = -3.17, Last reward = -5.0, Steps = 13
# Episode 974: Reward sum = -7.65, Last reward = -10.0, Steps = 15
# Episode 975: Reward sum = -4.88, Last reward = -8.0, Steps = 16
# Episode 976: Reward sum = -23.84, Last reward = -26.0, Steps = 18
# Episode 977: Reward sum = -51.93, Last reward = -55.0, Steps = 16
# Episode 978: Reward sum = 11.56, Last reward = 10.0, Steps = 16
# Episode 979: Reward sum = -70.96, Last reward = -73.0, Steps = 15
# Episode 980: Reward sum = -7.24, Last reward = -8.0, Steps = 11
# Episode 981: Reward sum = -37.43, Last reward = -40.0, Steps = 17
# Episode 982: Reward sum = -4.20, Last reward = -5.0, Steps = 6
# Episode 983: Reward sum = -3.18, Last reward = -5.0, Steps = 10
# Episode 984: Reward sum = -16.77, Last reward = -20.0, Steps = 16
# Episode 985: Reward sum = -28.92, Last reward = -30.0, Steps = 10
# Episode 986: Reward sum = -20.22, Last reward = -23.0, Steps = 17
# Episode 987: Reward sum = -28.25, Last reward = -30.0, Steps = 16
# Episode 988: Reward sum = -4.82, Last reward = -5.0, Steps = 2
# Episode 989: Reward sum = -3.82, Last reward = -5.0, Steps = 13
# Episode 990: Reward sum = 91.61, Last reward = 90.0, Steps = 13
# Episode 991: Reward sum = -2.13, Last reward = -5.0, Steps = 15
# Episode 992: Reward sum = -2.37, Last reward = -5.0, Steps = 16
# Episode 993: Reward sum = -20.39, Last reward = -23.0, Steps = 16
# Episode 994: Reward sum = -4.12, Last reward = -5.0, Steps = 11
# Episode 995: Reward sum = 0.54, Last reward = 0.0, Steps = 4
# Episode 996: Reward sum = -4.07, Last reward = -5.0, Steps = 7
# Episode 997: Reward sum = -27.21, Last reward = -30.0, Steps = 18
# Episode 998: Reward sum = -13.27, Last reward = -15.0, Steps = 17
# Episode 999: Reward sum = -36.85, Last reward = -40.0, Steps = 16
# Episode 1000: Reward sum = -4.05, Last reward = -5.0, Steps = 17

# %%
print("Mean = ", np.mean(agent_eval.eval_rewards_per_episode_last_one))
plot_rewards(logger.log_dir, agent_eval.eval_rewards_per_episode_last_one, title="Evaluation Rewards", save_fig=True)
# Out:
# Mean =  -17.84
