# %%
import gymnasium as gym
import mahjong_env
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from time import strftime
import csv
np.random.seed(42)
tf.random.set_seed(42)

# %%
class Logger:
    def __init__(self):
        # Create a unique log directory
        self.log_dir = f"log_{strftime("%Y_%m_%d-%H_%M_%S")}"
        os.makedirs(self.log_dir, exist_ok=True)

        # Paths for logging files
        self.rewards_log_path = os.path.join(self.log_dir, "rewards.csv")
        self.transitions_log_path = os.path.join(self.log_dir, "transitions.csv")
        self.evaluation_log_path = os.path.join(self.log_dir, "evaluation_rewards.csv")
        self.policy_model_path = os.path.join(self.log_dir, "policy_model.keras")
        self.value_model_path = os.path.join(self.log_dir, "value_model.keras")

        # Initialize the CSV log files
        with open(self.rewards_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward sum", "last reward", "steps"])

        with open(self.transitions_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "state", "action", "next-state", "reward", "done", "truncated"])

        with open(self.evaluation_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward_sum", "last_reward", "steps"])

    def log_training_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])
            
    def log_eval_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])

    def log_transition(self, episode, state, action, next_state, reward, done, truncated):
        with open(self.transitions_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, state.tolist(), action, next_state.tolist(), reward, done, truncated])

    def save_policy_model(self, model):
        model.save(self.policy_model_path)
        
    def save_value_model(self, model):
        model.save(self.value_model_path)


class RewardNormalizer:
    def __init__(self):
        self.mean = 0
        self.var = 0
        self.count = 0

    def normalize(self, reward):
        self.count += 1
        old_mean = self.mean
        self.mean += (reward - self.mean) / self.count
        self.var += (reward - old_mean) * (reward - self.mean)
        std = (self.var / self.count) ** 0.5
        return (reward - self.mean) / (std + 1e-8)


class ActorCritic:
    def __init__(self, env, policy_network, value_network, logger, gamma=0.99):
        self.env = env
        self.policy_network = policy_network
        self.value_network = value_network
        self.gamma = gamma
        self.learning_rate = 0.001
        self.policy_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.value_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.training_rewards_per_episode_sum = []
        self.training_rewards_per_episode_last_one = []
        self.eval_rewards_per_episode_sum = []
        self.eval_rewards_per_episode_last_one = []
        self.logger = logger
        self.reward_normalizer = RewardNormalizer()


    def take_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        action_probs[(state[:27]==0)] = -np.inf
        action = np.argmax(action_probs)
        return action
    
    
    
    def sample_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        valid_actions = np.where(state[:27] != 0)[0]
        invalid_actions = np.where(state[:27] == 0)[0]
        action_probs[invalid_actions] = 0.0
        total_prob = np.sum(action_probs)
        if total_prob == 0.0:
            print("No valid actions")
            return np.random.choice(valid_actions)

        # Create normalized probabilities only for valid actions
        normalized_probs = np.zeros_like(action_probs)
        normalized_probs[valid_actions] = action_probs[valid_actions] / total_prob

        # Sample an action using normalized probabilities
        action = np.random.choice(range(len(normalized_probs)), p=normalized_probs)
        return action

    
    def train_step(self, state, action, reward, next_state, done):
        # Compute target Q-value
        with tf.GradientTape() as value_tape:
            q_value = tf.squeeze(self.value_network(tf.expand_dims(state, axis=0)), axis=-1)
            target_q_value = reward + self.gamma * tf.squeeze(self.value_network(tf.expand_dims(next_state, axis=0)), axis=-1) * (1 - done)
            value_loss = tf.keras.losses.Huber()(target_q_value, q_value)
    
        # Update value network
        value_grads = value_tape.gradient(value_loss, self.value_network.trainable_variables)
        self.value_optimizer.apply_gradients(zip(value_grads, self.value_network.trainable_variables))
    
        # Compute policy loss using TD error
        td_error = target_q_value - q_value
        with tf.GradientTape() as policy_tape:
            action_probs = self.policy_network(tf.expand_dims(state, axis=0))
            mask = tf.constant(state[:27] != 0, dtype=tf.float32)
            masked_action_probs = action_probs * mask
            masked_action_probs /= (tf.reduce_sum(masked_action_probs) + 1e-8)
            selected_action_prob = tf.gather_nd(masked_action_probs, [[0, action]])
            selected_action_prob = tf.maximum(selected_action_prob, 1e-8)
            policy_loss = -tf.reduce_mean(tf.math.log(selected_action_prob) * tf.stop_gradient(td_error))
    
        # Update policy network
        policy_grads = policy_tape.gradient(policy_loss, self.policy_network.trainable_variables)
        self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_network.trainable_variables))


    def process_state(self, state):
        normalized_hand = state['hand'] / 4.0
        normalized_visible_cards = state['visible cards'] / 4.0
        kangs_one_hot = tf.one_hot(state['kangs'], depth=4).numpy()
        kangs_one_hot_flat = kangs_one_hot.reshape(-1)
        final_array = np.concatenate((
            normalized_hand,
            state['pongs'],
            kangs_one_hot_flat,
            normalized_visible_cards
        ))
        return final_array
    
    
    def run_episode(self):
        state, _ = self.env.reset()
        state = self.process_state(state)
        episode_reward = 0
        done = False
        steps = 0
        last_reward = 0
        while not done:
            action = self.sample_action(state)
            next_state, reward, done, truncated, _ = self.env.step(action)
            next_state = self.process_state(next_state)
            done = done or truncated
            normalized_reward = self.reward_normalizer.normalize(reward)
            self.train_step(state, action, normalized_reward, next_state, done)
            steps += 1
            episode_reward += reward
            if done:
                last_reward = reward
            state = next_state

        return episode_reward, last_reward, steps
    
    def evaluate(self, episodes):
        for episode in range(episodes):
            state, _ = self.env.reset()
            state = self.process_state(state)
            episode_reward = 0
            done = False
            steps = 0
            last_reward = 0
            while not done:
                action = self.take_action(state)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_state = self.process_state(next_state)
                done = done or truncated
                steps += 1
                episode_reward += reward
                if done:
                    last_reward = reward
                state = next_state
            self.eval_rewards_per_episode_sum.append(episode_reward)
            self.eval_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_eval_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")


    def train(self, episodes=1, save_freq=20):
        for episode in range(episodes):
            episode_reward, last_reward, steps = self.run_episode()
            self.training_rewards_per_episode_sum.append(episode_reward)
            self.training_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_training_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")
            if (episode + 1) % save_freq == 0 and self.logger:
                self.logger.save_policy_model(self.policy_network)
                self.logger.save_value_model(self.value_network)


class PolicyNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(PolicyNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.dense3 = tf.keras.layers.Dense(64, activation='relu')
        self.dense4 = tf.keras.layers.Dense(num_actions, activation='softmax')

    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


class ValueNetwork(tf.keras.Model):
    def __init__(self):
        super(ValueNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.dense3 = tf.keras.layers.Dense(1)

    def call(self, state):
        x = self.dense1(state)
        return self.dense3(self.dense2(x))


def plot_rewards(root_folder, rewards, title, save_fig=False):
    plt.figure(figsize=(12, 8))
    plt.plot(rewards, label='Total Reward per Episode')
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.title(title)
    plt.grid(True)
    if save_fig:
        plt.savefig(root_folder + "/" + title + '_' + strftime("%Y_%m_%d_%H_%M_%S") +'_' + '.png')
    plt.legend()
    plt.show()

# %%
# Environment setup
env = gym.make("Mahjong-v2")
policy = PolicyNetwork(num_actions=27)
value_network = ValueNetwork()
logger = Logger()
agent = ActorCritic(env, policy, value_network, logger)
agent.train(10000)
# Out:
# 2024-12-10 18:05:55.309940: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Episode 1: Reward sum = -24.22, Last reward = -25.0, Steps = 15
# Episode 2: Reward sum = -4.32, Last reward = -5.0, Steps = 8
# Episode 3: Reward sum = -18.95, Last reward = -20.0, Steps = 13
# Episode 4: Reward sum = -22.95, Last reward = -25.0, Steps = 16
# Episode 5: Reward sum = -1.79, Last reward = -5.0, Steps = 17
# Episode 6: Reward sum = -3.21, Last reward = -5.0, Steps = 15
# Episode 7: Reward sum = -3.04, Last reward = -5.0, Steps = 13
# Episode 8: Reward sum = -17.81, Last reward = -20.0, Steps = 16
# Episode 9: Reward sum = -60.40, Last reward = -63.0, Steps = 15
# Episode 10: Reward sum = -78.73, Last reward = -80.0, Steps = 15
# Episode 11: Reward sum = -3.17, Last reward = -5.0, Steps = 16
# Episode 12: Reward sum = -28.69, Last reward = -30.0, Steps = 11
# Episode 13: Reward sum = -6.72, Last reward = -8.0, Steps = 7
# Episode 14: Reward sum = -28.72, Last reward = -30.0, Steps = 17
# Episode 15: Reward sum = -37.98, Last reward = -40.0, Steps = 16
# Episode 16: Reward sum = -4.28, Last reward = -5.0, Steps = 5
# Episode 17: Reward sum = -3.63, Last reward = -5.0, Steps = 8
# Episode 18: Reward sum = -4.74, Last reward = -5.0, Steps = 3
# Episode 19: Reward sum = 1.41, Last reward = 0.0, Steps = 17
# Episode 20: Reward sum = -28.21, Last reward = -30.0, Steps = 18
# Episode 21: Reward sum = -3.74, Last reward = -5.0, Steps = 16
# Episode 22: Reward sum = -3.51, Last reward = -5.0, Steps = 10
# Episode 23: Reward sum = -27.39, Last reward = -30.0, Steps = 16
# Episode 24: Reward sum = -3.32, Last reward = -5.0, Steps = 17
# Episode 25: Reward sum = -3.87, Last reward = -5.0, Steps = 7
# Episode 26: Reward sum = -38.66, Last reward = -40.0, Steps = 16
# Episode 27: Reward sum = -28.18, Last reward = -30.0, Steps = 16
# Episode 28: Reward sum = -8.08, Last reward = -10.0, Steps = 16
# Episode 29: Reward sum = -3.92, Last reward = -5.0, Steps = 15
# Episode 30: Reward sum = -3.29, Last reward = -5.0, Steps = 13
# Episode 31: Reward sum = 7.21, Last reward = 5.0, Steps = 16
# Episode 32: Reward sum = -7.93, Last reward = -10.0, Steps = 16
# Episode 33: Reward sum = -3.76, Last reward = -5.0, Steps = 14
# Episode 34: Reward sum = 1.19, Last reward = 0.0, Steps = 18
# Episode 35: Reward sum = -18.87, Last reward = -20.0, Steps = 18
# Episode 36: Reward sum = -79.02, Last reward = -80.0, Steps = 19
# Episode 37: Reward sum = -8.54, Last reward = -10.0, Steps = 15
# Episode 38: Reward sum = -39.10, Last reward = -40.0, Steps = 17
# Episode 39: Reward sum = -13.44, Last reward = -15.0, Steps = 17
# Episode 40: Reward sum = -66.20, Last reward = -68.0, Steps = 16
# Episode 41: Reward sum = -3.19, Last reward = -5.0, Steps = 15
# Episode 42: Reward sum = -53.61, Last reward = -55.0, Steps = 16
# Episode 43: Reward sum = -4.08, Last reward = -5.0, Steps = 12
# Episode 44: Reward sum = -6.73, Last reward = -8.0, Steps = 10
# Episode 45: Reward sum = -13.71, Last reward = -15.0, Steps = 17
# Episode 46: Reward sum = -11.57, Last reward = -13.0, Steps = 15
# Episode 47: Reward sum = -6.95, Last reward = -8.0, Steps = 9
# Episode 48: Reward sum = -6.10, Last reward = -8.0, Steps = 11
# Episode 49: Reward sum = -4.26, Last reward = -5.0, Steps = 14
# Episode 50: Reward sum = -8.20, Last reward = -10.0, Steps = 17
# Episode 51: Reward sum = -8.32, Last reward = -10.0, Steps = 17
# Episode 52: Reward sum = -28.10, Last reward = -30.0, Steps = 12
# Episode 53: Reward sum = -31.56, Last reward = -33.0, Steps = 17
# Episode 54: Reward sum = -12.89, Last reward = -15.0, Steps = 15
# Episode 55: Reward sum = -4.32, Last reward = -5.0, Steps = 12
# Episode 56: Reward sum = -18.07, Last reward = -20.0, Steps = 15
# Episode 57: Reward sum = -1.87, Last reward = -3.0, Steps = 13
# Episode 58: Reward sum = -63.57, Last reward = -65.0, Steps = 17
# Episode 59: Reward sum = -19.06, Last reward = -20.0, Steps = 9
# Episode 60: Reward sum = -9.04, Last reward = -10.0, Steps = 17
# Episode 61: Reward sum = -3.77, Last reward = -5.0, Steps = 14
# Episode 62: Reward sum = -28.45, Last reward = -30.0, Steps = 16
# Episode 63: Reward sum = -9.13, Last reward = -10.0, Steps = 16
# Episode 64: Reward sum = -3.84, Last reward = -5.0, Steps = 8
# Episode 65: Reward sum = -2.17, Last reward = -5.0, Steps = 12
# Episode 66: Reward sum = -7.67, Last reward = -10.0, Steps = 15
# Episode 67: Reward sum = -4.45, Last reward = -5.0, Steps = 9
# Episode 68: Reward sum = -4.52, Last reward = -5.0, Steps = 12
# Episode 69: Reward sum = -4.36, Last reward = -5.0, Steps = 5
# Episode 70: Reward sum = -6.97, Last reward = -8.0, Steps = 7
# Episode 71: Reward sum = -2.59, Last reward = -5.0, Steps = 16
# Episode 72: Reward sum = -34.37, Last reward = -35.0, Steps = 16
# Episode 73: Reward sum = -2.90, Last reward = -5.0, Steps = 12
# Episode 74: Reward sum = -6.76, Last reward = -8.0, Steps = 10
# Episode 75: Reward sum = -8.15, Last reward = -10.0, Steps = 16
# Episode 76: Reward sum = -3.72, Last reward = -5.0, Steps = 7
# Episode 77: Reward sum = -23.07, Last reward = -25.0, Steps = 17
# Episode 78: Reward sum = -4.00, Last reward = -5.0, Steps = 8
# Episode 79: Reward sum = -56.16, Last reward = -58.0, Steps = 17
# Episode 80: Reward sum = -18.21, Last reward = -20.0, Steps = 16
# Episode 81: Reward sum = -25.49, Last reward = -28.0, Steps = 16
# Episode 82: Reward sum = -63.50, Last reward = -65.0, Steps = 17
# Episode 83: Reward sum = -3.90, Last reward = -5.0, Steps = 9
# Episode 84: Reward sum = -81.79, Last reward = -83.0, Steps = 16
# Episode 85: Reward sum = -3.87, Last reward = -5.0, Steps = 12
# Episode 86: Reward sum = -2.95, Last reward = -5.0, Steps = 12
# Episode 87: Reward sum = -3.41, Last reward = -5.0, Steps = 10
# Episode 88: Reward sum = -18.52, Last reward = -20.0, Steps = 10
# Episode 89: Reward sum = -3.45, Last reward = -5.0, Steps = 12
# Episode 90: Reward sum = -5.82, Last reward = -8.0, Steps = 17
# Episode 91: Reward sum = -16.68, Last reward = -18.0, Steps = 15
# Episode 92: Reward sum = 1.48, Last reward = -2.0, Steps = 15
# Episode 93: Reward sum = -6.41, Last reward = -10.0, Steps = 16
# Episode 94: Reward sum = 0.78, Last reward = 0.0, Steps = 9
# Episode 95: Reward sum = -19.17, Last reward = -20.0, Steps = 9
# Episode 96: Reward sum = -18.04, Last reward = -20.0, Steps = 16
# Episode 97: Reward sum = -58.10, Last reward = -60.0, Steps = 17
# Episode 98: Reward sum = -13.54, Last reward = -15.0, Steps = 18
# Episode 99: Reward sum = -6.37, Last reward = -8.0, Steps = 12
# Episode 100: Reward sum = 2.71, Last reward = 0.0, Steps = 16
# Episode 101: Reward sum = 0.65, Last reward = 0.0, Steps = 17
# Episode 102: Reward sum = -21.30, Last reward = -23.0, Steps = 17
# Episode 103: Reward sum = -15.08, Last reward = -25.0, Steps = 17
# Episode 104: Reward sum = -18.74, Last reward = -20.0, Steps = 16
# Episode 105: Reward sum = -3.64, Last reward = -5.0, Steps = 8
# Episode 106: Reward sum = -4.03, Last reward = -5.0, Steps = 11
# Episode 107: Reward sum = -3.80, Last reward = -5.0, Steps = 15
# Episode 108: Reward sum = 2.43, Last reward = 0.0, Steps = 15
# Episode 109: Reward sum = -64.33, Last reward = -65.0, Steps = 16
# Episode 110: Reward sum = -31.69, Last reward = -33.0, Steps = 13
# Episode 111: Reward sum = -3.23, Last reward = -5.0, Steps = 13
# Episode 112: Reward sum = -43.16, Last reward = -45.0, Steps = 17
# Episode 113: Reward sum = -19.08, Last reward = -20.0, Steps = 11
# Episode 114: Reward sum = -18.04, Last reward = -20.0, Steps = 15
# Episode 115: Reward sum = -4.55, Last reward = -5.0, Steps = 8
# Episode 116: Reward sum = 30.82, Last reward = 30.0, Steps = 17
# Episode 117: Reward sum = -28.10, Last reward = -30.0, Steps = 15
# Episode 118: Reward sum = 34.61, Last reward = 33.0, Steps = 17
# Episode 119: Reward sum = -45.17, Last reward = -46.0, Steps = 17
# Episode 120: Reward sum = -6.28, Last reward = -8.0, Steps = 14
# Episode 121: Reward sum = -4.15, Last reward = -5.0, Steps = 17
# Episode 122: Reward sum = -58.77, Last reward = -61.0, Steps = 16
# Episode 123: Reward sum = -18.62, Last reward = -20.0, Steps = 15
# Episode 124: Reward sum = -18.50, Last reward = -20.0, Steps = 15
# Episode 125: Reward sum = 62.16, Last reward = 60.0, Steps = 15
# Episode 126: Reward sum = -2.59, Last reward = -5.0, Steps = 13
# Episode 127: Reward sum = -18.45, Last reward = -20.0, Steps = 18
# Episode 128: Reward sum = -6.89, Last reward = -8.0, Steps = 15
# Episode 129: Reward sum = -38.29, Last reward = -40.0, Steps = 14
# Episode 130: Reward sum = -3.39, Last reward = -5.0, Steps = 14
# Episode 131: Reward sum = -8.23, Last reward = -10.0, Steps = 16
# Episode 132: Reward sum = -2.86, Last reward = -5.0, Steps = 12
# Episode 133: Reward sum = -2.44, Last reward = -5.0, Steps = 13
# Episode 134: Reward sum = -33.57, Last reward = -35.0, Steps = 16
# Episode 135: Reward sum = -6.32, Last reward = -8.0, Steps = 11
# Episode 136: Reward sum = -3.31, Last reward = -5.0, Steps = 9
# Episode 137: Reward sum = -3.01, Last reward = -5.0, Steps = 17
# Episode 138: Reward sum = -3.19, Last reward = -5.0, Steps = 12
# Episode 139: Reward sum = -22.33, Last reward = -25.0, Steps = 15
# Episode 140: Reward sum = -28.12, Last reward = -30.0, Steps = 13
# Episode 141: Reward sum = -40.92, Last reward = -43.0, Steps = 15
# Episode 142: Reward sum = 16.16, Last reward = 15.0, Steps = 6
# Episode 143: Reward sum = -4.20, Last reward = -5.0, Steps = 16
# Episode 144: Reward sum = -8.55, Last reward = -10.0, Steps = 17
# Episode 145: Reward sum = -27.50, Last reward = -30.0, Steps = 17
# Episode 146: Reward sum = -23.75, Last reward = -25.0, Steps = 18
# Episode 147: Reward sum = -32.06, Last reward = -33.0, Steps = 16
# Episode 148: Reward sum = 4.20, Last reward = 2.0, Steps = 18
# Episode 149: Reward sum = -6.61, Last reward = -8.0, Steps = 10
# Episode 150: Reward sum = -38.05, Last reward = -40.0, Steps = 15
# Episode 151: Reward sum = -20.94, Last reward = -23.0, Steps = 14
# Episode 152: Reward sum = -55.50, Last reward = -58.0, Steps = 16
# Episode 153: Reward sum = 2.01, Last reward = 0.0, Steps = 18
# Episode 154: Reward sum = -3.70, Last reward = -5.0, Steps = 7
# Episode 155: Reward sum = -33.58, Last reward = -35.0, Steps = 16
# Episode 156: Reward sum = -3.10, Last reward = -5.0, Steps = 12
# Episode 157: Reward sum = -11.74, Last reward = -13.0, Steps = 17
# Episode 158: Reward sum = 18.82, Last reward = 17.0, Steps = 19
# Episode 159: Reward sum = -3.40, Last reward = -5.0, Steps = 13
# Episode 160: Reward sum = -4.57, Last reward = -5.0, Steps = 7
# Episode 161: Reward sum = -30.40, Last reward = -33.0, Steps = 16
# Episode 162: Reward sum = -27.48, Last reward = -30.0, Steps = 15
# Episode 163: Reward sum = -72.96, Last reward = -74.0, Steps = 16
# Episode 164: Reward sum = -3.95, Last reward = -5.0, Steps = 11
# Episode 165: Reward sum = -26.29, Last reward = -28.0, Steps = 17
# Episode 166: Reward sum = -3.84, Last reward = -5.0, Steps = 9
# Episode 167: Reward sum = -16.94, Last reward = -18.0, Steps = 18
# Episode 168: Reward sum = -4.47, Last reward = -5.0, Steps = 12
# Episode 169: Reward sum = 7.21, Last reward = 5.0, Steps = 16
# Episode 170: Reward sum = -6.26, Last reward = -8.0, Steps = 12
# Episode 171: Reward sum = -37.95, Last reward = -40.0, Steps = 16
# Episode 172: Reward sum = -53.73, Last reward = -55.0, Steps = 15
# Episode 173: Reward sum = -18.41, Last reward = -20.0, Steps = 14
# Episode 174: Reward sum = -63.03, Last reward = -65.0, Steps = 16
# Episode 175: Reward sum = -4.60, Last reward = -5.0, Steps = 7
# Episode 176: Reward sum = -4.25, Last reward = -5.0, Steps = 6
# Episode 177: Reward sum = -8.57, Last reward = -10.0, Steps = 16
# Episode 178: Reward sum = -3.78, Last reward = -5.0, Steps = 10
# Episode 179: Reward sum = -3.73, Last reward = -5.0, Steps = 10
# Episode 180: Reward sum = -3.85, Last reward = -5.0, Steps = 15
# Episode 181: Reward sum = -29.29, Last reward = -30.0, Steps = 16
# Episode 182: Reward sum = 2.88, Last reward = 0.0, Steps = 15
# Episode 183: Reward sum = -26.21, Last reward = -28.0, Steps = 17
# Episode 184: Reward sum = -21.37, Last reward = -23.0, Steps = 12
# No valid actions
# Episode 185: Reward sum = -36.10, Last reward = -38.0, Steps = 15
# Episode 186: Reward sum = -57.31, Last reward = -58.0, Steps = 15
# No valid actions
# Episode 187: Reward sum = -32.44, Last reward = -35.0, Steps = 17
# Episode 188: Reward sum = -41.28, Last reward = -43.0, Steps = 15
# Episode 189: Reward sum = -3.58, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# Episode 190: Reward sum = -36.96, Last reward = -40.0, Steps = 18
# Episode 191: Reward sum = -3.81, Last reward = -5.0, Steps = 9
# Episode 192: Reward sum = -18.95, Last reward = -20.0, Steps = 11
# Episode 193: Reward sum = -7.07, Last reward = -10.0, Steps = 17
# Episode 194: Reward sum = -28.67, Last reward = -30.0, Steps = 15
# Episode 195: Reward sum = -52.55, Last reward = -55.0, Steps = 16
# Episode 196: Reward sum = -25.10, Last reward = -28.0, Steps = 16
# Episode 197: Reward sum = -56.93, Last reward = -60.0, Steps = 17
# Episode 198: Reward sum = -3.28, Last reward = -5.0, Steps = 12
# Episode 199: Reward sum = -26.73, Last reward = -28.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 200: Reward sum = -3.91, Last reward = -5.0, Steps = 16
# Episode 201: Reward sum = -24.05, Last reward = -25.0, Steps = 16
# Episode 202: Reward sum = -3.22, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# Episode 203: Reward sum = 33.76, Last reward = 33.0, Steps = 17
# Episode 204: Reward sum = -2.60, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# Episode 205: Reward sum = 30.83, Last reward = 30.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 206: Reward sum = 61.13, Last reward = 60.0, Steps = 18
# Episode 207: Reward sum = -2.09, Last reward = -5.0, Steps = 16
# Episode 208: Reward sum = -65.60, Last reward = -68.0, Steps = 18
# Episode 209: Reward sum = -2.39, Last reward = -5.0, Steps = 16
# Episode 210: Reward sum = -33.15, Last reward = -35.0, Steps = 14
# Episode 211: Reward sum = -4.46, Last reward = -5.0, Steps = 4
# Episode 212: Reward sum = -32.86, Last reward = -35.0, Steps = 18
# Episode 213: Reward sum = -3.60, Last reward = -5.0, Steps = 8
# Episode 214: Reward sum = 10.45, Last reward = 9.0, Steps = 12
# Episode 215: Reward sum = 38.07, Last reward = 36.0, Steps = 16
# Episode 216: Reward sum = -3.90, Last reward = -5.0, Steps = 10
# Episode 217: Reward sum = -63.85, Last reward = -65.0, Steps = 17
# Episode 218: Reward sum = 19.16, Last reward = 18.0, Steps = 7
# Episode 219: Reward sum = -59.01, Last reward = -60.0, Steps = 17
# Episode 220: Reward sum = -62.22, Last reward = -63.0, Steps = 16
# Episode 221: Reward sum = -3.32, Last reward = -5.0, Steps = 14
# Episode 222: Reward sum = -81.85, Last reward = -83.0, Steps = 17
# Episode 223: Reward sum = -3.53, Last reward = -5.0, Steps = 9
# Episode 224: Reward sum = -32.31, Last reward = -33.0, Steps = 15
# Episode 225: Reward sum = -2.24, Last reward = -5.0, Steps = 14
# Episode 226: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 227: Reward sum = -3.75, Last reward = -5.0, Steps = 7
# Episode 228: Reward sum = -23.06, Last reward = -25.0, Steps = 17
# Episode 229: Reward sum = -35.47, Last reward = -38.0, Steps = 18
# Episode 230: Reward sum = -13.72, Last reward = -15.0, Steps = 16
# Episode 231: Reward sum = -18.57, Last reward = -20.0, Steps = 15
# Episode 232: Reward sum = -81.47, Last reward = -83.0, Steps = 15
# No valid actions
# Episode 233: Reward sum = -19.13, Last reward = -20.0, Steps = 17
# Episode 234: Reward sum = -108.18, Last reward = -110.0, Steps = 15
# Episode 235: Reward sum = -28.21, Last reward = -30.0, Steps = 14
# Episode 236: Reward sum = -3.04, Last reward = -5.0, Steps = 15
# Episode 237: Reward sum = -35.62, Last reward = -38.0, Steps = 16
# Episode 238: Reward sum = -3.24, Last reward = -5.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# Episode 239: Reward sum = -2.58, Last reward = -5.0, Steps = 17
# Episode 240: Reward sum = -4.25, Last reward = -5.0, Steps = 6
# Episode 241: Reward sum = -17.71, Last reward = -20.0, Steps = 14
# Episode 242: Reward sum = -4.05, Last reward = -5.0, Steps = 10
# Episode 243: Reward sum = -36.07, Last reward = -38.0, Steps = 15
# Episode 244: Reward sum = -77.74, Last reward = -80.0, Steps = 14
# Episode 245: Reward sum = -8.28, Last reward = -10.0, Steps = 19
# Episode 246: Reward sum = -7.48, Last reward = -10.0, Steps = 14
# Episode 247: Reward sum = 1.78, Last reward = 0.0, Steps = 17
# Episode 248: Reward sum = -18.24, Last reward = -20.0, Steps = 13
# Episode 249: Reward sum = -6.35, Last reward = -8.0, Steps = 17
# Episode 250: Reward sum = -32.89, Last reward = -35.0, Steps = 18
# Episode 251: Reward sum = -7.50, Last reward = -10.0, Steps = 15
# Episode 252: Reward sum = 1.84, Last reward = 0.0, Steps = 17
# Episode 253: Reward sum = -19.09, Last reward = -20.0, Steps = 12
# Episode 254: Reward sum = -32.10, Last reward = -35.0, Steps = 17
# Episode 255: Reward sum = -4.12, Last reward = -5.0, Steps = 6
# Episode 256: Reward sum = -3.85, Last reward = -5.0, Steps = 13
# Episode 257: Reward sum = -2.86, Last reward = -5.0, Steps = 16
# Episode 258: Reward sum = -8.35, Last reward = -10.0, Steps = 17
# Episode 259: Reward sum = -61.97, Last reward = -65.0, Steps = 17
# Episode 260: Reward sum = -6.19, Last reward = -8.0, Steps = 17
# Episode 261: Reward sum = -3.85, Last reward = -5.0, Steps = 11
# Episode 262: Reward sum = -7.76, Last reward = -10.0, Steps = 16
# Episode 263: Reward sum = -3.65, Last reward = -5.0, Steps = 11
# Episode 264: Reward sum = -4.28, Last reward = -5.0, Steps = 6
# Episode 265: Reward sum = -20.85, Last reward = -23.0, Steps = 12
# Episode 266: Reward sum = -3.52, Last reward = -5.0, Steps = 12
# Episode 267: Reward sum = -28.70, Last reward = -30.0, Steps = 16
# Episode 268: Reward sum = -11.30, Last reward = -13.0, Steps = 18
# Episode 269: Reward sum = -4.12, Last reward = -5.0, Steps = 7
# Episode 270: Reward sum = -23.55, Last reward = -25.0, Steps = 16
# Episode 271: Reward sum = -2.09, Last reward = -5.0, Steps = 17
# Episode 272: Reward sum = -3.80, Last reward = -5.0, Steps = 15
# Episode 273: Reward sum = -4.01, Last reward = -5.0, Steps = 13
# Episode 274: Reward sum = -3.69, Last reward = -5.0, Steps = 8
# Episode 275: Reward sum = -8.48, Last reward = -10.0, Steps = 16
# Episode 276: Reward sum = -3.55, Last reward = -5.0, Steps = 11
# Episode 277: Reward sum = -2.94, Last reward = -5.0, Steps = 14
# Episode 278: Reward sum = -12.63, Last reward = -15.0, Steps = 16
# Episode 279: Reward sum = -28.68, Last reward = -30.0, Steps = 14
# Episode 280: Reward sum = -27.64, Last reward = -30.0, Steps = 18
# Episode 281: Reward sum = -3.08, Last reward = -5.0, Steps = 15
# Episode 282: Reward sum = -3.58, Last reward = -5.0, Steps = 10
# Episode 283: Reward sum = -40.87, Last reward = -43.0, Steps = 16
# Episode 284: Reward sum = -15.99, Last reward = -18.0, Steps = 18
# Episode 285: Reward sum = -3.94, Last reward = -5.0, Steps = 14
# Episode 286: Reward sum = -2.91, Last reward = -5.0, Steps = 14
# Episode 287: Reward sum = 16.19, Last reward = 15.0, Steps = 16
# Episode 288: Reward sum = -7.53, Last reward = -10.0, Steps = 16
# Episode 289: Reward sum = -20.71, Last reward = -23.0, Steps = 11
# Episode 290: Reward sum = -17.73, Last reward = -20.0, Steps = 15
# Episode 291: Reward sum = -8.79, Last reward = -10.0, Steps = 17
# Episode 292: Reward sum = -32.17, Last reward = -33.0, Steps = 14
# Episode 293: Reward sum = -10.31, Last reward = -13.0, Steps = 18
# Episode 294: Reward sum = -53.91, Last reward = -55.0, Steps = 17
# No valid actions
# No valid actions
# Episode 295: Reward sum = 31.16, Last reward = 30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 296: Reward sum = -12.78, Last reward = -15.0, Steps = 18
# No valid actions
# Episode 297: Reward sum = -3.35, Last reward = -5.0, Steps = 14
# Episode 298: Reward sum = -65.46, Last reward = -68.0, Steps = 17
# No valid actions
# Episode 299: Reward sum = -62.30, Last reward = -65.0, Steps = 17
# Episode 300: Reward sum = -17.92, Last reward = -20.0, Steps = 18
# Episode 301: Reward sum = -30.07, Last reward = -33.0, Steps = 16
# No valid actions
# Episode 302: Reward sum = -4.23, Last reward = -5.0, Steps = 15
# Episode 303: Reward sum = -6.72, Last reward = -8.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 304: Reward sum = -31.44, Last reward = -33.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 305: Reward sum = -77.92, Last reward = -80.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 306: Reward sum = -28.58, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 307: Reward sum = -4.40, Last reward = -5.0, Steps = 18
# Episode 308: Reward sum = -4.87, Last reward = -5.0, Steps = 2
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 309: Reward sum = -1.30, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 310: Reward sum = -92.12, Last reward = -95.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 311: Reward sum = -80.92, Last reward = -83.0, Steps = 18
# Episode 312: Reward sum = -4.80, Last reward = -5.0, Steps = 2
# Episode 313: Reward sum = -4.52, Last reward = -5.0, Steps = 4
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 314: Reward sum = -72.27, Last reward = -73.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 315: Reward sum = -16.47, Last reward = -18.0, Steps = 15
# No valid actions
# Episode 316: Reward sum = -3.05, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# Episode 317: Reward sum = -4.04, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 318: Reward sum = -53.66, Last reward = -55.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 319: Reward sum = -31.00, Last reward = -33.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 320: Reward sum = -26.09, Last reward = -28.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 321: Reward sum = -28.99, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 322: Reward sum = -77.41, Last reward = -80.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 323: Reward sum = -4.04, Last reward = -5.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 324: Reward sum = -23.53, Last reward = -25.0, Steps = 17
# Episode 325: Reward sum = -3.98, Last reward = -5.0, Steps = 5
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 326: Reward sum = -8.93, Last reward = -11.0, Steps = 17
# No valid actions
# No valid actions
# Episode 327: Reward sum = -2.77, Last reward = -5.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# Episode 328: Reward sum = -8.29, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 329: Reward sum = -27.25, Last reward = -30.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 330: Reward sum = -3.12, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 331: Reward sum = -28.15, Last reward = -30.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 332: Reward sum = -7.95, Last reward = -10.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 333: Reward sum = -13.70, Last reward = -15.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 334: Reward sum = -22.14, Last reward = -23.0, Steps = 9
# No valid actions
# No valid actions
# Episode 335: Reward sum = -4.21, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 336: Reward sum = -40.39, Last reward = -43.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 337: Reward sum = -2.72, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# Episode 338: Reward sum = -28.85, Last reward = -30.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 339: Reward sum = -3.18, Last reward = -5.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 340: Reward sum = -8.61, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 341: Reward sum = -26.34, Last reward = -28.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 342: Reward sum = -18.52, Last reward = -20.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# Episode 343: Reward sum = -38.68, Last reward = -40.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 344: Reward sum = 0.91, Last reward = 0.0, Steps = 15
# No valid actions
# Episode 345: Reward sum = -3.87, Last reward = -5.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 346: Reward sum = -3.05, Last reward = -5.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 347: Reward sum = -33.22, Last reward = -35.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 348: Reward sum = -66.73, Last reward = -68.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 349: Reward sum = -62.76, Last reward = -65.0, Steps = 14
# No valid actions
# Episode 350: Reward sum = -19.85, Last reward = -20.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 351: Reward sum = -29.12, Last reward = -30.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 352: Reward sum = -54.68, Last reward = -58.0, Steps = 16
# Episode 353: Reward sum = -3.88, Last reward = -5.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 354: Reward sum = -33.80, Last reward = -35.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 355: Reward sum = -39.47, Last reward = -43.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 356: Reward sum = -38.70, Last reward = -40.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 357: Reward sum = -19.50, Last reward = -20.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 358: Reward sum = -3.02, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 359: Reward sum = -45.95, Last reward = -48.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 360: Reward sum = -18.19, Last reward = -20.0, Steps = 13
# No valid actions
# No valid actions
# No valid actions
# Episode 361: Reward sum = -18.53, Last reward = -20.0, Steps = 13
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 362: Reward sum = -13.74, Last reward = -16.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 363: Reward sum = 1.76, Last reward = 0.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 364: Reward sum = -3.74, Last reward = -5.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 365: Reward sum = -53.00, Last reward = -55.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 366: Reward sum = -1.62, Last reward = -5.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# Episode 367: Reward sum = -6.99, Last reward = -8.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 368: Reward sum = -66.75, Last reward = -70.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 369: Reward sum = -68.20, Last reward = -70.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 370: Reward sum = -12.92, Last reward = -15.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 371: Reward sum = -3.67, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 372: Reward sum = -63.10, Last reward = -65.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 373: Reward sum = -35.28, Last reward = -38.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 374: Reward sum = -22.00, Last reward = -25.0, Steps = 16
# No valid actions
# No valid actions
# Episode 375: Reward sum = -18.59, Last reward = -20.0, Steps = 9
# No valid actions
# Episode 376: Reward sum = -3.83, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 377: Reward sum = -7.89, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 378: Reward sum = -30.08, Last reward = -33.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 379: Reward sum = 94.28, Last reward = 93.0, Steps = 13
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 380: Reward sum = -78.80, Last reward = -80.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 381: Reward sum = -45.34, Last reward = -48.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 382: Reward sum = -18.51, Last reward = -20.0, Steps = 14
# No valid actions
# Episode 383: Reward sum = -4.50, Last reward = -5.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 384: Reward sum = -17.08, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 385: Reward sum = -73.91, Last reward = -76.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 386: Reward sum = -26.86, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 387: Reward sum = -39.12, Last reward = -40.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 388: Reward sum = -7.86, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# Episode 389: Reward sum = -6.39, Last reward = -8.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 390: Reward sum = -22.37, Last reward = -25.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 391: Reward sum = 2.78, Last reward = 0.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 392: Reward sum = -18.12, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 393: Reward sum = -26.50, Last reward = -28.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 394: Reward sum = -3.95, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 395: Reward sum = -23.31, Last reward = -25.0, Steps = 15
# No valid actions
# Episode 396: Reward sum = -3.87, Last reward = -5.0, Steps = 7
# Episode 397: Reward sum = -4.30, Last reward = -5.0, Steps = 6
# No valid actions
# No valid actions
# Episode 398: Reward sum = -3.24, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 399: Reward sum = -28.93, Last reward = -30.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 400: Reward sum = -31.82, Last reward = -35.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 401: Reward sum = -51.10, Last reward = -53.0, Steps = 17
# No valid actions
# Episode 402: Reward sum = -3.03, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 403: Reward sum = -6.54, Last reward = -8.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 404: Reward sum = 1.29, Last reward = 0.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 405: Reward sum = -3.45, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 406: Reward sum = -18.26, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 407: Reward sum = -29.20, Last reward = -30.0, Steps = 13
# No valid actions
# No valid actions
# Episode 408: Reward sum = -3.22, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# Episode 409: Reward sum = -4.01, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 410: Reward sum = -18.10, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 411: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 412: Reward sum = -28.96, Last reward = -30.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 413: Reward sum = -8.75, Last reward = -10.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 414: Reward sum = -16.14, Last reward = -18.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 415: Reward sum = -32.78, Last reward = -35.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 416: Reward sum = 38.09, Last reward = 36.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 417: Reward sum = -46.94, Last reward = -50.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 418: Reward sum = -58.27, Last reward = -60.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 419: Reward sum = -7.76, Last reward = -10.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 420: Reward sum = -52.46, Last reward = -55.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 421: Reward sum = -63.75, Last reward = -65.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# Episode 422: Reward sum = -19.45, Last reward = -20.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 423: Reward sum = -2.48, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# Episode 424: Reward sum = -3.80, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 425: Reward sum = -19.22, Last reward = -20.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 426: Reward sum = -63.00, Last reward = -65.0, Steps = 19
# No valid actions
# No valid actions
# No valid actions
# Episode 427: Reward sum = -3.45, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# Episode 428: Reward sum = -3.92, Last reward = -5.0, Steps = 13
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 429: Reward sum = 10.60, Last reward = 8.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 430: Reward sum = -21.90, Last reward = -23.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 431: Reward sum = -29.20, Last reward = -30.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 432: Reward sum = -58.95, Last reward = -60.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 433: Reward sum = -3.06, Last reward = -5.0, Steps = 16
# Episode 434: Reward sum = -4.59, Last reward = -5.0, Steps = 3
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 435: Reward sum = -8.73, Last reward = -10.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# Episode 436: Reward sum = -3.98, Last reward = -5.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 437: Reward sum = -8.45, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 438: Reward sum = -10.71, Last reward = -13.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 439: Reward sum = -8.66, Last reward = -10.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 440: Reward sum = -2.93, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 441: Reward sum = -3.92, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 442: Reward sum = -33.42, Last reward = -35.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 443: Reward sum = -20.49, Last reward = -23.0, Steps = 14
# Episode 444: Reward sum = 0.51, Last reward = 0.0, Steps = 5
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 445: Reward sum = -23.46, Last reward = -25.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 446: Reward sum = -4.21, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 447: Reward sum = -18.10, Last reward = -20.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 448: Reward sum = -16.68, Last reward = -20.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 449: Reward sum = -6.38, Last reward = -8.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 450: Reward sum = -17.94, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 451: Reward sum = -29.00, Last reward = -30.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 452: Reward sum = -53.01, Last reward = -55.0, Steps = 19
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 453: Reward sum = -7.10, Last reward = -8.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 454: Reward sum = -10.06, Last reward = -13.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 455: Reward sum = -13.52, Last reward = -15.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 456: Reward sum = -9.98, Last reward = -11.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 457: Reward sum = -21.58, Last reward = -23.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 458: Reward sum = -53.74, Last reward = -55.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 459: Reward sum = -4.17, Last reward = -5.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 460: Reward sum = -55.06, Last reward = -58.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 461: Reward sum = -84.00, Last reward = -86.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 462: Reward sum = -23.38, Last reward = -25.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 463: Reward sum = 5.76, Last reward = 5.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 464: Reward sum = -3.70, Last reward = -5.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 465: Reward sum = -16.92, Last reward = -20.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 466: Reward sum = -36.22, Last reward = -40.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 467: Reward sum = -29.55, Last reward = -30.0, Steps = 18
# No valid actions
# No valid actions
# Episode 468: Reward sum = -3.39, Last reward = -5.0, Steps = 12
# No valid actions
# No valid actions
# Episode 469: Reward sum = -18.92, Last reward = -20.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# Episode 470: Reward sum = -28.43, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 471: Reward sum = 34.99, Last reward = 33.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 472: Reward sum = -37.47, Last reward = -40.0, Steps = 15
# ...
# No valid actions
# No valid actions
# No valid actions
# Episode 9908: Reward sum = -28.37, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9909: Reward sum = -37.46, Last reward = -40.0, Steps = 16
# Episode 9910: Reward sum = -21.74, Last reward = -23.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9911: Reward sum = 6.49, Last reward = 5.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9912: Reward sum = -30.74, Last reward = -33.0, Steps = 17
# Episode 9913: Reward sum = -3.91, Last reward = -5.0, Steps = 9
# Episode 9914: Reward sum = -18.97, Last reward = -20.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9915: Reward sum = -8.40, Last reward = -11.0, Steps = 20
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9916: Reward sum = 1.38, Last reward = 0.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9917: Reward sum = -3.72, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# Episode 9918: Reward sum = 0.93, Last reward = 0.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9919: Reward sum = -17.00, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9920: Reward sum = -4.44, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9921: Reward sum = -80.64, Last reward = -83.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9922: Reward sum = -38.41, Last reward = -40.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9923: Reward sum = -5.96, Last reward = -8.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9924: Reward sum = -2.91, Last reward = -5.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9925: Reward sum = -23.47, Last reward = -25.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9926: Reward sum = -91.51, Last reward = -93.0, Steps = 19
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9927: Reward sum = -3.36, Last reward = -5.0, Steps = 13
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9928: Reward sum = -38.40, Last reward = -40.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9929: Reward sum = -3.18, Last reward = -5.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9930: Reward sum = -19.05, Last reward = -20.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# Episode 9931: Reward sum = -3.60, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9932: Reward sum = -52.82, Last reward = -55.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9933: Reward sum = -5.15, Last reward = -8.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9934: Reward sum = -32.39, Last reward = -35.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9935: Reward sum = -2.97, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9936: Reward sum = 1.89, Last reward = 0.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9937: Reward sum = -79.71, Last reward = -83.0, Steps = 15
# No valid actions
# Episode 9938: Reward sum = -4.55, Last reward = -5.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9939: Reward sum = -71.16, Last reward = -73.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9940: Reward sum = -12.06, Last reward = -13.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9941: Reward sum = -22.64, Last reward = -25.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9942: Reward sum = -54.52, Last reward = -56.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9943: Reward sum = -38.50, Last reward = -40.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# Episode 9944: Reward sum = -18.69, Last reward = -20.0, Steps = 8
# No valid actions
# No valid actions
# No valid actions
# Episode 9945: Reward sum = -4.13, Last reward = -5.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9946: Reward sum = 31.13, Last reward = 30.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9947: Reward sum = -63.37, Last reward = -65.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9948: Reward sum = -46.47, Last reward = -48.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9949: Reward sum = -42.49, Last reward = -43.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9950: Reward sum = -33.20, Last reward = -35.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9951: Reward sum = -17.92, Last reward = -20.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9952: Reward sum = -14.00, Last reward = -15.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9953: Reward sum = -3.79, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9954: Reward sum = -57.94, Last reward = -60.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9955: Reward sum = -2.15, Last reward = -5.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 9956: Reward sum = -3.11, Last reward = -5.0, Steps = 14
# No valid actions
# No valid actions
# Episode 9957: Reward sum = -3.14, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9958: Reward sum = 1.75, Last reward = 0.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9959: Reward sum = -64.07, Last reward = -65.0, Steps = 17
# Episode 9960: Reward sum = -4.38, Last reward = -5.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9961: Reward sum = -38.79, Last reward = -40.0, Steps = 20
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9962: Reward sum = -62.89, Last reward = -65.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# Episode 9963: Reward sum = -30.82, Last reward = -33.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9964: Reward sum = -26.74, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9965: Reward sum = -2.43, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9966: Reward sum = -18.56, Last reward = -20.0, Steps = 11
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9967: Reward sum = -48.01, Last reward = -50.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9968: Reward sum = -27.75, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9969: Reward sum = -28.95, Last reward = -30.0, Steps = 16
# Episode 9970: Reward sum = -4.72, Last reward = -5.0, Steps = 5
# No valid actions
# Episode 9971: Reward sum = -3.68, Last reward = -5.0, Steps = 7
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9972: Reward sum = -33.86, Last reward = -35.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9973: Reward sum = -36.84, Last reward = -40.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9974: Reward sum = -49.25, Last reward = -50.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9975: Reward sum = -27.75, Last reward = -30.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9976: Reward sum = -2.63, Last reward = -5.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9977: Reward sum = -2.10, Last reward = -5.0, Steps = 20
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9978: Reward sum = -2.64, Last reward = -5.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# Episode 9979: Reward sum = -3.58, Last reward = -5.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9980: Reward sum = 35.42, Last reward = 30.0, Steps = 18
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9981: Reward sum = -7.02, Last reward = -8.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9982: Reward sum = -66.56, Last reward = -68.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9983: Reward sum = -13.37, Last reward = -15.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# Episode 9984: Reward sum = -4.75, Last reward = -5.0, Steps = 10
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9985: Reward sum = -63.80, Last reward = -65.0, Steps = 15
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9986: Reward sum = -35.16, Last reward = -38.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9987: Reward sum = -27.57, Last reward = -30.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9988: Reward sum = -38.38, Last reward = -40.0, Steps = 17
# No valid actions
# No valid actions
# Episode 9989: Reward sum = -3.32, Last reward = -5.0, Steps = 9
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9990: Reward sum = -23.80, Last reward = -25.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9991: Reward sum = -38.30, Last reward = -40.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# Episode 9992: Reward sum = -18.18, Last reward = -20.0, Steps = 12
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9993: Reward sum = -87.67, Last reward = -89.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9994: Reward sum = -17.57, Last reward = -20.0, Steps = 14
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9995: Reward sum = -12.66, Last reward = -15.0, Steps = 17
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9996: Reward sum = -21.28, Last reward = -23.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 9997: Reward sum = -23.36, Last reward = -25.0, Steps = 16
# No valid actions
# No valid actions
# No valid actions
# Episode 9998: Reward sum = -4.32, Last reward = -5.0, Steps = 10
# Episode 9999: Reward sum = -4.23, Last reward = -5.0, Steps = 5
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# No valid actions
# Episode 10000: Reward sum = -31.47, Last reward = -33.0, Steps = 14

# %%
plot_rewards(logger.log_dir, agent.training_rewards_per_episode_last_one, title="Training Rewards", save_fig=True)
print("Mean = ", np.mean(agent.training_rewards_per_episode_last_one))
# Out:
# Mean =  -20.7676

# %%
agent_eval = ActorCritic(env, policy, value_network, logger)
agent_eval.evaluate(1000)
# Out:
# Episode 1: Reward sum = -2.72, Last reward = -5.0, Steps = 12
# Episode 2: Reward sum = -22.25, Last reward = -23.0, Steps = 11
# Episode 3: Reward sum = -37.01, Last reward = -38.0, Steps = 15
# Episode 4: Reward sum = -35.87, Last reward = -38.0, Steps = 18
# Episode 5: Reward sum = 22.39, Last reward = 20.0, Steps = 16
# Episode 6: Reward sum = -3.10, Last reward = -5.0, Steps = 13
# Episode 7: Reward sum = -2.07, Last reward = -5.0, Steps = 15
# Episode 8: Reward sum = -11.27, Last reward = -13.0, Steps = 16
# Episode 9: Reward sum = -32.57, Last reward = -35.0, Steps = 17
# Episode 10: Reward sum = -2.57, Last reward = -5.0, Steps = 17
# Episode 11: Reward sum = -7.48, Last reward = -10.0, Steps = 15
# Episode 12: Reward sum = -3.37, Last reward = -5.0, Steps = 11
# Episode 13: Reward sum = -29.34, Last reward = -30.0, Steps = 17
# Episode 14: Reward sum = -29.18, Last reward = -30.0, Steps = 16
# Episode 15: Reward sum = -3.28, Last reward = -5.0, Steps = 10
# Episode 16: Reward sum = -2.90, Last reward = -5.0, Steps = 12
# Episode 17: Reward sum = -12.59, Last reward = -14.0, Steps = 17
# Episode 18: Reward sum = -23.19, Last reward = -25.0, Steps = 18
# Episode 19: Reward sum = -4.37, Last reward = -5.0, Steps = 7
# Episode 20: Reward sum = -3.66, Last reward = -5.0, Steps = 8
# Episode 21: Reward sum = -3.98, Last reward = -5.0, Steps = 16
# Episode 22: Reward sum = 2.26, Last reward = 0.0, Steps = 17
# Episode 23: Reward sum = -3.25, Last reward = -5.0, Steps = 12
# Episode 24: Reward sum = -4.13, Last reward = -5.0, Steps = 12
# Episode 25: Reward sum = -4.53, Last reward = -5.0, Steps = 8
# Episode 26: Reward sum = -19.08, Last reward = -20.0, Steps = 5
# Episode 27: Reward sum = -33.24, Last reward = -35.0, Steps = 14
# Episode 28: Reward sum = -4.27, Last reward = -5.0, Steps = 7
# Episode 29: Reward sum = -3.02, Last reward = -5.0, Steps = 12
# Episode 30: Reward sum = 2.70, Last reward = 0.0, Steps = 18
# Episode 31: Reward sum = -3.64, Last reward = -5.0, Steps = 12
# Episode 32: Reward sum = -6.31, Last reward = -8.0, Steps = 12
# Episode 33: Reward sum = -62.43, Last reward = -65.0, Steps = 15
# Episode 34: Reward sum = -38.57, Last reward = -40.0, Steps = 15
# Episode 35: Reward sum = -38.62, Last reward = -40.0, Steps = 15
# Episode 36: Reward sum = -18.66, Last reward = -20.0, Steps = 11
# Episode 37: Reward sum = -65.74, Last reward = -68.0, Steps = 16
# Episode 38: Reward sum = 19.68, Last reward = 18.0, Steps = 13
# Episode 39: Reward sum = -43.99, Last reward = -45.0, Steps = 19
# Episode 40: Reward sum = -4.05, Last reward = -5.0, Steps = 11
# Episode 41: Reward sum = -3.08, Last reward = -5.0, Steps = 15
# Episode 42: Reward sum = 15.97, Last reward = 15.0, Steps = 10
# Episode 43: Reward sum = -93.56, Last reward = -95.0, Steps = 17
# Episode 44: Reward sum = -4.11, Last reward = -5.0, Steps = 9
# Episode 45: Reward sum = -63.35, Last reward = -65.0, Steps = 17
# Episode 46: Reward sum = -27.99, Last reward = -30.0, Steps = 15
# Episode 47: Reward sum = -18.51, Last reward = -20.0, Steps = 16
# Episode 48: Reward sum = -28.31, Last reward = -30.0, Steps = 16
# Episode 49: Reward sum = -3.46, Last reward = -5.0, Steps = 9
# Episode 50: Reward sum = 2.21, Last reward = 0.0, Steps = 15
# Episode 51: Reward sum = -26.71, Last reward = -28.0, Steps = 16
# Episode 52: Reward sum = -33.19, Last reward = -35.0, Steps = 15
# Episode 53: Reward sum = -18.83, Last reward = -20.0, Steps = 16
# Episode 54: Reward sum = -14.39, Last reward = -15.0, Steps = 16
# Episode 55: Reward sum = -38.87, Last reward = -40.0, Steps = 17
# Episode 56: Reward sum = -3.81, Last reward = -5.0, Steps = 7
# Episode 57: Reward sum = -33.77, Last reward = -35.0, Steps = 16
# Episode 58: Reward sum = -3.55, Last reward = -5.0, Steps = 9
# Episode 59: Reward sum = -6.62, Last reward = -8.0, Steps = 13
# Episode 60: Reward sum = 91.13, Last reward = 90.0, Steps = 12
# Episode 61: Reward sum = -4.34, Last reward = -5.0, Steps = 13
# Episode 62: Reward sum = -5.85, Last reward = -8.0, Steps = 16
# Episode 63: Reward sum = -38.39, Last reward = -40.0, Steps = 16
# Episode 64: Reward sum = -23.82, Last reward = -25.0, Steps = 17
# Episode 65: Reward sum = 64.05, Last reward = 63.0, Steps = 19
# Episode 66: Reward sum = -3.02, Last reward = -5.0, Steps = 15
# Episode 67: Reward sum = -54.33, Last reward = -55.0, Steps = 16
# Episode 68: Reward sum = 16.06, Last reward = 15.0, Steps = 8
# Episode 69: Reward sum = -12.56, Last reward = -15.0, Steps = 16
# Episode 70: Reward sum = -7.52, Last reward = -10.0, Steps = 16
# Episode 71: Reward sum = -3.46, Last reward = -5.0, Steps = 9
# Episode 72: Reward sum = -37.57, Last reward = -40.0, Steps = 17
# Episode 73: Reward sum = -4.24, Last reward = -5.0, Steps = 8
# Episode 74: Reward sum = -73.90, Last reward = -76.0, Steps = 16
# Episode 75: Reward sum = -48.86, Last reward = -50.0, Steps = 16
# Episode 76: Reward sum = -40.14, Last reward = -43.0, Steps = 16
# Episode 77: Reward sum = -0.62, Last reward = -5.0, Steps = 8
# Episode 78: Reward sum = -37.99, Last reward = -40.0, Steps = 17
# Episode 79: Reward sum = 2.08, Last reward = 0.0, Steps = 17
# Episode 80: Reward sum = -7.25, Last reward = -8.0, Steps = 9
# Episode 81: Reward sum = -3.58, Last reward = -5.0, Steps = 15
# Episode 82: Reward sum = 6.31, Last reward = 5.0, Steps = 17
# Episode 83: Reward sum = 2.24, Last reward = 0.0, Steps = 16
# Episode 84: Reward sum = -4.65, Last reward = -5.0, Steps = 7
# Episode 85: Reward sum = -31.34, Last reward = -33.0, Steps = 16
# Episode 86: Reward sum = -23.34, Last reward = -25.0, Steps = 17
# Episode 87: Reward sum = -36.10, Last reward = -38.0, Steps = 17
# Episode 88: Reward sum = -3.14, Last reward = -5.0, Steps = 12
# Episode 89: Reward sum = -2.02, Last reward = -5.0, Steps = 16
# Episode 90: Reward sum = -3.60, Last reward = -5.0, Steps = 8
# Episode 91: Reward sum = 0.61, Last reward = -5.0, Steps = 14
# Episode 92: Reward sum = -4.50, Last reward = -5.0, Steps = 5
# Episode 93: Reward sum = -18.04, Last reward = -20.0, Steps = 16
# Episode 94: Reward sum = -38.98, Last reward = -40.0, Steps = 15
# Episode 95: Reward sum = -24.23, Last reward = -25.0, Steps = 15
# Episode 96: Reward sum = -40.90, Last reward = -43.0, Steps = 16
# Episode 97: Reward sum = -19.60, Last reward = -20.0, Steps = 6
# Episode 98: Reward sum = -19.20, Last reward = -20.0, Steps = 10
# Episode 99: Reward sum = -16.58, Last reward = -20.0, Steps = 17
# Episode 100: Reward sum = -2.13, Last reward = -5.0, Steps = 15
# Episode 101: Reward sum = -32.04, Last reward = -33.0, Steps = 15
# Episode 102: Reward sum = -18.59, Last reward = -20.0, Steps = 10
# Episode 103: Reward sum = -6.79, Last reward = -8.0, Steps = 8
# Episode 104: Reward sum = -4.29, Last reward = -5.0, Steps = 4
# Episode 105: Reward sum = -7.30, Last reward = -10.0, Steps = 16
# Episode 106: Reward sum = -9.35, Last reward = -10.0, Steps = 16
# Episode 107: Reward sum = -84.37, Last reward = -85.0, Steps = 16
# Episode 108: Reward sum = -63.03, Last reward = -65.0, Steps = 16
# Episode 109: Reward sum = -4.23, Last reward = -5.0, Steps = 13
# Episode 110: Reward sum = -20.61, Last reward = -23.0, Steps = 12
# Episode 111: Reward sum = -2.33, Last reward = -5.0, Steps = 14
# Episode 112: Reward sum = -29.50, Last reward = -30.0, Steps = 17
# Episode 113: Reward sum = -26.62, Last reward = -28.0, Steps = 16
# Episode 114: Reward sum = 1.76, Last reward = 0.0, Steps = 17
# Episode 115: Reward sum = -14.93, Last reward = -17.0, Steps = 16
# Episode 116: Reward sum = -32.94, Last reward = -35.0, Steps = 18
# Episode 117: Reward sum = -23.32, Last reward = -25.0, Steps = 15
# Episode 118: Reward sum = -27.84, Last reward = -30.0, Steps = 17
# Episode 119: Reward sum = -17.43, Last reward = -20.0, Steps = 15
# Episode 120: Reward sum = -3.59, Last reward = -5.0, Steps = 13
# Episode 121: Reward sum = -18.17, Last reward = -20.0, Steps = 10
# Episode 122: Reward sum = -21.84, Last reward = -23.0, Steps = 18
# Episode 123: Reward sum = -18.09, Last reward = -20.0, Steps = 17
# Episode 124: Reward sum = -8.38, Last reward = -10.0, Steps = 15
# Episode 125: Reward sum = 8.25, Last reward = 5.0, Steps = 18
# Episode 126: Reward sum = 31.89, Last reward = 30.0, Steps = 19
# Episode 127: Reward sum = -9.34, Last reward = -10.0, Steps = 15
# Episode 128: Reward sum = -87.32, Last reward = -88.0, Steps = 16
# Episode 129: Reward sum = 1.96, Last reward = 0.0, Steps = 16
# Episode 130: Reward sum = 1.15, Last reward = 0.0, Steps = 17
# Episode 131: Reward sum = -2.97, Last reward = -5.0, Steps = 16
# Episode 132: Reward sum = -2.60, Last reward = -5.0, Steps = 11
# Episode 133: Reward sum = -16.16, Last reward = -18.0, Steps = 16
# Episode 134: Reward sum = -3.72, Last reward = -5.0, Steps = 15
# Episode 135: Reward sum = -18.55, Last reward = -20.0, Steps = 12
# Episode 136: Reward sum = -41.08, Last reward = -43.0, Steps = 17
# Episode 137: Reward sum = -37.36, Last reward = -40.0, Steps = 17
# Episode 138: Reward sum = -54.75, Last reward = -55.0, Steps = 17
# Episode 139: Reward sum = -6.97, Last reward = -10.0, Steps = 16
# Episode 140: Reward sum = 16.38, Last reward = 15.0, Steps = 18
# Episode 141: Reward sum = -22.21, Last reward = -25.0, Steps = 15
# Episode 142: Reward sum = -53.01, Last reward = -55.0, Steps = 16
# Episode 143: Reward sum = -3.68, Last reward = -5.0, Steps = 13
# Episode 144: Reward sum = -38.45, Last reward = -40.0, Steps = 17
# Episode 145: Reward sum = 22.29, Last reward = 20.0, Steps = 16
# Episode 146: Reward sum = -3.21, Last reward = -5.0, Steps = 10
# Episode 147: Reward sum = -37.88, Last reward = -40.0, Steps = 16
# Episode 148: Reward sum = -3.71, Last reward = -5.0, Steps = 14
# Episode 149: Reward sum = -52.37, Last reward = -55.0, Steps = 17
# Episode 150: Reward sum = -4.07, Last reward = -5.0, Steps = 13
# Episode 151: Reward sum = -18.92, Last reward = -20.0, Steps = 12
# Episode 152: Reward sum = -4.82, Last reward = -5.0, Steps = 2
# Episode 153: Reward sum = -20.32, Last reward = -23.0, Steps = 17
# Episode 154: Reward sum = -3.69, Last reward = -5.0, Steps = 9
# Episode 155: Reward sum = -6.80, Last reward = -8.0, Steps = 13
# Episode 156: Reward sum = -37.55, Last reward = -40.0, Steps = 16
# Episode 157: Reward sum = -4.07, Last reward = -5.0, Steps = 7
# Episode 158: Reward sum = -23.11, Last reward = -25.0, Steps = 15
# Episode 159: Reward sum = -3.97, Last reward = -5.0, Steps = 16
# Episode 160: Reward sum = -38.40, Last reward = -40.0, Steps = 16
# Episode 161: Reward sum = -3.61, Last reward = -5.0, Steps = 12
# Episode 162: Reward sum = -31.26, Last reward = -33.0, Steps = 13
# Episode 163: Reward sum = -38.84, Last reward = -40.0, Steps = 18
# Episode 164: Reward sum = -81.33, Last reward = -83.0, Steps = 17
# Episode 165: Reward sum = -5.86, Last reward = -8.0, Steps = 13
# Episode 166: Reward sum = -4.20, Last reward = -5.0, Steps = 9
# Episode 167: Reward sum = 10.78, Last reward = 8.0, Steps = 17
# Episode 168: Reward sum = -33.63, Last reward = -36.0, Steps = 17
# Episode 169: Reward sum = -55.35, Last reward = -58.0, Steps = 16
# Episode 170: Reward sum = 91.56, Last reward = 90.0, Steps = 14
# Episode 171: Reward sum = -2.83, Last reward = -5.0, Steps = 15
# Episode 172: Reward sum = 6.90, Last reward = 5.0, Steps = 16
# Episode 173: Reward sum = -32.09, Last reward = -33.0, Steps = 16
# Episode 174: Reward sum = -3.28, Last reward = -5.0, Steps = 16
# Episode 175: Reward sum = -23.59, Last reward = -25.0, Steps = 16
# Episode 176: Reward sum = -26.74, Last reward = -28.0, Steps = 15
# Episode 177: Reward sum = -7.02, Last reward = -8.0, Steps = 11
# Episode 178: Reward sum = 7.85, Last reward = 5.0, Steps = 16
# Episode 179: Reward sum = -3.57, Last reward = -5.0, Steps = 12
# Episode 180: Reward sum = -3.27, Last reward = -5.0, Steps = 15
# Episode 181: Reward sum = -8.16, Last reward = -10.0, Steps = 14
# Episode 182: Reward sum = -28.85, Last reward = -30.0, Steps = 13
# Episode 183: Reward sum = -6.24, Last reward = -8.0, Steps = 15
# Episode 184: Reward sum = -4.27, Last reward = -5.0, Steps = 8
# Episode 185: Reward sum = -19.60, Last reward = -20.0, Steps = 8
# Episode 186: Reward sum = 31.27, Last reward = 30.0, Steps = 17
# Episode 187: Reward sum = -22.91, Last reward = -25.0, Steps = 14
# Episode 188: Reward sum = 16.67, Last reward = 15.0, Steps = 10
# Episode 189: Reward sum = 16.45, Last reward = 15.0, Steps = 8
# Episode 190: Reward sum = 60.71, Last reward = 60.0, Steps = 17
# Episode 191: Reward sum = 7.79, Last reward = 5.0, Steps = 14
# Episode 192: Reward sum = 6.22, Last reward = 5.0, Steps = 16
# Episode 193: Reward sum = -28.33, Last reward = -30.0, Steps = 16
# Episode 194: Reward sum = -6.92, Last reward = -8.0, Steps = 16
# Episode 195: Reward sum = -17.85, Last reward = -20.0, Steps = 15
# Episode 196: Reward sum = -47.88, Last reward = -50.0, Steps = 17
# Episode 197: Reward sum = -8.04, Last reward = -10.0, Steps = 15
# Episode 198: Reward sum = -36.54, Last reward = -38.0, Steps = 15
# Episode 199: Reward sum = -62.03, Last reward = -63.0, Steps = 18
# Episode 200: Reward sum = -53.58, Last reward = -55.0, Steps = 16
# Episode 201: Reward sum = -7.75, Last reward = -10.0, Steps = 17
# Episode 202: Reward sum = -22.94, Last reward = -25.0, Steps = 18
# Episode 203: Reward sum = -27.85, Last reward = -30.0, Steps = 16
# Episode 204: Reward sum = -18.81, Last reward = -20.0, Steps = 12
# Episode 205: Reward sum = -2.34, Last reward = -5.0, Steps = 13
# Episode 206: Reward sum = -2.52, Last reward = -5.0, Steps = 16
# Episode 207: Reward sum = -18.73, Last reward = -20.0, Steps = 11
# Episode 208: Reward sum = 91.93, Last reward = 90.0, Steps = 16
# Episode 209: Reward sum = -32.55, Last reward = -35.0, Steps = 15
# Episode 210: Reward sum = -4.21, Last reward = -5.0, Steps = 10
# Episode 211: Reward sum = -4.40, Last reward = -5.0, Steps = 8
# Episode 212: Reward sum = -33.83, Last reward = -35.0, Steps = 17
# Episode 213: Reward sum = -2.07, Last reward = -5.0, Steps = 13
# Episode 214: Reward sum = -23.38, Last reward = -25.0, Steps = 16
# Episode 215: Reward sum = -32.01, Last reward = -33.0, Steps = 9
# Episode 216: Reward sum = -8.75, Last reward = -10.0, Steps = 17
# Episode 217: Reward sum = -28.73, Last reward = -30.0, Steps = 17
# Episode 218: Reward sum = -24.17, Last reward = -25.0, Steps = 16
# Episode 219: Reward sum = -67.34, Last reward = -70.0, Steps = 17
# Episode 220: Reward sum = -11.46, Last reward = -13.0, Steps = 15
# Episode 221: Reward sum = 13.28, Last reward = 12.0, Steps = 11
# Episode 222: Reward sum = -24.06, Last reward = -25.0, Steps = 16
# Episode 223: Reward sum = -35.52, Last reward = -38.0, Steps = 16
# Episode 224: Reward sum = -2.34, Last reward = -5.0, Steps = 15
# Episode 225: Reward sum = -4.41, Last reward = -5.0, Steps = 9
# Episode 226: Reward sum = -3.14, Last reward = -5.0, Steps = 9
# Episode 227: Reward sum = -25.40, Last reward = -28.0, Steps = 14
# Episode 228: Reward sum = -52.93, Last reward = -55.0, Steps = 15
# Episode 229: Reward sum = -19.29, Last reward = -20.0, Steps = 11
# Episode 230: Reward sum = -9.61, Last reward = -10.0, Steps = 16
# Episode 231: Reward sum = -3.77, Last reward = -5.0, Steps = 12
# Episode 232: Reward sum = 1.38, Last reward = 0.0, Steps = 16
# Episode 233: Reward sum = -7.47, Last reward = -10.0, Steps = 16
# Episode 234: Reward sum = -3.99, Last reward = -5.0, Steps = 8
# Episode 235: Reward sum = -22.19, Last reward = -25.0, Steps = 15
# Episode 236: Reward sum = -6.86, Last reward = -8.0, Steps = 12
# Episode 237: Reward sum = -5.92, Last reward = -8.0, Steps = 17
# Episode 238: Reward sum = 6.68, Last reward = 5.0, Steps = 16
# Episode 239: Reward sum = 15.05, Last reward = 12.0, Steps = 13
# Episode 240: Reward sum = -2.71, Last reward = -5.0, Steps = 14
# Episode 241: Reward sum = -28.67, Last reward = -30.0, Steps = 15
# Episode 242: Reward sum = -28.66, Last reward = -31.0, Steps = 14
# Episode 243: Reward sum = -18.46, Last reward = -20.0, Steps = 16
# Episode 244: Reward sum = 2.24, Last reward = 0.0, Steps = 19
# Episode 245: Reward sum = -4.20, Last reward = -5.0, Steps = 12
# Episode 246: Reward sum = 2.31, Last reward = 0.0, Steps = 12
# Episode 247: Reward sum = -20.33, Last reward = -23.0, Steps = 12
# Episode 248: Reward sum = -23.04, Last reward = -25.0, Steps = 17
# Episode 249: Reward sum = -3.29, Last reward = -5.0, Steps = 11
# Episode 250: Reward sum = -28.53, Last reward = -30.0, Steps = 13
# Episode 251: Reward sum = -13.13, Last reward = -15.0, Steps = 17
# Episode 252: Reward sum = 1.69, Last reward = 0.0, Steps = 9
# Episode 253: Reward sum = -18.63, Last reward = -20.0, Steps = 15
# Episode 254: Reward sum = 2.60, Last reward = 0.0, Steps = 17
# Episode 255: Reward sum = -3.33, Last reward = -5.0, Steps = 10
# Episode 256: Reward sum = 8.84, Last reward = 5.0, Steps = 15
# Episode 257: Reward sum = -7.74, Last reward = -10.0, Steps = 19
# Episode 258: Reward sum = -31.49, Last reward = -33.0, Steps = 14
# Episode 259: Reward sum = -4.35, Last reward = -5.0, Steps = 5
# Episode 260: Reward sum = -13.33, Last reward = -15.0, Steps = 15
# Episode 261: Reward sum = -23.18, Last reward = -25.0, Steps = 18
# Episode 262: Reward sum = -6.89, Last reward = -8.0, Steps = 8
# Episode 263: Reward sum = -2.86, Last reward = -5.0, Steps = 14
# Episode 264: Reward sum = -3.46, Last reward = -5.0, Steps = 15
# Episode 265: Reward sum = -4.40, Last reward = -5.0, Steps = 8
# Episode 266: Reward sum = 11.33, Last reward = 10.0, Steps = 15
# Episode 267: Reward sum = -0.62, Last reward = -2.0, Steps = 16
# Episode 268: Reward sum = -26.27, Last reward = -28.0, Steps = 15
# Episode 269: Reward sum = -3.70, Last reward = -5.0, Steps = 14
# Episode 270: Reward sum = 19.30, Last reward = 18.0, Steps = 14
# Episode 271: Reward sum = -14.03, Last reward = -15.0, Steps = 17
# Episode 272: Reward sum = -66.92, Last reward = -68.0, Steps = 16
# Episode 273: Reward sum = -4.03, Last reward = -5.0, Steps = 10
# Episode 274: Reward sum = -3.42, Last reward = -5.0, Steps = 12
# Episode 275: Reward sum = -18.85, Last reward = -20.0, Steps = 17
# Episode 276: Reward sum = -59.85, Last reward = -61.0, Steps = 17
# Episode 277: Reward sum = -3.89, Last reward = -5.0, Steps = 12
# Episode 278: Reward sum = 1.73, Last reward = 0.0, Steps = 18
# Episode 279: Reward sum = 14.74, Last reward = 12.0, Steps = 13
# Episode 280: Reward sum = -52.69, Last reward = -55.0, Steps = 16
# Episode 281: Reward sum = -32.52, Last reward = -35.0, Steps = 18
# Episode 282: Reward sum = -57.49, Last reward = -60.0, Steps = 16
# Episode 283: Reward sum = 16.00, Last reward = 15.0, Steps = 13
# Episode 284: Reward sum = -3.55, Last reward = -5.0, Steps = 11
# Episode 285: Reward sum = 32.28, Last reward = 30.0, Steps = 17
# Episode 286: Reward sum = 1.35, Last reward = 0.0, Steps = 16
# Episode 287: Reward sum = -6.88, Last reward = -8.0, Steps = 8
# Episode 288: Reward sum = -4.29, Last reward = -5.0, Steps = 5
# Episode 289: Reward sum = -4.61, Last reward = -5.0, Steps = 5
# Episode 290: Reward sum = -3.64, Last reward = -5.0, Steps = 8
# Episode 291: Reward sum = -65.75, Last reward = -68.0, Steps = 17
# Episode 292: Reward sum = -87.91, Last reward = -90.0, Steps = 19
# Episode 293: Reward sum = -4.36, Last reward = -5.0, Steps = 5
# Episode 294: Reward sum = -3.42, Last reward = -5.0, Steps = 12
# Episode 295: Reward sum = -4.48, Last reward = -5.0, Steps = 9
# Episode 296: Reward sum = 1.71, Last reward = 0.0, Steps = 16
# Episode 297: Reward sum = -5.57, Last reward = -8.0, Steps = 12
# Episode 298: Reward sum = -25.54, Last reward = -28.0, Steps = 15
# Episode 299: Reward sum = -26.31, Last reward = -30.0, Steps = 18
# Episode 300: Reward sum = -4.13, Last reward = -5.0, Steps = 7
# Episode 301: Reward sum = -3.91, Last reward = -5.0, Steps = 14
# Episode 302: Reward sum = -27.15, Last reward = -30.0, Steps = 16
# Episode 303: Reward sum = -3.75, Last reward = -5.0, Steps = 14
# Episode 304: Reward sum = -22.06, Last reward = -23.0, Steps = 11
# Episode 305: Reward sum = -8.28, Last reward = -10.0, Steps = 15
# Episode 306: Reward sum = 1.52, Last reward = 0.0, Steps = 12
# Episode 307: Reward sum = -3.29, Last reward = -5.0, Steps = 9
# Episode 308: Reward sum = 31.22, Last reward = 30.0, Steps = 17
# Episode 309: Reward sum = -4.52, Last reward = -5.0, Steps = 11
# Episode 310: Reward sum = -33.54, Last reward = -35.0, Steps = 16
# Episode 311: Reward sum = -33.56, Last reward = -35.0, Steps = 14
# Episode 312: Reward sum = -4.14, Last reward = -5.0, Steps = 11
# Episode 313: Reward sum = -3.64, Last reward = -5.0, Steps = 9
# Episode 314: Reward sum = -3.48, Last reward = -5.0, Steps = 13
# Episode 315: Reward sum = -21.92, Last reward = -25.0, Steps = 17
# Episode 316: Reward sum = -3.49, Last reward = -5.0, Steps = 12
# Episode 317: Reward sum = 3.43, Last reward = 0.0, Steps = 17
# Episode 318: Reward sum = -13.83, Last reward = -15.0, Steps = 17
# Episode 319: Reward sum = -36.26, Last reward = -38.0, Steps = 17
# Episode 320: Reward sum = -28.61, Last reward = -30.0, Steps = 14
# Episode 321: Reward sum = -18.31, Last reward = -20.0, Steps = 10
# Episode 322: Reward sum = -29.07, Last reward = -30.0, Steps = 17
# Episode 323: Reward sum = 1.73, Last reward = 0.0, Steps = 17
# Episode 324: Reward sum = 1.68, Last reward = 0.0, Steps = 15
# Episode 325: Reward sum = -3.67, Last reward = -5.0, Steps = 12
# Episode 326: Reward sum = -53.10, Last reward = -55.0, Steps = 17
# Episode 327: Reward sum = -37.91, Last reward = -40.0, Steps = 15
# Episode 328: Reward sum = -6.31, Last reward = -8.0, Steps = 14
# Episode 329: Reward sum = -20.85, Last reward = -23.0, Steps = 17
# Episode 330: Reward sum = -37.42, Last reward = -38.0, Steps = 17
# Episode 331: Reward sum = -3.11, Last reward = -5.0, Steps = 11
# Episode 332: Reward sum = -10.45, Last reward = -13.0, Steps = 16
# Episode 333: Reward sum = -4.54, Last reward = -5.0, Steps = 6
# Episode 334: Reward sum = 0.94, Last reward = 0.0, Steps = 17
# Episode 335: Reward sum = -27.84, Last reward = -30.0, Steps = 16
# Episode 336: Reward sum = -27.53, Last reward = -30.0, Steps = 14
# Episode 337: Reward sum = -3.39, Last reward = -5.0, Steps = 18
# Episode 338: Reward sum = 8.93, Last reward = 8.0, Steps = 16
# Episode 339: Reward sum = -53.28, Last reward = -55.0, Steps = 14
# Episode 340: Reward sum = -6.76, Last reward = -8.0, Steps = 12
# Episode 341: Reward sum = -34.07, Last reward = -35.0, Steps = 18
# Episode 342: Reward sum = -23.30, Last reward = -25.0, Steps = 17
# Episode 343: Reward sum = -34.10, Last reward = -35.0, Steps = 15
# Episode 344: Reward sum = -3.19, Last reward = -5.0, Steps = 13
# Episode 345: Reward sum = -25.69, Last reward = -28.0, Steps = 16
# Episode 346: Reward sum = -3.17, Last reward = -5.0, Steps = 10
# Episode 347: Reward sum = -27.78, Last reward = -30.0, Steps = 15
# Episode 348: Reward sum = -8.02, Last reward = -10.0, Steps = 18
# Episode 349: Reward sum = 6.41, Last reward = 5.0, Steps = 17
# Episode 350: Reward sum = -3.01, Last reward = -5.0, Steps = 14
# Episode 351: Reward sum = -2.83, Last reward = -5.0, Steps = 12
# Episode 352: Reward sum = -19.01, Last reward = -20.0, Steps = 11
# Episode 353: Reward sum = -3.33, Last reward = -5.0, Steps = 10
# Episode 354: Reward sum = -86.75, Last reward = -90.0, Steps = 17
# Episode 355: Reward sum = -27.52, Last reward = -29.0, Steps = 12
# Episode 356: Reward sum = -45.66, Last reward = -50.0, Steps = 16
# Episode 357: Reward sum = 0.95, Last reward = 0.0, Steps = 19
# Episode 358: Reward sum = -18.24, Last reward = -20.0, Steps = 10
# Episode 359: Reward sum = -3.57, Last reward = -5.0, Steps = 11
# Episode 360: Reward sum = -43.72, Last reward = -45.0, Steps = 16
# Episode 361: Reward sum = -31.75, Last reward = -35.0, Steps = 16
# Episode 362: Reward sum = -4.12, Last reward = -5.0, Steps = 12
# Episode 363: Reward sum = -32.49, Last reward = -35.0, Steps = 17
# Episode 364: Reward sum = -17.98, Last reward = -20.0, Steps = 14
# Episode 365: Reward sum = 0.96, Last reward = 0.0, Steps = 16
# Episode 366: Reward sum = -78.77, Last reward = -80.0, Steps = 16
# Episode 367: Reward sum = -3.30, Last reward = -5.0, Steps = 10
# Episode 368: Reward sum = -8.45, Last reward = -10.0, Steps = 17
# Episode 369: Reward sum = -2.96, Last reward = -5.0, Steps = 17
# Episode 370: Reward sum = -6.78, Last reward = -10.0, Steps = 15
# Episode 371: Reward sum = -8.32, Last reward = -10.0, Steps = 15
# Episode 372: Reward sum = -36.53, Last reward = -38.0, Steps = 15
# Episode 373: Reward sum = 62.80, Last reward = 60.0, Steps = 17
# Episode 374: Reward sum = -23.15, Last reward = -25.0, Steps = 16
# Episode 375: Reward sum = 6.73, Last reward = 5.0, Steps = 17
# Episode 376: Reward sum = -23.13, Last reward = -25.0, Steps = 16
# Episode 377: Reward sum = -7.26, Last reward = -8.0, Steps = 9
# Episode 378: Reward sum = -20.59, Last reward = -23.0, Steps = 18
# Episode 379: Reward sum = -3.93, Last reward = -5.0, Steps = 10
# Episode 380: Reward sum = -2.61, Last reward = -5.0, Steps = 15
# Episode 381: Reward sum = -22.22, Last reward = -25.0, Steps = 17
# Episode 382: Reward sum = -3.93, Last reward = -5.0, Steps = 11
# Episode 383: Reward sum = -39.19, Last reward = -40.0, Steps = 15
# Episode 384: Reward sum = -32.53, Last reward = -35.0, Steps = 16
# Episode 385: Reward sum = -4.15, Last reward = -5.0, Steps = 11
# Episode 386: Reward sum = 9.06, Last reward = 8.0, Steps = 19
# Episode 387: Reward sum = -13.16, Last reward = -15.0, Steps = 18
# Episode 388: Reward sum = 32.69, Last reward = 30.0, Steps = 17
# Episode 389: Reward sum = -8.34, Last reward = -10.0, Steps = 15
# Episode 390: Reward sum = -29.78, Last reward = -31.0, Steps = 17
# Episode 391: Reward sum = -28.30, Last reward = -30.0, Steps = 17
# Episode 392: Reward sum = -30.15, Last reward = -33.0, Steps = 16
# Episode 393: Reward sum = -37.05, Last reward = -40.0, Steps = 16
# Episode 394: Reward sum = -11.00, Last reward = -13.0, Steps = 16
# Episode 395: Reward sum = -8.40, Last reward = -10.0, Steps = 16
# Episode 396: Reward sum = -3.25, Last reward = -5.0, Steps = 16
# Episode 397: Reward sum = -7.35, Last reward = -8.0, Steps = 12
# Episode 398: Reward sum = 2.09, Last reward = 0.0, Steps = 16
# Episode 399: Reward sum = -29.51, Last reward = -30.0, Steps = 14
# Episode 400: Reward sum = -7.55, Last reward = -10.0, Steps = 16
# Episode 401: Reward sum = 61.32, Last reward = 60.0, Steps = 17
# Episode 402: Reward sum = -14.58, Last reward = -18.0, Steps = 15
# Episode 403: Reward sum = -3.96, Last reward = -5.0, Steps = 9
# Episode 404: Reward sum = -3.15, Last reward = -5.0, Steps = 18
# Episode 405: Reward sum = -7.26, Last reward = -10.0, Steps = 16
# Episode 406: Reward sum = 1.80, Last reward = 0.0, Steps = 16
# Episode 407: Reward sum = -28.08, Last reward = -30.0, Steps = 15
# Episode 408: Reward sum = -3.23, Last reward = -5.0, Steps = 15
# Episode 409: Reward sum = -31.82, Last reward = -35.0, Steps = 17
# Episode 410: Reward sum = -3.85, Last reward = -5.0, Steps = 8
# Episode 411: Reward sum = -11.02, Last reward = -13.0, Steps = 16
# Episode 412: Reward sum = -8.51, Last reward = -10.0, Steps = 17
# Episode 413: Reward sum = -2.63, Last reward = -5.0, Steps = 12
# Episode 414: Reward sum = -3.31, Last reward = -5.0, Steps = 13
# Episode 415: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 416: Reward sum = -15.86, Last reward = -18.0, Steps = 17
# Episode 417: Reward sum = -48.30, Last reward = -50.0, Steps = 16
# Episode 418: Reward sum = -47.90, Last reward = -50.0, Steps = 15
# Episode 419: Reward sum = -4.30, Last reward = -5.0, Steps = 6
# Episode 420: Reward sum = -63.75, Last reward = -65.0, Steps = 14
# Episode 421: Reward sum = -46.76, Last reward = -48.0, Steps = 18
# Episode 422: Reward sum = 20.94, Last reward = 20.0, Steps = 18
# Episode 423: Reward sum = -3.63, Last reward = -5.0, Steps = 10
# Episode 424: Reward sum = -48.19, Last reward = -50.0, Steps = 18
# Episode 425: Reward sum = -3.81, Last reward = -5.0, Steps = 12
# Episode 426: Reward sum = -4.10, Last reward = -5.0, Steps = 12
# Episode 427: Reward sum = 1.72, Last reward = 0.0, Steps = 17
# Episode 428: Reward sum = -18.29, Last reward = -20.0, Steps = 13
# Episode 429: Reward sum = -28.90, Last reward = -30.0, Steps = 16
# Episode 430: Reward sum = -7.75, Last reward = -10.0, Steps = 16
# Episode 431: Reward sum = -19.03, Last reward = -20.0, Steps = 13
# Episode 432: Reward sum = -28.07, Last reward = -30.0, Steps = 16
# Episode 433: Reward sum = -3.64, Last reward = -5.0, Steps = 8
# Episode 434: Reward sum = -24.44, Last reward = -25.0, Steps = 16
# Episode 435: Reward sum = -18.26, Last reward = -20.0, Steps = 9
# Episode 436: Reward sum = 32.07, Last reward = 30.0, Steps = 17
# Episode 437: Reward sum = -20.21, Last reward = -23.0, Steps = 15
# Episode 438: Reward sum = 6.78, Last reward = 5.0, Steps = 17
# Episode 439: Reward sum = 1.60, Last reward = 0.0, Steps = 14
# Episode 440: Reward sum = -66.03, Last reward = -68.0, Steps = 16
# Episode 441: Reward sum = -6.42, Last reward = -8.0, Steps = 10
# Episode 442: Reward sum = -27.78, Last reward = -30.0, Steps = 15
# Episode 443: Reward sum = -27.42, Last reward = -30.0, Steps = 17
# Episode 444: Reward sum = -7.85, Last reward = -10.0, Steps = 16
# Episode 445: Reward sum = -12.49, Last reward = -15.0, Steps = 16
# Episode 446: Reward sum = -8.29, Last reward = -10.0, Steps = 16
# Episode 447: Reward sum = -4.42, Last reward = -5.0, Steps = 4
# Episode 448: Reward sum = 18.60, Last reward = 18.0, Steps = 8
# Episode 449: Reward sum = 14.45, Last reward = 13.0, Steps = 14
# Episode 450: Reward sum = -3.87, Last reward = -5.0, Steps = 17
# Episode 451: Reward sum = -7.95, Last reward = -10.0, Steps = 16
# Episode 452: Reward sum = -28.77, Last reward = -30.0, Steps = 14
# Episode 453: Reward sum = -66.38, Last reward = -68.0, Steps = 16
# Episode 454: Reward sum = -18.26, Last reward = -20.0, Steps = 17
# Episode 455: Reward sum = -4.05, Last reward = -5.0, Steps = 16
# Episode 456: Reward sum = -29.01, Last reward = -30.0, Steps = 12
# Episode 457: Reward sum = -41.71, Last reward = -43.0, Steps = 17
# Episode 458: Reward sum = -23.76, Last reward = -25.0, Steps = 17
# Episode 459: Reward sum = -18.18, Last reward = -20.0, Steps = 15
# Episode 460: Reward sum = -40.93, Last reward = -43.0, Steps = 15
# Episode 461: Reward sum = -17.12, Last reward = -18.0, Steps = 17
# Episode 462: Reward sum = 34.84, Last reward = 33.0, Steps = 17
# Episode 463: Reward sum = -4.06, Last reward = -5.0, Steps = 6
# Episode 464: Reward sum = -30.21, Last reward = -33.0, Steps = 15
# Episode 465: Reward sum = -68.93, Last reward = -70.0, Steps = 15
# Episode 466: Reward sum = -48.69, Last reward = -50.0, Steps = 16
# Episode 467: Reward sum = -4.80, Last reward = -5.0, Steps = 7
# Episode 468: Reward sum = -4.17, Last reward = -5.0, Steps = 15
# Episode 469: Reward sum = -22.61, Last reward = -25.0, Steps = 14
# Episode 470: Reward sum = -6.70, Last reward = -10.0, Steps = 16
# Episode 471: Reward sum = -69.54, Last reward = -71.0, Steps = 18
# Episode 472: Reward sum = -3.49, Last reward = -5.0, Steps = 14
# Episode 473: Reward sum = -81.97, Last reward = -83.0, Steps = 16
# Episode 474: Reward sum = 62.13, Last reward = 60.0, Steps = 17
# Episode 475: Reward sum = -47.16, Last reward = -50.0, Steps = 15
# Episode 476: Reward sum = -32.06, Last reward = -33.0, Steps = 16
# Episode 477: Reward sum = 120.71, Last reward = 120.0, Steps = 19
# Episode 478: Reward sum = -4.17, Last reward = -5.0, Steps = 10
# Episode 479: Reward sum = -3.75, Last reward = -5.0, Steps = 16
# Episode 480: Reward sum = -28.56, Last reward = -31.0, Steps = 16
# Episode 481: Reward sum = -22.16, Last reward = -23.0, Steps = 16
# Episode 482: Reward sum = -32.75, Last reward = -35.0, Steps = 15
# Episode 483: Reward sum = 4.60, Last reward = 0.0, Steps = 18
# Episode 484: Reward sum = -3.29, Last reward = -5.0, Steps = 15
# Episode 485: Reward sum = -18.07, Last reward = -20.0, Steps = 12
# Episode 486: Reward sum = 30.90, Last reward = 30.0, Steps = 17
# Episode 487: Reward sum = -3.76, Last reward = -5.0, Steps = 15
# Episode 488: Reward sum = -8.39, Last reward = -10.0, Steps = 16
# Episode 489: Reward sum = -3.73, Last reward = -5.0, Steps = 16
# Episode 490: Reward sum = -3.65, Last reward = -5.0, Steps = 15
# Episode 491: Reward sum = -26.52, Last reward = -30.0, Steps = 18
# Episode 492: Reward sum = 0.95, Last reward = 0.0, Steps = 20
# Episode 493: Reward sum = -33.13, Last reward = -35.0, Steps = 15
# Episode 494: Reward sum = -29.22, Last reward = -30.0, Steps = 16
# Episode 495: Reward sum = -18.09, Last reward = -20.0, Steps = 15
# Episode 496: Reward sum = -18.68, Last reward = -20.0, Steps = 10
# Episode 497: Reward sum = -26.57, Last reward = -30.0, Steps = 17
# Episode 498: Reward sum = 1.05, Last reward = 0.0, Steps = 15
# Episode 499: Reward sum = -3.75, Last reward = -5.0, Steps = 12
# Episode 500: Reward sum = -65.39, Last reward = -68.0, Steps = 17
# Episode 501: Reward sum = -2.99, Last reward = -5.0, Steps = 14
# Episode 502: Reward sum = -4.08, Last reward = -5.0, Steps = 5
# Episode 503: Reward sum = 0.96, Last reward = 0.0, Steps = 9
# Episode 504: Reward sum = -4.42, Last reward = -5.0, Steps = 7
# Episode 505: Reward sum = -18.35, Last reward = -20.0, Steps = 14
# Episode 506: Reward sum = -3.84, Last reward = -5.0, Steps = 12
# Episode 507: Reward sum = -9.90, Last reward = -13.0, Steps = 16
# Episode 508: Reward sum = 1.77, Last reward = 0.0, Steps = 17
# Episode 509: Reward sum = -18.02, Last reward = -20.0, Steps = 15
# Episode 510: Reward sum = -3.34, Last reward = -5.0, Steps = 7
# Episode 511: Reward sum = -23.88, Last reward = -25.0, Steps = 18
# Episode 512: Reward sum = -3.03, Last reward = -5.0, Steps = 16
# Episode 513: Reward sum = -3.58, Last reward = -5.0, Steps = 13
# Episode 514: Reward sum = -3.26, Last reward = -5.0, Steps = 13
# Episode 515: Reward sum = -2.81, Last reward = -5.0, Steps = 15
# Episode 516: Reward sum = -40.73, Last reward = -43.0, Steps = 15
# Episode 517: Reward sum = -6.42, Last reward = -8.0, Steps = 12
# Episode 518: Reward sum = -3.84, Last reward = -5.0, Steps = 14
# Episode 519: Reward sum = 5.68, Last reward = 5.0, Steps = 15
# Episode 520: Reward sum = -64.69, Last reward = -68.0, Steps = 18
# Episode 521: Reward sum = -4.85, Last reward = -5.0, Steps = 7
# Episode 522: Reward sum = -33.85, Last reward = -35.0, Steps = 15
# Episode 523: Reward sum = 13.51, Last reward = 12.0, Steps = 15
# Episode 524: Reward sum = -18.04, Last reward = -20.0, Steps = 15
# Episode 525: Reward sum = -38.46, Last reward = -40.0, Steps = 18
# Episode 526: Reward sum = -19.90, Last reward = -21.0, Steps = 16
# Episode 527: Reward sum = -10.30, Last reward = -13.0, Steps = 17
# Episode 528: Reward sum = -40.92, Last reward = -43.0, Steps = 17
# Episode 529: Reward sum = -3.95, Last reward = -5.0, Steps = 16
# Episode 530: Reward sum = -49.54, Last reward = -50.0, Steps = 16
# Episode 531: Reward sum = -3.50, Last reward = -5.0, Steps = 15
# Episode 532: Reward sum = -17.66, Last reward = -20.0, Steps = 10
# Episode 533: Reward sum = -7.03, Last reward = -8.0, Steps = 5
# Episode 534: Reward sum = -3.14, Last reward = -5.0, Steps = 18
# Episode 535: Reward sum = 6.90, Last reward = 5.0, Steps = 17
# Episode 536: Reward sum = 65.16, Last reward = 63.0, Steps = 17
# Episode 537: Reward sum = -9.60, Last reward = -10.0, Steps = 16
# Episode 538: Reward sum = -3.70, Last reward = -5.0, Steps = 13
# Episode 539: Reward sum = -4.27, Last reward = -5.0, Steps = 17
# Episode 540: Reward sum = -58.70, Last reward = -60.0, Steps = 16
# Episode 541: Reward sum = -34.31, Last reward = -35.0, Steps = 18
# Episode 542: Reward sum = -4.70, Last reward = -5.0, Steps = 10
# Episode 543: Reward sum = -28.98, Last reward = -30.0, Steps = 15
# Episode 544: Reward sum = -3.99, Last reward = -5.0, Steps = 10
# Episode 545: Reward sum = 64.24, Last reward = 63.0, Steps = 16
# Episode 546: Reward sum = -4.43, Last reward = -5.0, Steps = 5
# Episode 547: Reward sum = -8.58, Last reward = -10.0, Steps = 15
# Episode 548: Reward sum = -3.95, Last reward = -5.0, Steps = 15
# Episode 549: Reward sum = -28.12, Last reward = -30.0, Steps = 12
# Episode 550: Reward sum = -4.10, Last reward = -5.0, Steps = 12
# Episode 551: Reward sum = -2.43, Last reward = -5.0, Steps = 16
# Episode 552: Reward sum = -32.81, Last reward = -35.0, Steps = 19
# Episode 553: Reward sum = -18.65, Last reward = -20.0, Steps = 12
# Episode 554: Reward sum = -4.04, Last reward = -5.0, Steps = 17
# Episode 555: Reward sum = -32.65, Last reward = -35.0, Steps = 16
# Episode 556: Reward sum = -18.93, Last reward = -20.0, Steps = 14
# Episode 557: Reward sum = -3.72, Last reward = -5.0, Steps = 17
# Episode 558: Reward sum = -3.95, Last reward = -5.0, Steps = 6
# Episode 559: Reward sum = -62.39, Last reward = -65.0, Steps = 17
# Episode 560: Reward sum = 31.49, Last reward = 30.0, Steps = 19
# Episode 561: Reward sum = -19.12, Last reward = -20.0, Steps = 10
# Episode 562: Reward sum = -3.99, Last reward = -5.0, Steps = 9
# Episode 563: Reward sum = -4.44, Last reward = -5.0, Steps = 13
# Episode 564: Reward sum = -18.86, Last reward = -20.0, Steps = 17
# Episode 565: Reward sum = -32.84, Last reward = -35.0, Steps = 16
# Episode 566: Reward sum = -3.75, Last reward = -5.0, Steps = 11
# Episode 567: Reward sum = -87.65, Last reward = -90.0, Steps = 18
# Episode 568: Reward sum = -17.80, Last reward = -20.0, Steps = 16
# Episode 569: Reward sum = -23.10, Last reward = -25.0, Steps = 16
# Episode 570: Reward sum = -81.02, Last reward = -83.0, Steps = 17
# Episode 571: Reward sum = -33.13, Last reward = -35.0, Steps = 16
# Episode 572: Reward sum = -27.64, Last reward = -30.0, Steps = 12
# Episode 573: Reward sum = -2.95, Last reward = -5.0, Steps = 16
# Episode 574: Reward sum = -3.84, Last reward = -5.0, Steps = 8
# Episode 575: Reward sum = -2.43, Last reward = -5.0, Steps = 17
# Episode 576: Reward sum = 2.67, Last reward = 0.0, Steps = 17
# Episode 577: Reward sum = -87.58, Last reward = -90.0, Steps = 18
# Episode 578: Reward sum = -3.20, Last reward = -5.0, Steps = 14
# Episode 579: Reward sum = -33.41, Last reward = -35.0, Steps = 16
# Episode 580: Reward sum = -31.06, Last reward = -33.0, Steps = 15
# Episode 581: Reward sum = -19.04, Last reward = -20.0, Steps = 16
# Episode 582: Reward sum = -6.13, Last reward = -8.0, Steps = 10
# Episode 583: Reward sum = -18.94, Last reward = -20.0, Steps = 14
# Episode 584: Reward sum = -19.36, Last reward = -21.0, Steps = 17
# Episode 585: Reward sum = -4.33, Last reward = -5.0, Steps = 16
# Episode 586: Reward sum = -27.74, Last reward = -30.0, Steps = 17
# Episode 587: Reward sum = -3.54, Last reward = -5.0, Steps = 14
# Episode 588: Reward sum = -56.34, Last reward = -58.0, Steps = 16
# Episode 589: Reward sum = 7.13, Last reward = 5.0, Steps = 17
# Episode 590: Reward sum = -6.70, Last reward = -8.0, Steps = 14
# Episode 591: Reward sum = -2.30, Last reward = -5.0, Steps = 14
# Episode 592: Reward sum = -5.40, Last reward = -8.0, Steps = 16
# Episode 593: Reward sum = -15.48, Last reward = -18.0, Steps = 15
# Episode 594: Reward sum = -74.69, Last reward = -76.0, Steps = 16
# Episode 595: Reward sum = 2.92, Last reward = 0.0, Steps = 16
# Episode 596: Reward sum = -38.09, Last reward = -40.0, Steps = 16
# Episode 597: Reward sum = -13.39, Last reward = -15.0, Steps = 15
# Episode 598: Reward sum = -32.18, Last reward = -33.0, Steps = 14
# Episode 599: Reward sum = 8.02, Last reward = 5.0, Steps = 17
# Episode 600: Reward sum = -3.90, Last reward = -5.0, Steps = 7
# Episode 601: Reward sum = -4.49, Last reward = -5.0, Steps = 3
# Episode 602: Reward sum = -3.48, Last reward = -5.0, Steps = 9
# Episode 603: Reward sum = -66.98, Last reward = -68.0, Steps = 16
# Episode 604: Reward sum = -3.32, Last reward = -5.0, Steps = 15
# Episode 605: Reward sum = 7.36, Last reward = 5.0, Steps = 16
# Episode 606: Reward sum = -5.87, Last reward = -8.0, Steps = 12
# Episode 607: Reward sum = -12.23, Last reward = -14.0, Steps = 12
# Episode 608: Reward sum = -32.70, Last reward = -35.0, Steps = 16
# Episode 609: Reward sum = -3.34, Last reward = -5.0, Steps = 12
# Episode 610: Reward sum = 1.88, Last reward = 0.0, Steps = 17
# Episode 611: Reward sum = -8.64, Last reward = -10.0, Steps = 13
# Episode 612: Reward sum = -11.45, Last reward = -13.0, Steps = 17
# Episode 613: Reward sum = -63.25, Last reward = -65.0, Steps = 16
# Episode 614: Reward sum = -37.26, Last reward = -39.0, Steps = 16
# Episode 615: Reward sum = -59.95, Last reward = -61.0, Steps = 18
# Episode 616: Reward sum = 1.10, Last reward = 0.0, Steps = 16
# Episode 617: Reward sum = -28.37, Last reward = -30.0, Steps = 16
# Episode 618: Reward sum = -2.96, Last reward = -5.0, Steps = 14
# Episode 619: Reward sum = -3.98, Last reward = -5.0, Steps = 7
# Episode 620: Reward sum = 1.71, Last reward = 0.0, Steps = 16
# Episode 621: Reward sum = -3.42, Last reward = -5.0, Steps = 11
# Episode 622: Reward sum = -21.31, Last reward = -23.0, Steps = 16
# Episode 623: Reward sum = 16.63, Last reward = 15.0, Steps = 15
# Episode 624: Reward sum = -37.68, Last reward = -40.0, Steps = 16
# Episode 625: Reward sum = -29.32, Last reward = -30.0, Steps = 16
# Episode 626: Reward sum = -24.01, Last reward = -25.0, Steps = 16
# Episode 627: Reward sum = -3.37, Last reward = -5.0, Steps = 11
# Episode 628: Reward sum = -3.97, Last reward = -5.0, Steps = 7
# Episode 629: Reward sum = 33.95, Last reward = 33.0, Steps = 18
# Episode 630: Reward sum = -3.50, Last reward = -5.0, Steps = 11
# Episode 631: Reward sum = -39.55, Last reward = -43.0, Steps = 16
# Episode 632: Reward sum = -66.84, Last reward = -68.0, Steps = 15
# Episode 633: Reward sum = -2.31, Last reward = -5.0, Steps = 14
# Episode 634: Reward sum = -28.08, Last reward = -30.0, Steps = 14
# Episode 635: Reward sum = 1.81, Last reward = 0.0, Steps = 9
# Episode 636: Reward sum = -19.27, Last reward = -20.0, Steps = 8
# Episode 637: Reward sum = -11.10, Last reward = -13.0, Steps = 17
# Episode 638: Reward sum = -17.39, Last reward = -20.0, Steps = 14
# Episode 639: Reward sum = -4.67, Last reward = -5.0, Steps = 6
# Episode 640: Reward sum = 2.04, Last reward = 0.0, Steps = 14
# Episode 641: Reward sum = -11.90, Last reward = -13.0, Steps = 16
# Episode 642: Reward sum = -29.03, Last reward = -30.0, Steps = 9
# Episode 643: Reward sum = 7.20, Last reward = 5.0, Steps = 16
# Episode 644: Reward sum = 2.80, Last reward = 0.0, Steps = 16
# Episode 645: Reward sum = -38.76, Last reward = -40.0, Steps = 16
# Episode 646: Reward sum = -63.97, Last reward = -65.0, Steps = 18
# Episode 647: Reward sum = -3.00, Last reward = -5.0, Steps = 11
# Episode 648: Reward sum = -23.58, Last reward = -25.0, Steps = 16
# Episode 649: Reward sum = -2.88, Last reward = -5.0, Steps = 15
# Episode 650: Reward sum = -31.55, Last reward = -33.0, Steps = 15
# Episode 651: Reward sum = -2.84, Last reward = -5.0, Steps = 16
# Episode 652: Reward sum = -38.29, Last reward = -40.0, Steps = 17
# Episode 653: Reward sum = -4.44, Last reward = -5.0, Steps = 5
# Episode 654: Reward sum = -39.20, Last reward = -40.0, Steps = 14
# Episode 655: Reward sum = -11.19, Last reward = -13.0, Steps = 17
# Episode 656: Reward sum = -2.89, Last reward = -5.0, Steps = 13
# Episode 657: Reward sum = -4.59, Last reward = -5.0, Steps = 4
# Episode 658: Reward sum = 1.76, Last reward = 0.0, Steps = 16
# Episode 659: Reward sum = -3.79, Last reward = -5.0, Steps = 8
# Episode 660: Reward sum = -61.85, Last reward = -63.0, Steps = 18
# Episode 661: Reward sum = -42.46, Last reward = -46.0, Steps = 18
# Episode 662: Reward sum = 0.66, Last reward = 0.0, Steps = 16
# Episode 663: Reward sum = -3.26, Last reward = -5.0, Steps = 14
# Episode 664: Reward sum = -4.09, Last reward = -5.0, Steps = 9
# Episode 665: Reward sum = -21.75, Last reward = -23.0, Steps = 16
# Episode 666: Reward sum = -4.30, Last reward = -5.0, Steps = 12
# Episode 667: Reward sum = -33.72, Last reward = -35.0, Steps = 17
# Episode 668: Reward sum = -17.82, Last reward = -20.0, Steps = 15
# Episode 669: Reward sum = -4.21, Last reward = -5.0, Steps = 11
# Episode 670: Reward sum = -3.34, Last reward = -5.0, Steps = 11
# Episode 671: Reward sum = -4.36, Last reward = -5.0, Steps = 8
# Episode 672: Reward sum = -6.48, Last reward = -8.0, Steps = 17
# Episode 673: Reward sum = -18.32, Last reward = -20.0, Steps = 15
# Episode 674: Reward sum = -22.20, Last reward = -25.0, Steps = 16
# Episode 675: Reward sum = -3.79, Last reward = -5.0, Steps = 11
# Episode 676: Reward sum = -62.45, Last reward = -65.0, Steps = 16
# Episode 677: Reward sum = -3.60, Last reward = -5.0, Steps = 13
# Episode 678: Reward sum = -13.64, Last reward = -15.0, Steps = 15
# Episode 679: Reward sum = -3.90, Last reward = -5.0, Steps = 16
# Episode 680: Reward sum = -3.76, Last reward = -5.0, Steps = 9
# Episode 681: Reward sum = -63.28, Last reward = -65.0, Steps = 18
# Episode 682: Reward sum = -3.26, Last reward = -5.0, Steps = 13
# Episode 683: Reward sum = -5.91, Last reward = -8.0, Steps = 14
# Episode 684: Reward sum = -52.65, Last reward = -55.0, Steps = 16
# Episode 685: Reward sum = -19.08, Last reward = -20.0, Steps = 14
# Episode 686: Reward sum = 15.75, Last reward = 15.0, Steps = 8
# Episode 687: Reward sum = -25.68, Last reward = -28.0, Steps = 16
# Episode 688: Reward sum = -35.55, Last reward = -38.0, Steps = 16
# Episode 689: Reward sum = -7.05, Last reward = -8.0, Steps = 16
# Episode 690: Reward sum = -6.30, Last reward = -8.0, Steps = 18
# Episode 691: Reward sum = 1.05, Last reward = 0.0, Steps = 19
# Episode 692: Reward sum = -4.08, Last reward = -5.0, Steps = 6
# Episode 693: Reward sum = -31.60, Last reward = -35.0, Steps = 16
# Episode 694: Reward sum = -4.38, Last reward = -5.0, Steps = 5
# Episode 695: Reward sum = -16.32, Last reward = -18.0, Steps = 16
# Episode 696: Reward sum = -37.94, Last reward = -40.0, Steps = 18
# Episode 697: Reward sum = -6.12, Last reward = -8.0, Steps = 11
# Episode 698: Reward sum = -3.75, Last reward = -5.0, Steps = 12
# Episode 699: Reward sum = -29.22, Last reward = -30.0, Steps = 11
# Episode 700: Reward sum = -8.61, Last reward = -10.0, Steps = 16
# Episode 701: Reward sum = -3.92, Last reward = -5.0, Steps = 11
# Episode 702: Reward sum = -33.62, Last reward = -35.0, Steps = 17
# Episode 703: Reward sum = -32.07, Last reward = -33.0, Steps = 12
# Episode 704: Reward sum = -4.19, Last reward = -5.0, Steps = 12
# Episode 705: Reward sum = -3.80, Last reward = -5.0, Steps = 12
# Episode 706: Reward sum = -3.83, Last reward = -5.0, Steps = 13
# Episode 707: Reward sum = -53.97, Last reward = -55.0, Steps = 15
# Episode 708: Reward sum = 2.50, Last reward = 0.0, Steps = 19
# Episode 709: Reward sum = 2.96, Last reward = 0.0, Steps = 18
# Episode 710: Reward sum = -4.26, Last reward = -5.0, Steps = 8
# Episode 711: Reward sum = -3.07, Last reward = -5.0, Steps = 11
# Episode 712: Reward sum = -31.48, Last reward = -33.0, Steps = 16
# Episode 713: Reward sum = -4.75, Last reward = -5.0, Steps = 10
# Episode 714: Reward sum = -1.05, Last reward = -5.0, Steps = 9
# Episode 715: Reward sum = -3.30, Last reward = -5.0, Steps = 13
# Episode 716: Reward sum = -29.17, Last reward = -30.0, Steps = 7
# Episode 717: Reward sum = -3.94, Last reward = -5.0, Steps = 14
# Episode 718: Reward sum = -41.13, Last reward = -43.0, Steps = 17
# Episode 719: Reward sum = 0.58, Last reward = -5.0, Steps = 15
# Episode 720: Reward sum = -13.21, Last reward = -15.0, Steps = 14
# Episode 721: Reward sum = -2.92, Last reward = -5.0, Steps = 16
# Episode 722: Reward sum = -21.92, Last reward = -23.0, Steps = 14
# Episode 723: Reward sum = -6.82, Last reward = -8.0, Steps = 15
# Episode 724: Reward sum = 2.95, Last reward = 0.0, Steps = 18
# Episode 725: Reward sum = -31.92, Last reward = -33.0, Steps = 17
# Episode 726: Reward sum = 90.77, Last reward = 90.0, Steps = 14
# Episode 727: Reward sum = -3.88, Last reward = -5.0, Steps = 13
# Episode 728: Reward sum = -55.40, Last reward = -58.0, Steps = 18
# Episode 729: Reward sum = -28.93, Last reward = -30.0, Steps = 15
# Episode 730: Reward sum = -8.96, Last reward = -10.0, Steps = 17
# Episode 731: Reward sum = -28.41, Last reward = -30.0, Steps = 15
# Episode 732: Reward sum = -1.86, Last reward = -5.0, Steps = 14
# Episode 733: Reward sum = -4.19, Last reward = -5.0, Steps = 4
# Episode 734: Reward sum = -3.16, Last reward = -5.0, Steps = 14
# Episode 735: Reward sum = 1.85, Last reward = 0.0, Steps = 16
# Episode 736: Reward sum = -54.32, Last reward = -55.0, Steps = 14
# Episode 737: Reward sum = -17.78, Last reward = -20.0, Steps = 13
# Episode 738: Reward sum = 2.77, Last reward = 0.0, Steps = 16
# Episode 739: Reward sum = -25.65, Last reward = -26.0, Steps = 12
# Episode 740: Reward sum = -3.70, Last reward = -5.0, Steps = 13
# Episode 741: Reward sum = -87.68, Last reward = -90.0, Steps = 16
# Episode 742: Reward sum = -7.15, Last reward = -10.0, Steps = 17
# Episode 743: Reward sum = -3.29, Last reward = -5.0, Steps = 13
# Episode 744: Reward sum = -4.19, Last reward = -5.0, Steps = 6
# ...
# Episode 755: Reward sum = -4.05, Last reward = -5.0, Steps = 18
# Episode 756: Reward sum = -42.70, Last reward = -46.0, Steps = 15
# Episode 757: Reward sum = 41.20, Last reward = 40.0, Steps = 17
# Episode 758: Reward sum = -24.87, Last reward = -27.0, Steps = 16
# Episode 759: Reward sum = -3.42, Last reward = -5.0, Steps = 12
# Episode 760: Reward sum = -18.13, Last reward = -20.0, Steps = 14
# Episode 761: Reward sum = -31.96, Last reward = -35.0, Steps = 15
# Episode 762: Reward sum = -4.57, Last reward = -5.0, Steps = 9
# Episode 763: Reward sum = -28.46, Last reward = -30.0, Steps = 13
# Episode 764: Reward sum = -62.06, Last reward = -63.0, Steps = 17
# Episode 765: Reward sum = -83.41, Last reward = -85.0, Steps = 14
# Episode 766: Reward sum = 24.49, Last reward = 23.0, Steps = 18
# Episode 767: Reward sum = -3.77, Last reward = -5.0, Steps = 7
# Episode 768: Reward sum = -3.04, Last reward = -5.0, Steps = 13
# Episode 769: Reward sum = -17.87, Last reward = -20.0, Steps = 12
# Episode 770: Reward sum = -58.96, Last reward = -61.0, Steps = 16
# Episode 771: Reward sum = -3.42, Last reward = -5.0, Steps = 18
# Episode 772: Reward sum = 9.77, Last reward = 8.0, Steps = 15
# Episode 773: Reward sum = -31.10, Last reward = -33.0, Steps = 17
# Episode 774: Reward sum = -17.60, Last reward = -20.0, Steps = 16
# Episode 775: Reward sum = -53.34, Last reward = -55.0, Steps = 15
# Episode 776: Reward sum = 42.41, Last reward = 40.0, Steps = 18
# Episode 777: Reward sum = -5.34, Last reward = -8.0, Steps = 17
# Episode 778: Reward sum = -37.94, Last reward = -40.0, Steps = 16
# Episode 779: Reward sum = 24.92, Last reward = 23.0, Steps = 16
# Episode 780: Reward sum = -18.14, Last reward = -20.0, Steps = 16
# Episode 781: Reward sum = -68.11, Last reward = -70.0, Steps = 15
# Episode 782: Reward sum = -17.39, Last reward = -18.0, Steps = 15
# Episode 783: Reward sum = -45.37, Last reward = -46.0, Steps = 16
# Episode 784: Reward sum = -19.42, Last reward = -20.0, Steps = 16
# Episode 785: Reward sum = -8.05, Last reward = -10.0, Steps = 17
# Episode 786: Reward sum = -21.16, Last reward = -23.0, Steps = 15
# Episode 787: Reward sum = -3.89, Last reward = -5.0, Steps = 16
# Episode 788: Reward sum = -53.32, Last reward = -55.0, Steps = 15
# Episode 789: Reward sum = -38.41, Last reward = -40.0, Steps = 16
# Episode 790: Reward sum = -3.34, Last reward = -5.0, Steps = 17
# Episode 791: Reward sum = -26.90, Last reward = -30.0, Steps = 17
# Episode 792: Reward sum = -69.20, Last reward = -71.0, Steps = 15
# Episode 793: Reward sum = 6.67, Last reward = 5.0, Steps = 15
# Episode 794: Reward sum = -52.67, Last reward = -55.0, Steps = 15
# Episode 795: Reward sum = -28.58, Last reward = -30.0, Steps = 17
# Episode 796: Reward sum = -8.26, Last reward = -10.0, Steps = 19
# Episode 797: Reward sum = -36.20, Last reward = -38.0, Steps = 15
# Episode 798: Reward sum = -17.83, Last reward = -20.0, Steps = 19
# Episode 799: Reward sum = -6.55, Last reward = -8.0, Steps = 13
# Episode 800: Reward sum = -13.75, Last reward = -15.0, Steps = 16
# Episode 801: Reward sum = -6.68, Last reward = -8.0, Steps = 14
# Episode 802: Reward sum = -3.71, Last reward = -5.0, Steps = 10
# Episode 803: Reward sum = -31.57, Last reward = -35.0, Steps = 17
# Episode 804: Reward sum = 60.55, Last reward = 60.0, Steps = 17
# Episode 805: Reward sum = -10.60, Last reward = -13.0, Steps = 17
# Episode 806: Reward sum = -13.48, Last reward = -15.0, Steps = 16
# Episode 807: Reward sum = -2.36, Last reward = -5.0, Steps = 14
# Episode 808: Reward sum = -3.13, Last reward = -5.0, Steps = 12
# Episode 809: Reward sum = -35.22, Last reward = -36.0, Steps = 15
# Episode 810: Reward sum = -35.87, Last reward = -38.0, Steps = 17
# Episode 811: Reward sum = -2.15, Last reward = -5.0, Steps = 15
# Episode 812: Reward sum = -6.97, Last reward = -8.0, Steps = 12
# Episode 813: Reward sum = -52.66, Last reward = -55.0, Steps = 15
# Episode 814: Reward sum = -3.71, Last reward = -5.0, Steps = 11
# Episode 815: Reward sum = -31.87, Last reward = -33.0, Steps = 17
# Episode 816: Reward sum = -42.94, Last reward = -45.0, Steps = 16
# Episode 817: Reward sum = -33.28, Last reward = -35.0, Steps = 16
# Episode 818: Reward sum = -95.67, Last reward = -98.0, Steps = 17
# Episode 819: Reward sum = -21.22, Last reward = -23.0, Steps = 18
# Episode 820: Reward sum = -68.20, Last reward = -70.0, Steps = 14
# Episode 821: Reward sum = -4.62, Last reward = -5.0, Steps = 13
# Episode 822: Reward sum = -4.04, Last reward = -5.0, Steps = 10
# Episode 823: Reward sum = -6.96, Last reward = -8.0, Steps = 10
# Episode 824: Reward sum = -23.63, Last reward = -25.0, Steps = 16
# Episode 825: Reward sum = -18.83, Last reward = -20.0, Steps = 11
# Episode 826: Reward sum = 42.87, Last reward = 40.0, Steps = 17
# Episode 827: Reward sum = -7.59, Last reward = -10.0, Steps = 17
# Episode 828: Reward sum = -3.94, Last reward = -5.0, Steps = 8
# Episode 829: Reward sum = -12.23, Last reward = -15.0, Steps = 16
# Episode 830: Reward sum = -7.19, Last reward = -10.0, Steps = 16
# Episode 831: Reward sum = -62.91, Last reward = -65.0, Steps = 15
# Episode 832: Reward sum = -18.94, Last reward = -20.0, Steps = 13
# Episode 833: Reward sum = 1.01, Last reward = 0.0, Steps = 19
# Episode 834: Reward sum = -4.08, Last reward = -5.0, Steps = 9
# Episode 835: Reward sum = -55.80, Last reward = -58.0, Steps = 16
# Episode 836: Reward sum = -27.14, Last reward = -28.0, Steps = 17
# Episode 837: Reward sum = -28.79, Last reward = -30.0, Steps = 18
# Episode 838: Reward sum = -4.40, Last reward = -5.0, Steps = 8
# Episode 839: Reward sum = -2.80, Last reward = -5.0, Steps = 17
# Episode 840: Reward sum = -38.54, Last reward = -40.0, Steps = 16
# Episode 841: Reward sum = -31.20, Last reward = -33.0, Steps = 17
# Episode 842: Reward sum = -38.13, Last reward = -40.0, Steps = 18
# Episode 843: Reward sum = -4.01, Last reward = -5.0, Steps = 16
# Episode 844: Reward sum = -25.95, Last reward = -28.0, Steps = 16
# Episode 845: Reward sum = -22.06, Last reward = -25.0, Steps = 14
# Episode 846: Reward sum = -4.30, Last reward = -5.0, Steps = 7
# Episode 847: Reward sum = -18.89, Last reward = -20.0, Steps = 8
# Episode 848: Reward sum = -31.37, Last reward = -33.0, Steps = 13
# Episode 849: Reward sum = -3.19, Last reward = -5.0, Steps = 12
# Episode 850: Reward sum = -2.39, Last reward = -5.0, Steps = 13
# Episode 851: Reward sum = -64.70, Last reward = -68.0, Steps = 16
# Episode 852: Reward sum = -36.25, Last reward = -38.0, Steps = 14
# Episode 853: Reward sum = -21.20, Last reward = -23.0, Steps = 14
# Episode 854: Reward sum = -29.15, Last reward = -30.0, Steps = 9
# Episode 855: Reward sum = -3.53, Last reward = -5.0, Steps = 16
# Episode 856: Reward sum = -99.42, Last reward = -103.0, Steps = 17
# Episode 857: Reward sum = -27.11, Last reward = -28.0, Steps = 17
# Episode 858: Reward sum = -3.95, Last reward = -5.0, Steps = 15
# Episode 859: Reward sum = -77.65, Last reward = -80.0, Steps = 17
# Episode 860: Reward sum = -27.72, Last reward = -30.0, Steps = 16
# Episode 861: Reward sum = -3.31, Last reward = -5.0, Steps = 18
# Episode 862: Reward sum = 2.05, Last reward = 0.0, Steps = 17
# Episode 863: Reward sum = 2.43, Last reward = 0.0, Steps = 18
# Episode 864: Reward sum = -3.81, Last reward = -5.0, Steps = 13
# Episode 865: Reward sum = -66.11, Last reward = -68.0, Steps = 17
# Episode 866: Reward sum = -4.29, Last reward = -5.0, Steps = 13
# Episode 867: Reward sum = -3.97, Last reward = -5.0, Steps = 5
# Episode 868: Reward sum = -4.62, Last reward = -5.0, Steps = 4
# Episode 869: Reward sum = -2.11, Last reward = -5.0, Steps = 16
# Episode 870: Reward sum = -4.20, Last reward = -5.0, Steps = 9
# Episode 871: Reward sum = -19.00, Last reward = -20.0, Steps = 13
# Episode 872: Reward sum = -23.41, Last reward = -25.0, Steps = 17
# Episode 873: Reward sum = -7.42, Last reward = -8.0, Steps = 7
# Episode 874: Reward sum = -8.90, Last reward = -10.0, Steps = 16
# Episode 875: Reward sum = -37.43, Last reward = -40.0, Steps = 15
# Episode 876: Reward sum = -54.02, Last reward = -55.0, Steps = 17
# Episode 877: Reward sum = -3.52, Last reward = -5.0, Steps = 16
# Episode 878: Reward sum = -63.51, Last reward = -65.0, Steps = 18
# Episode 879: Reward sum = -3.67, Last reward = -5.0, Steps = 17
# Episode 880: Reward sum = -2.34, Last reward = -5.0, Steps = 17
# Episode 881: Reward sum = -19.06, Last reward = -21.0, Steps = 16
# Episode 882: Reward sum = -3.16, Last reward = -5.0, Steps = 9
# Episode 883: Reward sum = -31.04, Last reward = -33.0, Steps = 18
# Episode 884: Reward sum = 3.37, Last reward = 0.0, Steps = 18
# Episode 885: Reward sum = -4.11, Last reward = -5.0, Steps = 13
# Episode 886: Reward sum = 13.52, Last reward = 12.0, Steps = 15
# Episode 887: Reward sum = -8.09, Last reward = -10.0, Steps = 16
# Episode 888: Reward sum = 42.05, Last reward = 40.0, Steps = 16
# Episode 889: Reward sum = -8.46, Last reward = -10.0, Steps = 14
# Episode 890: Reward sum = -4.61, Last reward = -5.0, Steps = 7
# Episode 891: Reward sum = -26.72, Last reward = -30.0, Steps = 16
# Episode 892: Reward sum = -23.24, Last reward = -25.0, Steps = 15
# Episode 893: Reward sum = 2.05, Last reward = 0.0, Steps = 15
# Episode 894: Reward sum = -38.02, Last reward = -40.0, Steps = 17
# Episode 895: Reward sum = -3.87, Last reward = -5.0, Steps = 10
# Episode 896: Reward sum = -58.91, Last reward = -60.0, Steps = 17
# Episode 897: Reward sum = -28.60, Last reward = -30.0, Steps = 14
# Episode 898: Reward sum = -58.43, Last reward = -60.0, Steps = 18
# Episode 899: Reward sum = 1.53, Last reward = 0.0, Steps = 17
# Episode 900: Reward sum = -3.52, Last reward = -5.0, Steps = 16
# Episode 901: Reward sum = -26.43, Last reward = -28.0, Steps = 16
# Episode 902: Reward sum = -42.22, Last reward = -45.0, Steps = 17
# Episode 903: Reward sum = -30.77, Last reward = -33.0, Steps = 16
# Episode 904: Reward sum = -7.88, Last reward = -10.0, Steps = 15
# Episode 905: Reward sum = -22.65, Last reward = -25.0, Steps = 16
# Episode 906: Reward sum = 88.26, Last reward = 87.0, Steps = 16
# Episode 907: Reward sum = -28.02, Last reward = -30.0, Steps = 15
# Episode 908: Reward sum = -3.72, Last reward = -5.0, Steps = 10
# Episode 909: Reward sum = -13.94, Last reward = -15.0, Steps = 15
# Episode 910: Reward sum = 1.29, Last reward = 0.0, Steps = 20
# Episode 911: Reward sum = -3.65, Last reward = -5.0, Steps = 11
# Episode 912: Reward sum = 15.43, Last reward = 15.0, Steps = 9
# Episode 913: Reward sum = -52.98, Last reward = -55.0, Steps = 17
# Episode 914: Reward sum = -3.73, Last reward = -5.0, Steps = 5
# Episode 915: Reward sum = -3.70, Last reward = -5.0, Steps = 12
# Episode 916: Reward sum = -18.39, Last reward = -20.0, Steps = 14
# Episode 917: Reward sum = -34.08, Last reward = -35.0, Steps = 14
# Episode 918: Reward sum = -28.45, Last reward = -30.0, Steps = 17
# Episode 919: Reward sum = 32.08, Last reward = 30.0, Steps = 17
# Episode 920: Reward sum = -4.21, Last reward = -5.0, Steps = 10
# Episode 921: Reward sum = -7.15, Last reward = -10.0, Steps = 16
# Episode 922: Reward sum = -3.19, Last reward = -5.0, Steps = 13
# Episode 923: Reward sum = 91.75, Last reward = 90.0, Steps = 16
# Episode 924: Reward sum = -26.30, Last reward = -28.0, Steps = 14
# Episode 925: Reward sum = -22.04, Last reward = -25.0, Steps = 15
# Episode 926: Reward sum = -3.87, Last reward = -5.0, Steps = 12
# Episode 927: Reward sum = -8.57, Last reward = -11.0, Steps = 15
# Episode 928: Reward sum = -80.93, Last reward = -83.0, Steps = 18
# Episode 929: Reward sum = 21.57, Last reward = 20.0, Steps = 18
# Episode 930: Reward sum = -38.29, Last reward = -40.0, Steps = 18
# Episode 931: Reward sum = -21.70, Last reward = -23.0, Steps = 11
# Episode 932: Reward sum = -3.91, Last reward = -5.0, Steps = 9
# Episode 933: Reward sum = 1.23, Last reward = 0.0, Steps = 17
# Episode 934: Reward sum = -22.70, Last reward = -25.0, Steps = 17
# Episode 935: Reward sum = -0.35, Last reward = -2.0, Steps = 15
# Episode 936: Reward sum = 2.79, Last reward = 2.0, Steps = 15
# Episode 937: Reward sum = -2.55, Last reward = -5.0, Steps = 14
# Episode 938: Reward sum = -69.59, Last reward = -71.0, Steps = 17
# Episode 939: Reward sum = 4.13, Last reward = 2.0, Steps = 16
# Episode 940: Reward sum = -38.86, Last reward = -40.0, Steps = 15
# Episode 941: Reward sum = -12.70, Last reward = -20.0, Steps = 14
# Episode 942: Reward sum = -18.92, Last reward = -20.0, Steps = 8
# Episode 943: Reward sum = -31.29, Last reward = -33.0, Steps = 16
# Episode 944: Reward sum = -18.61, Last reward = -20.0, Steps = 11
# Episode 945: Reward sum = -2.82, Last reward = -5.0, Steps = 17
# Episode 946: Reward sum = -41.65, Last reward = -43.0, Steps = 16
# Episode 947: Reward sum = -2.18, Last reward = -5.0, Steps = 15
# Episode 948: Reward sum = -35.42, Last reward = -38.0, Steps = 15
# Episode 949: Reward sum = 33.04, Last reward = 30.0, Steps = 19
# Episode 950: Reward sum = -4.08, Last reward = -5.0, Steps = 11
# Episode 951: Reward sum = -52.66, Last reward = -55.0, Steps = 16
# Episode 952: Reward sum = -59.25, Last reward = -61.0, Steps = 17
# Episode 953: Reward sum = -12.55, Last reward = -15.0, Steps = 16
# Episode 954: Reward sum = 64.79, Last reward = 63.0, Steps = 12
# Episode 955: Reward sum = 63.58, Last reward = 63.0, Steps = 18
# Episode 956: Reward sum = -6.99, Last reward = -8.0, Steps = 11
# Episode 957: Reward sum = -3.06, Last reward = -5.0, Steps = 9
# Episode 958: Reward sum = -22.10, Last reward = -24.0, Steps = 16
# Episode 959: Reward sum = -78.84, Last reward = -80.0, Steps = 16
# Episode 960: Reward sum = -88.49, Last reward = -90.0, Steps = 16
# Episode 961: Reward sum = -32.65, Last reward = -35.0, Steps = 17
# Episode 962: Reward sum = -34.32, Last reward = -35.0, Steps = 17
# Episode 963: Reward sum = -4.10, Last reward = -5.0, Steps = 7
# Episode 964: Reward sum = 2.54, Last reward = 0.0, Steps = 17
# Episode 965: Reward sum = -43.47, Last reward = -46.0, Steps = 18
# Episode 966: Reward sum = -4.42, Last reward = -5.0, Steps = 15
# Episode 967: Reward sum = -3.05, Last reward = -5.0, Steps = 15
# Episode 968: Reward sum = -26.38, Last reward = -30.0, Steps = 15
# Episode 969: Reward sum = 0.50, Last reward = 0.0, Steps = 17
# Episode 970: Reward sum = -4.20, Last reward = -5.0, Steps = 15
# Episode 971: Reward sum = -37.22, Last reward = -40.0, Steps = 17
# Episode 972: Reward sum = -4.00, Last reward = -5.0, Steps = 11
# Episode 973: Reward sum = -27.30, Last reward = -30.0, Steps = 16
# Episode 974: Reward sum = -86.93, Last reward = -89.0, Steps = 18
# Episode 975: Reward sum = -3.78, Last reward = -5.0, Steps = 12
# Episode 976: Reward sum = -8.23, Last reward = -10.0, Steps = 14
# Episode 977: Reward sum = 2.96, Last reward = 0.0, Steps = 18
# Episode 978: Reward sum = 10.07, Last reward = 8.0, Steps = 16
# Episode 979: Reward sum = -3.39, Last reward = -5.0, Steps = 16
# Episode 980: Reward sum = 90.76, Last reward = 90.0, Steps = 16
# Episode 981: Reward sum = -4.44, Last reward = -5.0, Steps = 6
# Episode 982: Reward sum = -33.59, Last reward = -35.0, Steps = 18
# Episode 983: Reward sum = -23.00, Last reward = -25.0, Steps = 16
# Episode 984: Reward sum = -5.64, Last reward = -8.0, Steps = 18
# Episode 985: Reward sum = -4.24, Last reward = -5.0, Steps = 9
# Episode 986: Reward sum = -0.72, Last reward = -2.0, Steps = 15
# Episode 987: Reward sum = -4.39, Last reward = -5.0, Steps = 17
# Episode 988: Reward sum = -34.22, Last reward = -35.0, Steps = 18
# Episode 989: Reward sum = -6.10, Last reward = -8.0, Steps = 15
# Episode 990: Reward sum = -3.73, Last reward = -5.0, Steps = 15
# Episode 991: Reward sum = 1.73, Last reward = 0.0, Steps = 17
# Episode 992: Reward sum = -6.28, Last reward = -8.0, Steps = 15
# Episode 993: Reward sum = -22.58, Last reward = -25.0, Steps = 16
# Episode 994: Reward sum = -58.28, Last reward = -60.0, Steps = 15
# Episode 995: Reward sum = 1.96, Last reward = 0.0, Steps = 15
# Episode 996: Reward sum = 2.80, Last reward = 0.0, Steps = 18
# Episode 997: Reward sum = 16.12, Last reward = 15.0, Steps = 12
# Episode 998: Reward sum = -30.83, Last reward = -33.0, Steps = 17
# Episode 999: Reward sum = -3.33, Last reward = -5.0, Steps = 12
# Episode 1000: Reward sum = -18.04, Last reward = -20.0, Steps = 15

# %%
print("Mean = ", np.mean(agent_eval.eval_rewards_per_episode_last_one))
plot_rewards(logger.log_dir, agent_eval.eval_rewards_per_episode_last_one, title="Evaluation Rewards", save_fig=True)
# Out:
# Mean =  -16.69
