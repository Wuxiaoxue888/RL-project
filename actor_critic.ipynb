# %%
import gymnasium as gym
import mahjong_env
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from time import strftime
import csv
np.random.seed(42)
tf.random.set_seed(42)

# %%
class Logger:
    def __init__(self):
        # Create a unique log directory
        self.log_dir = f"log_{strftime("%Y_%m_%d-%H_%M_%S")}"
        os.makedirs(self.log_dir, exist_ok=True)

        # Paths for logging files
        self.rewards_log_path = os.path.join(self.log_dir, "rewards.csv")
        self.transitions_log_path = os.path.join(self.log_dir, "transitions.csv")
        self.evaluation_log_path = os.path.join(self.log_dir, "evaluation_rewards.csv")
        self.policy_model_path = os.path.join(self.log_dir, "policy_model.keras")
        self.value_model_path = os.path.join(self.log_dir, "value_model.keras")

        # Initialize the CSV log files
        with open(self.rewards_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward sum", "last reward", "steps"])

        with open(self.transitions_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "state", "action", "next-state", "reward", "done", "truncated"])

        with open(self.evaluation_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward_sum", "last_reward", "steps"])

    def log_training_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])
            
    def log_eval_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])

    def log_transition(self, episode, state, action, next_state, reward, done, truncated):
        with open(self.transitions_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, state.tolist(), action, next_state.tolist(), reward, done, truncated])

    def save_policy_model(self, model):
        model.save(self.policy_model_path)
        
    def save_value_model(self, model):
        model.save(self.value_model_path)


class RewardNormalizer:
    def __init__(self):
        self.mean = 0
        self.var = 0
        self.count = 0

    def normalize(self, reward):
        self.count += 1
        old_mean = self.mean
        self.mean += (reward - self.mean) / self.count
        self.var += (reward - old_mean) * (reward - self.mean)
        std = (self.var / self.count) ** 0.5
        return (reward - self.mean) / (std + 1e-8)


class ActorCritic:
    def __init__(self, env, policy_network, value_network, logger, gamma=0.99):
        self.env = env
        self.policy_network = policy_network
        self.value_network = value_network
        self.gamma = gamma
        self.learning_rate = 0.001
        self.policy_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.value_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.training_rewards_per_episode_sum = []
        self.training_rewards_per_episode_last_one = []
        self.eval_rewards_per_episode_sum = []
        self.eval_rewards_per_episode_last_one = []
        self.logger = logger
        self.reward_normalizer = RewardNormalizer()

    def sample_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        action_probs[(state[:27]==0)] = 0.0
        total_prob = np.sum(action_probs)
        if total_prob == 0.0 or total_prob==np.nan:
            # If all probabilities are zero, choose a random valid action
            valid_actions = np.where(state[:27] != 0)[0]
            action = np.random.choice(valid_actions)
            return action
        # Normalize probabilities
        action_probs /= total_prob
        #action_probs /= np.sum(action_probs)
        action = np.random.choice(len(action_probs), p=action_probs)
        return action
    
    def take_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        action_probs[(state[:27]==0)] = -np.inf
        action = np.argmax(action_probs)
        return action
    
    def train_step(self, state, action, reward, next_state, done):
        # Compute target Q-value
        with tf.GradientTape() as value_tape:
            q_value = tf.squeeze(self.value_network(tf.expand_dims(state, axis=0)), axis=-1)
            target_q_value = reward + self.gamma * tf.squeeze(self.value_network(tf.expand_dims(next_state, axis=0)), axis=-1) * (1 - done)
            value_loss = tf.keras.losses.Huber()(target_q_value, q_value)
    
        # Update value network
        value_grads = value_tape.gradient(value_loss, self.value_network.trainable_variables)
        self.value_optimizer.apply_gradients(zip(value_grads, self.value_network.trainable_variables))
    
        # Compute policy loss using TD error
        td_error = target_q_value - q_value
        with tf.GradientTape() as policy_tape:
            action_probs = self.policy_network(tf.expand_dims(state, axis=0))
            mask = tf.constant(state[:27] != 0, dtype=tf.float32)
            masked_action_probs = action_probs * mask
            masked_action_probs /= tf.reduce_sum(masked_action_probs)
            selected_action_prob = tf.gather_nd(masked_action_probs, [[0, action]])
            policy_loss = -tf.reduce_mean(tf.math.log(selected_action_prob) * tf.stop_gradient(td_error))
    
        # Update policy network
        policy_grads = policy_tape.gradient(policy_loss, self.policy_network.trainable_variables)
        self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_network.trainable_variables))


    def process_state(self, state):
        normalized_hand = state['hand'] / 4.0
        normalized_visible_cards = state['visible cards'] / 4.0
        kangs_one_hot = tf.one_hot(state['kangs'], depth=4).numpy()
        kangs_one_hot_flat = kangs_one_hot.reshape(-1)
        final_array = np.concatenate((
            normalized_hand,
            state['pongs'],
            kangs_one_hot_flat,
            normalized_visible_cards
        ))
        return final_array
    
    
    def run_episode(self, log_transition=False):
        state, _ = self.env.reset()
        state = self.process_state(state)
        episode_reward = 0
        done = False
        steps = 0
        last_reward = 0
        while not done:
            action = self.sample_action(state)
            next_state, reward, done, truncated, _ = self.env.step(action)
            next_state = self.process_state(next_state)
            done = done or truncated
            normalized_reward = self.reward_normalizer.normalize(reward)
            self.train_step(state, action, normalized_reward, next_state, done)
            steps += 1
            episode_reward += reward
            if done:
                last_reward = reward
            # if log_transition and self.logger:
            #     self.logger.log_transition(episode, state, action, next_state, reward, done, truncated)
            state = next_state

        return episode_reward, last_reward, steps
    
    def evaluate(self, episodes):
        for episode in range(episodes):
            state, _ = self.env.reset()
            state = self.process_state(state)
            episode_reward = 0
            done = False
            steps = 0
            last_reward = 0
            while not done:
                action = self.take_action(state)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_state = self.process_state(next_state)
                done = done or truncated
                steps += 1
                episode_reward += reward
                if done:
                    last_reward = reward
                state = next_state
            self.eval_rewards_per_episode_sum.append(episode_reward)
            self.eval_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_eval_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")


    def train(self, episodes=1, save_freq=20):
        for episode in range(episodes):
            episode_reward, last_reward, steps = self.run_episode()
            self.training_rewards_per_episode_sum.append(episode_reward)
            self.training_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_training_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")
            if (episode + 1) % save_freq == 0 and self.logger:
                self.logger.save_policy_model(self.policy_network)
                self.logger.save_value_model(self.value_network)


# class PolicyNetwork(tf.keras.Model):
#     def __init__(self, num_actions):
#         super(PolicyNetwork, self).__init__()
#         self.dense1 = tf.keras.layers.Dense(128, activation='relu')
#         self.dense2 = tf.keras.layers.Dense(128, activation='relu')
#         self.dense3 = tf.keras.layers.Dense(num_actions, activation='softmax')
# 
#     def call(self, state):
#         x = self.dense1(state)
#         return self.dense3(self.dense2(x))
# 
# 
# class ValueNetwork(tf.keras.Model):
#     def __init__(self):
#         super(ValueNetwork, self).__init__()
#         self.dense1 = tf.keras.layers.Dense(128, activation='relu')
#         self.dense2 = tf.keras.layers.Dense(128, activation='relu')
#         self.dense3 = tf.keras.layers.Dense(1)
# 
#     def call(self, state):
#         x = self.dense1(state)
#         return self.dense3(self.dense2(x))

class PolicyNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(PolicyNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128)
        self.leaky_relu1 = tf.keras.layers.LeakyReLU()
        self.dense2 = tf.keras.layers.Dense(128)
        self.leaky_relu2 = tf.keras.layers.LeakyReLU()
        self.dense3 = tf.keras.layers.Dense(num_actions, activation='softmax')

    def call(self, state):
        x = self.leaky_relu1(self.dense1(state))
        x = self.leaky_relu2(self.dense2(x))
        return self.dense3(x)


class ValueNetwork(tf.keras.Model):
    def __init__(self):
        super(ValueNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128)
        self.leaky_relu1 = tf.keras.layers.LeakyReLU()
        self.dense2 = tf.keras.layers.Dense(128)
        self.leaky_relu2 = tf.keras.layers.LeakyReLU()
        self.dense3 = tf.keras.layers.Dense(1)

    def call(self, state):
        x = self.leaky_relu1(self.dense1(state))
        x = self.leaky_relu2(self.dense2(x))
        return self.dense3(x)


def plot_rewards(root_folder, rewards, title, save_fig=False):
    plt.plot(rewards, label='Total Reward per Episode')
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.title(title)
    if save_fig:
        plt.savefig(root_folder + "/" + title + '_' + strftime("%Y_%m_%d_%H_%M_%S") +'_' + '.png')
    plt.legend()
    plt.show()

# %%
# Environment setup
env = gym.make("Mahjong-v0")
policy = PolicyNetwork(num_actions=27)
value_network = ValueNetwork()
logger = Logger()
agent = ActorCritic(env, policy, value_network, logger)
agent.train(2000)
# Out:
# Episode 1: Reward sum = -17.03, Last reward = -20.0, Steps = 17
# Episode 2: Reward sum = 16.45, Last reward = 15.0, Steps = 16
# Episode 3: Reward sum = 1.63, Last reward = 0.0, Steps = 15
# Episode 4: Reward sum = 1.60, Last reward = 0.0, Steps = 16
# Episode 5: Reward sum = 2.94, Last reward = 0.0, Steps = 14
# Episode 6: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 7: Reward sum = 2.84, Last reward = 0.0, Steps = 16
# Episode 8: Reward sum = 3.49, Last reward = 0.0, Steps = 15
# Episode 9: Reward sum = 1.33, Last reward = 0.0, Steps = 16
# Episode 10: Reward sum = 1.58, Last reward = 0.0, Steps = 16
# Episode 11: Reward sum = 100.75, Last reward = 99.0, Steps = 17
# Episode 12: Reward sum = -17.68, Last reward = -20.0, Steps = 16
# Episode 13: Reward sum = 2.17, Last reward = 0.0, Steps = 15
# Episode 14: Reward sum = 2.09, Last reward = 0.0, Steps = 15
# Episode 15: Reward sum = 1.95, Last reward = 0.0, Steps = 16
# Episode 16: Reward sum = 2.08, Last reward = 0.0, Steps = 16
# Episode 17: Reward sum = 1.43, Last reward = 0.0, Steps = 18
# Episode 18: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 19: Reward sum = 1.56, Last reward = 0.0, Steps = 16
# Episode 20: Reward sum = -18.50, Last reward = -20.0, Steps = 16
# Episode 21: Reward sum = 2.08, Last reward = 0.0, Steps = 15
# Episode 22: Reward sum = 1.83, Last reward = 0.0, Steps = 15
# Episode 23: Reward sum = 1.82, Last reward = 0.0, Steps = 18
# Episode 24: Reward sum = 2.14, Last reward = 0.0, Steps = 18
# Episode 25: Reward sum = 2.17, Last reward = 0.0, Steps = 15
# Episode 26: Reward sum = 1.31, Last reward = 0.0, Steps = 15
# Episode 27: Reward sum = 2.36, Last reward = 0.0, Steps = 16
# Episode 28: Reward sum = 0.95, Last reward = 0.0, Steps = 16
# Episode 29: Reward sum = 2.25, Last reward = 0.0, Steps = 15
# Episode 30: Reward sum = 2.56, Last reward = 0.0, Steps = 16
# Episode 31: Reward sum = 2.43, Last reward = 0.0, Steps = 17
# Episode 32: Reward sum = 1.97, Last reward = 0.0, Steps = 16
# Episode 33: Reward sum = 1.96, Last reward = 0.0, Steps = 17
# Episode 34: Reward sum = 1.79, Last reward = 0.0, Steps = 14
# Episode 35: Reward sum = -28.81, Last reward = -30.0, Steps = 15
# Episode 36: Reward sum = 1.89, Last reward = 0.0, Steps = 17
# Episode 37: Reward sum = -2.65, Last reward = -5.0, Steps = 16
# Episode 38: Reward sum = 0.54, Last reward = 0.0, Steps = 15
# Episode 39: Reward sum = 2.46, Last reward = 0.0, Steps = 13
# Episode 40: Reward sum = 0.74, Last reward = 0.0, Steps = 17
# Episode 41: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 42: Reward sum = 1.00, Last reward = 0.0, Steps = 16
# Episode 43: Reward sum = 2.93, Last reward = 0.0, Steps = 17
# Episode 44: Reward sum = 90.53, Last reward = 90.0, Steps = 16
# Episode 45: Reward sum = 94.48, Last reward = 93.0, Steps = 13
# Episode 46: Reward sum = 1.79, Last reward = 0.0, Steps = 15
# Episode 47: Reward sum = -2.56, Last reward = -5.0, Steps = 17
# Episode 48: Reward sum = 1.23, Last reward = 0.0, Steps = 14
# Episode 49: Reward sum = 1.62, Last reward = 0.0, Steps = 16
# Episode 50: Reward sum = 3.57, Last reward = 0.0, Steps = 14
# Episode 51: Reward sum = 1.61, Last reward = 0.0, Steps = 15
# Episode 52: Reward sum = 0.85, Last reward = 0.0, Steps = 16
# Episode 53: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 54: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 55: Reward sum = 2.15, Last reward = 0.0, Steps = 15
# Episode 56: Reward sum = 1.52, Last reward = 0.0, Steps = 17
# Episode 57: Reward sum = 100.81, Last reward = 99.0, Steps = 18
# Episode 58: Reward sum = 104.10, Last reward = 102.0, Steps = 16
# Episode 59: Reward sum = -18.39, Last reward = -20.0, Steps = 17
# Episode 60: Reward sum = 2.26, Last reward = 0.0, Steps = 17
# Episode 61: Reward sum = 1.70, Last reward = 0.0, Steps = 18
# Episode 62: Reward sum = 2.08, Last reward = 0.0, Steps = 16
# Episode 63: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 64: Reward sum = 1.26, Last reward = 0.0, Steps = 16
# Episode 65: Reward sum = 1.36, Last reward = 0.0, Steps = 16
# Episode 66: Reward sum = 2.46, Last reward = 0.0, Steps = 17
# Episode 67: Reward sum = 1.55, Last reward = 0.0, Steps = 15
# Episode 68: Reward sum = 1.94, Last reward = 0.0, Steps = 17
# Episode 69: Reward sum = 1.61, Last reward = 0.0, Steps = 17
# Episode 70: Reward sum = -28.35, Last reward = -30.0, Steps = 18
# Episode 71: Reward sum = 17.58, Last reward = 15.0, Steps = 17
# Episode 72: Reward sum = 2.00, Last reward = 0.0, Steps = 17
# Episode 73: Reward sum = 2.24, Last reward = 0.0, Steps = 17
# Episode 74: Reward sum = 62.38, Last reward = 60.0, Steps = 18
# Episode 75: Reward sum = 73.06, Last reward = 69.0, Steps = 17
# Episode 76: Reward sum = 1.31, Last reward = 0.0, Steps = 15
# Episode 77: Reward sum = 2.10, Last reward = 0.0, Steps = 17
# Episode 78: Reward sum = 1.49, Last reward = 0.0, Steps = 17
# Episode 79: Reward sum = -31.72, Last reward = -33.0, Steps = 16
# Episode 80: Reward sum = 2.38, Last reward = 0.0, Steps = 16
# Episode 81: Reward sum = 3.40, Last reward = 0.0, Steps = 16
# Episode 82: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 83: Reward sum = -27.46, Last reward = -30.0, Steps = 17
# Episode 84: Reward sum = 2.14, Last reward = 0.0, Steps = 15
# Episode 85: Reward sum = 1.30, Last reward = 0.0, Steps = 16
# Episode 86: Reward sum = 2.91, Last reward = 0.0, Steps = 17
# Episode 87: Reward sum = -6.61, Last reward = -8.0, Steps = 16
# Episode 88: Reward sum = 2.41, Last reward = 0.0, Steps = 15
# Episode 89: Reward sum = 3.04, Last reward = 0.0, Steps = 17
# Episode 90: Reward sum = 1.25, Last reward = 0.0, Steps = 16
# Episode 91: Reward sum = 1.31, Last reward = 0.0, Steps = 15
# Episode 92: Reward sum = 25.30, Last reward = 24.0, Steps = 16
# Episode 93: Reward sum = 2.18, Last reward = 0.0, Steps = 16
# Episode 94: Reward sum = 2.09, Last reward = 0.0, Steps = 15
# Episode 95: Reward sum = 3.94, Last reward = 0.0, Steps = 17
# Episode 96: Reward sum = 1.72, Last reward = 0.0, Steps = 14
# Episode 97: Reward sum = 1.32, Last reward = 0.0, Steps = 17
# Episode 98: Reward sum = 1.63, Last reward = 0.0, Steps = 16
# Episode 99: Reward sum = 2.82, Last reward = 0.0, Steps = 15
# Episode 100: Reward sum = 2.80, Last reward = 0.0, Steps = 15
# Episode 101: Reward sum = 1.62, Last reward = 0.0, Steps = 17
# Episode 102: Reward sum = 62.97, Last reward = 60.0, Steps = 18
# Episode 103: Reward sum = 40.60, Last reward = 39.0, Steps = 16
# Episode 104: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 105: Reward sum = 2.08, Last reward = 0.0, Steps = 16
# Episode 106: Reward sum = 2.54, Last reward = 0.0, Steps = 16
# Episode 107: Reward sum = 1.52, Last reward = 0.0, Steps = 16
# Episode 108: Reward sum = -36.40, Last reward = -39.0, Steps = 18
# Episode 109: Reward sum = -19.04, Last reward = -20.0, Steps = 10
# Episode 110: Reward sum = 1.16, Last reward = 0.0, Steps = 16
# Episode 111: Reward sum = 2.18, Last reward = 0.0, Steps = 16
# Episode 112: Reward sum = 1.26, Last reward = 0.0, Steps = 17
# Episode 113: Reward sum = 1.42, Last reward = 0.0, Steps = 15
# Episode 114: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 115: Reward sum = 2.11, Last reward = 0.0, Steps = 16
# Episode 116: Reward sum = -29.47, Last reward = -30.0, Steps = 17
# Episode 117: Reward sum = 3.47, Last reward = 0.0, Steps = 17
# Episode 118: Reward sum = 1.80, Last reward = 0.0, Steps = 15
# Episode 119: Reward sum = 2.05, Last reward = 0.0, Steps = 14
# Episode 120: Reward sum = 1.77, Last reward = 0.0, Steps = 16
# Episode 121: Reward sum = 2.41, Last reward = 0.0, Steps = 16
# Episode 122: Reward sum = 91.89, Last reward = 90.0, Steps = 17
# Episode 123: Reward sum = 1.64, Last reward = 0.0, Steps = 16
# Episode 124: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 125: Reward sum = -28.99, Last reward = -30.0, Steps = 16
# Episode 126: Reward sum = 1.10, Last reward = 0.0, Steps = 18
# Episode 127: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 128: Reward sum = 1.87, Last reward = 0.0, Steps = 15
# Episode 129: Reward sum = 3.17, Last reward = 0.0, Steps = 16
# Episode 130: Reward sum = 2.14, Last reward = 0.0, Steps = 17
# Episode 131: Reward sum = 1.28, Last reward = 0.0, Steps = 17
# Episode 132: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 133: Reward sum = 1.50, Last reward = 0.0, Steps = 15
# Episode 134: Reward sum = 0.88, Last reward = 0.0, Steps = 15
# Episode 135: Reward sum = 2.14, Last reward = 0.0, Steps = 14
# Episode 136: Reward sum = 1.58, Last reward = 0.0, Steps = 16
# Episode 137: Reward sum = 0.72, Last reward = 0.0, Steps = 15
# Episode 138: Reward sum = 2.32, Last reward = 0.0, Steps = 17
# Episode 139: Reward sum = 1.51, Last reward = 0.0, Steps = 17
# Episode 140: Reward sum = 1.88, Last reward = 0.0, Steps = 17
# Episode 141: Reward sum = 1.63, Last reward = 0.0, Steps = 17
# Episode 142: Reward sum = 1.42, Last reward = 0.0, Steps = 17
# Episode 143: Reward sum = 1.08, Last reward = 0.0, Steps = 14
# Episode 144: Reward sum = 1.03, Last reward = 0.0, Steps = 15
# Episode 145: Reward sum = 2.79, Last reward = 0.0, Steps = 16
# Episode 146: Reward sum = 1.25, Last reward = 0.0, Steps = 16
# Episode 147: Reward sum = 1.79, Last reward = 0.0, Steps = 17
# Episode 148: Reward sum = 2.13, Last reward = 0.0, Steps = 15
# Episode 149: Reward sum = 1.33, Last reward = 0.0, Steps = 15
# Episode 150: Reward sum = 71.29, Last reward = 69.0, Steps = 17
# Episode 151: Reward sum = 2.24, Last reward = 0.0, Steps = 15
# Episode 152: Reward sum = 100.52, Last reward = 99.0, Steps = 16
# Episode 153: Reward sum = 3.26, Last reward = 0.0, Steps = 16
# Episode 154: Reward sum = 1.80, Last reward = 0.0, Steps = 17
# Episode 155: Reward sum = 1.80, Last reward = 1.0, Steps = 8
# Episode 156: Reward sum = 1.50, Last reward = 0.0, Steps = 16
# Episode 157: Reward sum = 1.22, Last reward = 0.0, Steps = 16
# Episode 158: Reward sum = 1.38, Last reward = 0.0, Steps = 15
# Episode 159: Reward sum = 1.49, Last reward = 0.0, Steps = 16
# Episode 160: Reward sum = 1.14, Last reward = 0.0, Steps = 14
# Episode 161: Reward sum = 3.31, Last reward = 0.0, Steps = 17
# Episode 162: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 163: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 164: Reward sum = 1.79, Last reward = 0.0, Steps = 15
# Episode 165: Reward sum = 1.33, Last reward = 0.0, Steps = 17
# Episode 166: Reward sum = 3.87, Last reward = 0.0, Steps = 16
# Episode 167: Reward sum = 94.64, Last reward = 93.0, Steps = 18
# Episode 168: Reward sum = -37.37, Last reward = -39.0, Steps = 15
# Episode 169: Reward sum = 2.35, Last reward = 0.0, Steps = 15
# Episode 170: Reward sum = 2.80, Last reward = 0.0, Steps = 17
# Episode 171: Reward sum = 1.26, Last reward = 0.0, Steps = 17
# Episode 172: Reward sum = 2.73, Last reward = 0.0, Steps = 16
# Episode 173: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 174: Reward sum = 2.54, Last reward = 0.0, Steps = 18
# Episode 175: Reward sum = 3.31, Last reward = 0.0, Steps = 16
# Episode 176: Reward sum = -6.38, Last reward = -8.0, Steps = 15
# Episode 177: Reward sum = 0.78, Last reward = 0.0, Steps = 16
# Episode 178: Reward sum = 1.52, Last reward = 0.0, Steps = 16
# Episode 179: Reward sum = 3.80, Last reward = 0.0, Steps = 16
# Episode 180: Reward sum = 1.19, Last reward = 0.0, Steps = 16
# Episode 181: Reward sum = 3.19, Last reward = 0.0, Steps = 16
# Episode 182: Reward sum = -18.57, Last reward = -20.0, Steps = 14
# Episode 183: Reward sum = 2.65, Last reward = 0.0, Steps = 17
# Episode 184: Reward sum = 0.88, Last reward = 0.0, Steps = 16
# Episode 185: Reward sum = 17.56, Last reward = 15.0, Steps = 16
# Episode 186: Reward sum = 1.80, Last reward = 0.0, Steps = 16
# Episode 187: Reward sum = 2.40, Last reward = 0.0, Steps = 15
# Episode 188: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 189: Reward sum = 2.48, Last reward = 0.0, Steps = 17
# Episode 190: Reward sum = 1.43, Last reward = 0.0, Steps = 18
# Episode 191: Reward sum = 1.49, Last reward = 0.0, Steps = 17
# Episode 192: Reward sum = -35.79, Last reward = -38.0, Steps = 16
# Episode 193: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 194: Reward sum = 1.22, Last reward = 0.0, Steps = 17
# Episode 195: Reward sum = 2.46, Last reward = 0.0, Steps = 15
# Episode 196: Reward sum = 1.49, Last reward = 0.0, Steps = 17
# Episode 197: Reward sum = 3.19, Last reward = 0.0, Steps = 14
# Episode 198: Reward sum = 3.47, Last reward = 0.0, Steps = 16
# Episode 199: Reward sum = 1.31, Last reward = 0.0, Steps = 17
# Episode 200: Reward sum = 1.98, Last reward = 0.0, Steps = 15
# Episode 201: Reward sum = -6.73, Last reward = -8.0, Steps = 15
# Episode 202: Reward sum = 1.43, Last reward = 0.0, Steps = 16
# Episode 203: Reward sum = 1.78, Last reward = 0.0, Steps = 17
# Episode 204: Reward sum = -0.37, Last reward = -2.0, Steps = 16
# Episode 205: Reward sum = 1.15, Last reward = 0.0, Steps = 15
# Episode 206: Reward sum = 1.81, Last reward = 0.0, Steps = 18
# Episode 207: Reward sum = 2.41, Last reward = 0.0, Steps = 17
# Episode 208: Reward sum = 2.13, Last reward = 0.0, Steps = 16
# Episode 209: Reward sum = -29.17, Last reward = -30.0, Steps = 16
# Episode 210: Reward sum = 1.86, Last reward = 0.0, Steps = 17
# Episode 211: Reward sum = 1.69, Last reward = 0.0, Steps = 16
# Episode 212: Reward sum = 2.56, Last reward = 0.0, Steps = 15
# Episode 213: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 214: Reward sum = 2.88, Last reward = 0.0, Steps = 18
# Episode 215: Reward sum = 1.10, Last reward = 0.0, Steps = 17
# Episode 216: Reward sum = -29.20, Last reward = -30.0, Steps = 15
# Episode 217: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 218: Reward sum = -28.51, Last reward = -30.0, Steps = 18
# Episode 219: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 220: Reward sum = 2.20, Last reward = 0.0, Steps = 17
# Episode 221: Reward sum = 2.01, Last reward = 0.0, Steps = 15
# Episode 222: Reward sum = 1.91, Last reward = 0.0, Steps = 15
# Episode 223: Reward sum = 1.66, Last reward = 0.0, Steps = 17
# Episode 224: Reward sum = 97.46, Last reward = 96.0, Steps = 16
# Episode 225: Reward sum = 0.99, Last reward = 0.0, Steps = 16
# Episode 226: Reward sum = 2.65, Last reward = 0.0, Steps = 18
# Episode 227: Reward sum = 1.25, Last reward = 0.0, Steps = 15
# Episode 228: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 229: Reward sum = 2.39, Last reward = 0.0, Steps = 18
# Episode 230: Reward sum = 17.16, Last reward = 15.0, Steps = 17
# Episode 231: Reward sum = 2.61, Last reward = 0.0, Steps = 17
# Episode 232: Reward sum = 1.51, Last reward = 0.0, Steps = 17
# Episode 233: Reward sum = 2.51, Last reward = 0.0, Steps = 15
# Episode 234: Reward sum = 2.71, Last reward = 0.0, Steps = 18
# Episode 235: Reward sum = 1.48, Last reward = 0.0, Steps = 16
# Episode 236: Reward sum = 0.66, Last reward = 0.0, Steps = 16
# Episode 237: Reward sum = 1.43, Last reward = 0.0, Steps = 16
# Episode 238: Reward sum = 1.04, Last reward = 0.0, Steps = 17
# Episode 239: Reward sum = 1.40, Last reward = 0.0, Steps = 15
# Episode 240: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 241: Reward sum = 0.69, Last reward = 0.0, Steps = 17
# Episode 242: Reward sum = 2.14, Last reward = 0.0, Steps = 16
# Episode 243: Reward sum = 1.99, Last reward = 0.0, Steps = 15
# Episode 244: Reward sum = 2.39, Last reward = 0.0, Steps = 17
# Episode 245: Reward sum = -11.91, Last reward = -14.0, Steps = 16
# Episode 246: Reward sum = 2.06, Last reward = 0.0, Steps = 17
# Episode 247: Reward sum = 2.00, Last reward = 0.0, Steps = 14
# Episode 248: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 249: Reward sum = 19.86, Last reward = 18.0, Steps = 16
# Episode 250: Reward sum = 1.46, Last reward = 0.0, Steps = 17
# Episode 251: Reward sum = -38.39, Last reward = -39.0, Steps = 16
# Episode 252: Reward sum = -14.64, Last reward = -17.0, Steps = 16
# Episode 253: Reward sum = 2.05, Last reward = 0.0, Steps = 18
# Episode 254: Reward sum = 3.62, Last reward = 0.0, Steps = 15
# Episode 255: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 256: Reward sum = 2.34, Last reward = 0.0, Steps = 16
# Episode 257: Reward sum = 1.62, Last reward = 0.0, Steps = 15
# Episode 258: Reward sum = 1.14, Last reward = 0.0, Steps = 17
# Episode 259: Reward sum = 1.36, Last reward = 0.0, Steps = 17
# Episode 260: Reward sum = -10.64, Last reward = -13.0, Steps = 17
# Episode 261: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 262: Reward sum = 2.88, Last reward = 0.0, Steps = 14
# Episode 263: Reward sum = 1.12, Last reward = 0.0, Steps = 17
# Episode 264: Reward sum = 2.24, Last reward = 0.0, Steps = 18
# Episode 265: Reward sum = -3.11, Last reward = -8.0, Steps = 16
# Episode 266: Reward sum = 0.67, Last reward = 0.0, Steps = 16
# Episode 267: Reward sum = 1.22, Last reward = 0.0, Steps = 16
# Episode 268: Reward sum = 1.90, Last reward = 0.0, Steps = 16
# Episode 269: Reward sum = 2.52, Last reward = 0.0, Steps = 15
# Episode 270: Reward sum = 1.93, Last reward = 0.0, Steps = 14
# Episode 271: Reward sum = 1.80, Last reward = 0.0, Steps = 17
# Episode 272: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 273: Reward sum = 1.38, Last reward = 0.0, Steps = 16
# Episode 274: Reward sum = 1.41, Last reward = 0.0, Steps = 17
# Episode 275: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 276: Reward sum = 1.56, Last reward = 0.0, Steps = 17
# Episode 277: Reward sum = 2.47, Last reward = 0.0, Steps = 17
# Episode 278: Reward sum = 0.88, Last reward = 0.0, Steps = 15
# Episode 279: Reward sum = 1.43, Last reward = 0.0, Steps = 15
# Episode 280: Reward sum = 1.31, Last reward = 0.0, Steps = 15
# Episode 281: Reward sum = 1.72, Last reward = 0.0, Steps = 17
# Episode 282: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 283: Reward sum = 1.77, Last reward = 0.0, Steps = 17
# Episode 284: Reward sum = -2.31, Last reward = -5.0, Steps = 16
# Episode 285: Reward sum = -13.13, Last reward = -14.0, Steps = 17
# Episode 286: Reward sum = -27.99, Last reward = -30.0, Steps = 15
# Episode 287: Reward sum = 3.49, Last reward = 0.0, Steps = 17
# Episode 288: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 289: Reward sum = 2.80, Last reward = 0.0, Steps = 16
# Episode 290: Reward sum = 1.03, Last reward = 0.0, Steps = 15
# Episode 291: Reward sum = 2.24, Last reward = 0.0, Steps = 16
# Episode 292: Reward sum = 0.80, Last reward = 0.0, Steps = 16
# Episode 293: Reward sum = 2.16, Last reward = 0.0, Steps = 16
# Episode 294: Reward sum = 2.40, Last reward = 0.0, Steps = 15
# Episode 295: Reward sum = 2.44, Last reward = 0.0, Steps = 18
# Episode 296: Reward sum = 2.45, Last reward = 0.0, Steps = 15
# Episode 297: Reward sum = 94.54, Last reward = 93.0, Steps = 17
# Episode 298: Reward sum = 2.07, Last reward = 0.0, Steps = 16
# Episode 299: Reward sum = 3.20, Last reward = 0.0, Steps = 17
# Episode 300: Reward sum = 1.14, Last reward = 0.0, Steps = 18
# Episode 301: Reward sum = 2.41, Last reward = 0.0, Steps = 16
# Episode 302: Reward sum = 1.43, Last reward = 0.0, Steps = 16
# Episode 303: Reward sum = 1.62, Last reward = 0.0, Steps = 17
# Episode 304: Reward sum = 3.57, Last reward = 0.0, Steps = 16
# Episode 305: Reward sum = 0.90, Last reward = 0.0, Steps = 15
# Episode 306: Reward sum = 1.73, Last reward = 0.0, Steps = 18
# Episode 307: Reward sum = 91.29, Last reward = 90.0, Steps = 16
# Episode 308: Reward sum = 92.06, Last reward = 90.0, Steps = 18
# Episode 309: Reward sum = 2.01, Last reward = 0.0, Steps = 16
# Episode 310: Reward sum = 2.74, Last reward = 0.0, Steps = 16
# Episode 311: Reward sum = 2.79, Last reward = 0.0, Steps = 14
# Episode 312: Reward sum = 53.18, Last reward = 51.0, Steps = 14
# Episode 313: Reward sum = 0.36, Last reward = 0.0, Steps = 16
# Episode 314: Reward sum = 91.05, Last reward = 90.0, Steps = 18
# Episode 315: Reward sum = -8.72, Last reward = -10.0, Steps = 18
# Episode 316: Reward sum = 0.79, Last reward = 0.0, Steps = 18
# Episode 317: Reward sum = -9.49, Last reward = -11.0, Steps = 17
# Episode 318: Reward sum = 1.89, Last reward = 0.0, Steps = 15
# Episode 319: Reward sum = 4.00, Last reward = 0.0, Steps = 17
# Episode 320: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 321: Reward sum = 1.14, Last reward = 0.0, Steps = 17
# Episode 322: Reward sum = 1.73, Last reward = 0.0, Steps = 15
# Episode 323: Reward sum = 2.61, Last reward = 0.0, Steps = 17
# Episode 324: Reward sum = 1.27, Last reward = 0.0, Steps = 16
# Episode 325: Reward sum = 2.49, Last reward = 0.0, Steps = 15
# Episode 326: Reward sum = 1.65, Last reward = 0.0, Steps = 16
# Episode 327: Reward sum = 1.71, Last reward = 0.0, Steps = 16
# Episode 328: Reward sum = 1.45, Last reward = 0.0, Steps = 15
# Episode 329: Reward sum = 3.22, Last reward = 0.0, Steps = 15
# Episode 330: Reward sum = 2.24, Last reward = 0.0, Steps = 17
# Episode 331: Reward sum = 3.11, Last reward = 0.0, Steps = 16
# Episode 332: Reward sum = 1.63, Last reward = 0.0, Steps = 15
# Episode 333: Reward sum = 104.13, Last reward = 102.0, Steps = 17
# Episode 334: Reward sum = 2.22, Last reward = 0.0, Steps = 17
# Episode 335: Reward sum = 2.38, Last reward = 0.0, Steps = 17
# Episode 336: Reward sum = 0.49, Last reward = 0.0, Steps = 17
# Episode 337: Reward sum = 2.46, Last reward = 0.0, Steps = 16
# Episode 338: Reward sum = 3.11, Last reward = 0.0, Steps = 15
# Episode 339: Reward sum = -6.42, Last reward = -8.0, Steps = 18
# Episode 340: Reward sum = -33.78, Last reward = -35.0, Steps = 19
# Episode 341: Reward sum = 1.74, Last reward = 0.0, Steps = 17
# Episode 342: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 343: Reward sum = 1.20, Last reward = 0.0, Steps = 15
# Episode 344: Reward sum = 1.69, Last reward = 0.0, Steps = 14
# Episode 345: Reward sum = 2.86, Last reward = 0.0, Steps = 16
# Episode 346: Reward sum = 1.56, Last reward = 0.0, Steps = 16
# Episode 347: Reward sum = 0.92, Last reward = 0.0, Steps = 15
# Episode 348: Reward sum = 0.93, Last reward = 0.0, Steps = 16
# Episode 349: Reward sum = -2.53, Last reward = -5.0, Steps = 16
# Episode 350: Reward sum = 0.66, Last reward = 0.0, Steps = 15
# Episode 351: Reward sum = 75.41, Last reward = 72.0, Steps = 15
# Episode 352: Reward sum = 2.88, Last reward = 0.0, Steps = 16
# Episode 353: Reward sum = 0.54, Last reward = 0.0, Steps = 16
# Episode 354: Reward sum = 1.14, Last reward = 0.0, Steps = 17
# Episode 355: Reward sum = 2.72, Last reward = 0.0, Steps = 16
# Episode 356: Reward sum = 1.34, Last reward = 0.0, Steps = 14
# Episode 357: Reward sum = 100.40, Last reward = 90.0, Steps = 17
# Episode 358: Reward sum = 3.20, Last reward = 0.0, Steps = 16
# Episode 359: Reward sum = 3.35, Last reward = 0.0, Steps = 18
# Episode 360: Reward sum = 2.47, Last reward = 0.0, Steps = 16
# Episode 361: Reward sum = 1.93, Last reward = 0.0, Steps = 15
# Episode 362: Reward sum = 2.03, Last reward = 0.0, Steps = 15
# Episode 363: Reward sum = 1.30, Last reward = 0.0, Steps = 16
# Episode 364: Reward sum = 1.95, Last reward = 0.0, Steps = 15
# Episode 365: Reward sum = 2.23, Last reward = 0.0, Steps = 15
# Episode 366: Reward sum = 1.94, Last reward = 0.0, Steps = 19
# Episode 367: Reward sum = -33.12, Last reward = -36.0, Steps = 15
# Episode 368: Reward sum = 91.40, Last reward = 90.0, Steps = 19
# Episode 369: Reward sum = 61.58, Last reward = 60.0, Steps = 15
# Episode 370: Reward sum = 1.90, Last reward = 0.0, Steps = 16
# Episode 371: Reward sum = -28.48, Last reward = -30.0, Steps = 15
# Episode 372: Reward sum = 1.38, Last reward = 0.0, Steps = 16
# Episode 373: Reward sum = 91.88, Last reward = 90.0, Steps = 17
# Episode 374: Reward sum = 1.01, Last reward = 0.0, Steps = 15
# Episode 375: Reward sum = 1.67, Last reward = 0.0, Steps = 14
# Episode 376: Reward sum = 2.41, Last reward = 0.0, Steps = 15
# Episode 377: Reward sum = 1.62, Last reward = 0.0, Steps = 14
# Episode 378: Reward sum = 1.50, Last reward = 0.0, Steps = 17
# Episode 379: Reward sum = 0.65, Last reward = 0.0, Steps = 16
# Episode 380: Reward sum = 17.54, Last reward = 0.0, Steps = 14
# Episode 381: Reward sum = 1.92, Last reward = 0.0, Steps = 15
# Episode 382: Reward sum = -32.15, Last reward = -36.0, Steps = 16
# Episode 383: Reward sum = 1.78, Last reward = 0.0, Steps = 15
# Episode 384: Reward sum = 0.35, Last reward = 0.0, Steps = 17
# Episode 385: Reward sum = 1.79, Last reward = 0.0, Steps = 16
# Episode 386: Reward sum = -27.30, Last reward = -30.0, Steps = 17
# Episode 387: Reward sum = 1.13, Last reward = 0.0, Steps = 18
# Episode 388: Reward sum = 1.98, Last reward = 0.0, Steps = 17
# Episode 389: Reward sum = 62.39, Last reward = 60.0, Steps = 17
# Episode 390: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 391: Reward sum = 2.14, Last reward = 0.0, Steps = 17
# Episode 392: Reward sum = 1.42, Last reward = 0.0, Steps = 15
# Episode 393: Reward sum = 1.55, Last reward = 0.0, Steps = 17
# Episode 394: Reward sum = 1.84, Last reward = 0.0, Steps = 15
# Episode 395: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 396: Reward sum = 1.82, Last reward = 0.0, Steps = 16
# Episode 397: Reward sum = 7.15, Last reward = 6.0, Steps = 6
# Episode 398: Reward sum = 1.54, Last reward = 0.0, Steps = 17
# Episode 399: Reward sum = 62.26, Last reward = 60.0, Steps = 16
# Episode 400: Reward sum = 0.98, Last reward = 0.0, Steps = 14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 7
#       5 logger = Logger()
#       6 agent = ActorCritic(env, policy, value_network, logger)
# ----> 7 agent.train(2000)
#
# Cell In[107], line 192, in ActorCritic.train(self, episodes, save_freq)
#     190 def train(self, episodes=1, save_freq=20):
#     191     for episode in range(episodes):
# --> 192         episode_reward, last_reward, steps = self.run_episode()
#     193         self.training_rewards_per_episode_sum.append(episode_reward)
#     194         self.training_rewards_per_episode_last_one.append(last_reward)
#
# Cell In[107], line 149, in ActorCritic.run_episode(self, log_transition)
#     147 last_reward = 0
#     148 while not done:
# --> 149     action = self.sample_action(state)
#     150     next_state, reward, done, truncated, _ = self.env.step(action)
#     151     next_state = self.process_state(next_state)
#
# Cell In[107], line 92, in ActorCritic.sample_action(self, state)
#      90 action_probs /= total_prob
#      91 #action_probs /= np.sum(action_probs)
# ---> 92 action = np.random.choice(len(action_probs), p=action_probs)
#      93 return action
#
# File numpy/random/mtrand.pyx:994, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN

# %%
plot_rewards(logger.log_dir, agent.training_rewards_per_episode_last_one, title="Training Rewards", save_fig=True)

# %%
agent_eval = ActorCritic(env, policy, value_network, logger)
agent_eval.evaluate(400)
# Out:
# Episode 1: Reward sum = 2.65, Last reward = 0.0, Steps = 15
# Episode 2: Reward sum = -8.62, Last reward = -11.0, Steps = 14
# Episode 3: Reward sum = 90.95, Last reward = 90.0, Steps = 18
# Episode 4: Reward sum = 1.57, Last reward = 0.0, Steps = 15
# Episode 5: Reward sum = 16.92, Last reward = 15.0, Steps = 10
# Episode 6: Reward sum = 2.83, Last reward = 0.0, Steps = 17
# Episode 7: Reward sum = 96.50, Last reward = 93.0, Steps = 16
# Episode 8: Reward sum = 1.85, Last reward = 0.0, Steps = 15
# Episode 9: Reward sum = 2.28, Last reward = 0.0, Steps = 16
# Episode 10: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 11: Reward sum = 8.08, Last reward = 6.0, Steps = 12
# Episode 12: Reward sum = 11.94, Last reward = 10.0, Steps = 16
# Episode 13: Reward sum = 17.97, Last reward = 15.0, Steps = 15
# Episode 14: Reward sum = 17.50, Last reward = 15.0, Steps = 16
# Episode 15: Reward sum = 19.90, Last reward = 18.0, Steps = 16
# Episode 16: Reward sum = 1.98, Last reward = 0.0, Steps = 15
# Episode 17: Reward sum = 1.51, Last reward = 0.0, Steps = 15
# Episode 18: Reward sum = -25.33, Last reward = -30.0, Steps = 17
# Episode 19: Reward sum = 19.21, Last reward = 18.0, Steps = 8
# Episode 20: Reward sum = 2.89, Last reward = 0.0, Steps = 16
# Episode 21: Reward sum = 2.64, Last reward = 0.0, Steps = 14
# Episode 22: Reward sum = 2.53, Last reward = 0.0, Steps = 15
# Episode 23: Reward sum = 2.34, Last reward = 0.0, Steps = 16
# Episode 24: Reward sum = 4.50, Last reward = 0.0, Steps = 16
# Episode 25: Reward sum = 2.17, Last reward = 0.0, Steps = 15
# Episode 26: Reward sum = 1.84, Last reward = 0.0, Steps = 16
# Episode 27: Reward sum = -21.61, Last reward = -24.0, Steps = 16
# Episode 28: Reward sum = 2.78, Last reward = 0.0, Steps = 16
# Episode 29: Reward sum = 3.35, Last reward = 0.0, Steps = 17
# Episode 30: Reward sum = 94.03, Last reward = 90.0, Steps = 17
# Episode 31: Reward sum = 2.05, Last reward = 0.0, Steps = 16
# Episode 32: Reward sum = 2.25, Last reward = 0.0, Steps = 15
# Episode 33: Reward sum = 17.05, Last reward = 15.0, Steps = 16
# Episode 34: Reward sum = 1.97, Last reward = 0.0, Steps = 17
# Episode 35: Reward sum = 8.19, Last reward = 6.0, Steps = 15
# Episode 36: Reward sum = 26.82, Last reward = 24.0, Steps = 15
# Episode 37: Reward sum = 19.84, Last reward = 18.0, Steps = 14
# Episode 38: Reward sum = 94.65, Last reward = 90.0, Steps = 13
# Episode 39: Reward sum = -10.25, Last reward = -14.0, Steps = 16
# Episode 40: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 41: Reward sum = 3.04, Last reward = 0.0, Steps = 16
# Episode 42: Reward sum = 61.21, Last reward = 60.0, Steps = 17
# Episode 43: Reward sum = 19.98, Last reward = 18.0, Steps = 18
# Episode 44: Reward sum = 27.36, Last reward = 24.0, Steps = 18
# Episode 45: Reward sum = -3.98, Last reward = -5.0, Steps = 15
# Episode 46: Reward sum = 2.09, Last reward = 0.0, Steps = 15
# Episode 47: Reward sum = 29.60, Last reward = 27.0, Steps = 15
# Episode 48: Reward sum = 16.27, Last reward = 15.0, Steps = 17
# Episode 49: Reward sum = 3.05, Last reward = 0.0, Steps = 16
# Episode 50: Reward sum = 12.50, Last reward = 10.0, Steps = 16
# Episode 51: Reward sum = 16.01, Last reward = 15.0, Steps = 8
# Episode 52: Reward sum = 16.80, Last reward = 15.0, Steps = 16
# Episode 53: Reward sum = 1.72, Last reward = 0.0, Steps = 19
# Episode 54: Reward sum = 19.72, Last reward = 18.0, Steps = 16
# Episode 55: Reward sum = 19.40, Last reward = 18.0, Steps = 15
# Episode 56: Reward sum = 17.52, Last reward = 15.0, Steps = 16
# Episode 57: Reward sum = -1.01, Last reward = -2.0, Steps = 15
# Episode 58: Reward sum = 17.30, Last reward = 15.0, Steps = 16
# Episode 59: Reward sum = 1.45, Last reward = 0.0, Steps = 17
# Episode 60: Reward sum = 17.53, Last reward = 15.0, Steps = 15
# Episode 61: Reward sum = 21.14, Last reward = 18.0, Steps = 17
# Episode 62: Reward sum = 26.89, Last reward = 24.0, Steps = 16
# Episode 63: Reward sum = 101.81, Last reward = 99.0, Steps = 18
# Episode 64: Reward sum = 1.39, Last reward = 0.0, Steps = 16
# Episode 65: Reward sum = 3.88, Last reward = 0.0, Steps = 17
# Episode 66: Reward sum = 3.54, Last reward = 0.0, Steps = 16
# Episode 67: Reward sum = 2.42, Last reward = 0.0, Steps = 15
# Episode 68: Reward sum = 16.87, Last reward = 15.0, Steps = 10
# Episode 69: Reward sum = 18.10, Last reward = 15.0, Steps = 17
# Episode 70: Reward sum = 91.55, Last reward = 90.0, Steps = 11
# Episode 71: Reward sum = 3.25, Last reward = 0.0, Steps = 17
# Episode 72: Reward sum = 1.17, Last reward = 0.0, Steps = 17
# Episode 73: Reward sum = 93.80, Last reward = 93.0, Steps = 18
# Episode 74: Reward sum = -3.38, Last reward = -5.0, Steps = 18
# Episode 75: Reward sum = 93.89, Last reward = 93.0, Steps = 15
# Episode 76: Reward sum = 14.20, Last reward = 13.0, Steps = 17
# Episode 77: Reward sum = 1.67, Last reward = 0.0, Steps = 17
# Episode 78: Reward sum = 1.69, Last reward = 0.0, Steps = 15
# Episode 79: Reward sum = 16.68, Last reward = 15.0, Steps = 17
# Episode 80: Reward sum = 91.00, Last reward = 90.0, Steps = 13
# Episode 81: Reward sum = 17.08, Last reward = 15.0, Steps = 17
# Episode 82: Reward sum = 2.47, Last reward = 0.0, Steps = 16
# Episode 83: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 84: Reward sum = 1.59, Last reward = 0.0, Steps = 18
# Episode 85: Reward sum = 11.38, Last reward = 10.0, Steps = 17
# Episode 86: Reward sum = -26.39, Last reward = -29.0, Steps = 14
# Episode 87: Reward sum = 185.98, Last reward = 183.0, Steps = 17
# Episode 88: Reward sum = 20.92, Last reward = 18.0, Steps = 15
# Episode 89: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 90: Reward sum = 62.77, Last reward = 60.0, Steps = 15
# Episode 91: Reward sum = 118.55, Last reward = 117.0, Steps = 17
# Episode 92: Reward sum = 1.82, Last reward = 0.0, Steps = 15
# Episode 93: Reward sum = -3.33, Last reward = -5.0, Steps = 10
# Episode 94: Reward sum = 29.35, Last reward = 27.0, Steps = 17
# Episode 95: Reward sum = 18.10, Last reward = 15.0, Steps = 16
# Episode 96: Reward sum = 0.91, Last reward = 0.0, Steps = 16
# Episode 97: Reward sum = 2.75, Last reward = 0.0, Steps = 18
# Episode 98: Reward sum = 101.32, Last reward = 99.0, Steps = 16
# Episode 99: Reward sum = 95.37, Last reward = 93.0, Steps = 17
# Episode 100: Reward sum = 3.00, Last reward = 0.0, Steps = 15
# Episode 101: Reward sum = 103.53, Last reward = 99.0, Steps = 17
# Episode 102: Reward sum = 92.12, Last reward = 90.0, Steps = 15
# Episode 103: Reward sum = 26.12, Last reward = 24.0, Steps = 17
# Episode 104: Reward sum = 1.70, Last reward = 0.0, Steps = 17
# Episode 105: Reward sum = 2.88, Last reward = 0.0, Steps = 17
# Episode 106: Reward sum = 1.99, Last reward = 0.0, Steps = 16
# Episode 107: Reward sum = 2.54, Last reward = 0.0, Steps = 16
# Episode 108: Reward sum = 18.83, Last reward = 18.0, Steps = 18
# Episode 109: Reward sum = 17.16, Last reward = 15.0, Steps = 17
# Episode 110: Reward sum = 2.33, Last reward = 0.0, Steps = 17
# Episode 111: Reward sum = 101.65, Last reward = 99.0, Steps = 17
# Episode 112: Reward sum = 0.65, Last reward = 0.0, Steps = 17
# Episode 113: Reward sum = -18.63, Last reward = -20.0, Steps = 17
# Episode 114: Reward sum = 24.01, Last reward = 21.0, Steps = 17
# Episode 115: Reward sum = 184.76, Last reward = 183.0, Steps = 18
# Episode 116: Reward sum = 2.01, Last reward = 0.0, Steps = 17
# Episode 117: Reward sum = 3.62, Last reward = 0.0, Steps = 16
# Episode 118: Reward sum = 182.45, Last reward = 180.0, Steps = 18
# Episode 119: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 120: Reward sum = 18.33, Last reward = 15.0, Steps = 17
# Episode 121: Reward sum = -3.40, Last reward = -5.0, Steps = 16
# Episode 122: Reward sum = 20.35, Last reward = 18.0, Steps = 16
# Episode 123: Reward sum = 2.32, Last reward = 0.0, Steps = 16
# Episode 124: Reward sum = 3.04, Last reward = 0.0, Steps = 18
# Episode 125: Reward sum = 6.68, Last reward = 6.0, Steps = 11
# Episode 126: Reward sum = 3.50, Last reward = 0.0, Steps = 16
# Episode 127: Reward sum = 1.35, Last reward = 0.0, Steps = 18
# Episode 128: Reward sum = 18.51, Last reward = 15.0, Steps = 18
# Episode 129: Reward sum = 92.51, Last reward = 90.0, Steps = 18
# Episode 130: Reward sum = -26.29, Last reward = -27.0, Steps = 16
# Episode 131: Reward sum = 2.55, Last reward = 1.0, Steps = 15
# Episode 132: Reward sum = 3.29, Last reward = 0.0, Steps = 16
# Episode 133: Reward sum = 16.90, Last reward = 15.0, Steps = 17
# Episode 134: Reward sum = 14.49, Last reward = 13.0, Steps = 16
# Episode 135: Reward sum = 3.30, Last reward = 0.0, Steps = 16
# Episode 136: Reward sum = 2.10, Last reward = 0.0, Steps = 17
# Episode 137: Reward sum = 23.37, Last reward = 21.0, Steps = 16
# Episode 138: Reward sum = 2.19, Last reward = 0.0, Steps = 16
# Episode 139: Reward sum = 3.36, Last reward = 0.0, Steps = 17
# Episode 140: Reward sum = 17.51, Last reward = 15.0, Steps = 16
# Episode 141: Reward sum = 13.58, Last reward = 11.0, Steps = 17
# Episode 142: Reward sum = 7.25, Last reward = 6.0, Steps = 11
# Episode 143: Reward sum = 102.25, Last reward = 99.0, Steps = 18
# Episode 144: Reward sum = 19.80, Last reward = 18.0, Steps = 17
# Episode 145: Reward sum = 2.66, Last reward = 1.0, Steps = 13
# Episode 146: Reward sum = 1.46, Last reward = 0.0, Steps = 15
# Episode 147: Reward sum = -6.04, Last reward = -8.0, Steps = 16
# Episode 148: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 149: Reward sum = 0.90, Last reward = 0.0, Steps = 16
# Episode 150: Reward sum = 1.95, Last reward = 0.0, Steps = 15
# Episode 151: Reward sum = 2.71, Last reward = 0.0, Steps = 17
# Episode 152: Reward sum = 2.96, Last reward = 0.0, Steps = 19
# Episode 153: Reward sum = 1.66, Last reward = 0.0, Steps = 16
# Episode 154: Reward sum = 1.34, Last reward = 0.0, Steps = 16
# Episode 155: Reward sum = 92.21, Last reward = 90.0, Steps = 17
# Episode 156: Reward sum = 16.86, Last reward = 15.0, Steps = 18
# Episode 157: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 158: Reward sum = 16.25, Last reward = 15.0, Steps = 11
# Episode 159: Reward sum = 3.30, Last reward = 0.0, Steps = 16
# Episode 160: Reward sum = 1.00, Last reward = 0.0, Steps = 16
# Episode 161: Reward sum = 1.83, Last reward = 0.0, Steps = 17
# Episode 162: Reward sum = -2.64, Last reward = -5.0, Steps = 13
# Episode 163: Reward sum = 64.81, Last reward = 63.0, Steps = 16
# Episode 164: Reward sum = 2.59, Last reward = 0.0, Steps = 14
# Episode 165: Reward sum = 1.18, Last reward = 0.0, Steps = 16
# Episode 166: Reward sum = 17.05, Last reward = 15.0, Steps = 16
# Episode 167: Reward sum = 1.68, Last reward = 0.0, Steps = 17
# Episode 168: Reward sum = 15.22, Last reward = 13.0, Steps = 15
# Episode 169: Reward sum = 2.21, Last reward = 0.0, Steps = 15
# Episode 170: Reward sum = 26.20, Last reward = 24.0, Steps = 17
# Episode 171: Reward sum = 16.62, Last reward = 15.0, Steps = 10
# Episode 172: Reward sum = 17.73, Last reward = 15.0, Steps = 18
# Episode 173: Reward sum = 2.57, Last reward = 0.0, Steps = 15
# Episode 174: Reward sum = 94.15, Last reward = 90.0, Steps = 16
# Episode 175: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 176: Reward sum = 17.65, Last reward = 15.0, Steps = 16
# Episode 177: Reward sum = 3.59, Last reward = 0.0, Steps = 16
# Episode 178: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 179: Reward sum = 20.64, Last reward = 18.0, Steps = 17
# Episode 180: Reward sum = 1.70, Last reward = 0.0, Steps = 16
# Episode 181: Reward sum = 16.56, Last reward = 15.0, Steps = 14
# Episode 182: Reward sum = 2.82, Last reward = 0.0, Steps = 15
# Episode 183: Reward sum = 2.37, Last reward = 0.0, Steps = 15
# Episode 184: Reward sum = 23.28, Last reward = 21.0, Steps = 17
# Episode 185: Reward sum = 1.90, Last reward = 0.0, Steps = 16
# Episode 186: Reward sum = 3.52, Last reward = 0.0, Steps = 15
# Episode 187: Reward sum = 97.98, Last reward = 90.0, Steps = 17
# Episode 188: Reward sum = 27.13, Last reward = 24.0, Steps = 17
# Episode 189: Reward sum = -2.74, Last reward = -5.0, Steps = 18
# Episode 190: Reward sum = -25.91, Last reward = -29.0, Steps = 16
# Episode 191: Reward sum = 1.85, Last reward = 0.0, Steps = 17
# Episode 192: Reward sum = 16.18, Last reward = 15.0, Steps = 18
# Episode 193: Reward sum = 92.60, Last reward = 90.0, Steps = 16
# Episode 194: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 195: Reward sum = 1.82, Last reward = 0.0, Steps = 16
# Episode 196: Reward sum = 2.93, Last reward = 0.0, Steps = 17
# Episode 197: Reward sum = 2.42, Last reward = 0.0, Steps = 15
# Episode 198: Reward sum = 0.68, Last reward = 0.0, Steps = 14
# Episode 199: Reward sum = 25.73, Last reward = 24.0, Steps = 17
# Episode 200: Reward sum = 91.51, Last reward = 90.0, Steps = 16
# Episode 201: Reward sum = 92.88, Last reward = 90.0, Steps = 18
# Episode 202: Reward sum = 98.89, Last reward = 96.0, Steps = 16
# Episode 203: Reward sum = 3.05, Last reward = 0.0, Steps = 16
# Episode 204: Reward sum = 1.17, Last reward = 0.0, Steps = 16
# Episode 205: Reward sum = 3.48, Last reward = 0.0, Steps = 16
# Episode 206: Reward sum = 2.09, Last reward = 0.0, Steps = 16
# Episode 207: Reward sum = 1.39, Last reward = 0.0, Steps = 14
# Episode 208: Reward sum = 1.82, Last reward = 0.0, Steps = 17
# Episode 209: Reward sum = 186.12, Last reward = 183.0, Steps = 17
# Episode 210: Reward sum = 1.50, Last reward = 0.0, Steps = 18
# Episode 211: Reward sum = 101.80, Last reward = 99.0, Steps = 16
# Episode 212: Reward sum = 3.52, Last reward = 0.0, Steps = 17
# Episode 213: Reward sum = -0.71, Last reward = -5.0, Steps = 17
# Episode 214: Reward sum = 93.80, Last reward = 93.0, Steps = 16
# Episode 215: Reward sum = 3.09, Last reward = 0.0, Steps = 15
# Episode 216: Reward sum = 2.26, Last reward = 0.0, Steps = 16
# Episode 217: Reward sum = 1.77, Last reward = 0.0, Steps = 16
# Episode 218: Reward sum = 20.66, Last reward = 18.0, Steps = 17
# Episode 219: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 220: Reward sum = 1.39, Last reward = 0.0, Steps = 16
# Episode 221: Reward sum = -3.66, Last reward = -5.0, Steps = 16
# Episode 222: Reward sum = 2.92, Last reward = 0.0, Steps = 17
# Episode 223: Reward sum = 93.56, Last reward = 90.0, Steps = 18
# Episode 224: Reward sum = 8.40, Last reward = 6.0, Steps = 14
# Episode 225: Reward sum = 16.63, Last reward = 15.0, Steps = 17
# Episode 226: Reward sum = 2.17, Last reward = 0.0, Steps = 16
# Episode 227: Reward sum = 17.08, Last reward = 15.0, Steps = 17
# Episode 228: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 229: Reward sum = 176.54, Last reward = 174.0, Steps = 14
# Episode 230: Reward sum = 11.75, Last reward = 10.0, Steps = 19
# Episode 231: Reward sum = 1.19, Last reward = 0.0, Steps = 15
# Episode 232: Reward sum = 2.84, Last reward = 0.0, Steps = 16
# Episode 233: Reward sum = 1.99, Last reward = 0.0, Steps = 15
# Episode 234: Reward sum = 1.96, Last reward = 0.0, Steps = 15
# Episode 235: Reward sum = 91.80, Last reward = 90.0, Steps = 16
# Episode 236: Reward sum = 1.75, Last reward = 0.0, Steps = 17
# Episode 237: Reward sum = 1.69, Last reward = 0.0, Steps = 15
# Episode 238: Reward sum = 1.92, Last reward = 0.0, Steps = 15
# Episode 239: Reward sum = 2.02, Last reward = 0.0, Steps = 16
# Episode 240: Reward sum = 1.45, Last reward = 0.0, Steps = 16
# Episode 241: Reward sum = 27.00, Last reward = 24.0, Steps = 16
# Episode 242: Reward sum = 62.08, Last reward = 60.0, Steps = 17
# Episode 243: Reward sum = 19.82, Last reward = 18.0, Steps = 10
# Episode 244: Reward sum = 17.48, Last reward = 15.0, Steps = 16
# Episode 245: Reward sum = 19.21, Last reward = 18.0, Steps = 13
# Episode 246: Reward sum = 2.67, Last reward = 0.0, Steps = 16
# Episode 247: Reward sum = 94.98, Last reward = 93.0, Steps = 17
# Episode 248: Reward sum = 17.22, Last reward = 15.0, Steps = 15
# Episode 249: Reward sum = 3.80, Last reward = 0.0, Steps = 16
# Episode 250: Reward sum = 1.92, Last reward = 0.0, Steps = 17
# Episode 251: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 252: Reward sum = 3.63, Last reward = 0.0, Steps = 17
# Episode 253: Reward sum = 104.65, Last reward = 102.0, Steps = 16
# Episode 254: Reward sum = 104.76, Last reward = 102.0, Steps = 17
# Episode 255: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 256: Reward sum = 3.33, Last reward = 0.0, Steps = 17
# Episode 257: Reward sum = 94.25, Last reward = 93.0, Steps = 17
# Episode 258: Reward sum = 91.49, Last reward = 90.0, Steps = 13
# Episode 259: Reward sum = 19.12, Last reward = 16.0, Steps = 15
# Episode 260: Reward sum = 3.84, Last reward = 0.0, Steps = 17
# Episode 261: Reward sum = 4.20, Last reward = 0.0, Steps = 16
# Episode 262: Reward sum = -1.80, Last reward = -5.0, Steps = 17
# Episode 263: Reward sum = 2.14, Last reward = 0.0, Steps = 17
# Episode 264: Reward sum = 1.18, Last reward = 0.0, Steps = 18
# Episode 265: Reward sum = 41.90, Last reward = 39.0, Steps = 15
# Episode 266: Reward sum = 2.35, Last reward = 0.0, Steps = 17
# Episode 267: Reward sum = 2.39, Last reward = 0.0, Steps = 16
# Episode 268: Reward sum = 12.28, Last reward = 10.0, Steps = 17
# Episode 269: Reward sum = 2.87, Last reward = 0.0, Steps = 15
# Episode 270: Reward sum = 2.26, Last reward = 0.0, Steps = 18
# Episode 271: Reward sum = 2.55, Last reward = 0.0, Steps = 16
# Episode 272: Reward sum = 17.03, Last reward = 15.0, Steps = 12
# Episode 273: Reward sum = 26.37, Last reward = 24.0, Steps = 15
# Episode 274: Reward sum = 2.52, Last reward = 0.0, Steps = 15
# Episode 275: Reward sum = 102.44, Last reward = 99.0, Steps = 16
# Episode 276: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 277: Reward sum = 1.37, Last reward = 0.0, Steps = 15
# Episode 278: Reward sum = -5.04, Last reward = -8.0, Steps = 15
# Episode 279: Reward sum = 62.42, Last reward = 60.0, Steps = 18
# Episode 280: Reward sum = 2.75, Last reward = 0.0, Steps = 16
# Episode 281: Reward sum = 19.97, Last reward = 18.0, Steps = 15
# Episode 282: Reward sum = 16.65, Last reward = 15.0, Steps = 16
# Episode 283: Reward sum = 1.51, Last reward = 0.0, Steps = 16
# Episode 284: Reward sum = 20.01, Last reward = 18.0, Steps = 13
# Episode 285: Reward sum = 2.97, Last reward = 0.0, Steps = 15
# Episode 286: Reward sum = -27.76, Last reward = -30.0, Steps = 15
# Episode 287: Reward sum = 61.90, Last reward = 60.0, Steps = 17
# Episode 288: Reward sum = 2.66, Last reward = 0.0, Steps = 15
# Episode 289: Reward sum = 62.06, Last reward = 60.0, Steps = 18
# Episode 290: Reward sum = 3.15, Last reward = 0.0, Steps = 17
# Episode 291: Reward sum = 3.17, Last reward = 0.0, Steps = 16
# Episode 292: Reward sum = 3.15, Last reward = 0.0, Steps = 16
# Episode 293: Reward sum = 17.96, Last reward = 15.0, Steps = 15
# Episode 294: Reward sum = -27.71, Last reward = -30.0, Steps = 18
# Episode 295: Reward sum = 2.27, Last reward = 0.0, Steps = 17
# Episode 296: Reward sum = 16.90, Last reward = 15.0, Steps = 16
# Episode 297: Reward sum = 3.35, Last reward = 0.0, Steps = 16
# Episode 298: Reward sum = 17.01, Last reward = 15.0, Steps = 16
# Episode 299: Reward sum = 2.44, Last reward = 0.0, Steps = 17
# Episode 300: Reward sum = -6.09, Last reward = -8.0, Steps = 18
# Episode 301: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 302: Reward sum = 1.08, Last reward = 0.0, Steps = 17
# Episode 303: Reward sum = 2.83, Last reward = 0.0, Steps = 17
# Episode 304: Reward sum = 101.73, Last reward = 99.0, Steps = 18
# Episode 305: Reward sum = 17.22, Last reward = 15.0, Steps = 16
# Episode 306: Reward sum = 2.89, Last reward = 0.0, Steps = 14
# Episode 307: Reward sum = 1.89, Last reward = 0.0, Steps = 16
# Episode 308: Reward sum = 8.05, Last reward = 6.0, Steps = 13
# Episode 309: Reward sum = 25.28, Last reward = 24.0, Steps = 17
# Episode 310: Reward sum = 2.17, Last reward = 0.0, Steps = 15
# Episode 311: Reward sum = 3.31, Last reward = 0.0, Steps = 18
# Episode 312: Reward sum = 2.06, Last reward = 0.0, Steps = 14
# Episode 313: Reward sum = 1.82, Last reward = 0.0, Steps = 15
# Episode 314: Reward sum = 1.80, Last reward = 0.0, Steps = 16
# Episode 315: Reward sum = 16.91, Last reward = 15.0, Steps = 15
# Episode 316: Reward sum = -27.87, Last reward = -30.0, Steps = 17
# Episode 317: Reward sum = 26.24, Last reward = 24.0, Steps = 16
# Episode 318: Reward sum = -25.02, Last reward = -27.0, Steps = 19
# Episode 319: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 320: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 321: Reward sum = 16.18, Last reward = 15.0, Steps = 7
# Episode 322: Reward sum = 1.03, Last reward = 0.0, Steps = 16
# Episode 323: Reward sum = 2.59, Last reward = 0.0, Steps = 14
# Episode 324: Reward sum = 2.70, Last reward = 0.0, Steps = 16
# Episode 325: Reward sum = 2.51, Last reward = 0.0, Steps = 15
# Episode 326: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 327: Reward sum = 182.03, Last reward = 180.0, Steps = 17
# Episode 328: Reward sum = 3.26, Last reward = 0.0, Steps = 16
# Episode 329: Reward sum = 1.26, Last reward = 0.0, Steps = 17
# Episode 330: Reward sum = -22.78, Last reward = -26.0, Steps = 16
# Episode 331: Reward sum = 28.58, Last reward = 27.0, Steps = 15
# Episode 332: Reward sum = 1.81, Last reward = 0.0, Steps = 17
# Episode 333: Reward sum = 2.25, Last reward = 0.0, Steps = 15
# Episode 334: Reward sum = 2.34, Last reward = 0.0, Steps = 14
# Episode 335: Reward sum = 3.35, Last reward = 0.0, Steps = 16
# Episode 336: Reward sum = 91.95, Last reward = 90.0, Steps = 16
# Episode 337: Reward sum = 2.51, Last reward = 0.0, Steps = 16
# Episode 338: Reward sum = 93.90, Last reward = 93.0, Steps = 16
# Episode 339: Reward sum = -0.13, Last reward = -2.0, Steps = 15
# Episode 340: Reward sum = 2.01, Last reward = 0.0, Steps = 16
# Episode 341: Reward sum = 1.37, Last reward = 0.0, Steps = 16
# Episode 342: Reward sum = 3.13, Last reward = 0.0, Steps = 17
# Episode 343: Reward sum = 0.99, Last reward = 0.0, Steps = 15
# Episode 344: Reward sum = 6.70, Last reward = 4.0, Steps = 18
# Episode 345: Reward sum = 1.46, Last reward = 0.0, Steps = 17
# Episode 346: Reward sum = 4.22, Last reward = 0.0, Steps = 15
# Episode 347: Reward sum = 2.90, Last reward = 0.0, Steps = 15
# Episode 348: Reward sum = 2.20, Last reward = 0.0, Steps = 17
# Episode 349: Reward sum = 16.52, Last reward = 15.0, Steps = 10
# Episode 350: Reward sum = -2.58, Last reward = -5.0, Steps = 15
# Episode 351: Reward sum = 7.20, Last reward = 6.0, Steps = 7
# Episode 352: Reward sum = 2.59, Last reward = 0.0, Steps = 16
# Episode 353: Reward sum = 20.16, Last reward = 18.0, Steps = 16
# Episode 354: Reward sum = 23.13, Last reward = 21.0, Steps = 17
# Episode 355: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 356: Reward sum = 19.76, Last reward = 18.0, Steps = 16
# Episode 357: Reward sum = 2.65, Last reward = 0.0, Steps = 17
# Episode 358: Reward sum = 18.73, Last reward = 16.0, Steps = 19
# Episode 359: Reward sum = 3.35, Last reward = 0.0, Steps = 16
# Episode 360: Reward sum = -27.74, Last reward = -30.0, Steps = 16
# Episode 361: Reward sum = 1.83, Last reward = 0.0, Steps = 15
# Episode 362: Reward sum = 3.03, Last reward = 0.0, Steps = 14
# Episode 363: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 364: Reward sum = 1.29, Last reward = 0.0, Steps = 16
# Episode 365: Reward sum = 17.05, Last reward = 15.0, Steps = 16
# Episode 366: Reward sum = 1.68, Last reward = 0.0, Steps = 17
# Episode 367: Reward sum = 20.01, Last reward = 18.0, Steps = 15
# Episode 368: Reward sum = -37.68, Last reward = -39.0, Steps = 16
# Episode 369: Reward sum = 1.26, Last reward = 0.0, Steps = 18
# Episode 370: Reward sum = -19.08, Last reward = -20.0, Steps = 16
# Episode 371: Reward sum = 93.05, Last reward = 90.0, Steps = 16
# Episode 372: Reward sum = 1.94, Last reward = 0.0, Steps = 15
# Episode 373: Reward sum = 27.09, Last reward = 24.0, Steps = 16
# Episode 374: Reward sum = 3.20, Last reward = 0.0, Steps = 16
# Episode 375: Reward sum = 1.92, Last reward = 0.0, Steps = 15
# Episode 376: Reward sum = 3.25, Last reward = 0.0, Steps = 17
# Episode 377: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 378: Reward sum = 1.85, Last reward = 0.0, Steps = 15
# Episode 379: Reward sum = 93.10, Last reward = 90.0, Steps = 18
# Episode 380: Reward sum = 16.80, Last reward = 15.0, Steps = 16
# Episode 381: Reward sum = 2.70, Last reward = 0.0, Steps = 16
# Episode 382: Reward sum = 3.35, Last reward = 0.0, Steps = 16
# Episode 383: Reward sum = 1.34, Last reward = 0.0, Steps = 16
# Episode 384: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 385: Reward sum = 72.90, Last reward = 72.0, Steps = 16
# Episode 386: Reward sum = 3.92, Last reward = 0.0, Steps = 16
# Episode 387: Reward sum = 20.32, Last reward = 18.0, Steps = 15
# Episode 388: Reward sum = 7.95, Last reward = 0.0, Steps = 16
# Episode 389: Reward sum = 62.71, Last reward = 60.0, Steps = 17
# Episode 390: Reward sum = 2.99, Last reward = 0.0, Steps = 15
# Episode 391: Reward sum = 8.70, Last reward = 6.0, Steps = 11
# Episode 392: Reward sum = -3.08, Last reward = -5.0, Steps = 17
# Episode 393: Reward sum = -25.80, Last reward = -30.0, Steps = 16
# Episode 394: Reward sum = 20.90, Last reward = 18.0, Steps = 16
# Episode 395: Reward sum = 177.94, Last reward = 177.0, Steps = 14
# Episode 396: Reward sum = -30.46, Last reward = -33.0, Steps = 17
# Episode 397: Reward sum = 16.99, Last reward = 15.0, Steps = 16
# Episode 398: Reward sum = -14.53, Last reward = -17.0, Steps = 16
# Episode 399: Reward sum = 16.10, Last reward = 15.0, Steps = 6
# Episode 400: Reward sum = 1.59, Last reward = 0.0, Steps = 14

# %%
plot_rewards(logger.log_dir, agent_eval.eval_rewards_per_episode_last_one, title="Evaluation Rewards", save_fig=True)
