# %%
import gymnasium as gym
import mahjong_env
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from time import strftime
import csv
np.random.seed(42)
tf.random.set_seed(42)

# %%
class Logger:
    def __init__(self):
        # Create a unique log directory
        self.log_dir = f"log_{strftime("%Y_%m_%d-%H_%M_%S")}"
        os.makedirs(self.log_dir, exist_ok=True)

        # Paths for logging files
        self.rewards_log_path = os.path.join(self.log_dir, "rewards.csv")
        self.transitions_log_path = os.path.join(self.log_dir, "transitions.csv")
        self.evaluation_log_path = os.path.join(self.log_dir, "evaluation_rewards.csv")
        self.policy_model_path = os.path.join(self.log_dir, "policy_model.keras")
        self.value_model_path = os.path.join(self.log_dir, "value_model.keras")

        # Initialize the CSV log files
        with open(self.rewards_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward sum", "last reward", "steps"])

        with open(self.transitions_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "state", "action", "next-state", "reward", "done", "truncated"])

        with open(self.evaluation_log_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["episode", "reward_sum", "last_reward", "steps"])

    def log_training_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])
            
    def log_eval_reward(self, episode, reward_sum, last_reward, steps):
        with open(self.rewards_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, reward_sum, last_reward, steps])

    def log_transition(self, episode, state, action, next_state, reward, done, truncated):
        with open(self.transitions_log_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([episode, state.tolist(), action, next_state.tolist(), reward, done, truncated])

    def save_policy_model(self, model):
        model.save(self.policy_model_path)
        
    def save_value_model(self, model):
        model.save(self.value_model_path)


class RewardNormalizer:
    def __init__(self):
        self.mean = 0
        self.var = 0
        self.count = 0

    def normalize(self, reward):
        self.count += 1
        old_mean = self.mean
        self.mean += (reward - self.mean) / self.count
        self.var += (reward - old_mean) * (reward - self.mean)
        std = (self.var / self.count) ** 0.5
        return (reward - self.mean) / (std + 1e-8)


class ActorCritic:
    def __init__(self, env, policy_network, value_network, logger, gamma=0.99):
        self.env = env
        self.policy_network = policy_network
        self.value_network = value_network
        self.gamma = gamma
        self.learning_rate = 0.001
        self.policy_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.value_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.training_rewards_per_episode_sum = []
        self.training_rewards_per_episode_last_one = []
        self.eval_rewards_per_episode_sum = []
        self.eval_rewards_per_episode_last_one = []
        self.logger = logger
        self.reward_normalizer = RewardNormalizer()

    def sample_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        action_probs[(state[:27]==0)] = 0.0
        action_probs /= np.sum(action_probs)
        action = np.random.choice(len(action_probs), p=action_probs)
        return action
    
    def take_action(self, state):
        action_probs = self.policy_network(state[np.newaxis]).numpy()[0]
        action_probs[(state[:27]==0)] = -np.inf
        action = np.argmax(action_probs)
        return action
    
    def train_step(self, state, action, reward, next_state, done):
        # Compute target Q-value
        with tf.GradientTape() as value_tape:
            q_value = tf.squeeze(self.value_network(tf.expand_dims(state, axis=0)), axis=-1)
            target_q_value = reward + self.gamma * tf.squeeze(self.value_network(tf.expand_dims(next_state, axis=0)), axis=-1) * (1 - done)
            value_loss = tf.keras.losses.Huber()(target_q_value, q_value)
    
        # Update value network
        value_grads = value_tape.gradient(value_loss, self.value_network.trainable_variables)
        self.value_optimizer.apply_gradients(zip(value_grads, self.value_network.trainable_variables))
    
        # Compute policy loss using TD error
        td_error = target_q_value - q_value
        with tf.GradientTape() as policy_tape:
            action_probs = self.policy_network(tf.expand_dims(state, axis=0))
            mask = tf.constant(state[:27] != 0, dtype=tf.float32)
            masked_action_probs = action_probs * mask
            masked_action_probs /= tf.reduce_sum(masked_action_probs)
            selected_action_prob = tf.gather_nd(masked_action_probs, [[0, action]])
            policy_loss = -tf.reduce_mean(tf.math.log(selected_action_prob) * tf.stop_gradient(td_error))
    
        # Update policy network
        policy_grads = policy_tape.gradient(policy_loss, self.policy_network.trainable_variables)
        self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_network.trainable_variables))


    def process_state(self, state):
        normalized_hand = state['hand'] / 4.0
        normalized_visible_cards = state['visible cards'] / 4.0
        kangs_one_hot = tf.one_hot(state['kangs'], depth=4).numpy()
        kangs_one_hot_flat = kangs_one_hot.reshape(-1)
        final_array = np.concatenate((
            normalized_hand,
            state['pongs'],
            kangs_one_hot_flat,
            normalized_visible_cards
        ))
        return final_array
    
    
    def run_episode(self, log_transition=False):
        state, _ = self.env.reset()
        state = self.process_state(state)
        episode_reward = 0
        done = False
        steps = 0
        last_reward = 0
        while not done:
            action = self.sample_action(state)
            next_state, reward, done, truncated, _ = self.env.step(action)
            next_state = self.process_state(next_state)
            done = done or truncated
            normalized_reward = self.reward_normalizer.normalize(reward)
            self.train_step(state, action, normalized_reward, next_state, done)
            steps += 1
            episode_reward += reward
            if done:
                last_reward = reward
            # if log_transition and self.logger:
            #     self.logger.log_transition(episode, state, action, next_state, reward, done, truncated)
            state = next_state

        return episode_reward, last_reward, steps
    
    def evaluate(self, episodes):
        for episode in range(episodes):
            state, _ = self.env.reset()
            state = self.process_state(state)
            episode_reward = 0
            done = False
            steps = 0
            last_reward = 0
            while not done:
                action = self.take_action(state)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_state = self.process_state(next_state)
                done = done or truncated
                steps += 1
                episode_reward += reward
                if done:
                    last_reward = reward
                state = next_state
            self.eval_rewards_per_episode_sum.append(episode_reward)
            self.eval_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_eval_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")


    def train(self, episodes=1, save_freq=20):
        for episode in range(episodes):
            episode_reward, last_reward, steps = self.run_episode()
            self.training_rewards_per_episode_sum.append(episode_reward)
            self.training_rewards_per_episode_last_one.append(last_reward)
            if self.logger:
                self.logger.log_training_reward(episode, episode_reward, last_reward, steps)
            print(f"Episode {episode + 1}: Reward sum = {episode_reward:.2f}, Last reward = {last_reward}, Steps = {steps}")
            if (episode + 1) % save_freq == 0 and self.logger:
                self.logger.save_policy_model(self.policy_network)
                self.logger.save_value_model(self.value_network)


class PolicyNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(PolicyNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128, activation='relu')
        self.dense2 = tf.keras.layers.Dense(128, activation='relu')
        self.dense3 = tf.keras.layers.Dense(num_actions, activation='softmax')

    def call(self, state):
        x = self.dense1(state)
        return self.dense3(self.dense2(x))


class ValueNetwork(tf.keras.Model):
    def __init__(self):
        super(ValueNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128, activation='relu')
        self.dense2 = tf.keras.layers.Dense(128, activation='relu')
        self.dense3 = tf.keras.layers.Dense(1)

    def call(self, state):
        x = self.dense1(state)
        return self.dense3(self.dense2(x))

# class PolicyNetwork(tf.keras.Model):
#     def __init__(self, num_actions):
#         super(PolicyNetwork, self).__init__()
#         self.dense1 = tf.keras.layers.Dense(128)
#         self.leaky_relu1 = tf.keras.layers.LeakyReLU()
#         self.dense2 = tf.keras.layers.Dense(128)
#         self.leaky_relu2 = tf.keras.layers.LeakyReLU()
#         self.dense3 = tf.keras.layers.Dense(num_actions, activation='softmax')
# 
#     def call(self, state):
#         x = self.leaky_relu1(self.dense1(state))
#         x = self.leaky_relu2(self.dense2(x))
#         return self.dense3(x)
#     
# 
# class ValueNetwork(tf.keras.Model):
#     def __init__(self):
#         super(ValueNetwork, self).__init__()
#         self.dense1 = tf.keras.layers.Dense(128)
#         self.leaky_relu1 = tf.keras.layers.LeakyReLU()
#         self.dense2 = tf.keras.layers.Dense(128)
#         self.leaky_relu2 = tf.keras.layers.LeakyReLU()
#         self.dense3 = tf.keras.layers.Dense(1)
# 
#     def call(self, state):
#         x = self.leaky_relu1(self.dense1(state))
#         x = self.leaky_relu2(self.dense2(x))
#         return self.dense3(x)


    

def plot_rewards(root_folder, rewards, title, save_fig=False):
    plt.plot(rewards, label='Total Reward per Episode')
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.title(title)
    if save_fig:
        plt.savefig(root_folder + "/" + title + '_' + strftime("%Y_%m_%d_%H_%M_%S") +'_' + '.png')
    plt.legend()
    plt.show()

# %%
# Environment setup
env = gym.make("Mahjong-v0")
policy = PolicyNetwork(num_actions=27)
value_network = ValueNetwork()
logger = Logger()
agent = ActorCritic(env, policy, value_network, logger)
agent.train(2000)
# Out:
# Episode 1: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 2: Reward sum = 1.45, Last reward = 0.0, Steps = 16
# Episode 3: Reward sum = 0.85, Last reward = 0.0, Steps = 16
# Episode 4: Reward sum = 2.26, Last reward = 0.0, Steps = 17
# Episode 5: Reward sum = 94.11, Last reward = 93.0, Steps = 17
# Episode 6: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 7: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 8: Reward sum = 0.80, Last reward = 0.0, Steps = 17
# Episode 9: Reward sum = 2.29, Last reward = 0.0, Steps = 16
# Episode 10: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 11: Reward sum = 3.01, Last reward = 0.0, Steps = 17
# Episode 12: Reward sum = 2.27, Last reward = 0.0, Steps = 16
# Episode 13: Reward sum = 2.41, Last reward = 0.0, Steps = 18
# Episode 14: Reward sum = 2.48, Last reward = 0.0, Steps = 16
# Episode 15: Reward sum = 2.90, Last reward = 0.0, Steps = 15
# Episode 16: Reward sum = 2.60, Last reward = 0.0, Steps = 17
# Episode 17: Reward sum = -1.00, Last reward = -2.0, Steps = 15
# Episode 18: Reward sum = 2.27, Last reward = 0.0, Steps = 18
# Episode 19: Reward sum = -35.45, Last reward = -39.0, Steps = 16
# Episode 20: Reward sum = 91.58, Last reward = 90.0, Steps = 18
# Episode 21: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 22: Reward sum = 2.11, Last reward = 0.0, Steps = 14
# Episode 23: Reward sum = -3.27, Last reward = -5.0, Steps = 17
# Episode 24: Reward sum = -17.91, Last reward = -20.0, Steps = 17
# Episode 25: Reward sum = 2.55, Last reward = 0.0, Steps = 16
# Episode 26: Reward sum = -10.28, Last reward = -14.0, Steps = 19
# Episode 27: Reward sum = 2.99, Last reward = 0.0, Steps = 16
# Episode 28: Reward sum = 1.79, Last reward = 0.0, Steps = 16
# Episode 29: Reward sum = 2.23, Last reward = 0.0, Steps = 17
# Episode 30: Reward sum = 1.28, Last reward = 0.0, Steps = 16
# Episode 31: Reward sum = 1.62, Last reward = 0.0, Steps = 16
# Episode 32: Reward sum = 2.09, Last reward = 0.0, Steps = 16
# Episode 33: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 34: Reward sum = 1.05, Last reward = 0.0, Steps = 17
# Episode 35: Reward sum = 1.14, Last reward = 0.0, Steps = 15
# Episode 36: Reward sum = 3.03, Last reward = 0.0, Steps = 18
# Episode 37: Reward sum = -27.97, Last reward = -30.0, Steps = 19
# Episode 38: Reward sum = -28.22, Last reward = -30.0, Steps = 17
# Episode 39: Reward sum = 2.10, Last reward = 0.0, Steps = 17
# Episode 40: Reward sum = 0.86, Last reward = 0.0, Steps = 15
# Episode 41: Reward sum = 2.96, Last reward = 0.0, Steps = 16
# Episode 42: Reward sum = 1.80, Last reward = 0.0, Steps = 17
# Episode 43: Reward sum = 1.32, Last reward = 0.0, Steps = 15
# Episode 44: Reward sum = 2.55, Last reward = 0.0, Steps = 15
# Episode 45: Reward sum = 1.24, Last reward = 0.0, Steps = 16
# Episode 46: Reward sum = 1.15, Last reward = 0.0, Steps = 17
# Episode 47: Reward sum = 2.90, Last reward = 0.0, Steps = 15
# Episode 48: Reward sum = 2.75, Last reward = 0.0, Steps = 17
# Episode 49: Reward sum = 1.69, Last reward = 0.0, Steps = 14
# Episode 50: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 51: Reward sum = 1.67, Last reward = 0.0, Steps = 15
# Episode 52: Reward sum = 2.40, Last reward = 0.0, Steps = 15
# Episode 53: Reward sum = 1.41, Last reward = 0.0, Steps = 17
# Episode 54: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 55: Reward sum = 2.39, Last reward = 0.0, Steps = 16
# Episode 56: Reward sum = 2.92, Last reward = 0.0, Steps = 16
# Episode 57: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 58: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 59: Reward sum = 2.78, Last reward = 0.0, Steps = 16
# Episode 60: Reward sum = 1.42, Last reward = 0.0, Steps = 15
# Episode 61: Reward sum = -3.96, Last reward = -5.0, Steps = 17
# Episode 62: Reward sum = 0.48, Last reward = 0.0, Steps = 15
# Episode 63: Reward sum = 4.40, Last reward = 0.0, Steps = 17
# Episode 64: Reward sum = 1.25, Last reward = 0.0, Steps = 16
# Episode 65: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 66: Reward sum = -17.74, Last reward = -20.0, Steps = 17
# Episode 67: Reward sum = 3.40, Last reward = 0.0, Steps = 16
# Episode 68: Reward sum = 1.34, Last reward = 0.0, Steps = 16
# Episode 69: Reward sum = 2.04, Last reward = 0.0, Steps = 15
# Episode 70: Reward sum = 1.67, Last reward = 0.0, Steps = 15
# Episode 71: Reward sum = 1.89, Last reward = 0.0, Steps = 17
# Episode 72: Reward sum = 2.58, Last reward = 0.0, Steps = 17
# Episode 73: Reward sum = -25.12, Last reward = -27.0, Steps = 17
# Episode 74: Reward sum = 2.72, Last reward = 0.0, Steps = 16
# Episode 75: Reward sum = 2.04, Last reward = 0.0, Steps = 14
# Episode 76: Reward sum = 1.81, Last reward = 0.0, Steps = 15
# Episode 77: Reward sum = 1.47, Last reward = 0.0, Steps = 17
# Episode 78: Reward sum = 1.46, Last reward = 0.0, Steps = 15
# Episode 79: Reward sum = -3.23, Last reward = -5.0, Steps = 13
# Episode 80: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 81: Reward sum = 1.49, Last reward = 0.0, Steps = 15
# Episode 82: Reward sum = 1.82, Last reward = 0.0, Steps = 16
# Episode 83: Reward sum = -0.29, Last reward = -2.0, Steps = 10
# Episode 84: Reward sum = 103.98, Last reward = 102.0, Steps = 15
# Episode 85: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 86: Reward sum = 1.94, Last reward = 0.0, Steps = 14
# Episode 87: Reward sum = 1.90, Last reward = 0.0, Steps = 15
# Episode 88: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 89: Reward sum = 2.65, Last reward = 0.0, Steps = 17
# Episode 90: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 91: Reward sum = 2.11, Last reward = 0.0, Steps = 15
# Episode 92: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 93: Reward sum = -29.55, Last reward = -31.0, Steps = 15
# Episode 94: Reward sum = 1.30, Last reward = 0.0, Steps = 17
# Episode 95: Reward sum = -46.00, Last reward = -48.0, Steps = 17
# Episode 96: Reward sum = 1.21, Last reward = 0.0, Steps = 13
# Episode 97: Reward sum = 1.68, Last reward = 0.0, Steps = 15
# Episode 98: Reward sum = 2.02, Last reward = 0.0, Steps = 17
# Episode 99: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 100: Reward sum = 2.61, Last reward = 0.0, Steps = 15
# Episode 101: Reward sum = 1.34, Last reward = 0.0, Steps = 17
# Episode 102: Reward sum = 0.41, Last reward = 0.0, Steps = 16
# Episode 103: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 104: Reward sum = 3.69, Last reward = 0.0, Steps = 15
# Episode 105: Reward sum = -9.59, Last reward = -11.0, Steps = 16
# Episode 106: Reward sum = 92.56, Last reward = 90.0, Steps = 18
# Episode 107: Reward sum = 1.94, Last reward = 0.0, Steps = 15
# Episode 108: Reward sum = 2.00, Last reward = 0.0, Steps = 15
# Episode 109: Reward sum = 2.32, Last reward = 0.0, Steps = 14
# Episode 110: Reward sum = 2.46, Last reward = 0.0, Steps = 15
# Episode 111: Reward sum = 1.57, Last reward = 0.0, Steps = 15
# Episode 112: Reward sum = 2.14, Last reward = 0.0, Steps = 16
# Episode 113: Reward sum = 2.54, Last reward = 0.0, Steps = 16
# Episode 114: Reward sum = 2.62, Last reward = 0.0, Steps = 18
# Episode 115: Reward sum = 2.07, Last reward = 0.0, Steps = 16
# Episode 116: Reward sum = -2.51, Last reward = -5.0, Steps = 14
# Episode 117: Reward sum = 1.86, Last reward = 0.0, Steps = 17
# Episode 118: Reward sum = 0.66, Last reward = 0.0, Steps = 17
# Episode 119: Reward sum = 1.84, Last reward = 0.0, Steps = 16
# Episode 120: Reward sum = 2.71, Last reward = 0.0, Steps = 15
# Episode 121: Reward sum = 1.94, Last reward = 0.0, Steps = 14
# Episode 122: Reward sum = 0.71, Last reward = 0.0, Steps = 18
# Episode 123: Reward sum = 58.78, Last reward = 57.0, Steps = 15
# Episode 124: Reward sum = 1.81, Last reward = 0.0, Steps = 18
# Episode 125: Reward sum = 2.87, Last reward = 0.0, Steps = 17
# Episode 126: Reward sum = 1.98, Last reward = 0.0, Steps = 17
# Episode 127: Reward sum = -28.72, Last reward = -30.0, Steps = 11
# Episode 128: Reward sum = 94.80, Last reward = 93.0, Steps = 19
# Episode 129: Reward sum = -3.15, Last reward = -5.0, Steps = 15
# Episode 130: Reward sum = 2.17, Last reward = 0.0, Steps = 13
# Episode 131: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 132: Reward sum = 1.63, Last reward = 0.0, Steps = 16
# Episode 133: Reward sum = 2.18, Last reward = 0.0, Steps = 17
# Episode 134: Reward sum = 2.51, Last reward = 0.0, Steps = 16
# Episode 135: Reward sum = 1.55, Last reward = 0.0, Steps = 15
# Episode 136: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 137: Reward sum = 2.29, Last reward = 0.0, Steps = 17
# Episode 138: Reward sum = 1.89, Last reward = 0.0, Steps = 14
# Episode 139: Reward sum = 2.10, Last reward = 0.0, Steps = 16
# Episode 140: Reward sum = 2.23, Last reward = 0.0, Steps = 15
# Episode 141: Reward sum = 1.04, Last reward = 0.0, Steps = 18
# Episode 142: Reward sum = 2.38, Last reward = 0.0, Steps = 16
# Episode 143: Reward sum = 1.08, Last reward = 0.0, Steps = 16
# Episode 144: Reward sum = 1.78, Last reward = 0.0, Steps = 16
# Episode 145: Reward sum = 2.76, Last reward = 0.0, Steps = 15
# Episode 146: Reward sum = 2.60, Last reward = 0.0, Steps = 16
# Episode 147: Reward sum = 0.76, Last reward = 0.0, Steps = 16
# Episode 148: Reward sum = 1.90, Last reward = 0.0, Steps = 16
# Episode 149: Reward sum = 2.84, Last reward = 0.0, Steps = 16
# Episode 150: Reward sum = -31.40, Last reward = -33.0, Steps = 17
# Episode 151: Reward sum = 98.24, Last reward = 96.0, Steps = 17
# Episode 152: Reward sum = 2.55, Last reward = 0.0, Steps = 16
# Episode 153: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 154: Reward sum = 1.99, Last reward = 0.0, Steps = 18
# Episode 155: Reward sum = 1.76, Last reward = 0.0, Steps = 15
# Episode 156: Reward sum = 1.55, Last reward = 0.0, Steps = 16
# Episode 157: Reward sum = 2.49, Last reward = 0.0, Steps = 16
# Episode 158: Reward sum = 1.69, Last reward = 0.0, Steps = 17
# Episode 159: Reward sum = 1.22, Last reward = 0.0, Steps = 15
# Episode 160: Reward sum = 1.11, Last reward = 0.0, Steps = 15
# Episode 161: Reward sum = 1.53, Last reward = 0.0, Steps = 17
# Episode 162: Reward sum = 1.97, Last reward = 0.0, Steps = 17
# Episode 163: Reward sum = 2.35, Last reward = 0.0, Steps = 15
# Episode 164: Reward sum = 1.07, Last reward = 0.0, Steps = 17
# Episode 165: Reward sum = 3.62, Last reward = 0.0, Steps = 16
# Episode 166: Reward sum = 1.43, Last reward = 0.0, Steps = 18
# Episode 167: Reward sum = -27.62, Last reward = -30.0, Steps = 19
# Episode 168: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 169: Reward sum = -3.50, Last reward = -5.0, Steps = 16
# Episode 170: Reward sum = 2.57, Last reward = 0.0, Steps = 15
# Episode 171: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 172: Reward sum = 1.93, Last reward = 0.0, Steps = 15
# Episode 173: Reward sum = 2.97, Last reward = 0.0, Steps = 16
# Episode 174: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 175: Reward sum = 91.53, Last reward = 90.0, Steps = 17
# Episode 176: Reward sum = 0.87, Last reward = 0.0, Steps = 15
# Episode 177: Reward sum = 1.45, Last reward = 0.0, Steps = 16
# Episode 178: Reward sum = 1.78, Last reward = 0.0, Steps = 16
# Episode 179: Reward sum = 2.28, Last reward = 0.0, Steps = 17
# Episode 180: Reward sum = -29.04, Last reward = -30.0, Steps = 17
# Episode 181: Reward sum = 2.37, Last reward = 0.0, Steps = 16
# Episode 182: Reward sum = 16.68, Last reward = 15.0, Steps = 18
# Episode 183: Reward sum = 2.75, Last reward = 0.0, Steps = 16
# Episode 184: Reward sum = 1.35, Last reward = 0.0, Steps = 16
# Episode 185: Reward sum = 1.99, Last reward = 0.0, Steps = 16
# Episode 186: Reward sum = -30.34, Last reward = -33.0, Steps = 17
# Episode 187: Reward sum = 3.13, Last reward = 0.0, Steps = 16
# Episode 188: Reward sum = 1.44, Last reward = 0.0, Steps = 17
# Episode 189: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 190: Reward sum = 2.83, Last reward = 0.0, Steps = 17
# Episode 191: Reward sum = 1.48, Last reward = 0.0, Steps = 18
# Episode 192: Reward sum = 1.05, Last reward = 0.0, Steps = 16
# Episode 193: Reward sum = 0.33, Last reward = 0.0, Steps = 17
# Episode 194: Reward sum = 3.23, Last reward = 0.0, Steps = 16
# Episode 195: Reward sum = 92.61, Last reward = 90.0, Steps = 17
# Episode 196: Reward sum = -29.04, Last reward = -30.0, Steps = 15
# Episode 197: Reward sum = 1.68, Last reward = 0.0, Steps = 15
# Episode 198: Reward sum = 83.09, Last reward = 81.0, Steps = 16
# Episode 199: Reward sum = 2.70, Last reward = 0.0, Steps = 16
# Episode 200: Reward sum = 3.08, Last reward = 0.0, Steps = 17
# Episode 201: Reward sum = -2.54, Last reward = -5.0, Steps = 15
# Episode 202: Reward sum = 2.68, Last reward = 0.0, Steps = 17
# Episode 203: Reward sum = 1.41, Last reward = 0.0, Steps = 15
# Episode 204: Reward sum = 92.17, Last reward = 90.0, Steps = 17
# Episode 205: Reward sum = 3.39, Last reward = 0.0, Steps = 15
# Episode 206: Reward sum = 1.64, Last reward = 0.0, Steps = 14
# Episode 207: Reward sum = -28.38, Last reward = -30.0, Steps = 17
# Episode 208: Reward sum = 1.39, Last reward = 0.0, Steps = 14
# Episode 209: Reward sum = 2.42, Last reward = 0.0, Steps = 18
# Episode 210: Reward sum = 61.98, Last reward = 60.0, Steps = 17
# Episode 211: Reward sum = 1.77, Last reward = 0.0, Steps = 14
# Episode 212: Reward sum = 2.78, Last reward = 0.0, Steps = 17
# Episode 213: Reward sum = 0.88, Last reward = 0.0, Steps = 17
# Episode 214: Reward sum = 1.39, Last reward = 0.0, Steps = 16
# Episode 215: Reward sum = 1.74, Last reward = 0.0, Steps = 16
# Episode 216: Reward sum = 15.96, Last reward = 15.0, Steps = 16
# Episode 217: Reward sum = 2.78, Last reward = 0.0, Steps = 16
# Episode 218: Reward sum = 1.44, Last reward = 0.0, Steps = 16
# Episode 219: Reward sum = 1.67, Last reward = 0.0, Steps = 15
# Episode 220: Reward sum = 1.06, Last reward = 0.0, Steps = 16
# Episode 221: Reward sum = 2.09, Last reward = 0.0, Steps = 16
# Episode 222: Reward sum = 3.01, Last reward = 0.0, Steps = 16
# Episode 223: Reward sum = 0.97, Last reward = 0.0, Steps = 16
# Episode 224: Reward sum = 2.24, Last reward = 0.0, Steps = 17
# Episode 225: Reward sum = 2.88, Last reward = 0.0, Steps = 17
# Episode 226: Reward sum = 1.22, Last reward = 0.0, Steps = 17
# Episode 227: Reward sum = 1.54, Last reward = 0.0, Steps = 16
# Episode 228: Reward sum = 1.09, Last reward = 0.0, Steps = 15
# Episode 229: Reward sum = 1.50, Last reward = 0.0, Steps = 15
# Episode 230: Reward sum = 2.96, Last reward = 0.0, Steps = 17
# Episode 231: Reward sum = 2.08, Last reward = 0.0, Steps = 15
# Episode 232: Reward sum = 17.80, Last reward = 15.0, Steps = 15
# Episode 233: Reward sum = 1.09, Last reward = 0.0, Steps = 16
# Episode 234: Reward sum = 3.13, Last reward = 0.0, Steps = 15
# Episode 235: Reward sum = 2.49, Last reward = 0.0, Steps = 16
# Episode 236: Reward sum = 1.85, Last reward = 0.0, Steps = 17
# Episode 237: Reward sum = 1.56, Last reward = 0.0, Steps = 16
# Episode 238: Reward sum = 2.63, Last reward = 0.0, Steps = 16
# Episode 239: Reward sum = 1.30, Last reward = 0.0, Steps = 16
# Episode 240: Reward sum = -28.19, Last reward = -30.0, Steps = 18
# Episode 241: Reward sum = -37.55, Last reward = -39.0, Steps = 16
# Episode 242: Reward sum = -3.72, Last reward = -5.0, Steps = 17
# Episode 243: Reward sum = 2.06, Last reward = 0.0, Steps = 15
# Episode 244: Reward sum = 0.90, Last reward = 0.0, Steps = 14
# Episode 245: Reward sum = 1.93, Last reward = 0.0, Steps = 16
# Episode 246: Reward sum = 1.89, Last reward = 0.0, Steps = 17
# Episode 247: Reward sum = 62.14, Last reward = 60.0, Steps = 19
# Episode 248: Reward sum = -3.30, Last reward = -5.0, Steps = 16
# Episode 249: Reward sum = 0.50, Last reward = 0.0, Steps = 18
# Episode 250: Reward sum = -3.54, Last reward = -5.0, Steps = 17
# Episode 251: Reward sum = 1.14, Last reward = 0.0, Steps = 14
# Episode 252: Reward sum = 1.72, Last reward = 0.0, Steps = 15
# Episode 253: Reward sum = 1.34, Last reward = 0.0, Steps = 14
# Episode 254: Reward sum = 2.67, Last reward = 0.0, Steps = 16
# Episode 255: Reward sum = 2.28, Last reward = 0.0, Steps = 16
# Episode 256: Reward sum = -28.77, Last reward = -30.0, Steps = 17
# Episode 257: Reward sum = -4.10, Last reward = -5.0, Steps = 11
# Episode 258: Reward sum = -28.39, Last reward = -30.0, Steps = 10
# Episode 259: Reward sum = 1.91, Last reward = 0.0, Steps = 17
# Episode 260: Reward sum = 2.06, Last reward = 0.0, Steps = 15
# Episode 261: Reward sum = -27.86, Last reward = -30.0, Steps = 19
# Episode 262: Reward sum = 63.70, Last reward = 63.0, Steps = 20
# Episode 263: Reward sum = 3.52, Last reward = 0.0, Steps = 15
# Episode 264: Reward sum = 0.93, Last reward = 0.0, Steps = 17
# Episode 265: Reward sum = 2.01, Last reward = 0.0, Steps = 16
# Episode 266: Reward sum = -11.06, Last reward = -14.0, Steps = 16
# Episode 267: Reward sum = 2.26, Last reward = 0.0, Steps = 15
# Episode 268: Reward sum = 16.73, Last reward = 15.0, Steps = 18
# Episode 269: Reward sum = 1.74, Last reward = 0.0, Steps = 17
# Episode 270: Reward sum = 1.20, Last reward = 0.0, Steps = 17
# Episode 271: Reward sum = 1.23, Last reward = 0.0, Steps = 16
# Episode 272: Reward sum = 2.00, Last reward = 0.0, Steps = 17
# Episode 273: Reward sum = 1.61, Last reward = 0.0, Steps = 16
# Episode 274: Reward sum = 1.92, Last reward = 0.0, Steps = 18
# Episode 275: Reward sum = 1.19, Last reward = 0.0, Steps = 16
# Episode 276: Reward sum = 1.19, Last reward = 0.0, Steps = 16
# Episode 277: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 278: Reward sum = 2.75, Last reward = 0.0, Steps = 16
# Episode 279: Reward sum = -12.38, Last reward = -14.0, Steps = 18
# Episode 280: Reward sum = -25.07, Last reward = -27.0, Steps = 19
# Episode 281: Reward sum = 93.95, Last reward = 93.0, Steps = 18
# Episode 282: Reward sum = 2.76, Last reward = 0.0, Steps = 16
# Episode 283: Reward sum = 1.68, Last reward = 0.0, Steps = 14
# Episode 284: Reward sum = 94.41, Last reward = 93.0, Steps = 18
# Episode 285: Reward sum = 2.85, Last reward = 0.0, Steps = 16
# Episode 286: Reward sum = 3.55, Last reward = 0.0, Steps = 16
# Episode 287: Reward sum = 2.41, Last reward = 0.0, Steps = 15
# Episode 288: Reward sum = 1.71, Last reward = 0.0, Steps = 16
# Episode 289: Reward sum = 93.61, Last reward = 93.0, Steps = 17
# Episode 290: Reward sum = 1.62, Last reward = 0.0, Steps = 17
# Episode 291: Reward sum = -37.80, Last reward = -39.0, Steps = 17
# Episode 292: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 293: Reward sum = 1.30, Last reward = 0.0, Steps = 18
# Episode 294: Reward sum = -28.95, Last reward = -30.0, Steps = 16
# Episode 295: Reward sum = -29.22, Last reward = -30.0, Steps = 18
# Episode 296: Reward sum = 3.32, Last reward = 0.0, Steps = 15
# Episode 297: Reward sum = 2.25, Last reward = 0.0, Steps = 17
# Episode 298: Reward sum = 1.00, Last reward = 0.0, Steps = 16
# Episode 299: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 300: Reward sum = 1.19, Last reward = 0.0, Steps = 15
# Episode 301: Reward sum = 2.24, Last reward = 0.0, Steps = 16
# Episode 302: Reward sum = 2.46, Last reward = 0.0, Steps = 15
# Episode 303: Reward sum = 1.60, Last reward = 0.0, Steps = 15
# Episode 304: Reward sum = 61.30, Last reward = 60.0, Steps = 12
# Episode 305: Reward sum = 3.44, Last reward = 0.0, Steps = 17
# Episode 306: Reward sum = 1.73, Last reward = 0.0, Steps = 16
# Episode 307: Reward sum = 1.84, Last reward = 0.0, Steps = 16
# Episode 308: Reward sum = 0.80, Last reward = 0.0, Steps = 15
# Episode 309: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 310: Reward sum = 1.83, Last reward = 0.0, Steps = 16
# Episode 311: Reward sum = 1.54, Last reward = 0.0, Steps = 15
# Episode 312: Reward sum = 1.86, Last reward = 0.0, Steps = 15
# Episode 313: Reward sum = 1.23, Last reward = 0.0, Steps = 16
# Episode 314: Reward sum = 3.17, Last reward = 0.0, Steps = 17
# Episode 315: Reward sum = 1.34, Last reward = 0.0, Steps = 16
# Episode 316: Reward sum = 3.31, Last reward = 0.0, Steps = 14
# Episode 317: Reward sum = -27.66, Last reward = -30.0, Steps = 19
# Episode 318: Reward sum = 3.17, Last reward = 0.0, Steps = 16
# Episode 319: Reward sum = 2.34, Last reward = 0.0, Steps = 14
# Episode 320: Reward sum = -28.40, Last reward = -30.0, Steps = 18
# Episode 321: Reward sum = 0.98, Last reward = 0.0, Steps = 16
# Episode 322: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 323: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 324: Reward sum = 1.93, Last reward = 0.0, Steps = 16
# Episode 325: Reward sum = 2.60, Last reward = 0.0, Steps = 17
# Episode 326: Reward sum = 0.89, Last reward = 0.0, Steps = 17
# Episode 327: Reward sum = 1.14, Last reward = 0.0, Steps = 16
# Episode 328: Reward sum = 2.20, Last reward = 0.0, Steps = 17
# Episode 329: Reward sum = 16.86, Last reward = 15.0, Steps = 17
# Episode 330: Reward sum = 1.04, Last reward = 0.0, Steps = 16
# Episode 331: Reward sum = 100.84, Last reward = 99.0, Steps = 16
# Episode 332: Reward sum = -27.62, Last reward = -30.0, Steps = 17
# Episode 333: Reward sum = -4.00, Last reward = -5.0, Steps = 16
# Episode 334: Reward sum = 1.71, Last reward = 0.0, Steps = 16
# Episode 335: Reward sum = 2.58, Last reward = 0.0, Steps = 18
# Episode 336: Reward sum = -28.41, Last reward = -30.0, Steps = 16
# Episode 337: Reward sum = 1.67, Last reward = 0.0, Steps = 16
# Episode 338: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 339: Reward sum = 1.55, Last reward = 0.0, Steps = 16
# Episode 340: Reward sum = 1.87, Last reward = 0.0, Steps = 20
# Episode 341: Reward sum = 100.15, Last reward = 99.0, Steps = 17
# Episode 342: Reward sum = 1.62, Last reward = 0.0, Steps = 15
# Episode 343: Reward sum = 0.75, Last reward = 0.0, Steps = 16
# Episode 344: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 345: Reward sum = 0.86, Last reward = 0.0, Steps = 17
# Episode 346: Reward sum = -25.50, Last reward = -27.0, Steps = 17
# Episode 347: Reward sum = 2.13, Last reward = 0.0, Steps = 14
# Episode 348: Reward sum = 17.20, Last reward = 15.0, Steps = 16
# Episode 349: Reward sum = 1.87, Last reward = 0.0, Steps = 17
# Episode 350: Reward sum = -28.62, Last reward = -30.0, Steps = 17
# Episode 351: Reward sum = 0.60, Last reward = 0.0, Steps = 17
# Episode 352: Reward sum = 0.95, Last reward = 0.0, Steps = 17
# Episode 353: Reward sum = 3.46, Last reward = 0.0, Steps = 17
# Episode 354: Reward sum = 1.10, Last reward = 0.0, Steps = 15
# Episode 355: Reward sum = -30.49, Last reward = -33.0, Steps = 18
# Episode 356: Reward sum = 94.44, Last reward = 93.0, Steps = 18
# Episode 357: Reward sum = 1.86, Last reward = 0.0, Steps = 14
# Episode 358: Reward sum = 1.82, Last reward = 0.0, Steps = 18
# Episode 359: Reward sum = 2.16, Last reward = 0.0, Steps = 17
# Episode 360: Reward sum = 1.54, Last reward = 0.0, Steps = 14
# Episode 361: Reward sum = 99.97, Last reward = 99.0, Steps = 17
# Episode 362: Reward sum = 1.62, Last reward = 0.0, Steps = 16
# Episode 363: Reward sum = 1.30, Last reward = 0.0, Steps = 15
# Episode 364: Reward sum = 1.14, Last reward = 0.0, Steps = 17
# Episode 365: Reward sum = 1.96, Last reward = 0.0, Steps = 16
# Episode 366: Reward sum = 1.18, Last reward = 0.0, Steps = 17
# Episode 367: Reward sum = 2.95, Last reward = 0.0, Steps = 16
# Episode 368: Reward sum = 1.68, Last reward = 0.0, Steps = 14
# Episode 369: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 370: Reward sum = 90.99, Last reward = 90.0, Steps = 18
# Episode 371: Reward sum = -27.72, Last reward = -30.0, Steps = 15
# Episode 372: Reward sum = 1.61, Last reward = 0.0, Steps = 16
# Episode 373: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 374: Reward sum = 1.90, Last reward = 0.0, Steps = 15
# Episode 375: Reward sum = 1.37, Last reward = 0.0, Steps = 17
# Episode 376: Reward sum = 1.48, Last reward = 0.0, Steps = 15
# Episode 377: Reward sum = 0.75, Last reward = 0.0, Steps = 16
# Episode 378: Reward sum = -3.17, Last reward = -5.0, Steps = 16
# Episode 379: Reward sum = 8.81, Last reward = 7.0, Steps = 13
# Episode 380: Reward sum = 0.93, Last reward = 0.0, Steps = 15
# Episode 381: Reward sum = 2.90, Last reward = 0.0, Steps = 19
# Episode 382: Reward sum = -3.26, Last reward = -5.0, Steps = 16
# Episode 383: Reward sum = 1.80, Last reward = 0.0, Steps = 15
# Episode 384: Reward sum = 0.80, Last reward = 0.0, Steps = 16
# Episode 385: Reward sum = 1.20, Last reward = 0.0, Steps = 17
# Episode 386: Reward sum = -2.97, Last reward = -5.0, Steps = 17
# Episode 387: Reward sum = 2.09, Last reward = 0.0, Steps = 17
# Episode 388: Reward sum = 2.58, Last reward = 0.0, Steps = 15
# Episode 389: Reward sum = 2.19, Last reward = 0.0, Steps = 17
# Episode 390: Reward sum = 1.87, Last reward = 0.0, Steps = 15
# Episode 391: Reward sum = 2.94, Last reward = 0.0, Steps = 18
# Episode 392: Reward sum = 2.98, Last reward = 0.0, Steps = 17
# Episode 393: Reward sum = 3.54, Last reward = 0.0, Steps = 15
# Episode 394: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 395: Reward sum = -2.88, Last reward = -5.0, Steps = 15
# Episode 396: Reward sum = 3.21, Last reward = 0.0, Steps = 18
# Episode 397: Reward sum = -0.26, Last reward = -2.0, Steps = 18
# Episode 398: Reward sum = 2.14, Last reward = 0.0, Steps = 15
# Episode 399: Reward sum = 2.37, Last reward = 0.0, Steps = 16
# Episode 400: Reward sum = 0.98, Last reward = 0.0, Steps = 16
# Episode 401: Reward sum = 90.51, Last reward = 90.0, Steps = 16
# Episode 402: Reward sum = -18.07, Last reward = -20.0, Steps = 18
# Episode 403: Reward sum = 1.68, Last reward = 0.0, Steps = 17
# Episode 404: Reward sum = 0.83, Last reward = 0.0, Steps = 15
# Episode 405: Reward sum = 1.65, Last reward = 0.0, Steps = 16
# Episode 406: Reward sum = 1.60, Last reward = 0.0, Steps = 15
# Episode 407: Reward sum = 1.03, Last reward = 0.0, Steps = 16
# Episode 408: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 409: Reward sum = 2.11, Last reward = 0.0, Steps = 17
# Episode 410: Reward sum = -18.20, Last reward = -19.0, Steps = 15
# Episode 411: Reward sum = 16.62, Last reward = 15.0, Steps = 16
# Episode 412: Reward sum = 0.90, Last reward = 0.0, Steps = 17
# Episode 413: Reward sum = 2.03, Last reward = 0.0, Steps = 17
# Episode 414: Reward sum = 1.54, Last reward = 0.0, Steps = 18
# Episode 415: Reward sum = 1.48, Last reward = 0.0, Steps = 15
# Episode 416: Reward sum = 0.71, Last reward = 0.0, Steps = 15
# Episode 417: Reward sum = 2.40, Last reward = 0.0, Steps = 15
# Episode 418: Reward sum = 1.03, Last reward = 0.0, Steps = 16
# Episode 419: Reward sum = 2.63, Last reward = 0.0, Steps = 15
# Episode 420: Reward sum = 1.02, Last reward = 0.0, Steps = 16
# Episode 421: Reward sum = 2.21, Last reward = 0.0, Steps = 16
# Episode 422: Reward sum = 1.69, Last reward = 0.0, Steps = 17
# Episode 423: Reward sum = -28.10, Last reward = -30.0, Steps = 16
# Episode 424: Reward sum = 1.94, Last reward = 0.0, Steps = 15
# Episode 425: Reward sum = -11.09, Last reward = -14.0, Steps = 16
# Episode 426: Reward sum = -3.55, Last reward = -5.0, Steps = 17
# Episode 427: Reward sum = 3.15, Last reward = 0.0, Steps = 18
# Episode 428: Reward sum = 1.93, Last reward = 0.0, Steps = 16
# Episode 429: Reward sum = 2.00, Last reward = 0.0, Steps = 15
# Episode 430: Reward sum = 1.29, Last reward = 0.0, Steps = 16
# Episode 431: Reward sum = 63.98, Last reward = 63.0, Steps = 16
# Episode 432: Reward sum = -27.30, Last reward = -30.0, Steps = 16
# Episode 433: Reward sum = 3.20, Last reward = 0.0, Steps = 16
# Episode 434: Reward sum = -19.40, Last reward = -20.0, Steps = 6
# Episode 435: Reward sum = 1.50, Last reward = 0.0, Steps = 16
# Episode 436: Reward sum = -31.90, Last reward = -33.0, Steps = 16
# Episode 437: Reward sum = 1.80, Last reward = 0.0, Steps = 15
# Episode 438: Reward sum = 1.19, Last reward = 0.0, Steps = 17
# Episode 439: Reward sum = -28.70, Last reward = -30.0, Steps = 17
# Episode 440: Reward sum = 1.33, Last reward = 0.0, Steps = 16
# Episode 441: Reward sum = 2.65, Last reward = 0.0, Steps = 16
# Episode 442: Reward sum = -26.57, Last reward = -27.0, Steps = 17
# Episode 443: Reward sum = 2.02, Last reward = 0.0, Steps = 16
# Episode 444: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 445: Reward sum = 1.79, Last reward = 0.0, Steps = 16
# Episode 446: Reward sum = 0.88, Last reward = 0.0, Steps = 16
# Episode 447: Reward sum = 62.72, Last reward = 60.0, Steps = 17
# Episode 448: Reward sum = 1.40, Last reward = 0.0, Steps = 18
# Episode 449: Reward sum = 2.08, Last reward = 0.0, Steps = 15
# Episode 450: Reward sum = 1.82, Last reward = 0.0, Steps = 16
# Episode 451: Reward sum = 2.16, Last reward = 0.0, Steps = 15
# Episode 452: Reward sum = 0.62, Last reward = 0.0, Steps = 15
# Episode 453: Reward sum = 20.06, Last reward = 18.0, Steps = 15
# Episode 454: Reward sum = 2.15, Last reward = 0.0, Steps = 18
# Episode 455: Reward sum = 91.22, Last reward = 90.0, Steps = 18
# Episode 456: Reward sum = 2.01, Last reward = 0.0, Steps = 17
# Episode 457: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 458: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 459: Reward sum = 2.71, Last reward = 0.0, Steps = 16
# Episode 460: Reward sum = 1.70, Last reward = 0.0, Steps = 15
# Episode 461: Reward sum = 1.97, Last reward = 0.0, Steps = 16
# Episode 462: Reward sum = 0.75, Last reward = 0.0, Steps = 18
# Episode 463: Reward sum = 1.50, Last reward = 0.0, Steps = 16
# Episode 464: Reward sum = 1.33, Last reward = 0.0, Steps = 16
# Episode 465: Reward sum = 1.07, Last reward = 0.0, Steps = 19
# Episode 466: Reward sum = 3.93, Last reward = 0.0, Steps = 16
# Episode 467: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 468: Reward sum = -4.21, Last reward = -5.0, Steps = 4
# Episode 469: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 470: Reward sum = 1.20, Last reward = 0.0, Steps = 15
# Episode 471: Reward sum = -28.16, Last reward = -30.0, Steps = 16
# Episode 472: Reward sum = 1.37, Last reward = 0.0, Steps = 16
# Episode 473: Reward sum = 62.47, Last reward = 60.0, Steps = 16
# Episode 474: Reward sum = 2.91, Last reward = 0.0, Steps = 15
# Episode 475: Reward sum = -6.12, Last reward = -8.0, Steps = 16
# Episode 476: Reward sum = 2.86, Last reward = 0.0, Steps = 17
# Episode 477: Reward sum = 2.67, Last reward = 0.0, Steps = 15
# Episode 478: Reward sum = 28.74, Last reward = 27.0, Steps = 15
# Episode 479: Reward sum = 0.73, Last reward = 0.0, Steps = 19
# Episode 480: Reward sum = 1.01, Last reward = 0.0, Steps = 15
# Episode 481: Reward sum = -11.53, Last reward = -14.0, Steps = 16
# Episode 482: Reward sum = 92.46, Last reward = 90.0, Steps = 17
# Episode 483: Reward sum = 2.49, Last reward = 0.0, Steps = 15
# Episode 484: Reward sum = -24.41, Last reward = -27.0, Steps = 17
# Episode 485: Reward sum = -24.97, Last reward = -27.0, Steps = 15
# Episode 486: Reward sum = 2.15, Last reward = 0.0, Steps = 15
# Episode 487: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 488: Reward sum = 1.72, Last reward = 0.0, Steps = 16
# Episode 489: Reward sum = 3.03, Last reward = 0.0, Steps = 15
# Episode 490: Reward sum = 1.95, Last reward = 0.0, Steps = 15
# Episode 491: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 492: Reward sum = 1.70, Last reward = 0.0, Steps = 15
# Episode 493: Reward sum = 2.37, Last reward = 0.0, Steps = 16
# Episode 494: Reward sum = 2.87, Last reward = 0.0, Steps = 15
# Episode 495: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 496: Reward sum = 1.34, Last reward = 0.0, Steps = 17
# Episode 497: Reward sum = 0.84, Last reward = -2.0, Steps = 15
# Episode 498: Reward sum = 1.99, Last reward = 0.0, Steps = 16
# Episode 499: Reward sum = 1.88, Last reward = 0.0, Steps = 16
# Episode 500: Reward sum = -32.25, Last reward = -33.0, Steps = 16
# Episode 501: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 502: Reward sum = 3.12, Last reward = 0.0, Steps = 16
# Episode 503: Reward sum = 96.37, Last reward = 93.0, Steps = 16
# Episode 504: Reward sum = 1.31, Last reward = 0.0, Steps = 16
# Episode 505: Reward sum = -27.00, Last reward = -29.0, Steps = 11
# Episode 506: Reward sum = 2.82, Last reward = 0.0, Steps = 16
# Episode 507: Reward sum = 2.10, Last reward = 0.0, Steps = 15
# Episode 508: Reward sum = 2.26, Last reward = 0.0, Steps = 15
# Episode 509: Reward sum = 2.62, Last reward = 0.0, Steps = 16
# Episode 510: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 511: Reward sum = 1.53, Last reward = 0.0, Steps = 16
# Episode 512: Reward sum = 3.47, Last reward = 0.0, Steps = 17
# Episode 513: Reward sum = -28.14, Last reward = -30.0, Steps = 16
# Episode 514: Reward sum = 2.66, Last reward = 0.0, Steps = 16
# Episode 515: Reward sum = 1.59, Last reward = 0.0, Steps = 15
# Episode 516: Reward sum = 1.90, Last reward = 0.0, Steps = 17
# Episode 517: Reward sum = 2.47, Last reward = 0.0, Steps = 17
# Episode 518: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 519: Reward sum = 100.40, Last reward = 99.0, Steps = 16
# Episode 520: Reward sum = -36.82, Last reward = -39.0, Steps = 12
# Episode 521: Reward sum = 62.17, Last reward = 60.0, Steps = 16
# Episode 522: Reward sum = -15.50, Last reward = -17.0, Steps = 17
# Episode 523: Reward sum = 1.23, Last reward = 0.0, Steps = 16
# Episode 524: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 525: Reward sum = 3.13, Last reward = 0.0, Steps = 17
# Episode 526: Reward sum = 3.20, Last reward = 0.0, Steps = 16
# Episode 527: Reward sum = 1.02, Last reward = 0.0, Steps = 16
# Episode 528: Reward sum = 2.14, Last reward = 0.0, Steps = 16
# Episode 529: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 530: Reward sum = 20.06, Last reward = 19.0, Steps = 16
# Episode 531: Reward sum = 2.87, Last reward = 0.0, Steps = 18
# Episode 532: Reward sum = 1.43, Last reward = 0.0, Steps = 17
# Episode 533: Reward sum = -15.46, Last reward = -17.0, Steps = 16
# Episode 534: Reward sum = 2.90, Last reward = 0.0, Steps = 16
# Episode 535: Reward sum = 2.02, Last reward = 0.0, Steps = 16
# Episode 536: Reward sum = 2.69, Last reward = 0.0, Steps = 16
# Episode 537: Reward sum = 1.94, Last reward = 0.0, Steps = 17
# Episode 538: Reward sum = 3.14, Last reward = 0.0, Steps = 17
# Episode 539: Reward sum = -29.19, Last reward = -30.0, Steps = 16
# Episode 540: Reward sum = 2.61, Last reward = 0.0, Steps = 17
# Episode 541: Reward sum = 2.05, Last reward = 0.0, Steps = 16
# Episode 542: Reward sum = 2.06, Last reward = 0.0, Steps = 17
# Episode 543: Reward sum = -26.07, Last reward = -27.0, Steps = 16
# Episode 544: Reward sum = 1.47, Last reward = 0.0, Steps = 19
# Episode 545: Reward sum = 3.89, Last reward = 0.0, Steps = 16
# Episode 546: Reward sum = -27.81, Last reward = -30.0, Steps = 17
# Episode 547: Reward sum = 2.88, Last reward = 0.0, Steps = 16
# Episode 548: Reward sum = 1.81, Last reward = 0.0, Steps = 16
# Episode 549: Reward sum = 11.75, Last reward = 10.0, Steps = 16
# Episode 550: Reward sum = 2.12, Last reward = 0.0, Steps = 16
# Episode 551: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 552: Reward sum = 3.01, Last reward = 0.0, Steps = 18
# Episode 553: Reward sum = -2.62, Last reward = -5.0, Steps = 17
# Episode 554: Reward sum = 1.89, Last reward = 0.0, Steps = 16
# Episode 555: Reward sum = 2.22, Last reward = 0.0, Steps = 15
# Episode 556: Reward sum = 2.71, Last reward = 0.0, Steps = 15
# Episode 557: Reward sum = 2.07, Last reward = 0.0, Steps = 17
# Episode 558: Reward sum = -28.28, Last reward = -30.0, Steps = 13
# Episode 559: Reward sum = 2.16, Last reward = 0.0, Steps = 15
# Episode 560: Reward sum = 1.68, Last reward = 0.0, Steps = 17
# Episode 561: Reward sum = 2.07, Last reward = 0.0, Steps = 16
# Episode 562: Reward sum = 2.52, Last reward = 0.0, Steps = 16
# Episode 563: Reward sum = 93.26, Last reward = 90.0, Steps = 18
# Episode 564: Reward sum = 2.24, Last reward = 0.0, Steps = 15
# Episode 565: Reward sum = 2.39, Last reward = 0.0, Steps = 15
# Episode 566: Reward sum = 0.63, Last reward = 0.0, Steps = 15
# Episode 567: Reward sum = 3.97, Last reward = 0.0, Steps = 15
# Episode 568: Reward sum = 19.64, Last reward = 18.0, Steps = 16
# Episode 569: Reward sum = -3.88, Last reward = -5.0, Steps = 17
# Episode 570: Reward sum = 15.72, Last reward = 15.0, Steps = 5
# Episode 571: Reward sum = 1.67, Last reward = 0.0, Steps = 18
# Episode 572: Reward sum = 90.95, Last reward = 90.0, Steps = 17
# Episode 573: Reward sum = 94.73, Last reward = 93.0, Steps = 16
# Episode 574: Reward sum = 90.98, Last reward = 90.0, Steps = 19
# Episode 575: Reward sum = 1.21, Last reward = 0.0, Steps = 16
# Episode 576: Reward sum = 95.09, Last reward = 93.0, Steps = 17
# Episode 577: Reward sum = 1.43, Last reward = 0.0, Steps = 17
# Episode 578: Reward sum = 0.92, Last reward = 0.0, Steps = 16
# Episode 579: Reward sum = -27.87, Last reward = -30.0, Steps = 17
# Episode 580: Reward sum = 1.53, Last reward = 0.0, Steps = 15
# Episode 581: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 582: Reward sum = 1.75, Last reward = 0.0, Steps = 16
# Episode 583: Reward sum = 0.53, Last reward = 0.0, Steps = 16
# Episode 584: Reward sum = 1.20, Last reward = 0.0, Steps = 17
# Episode 585: Reward sum = 2.21, Last reward = 0.0, Steps = 15
# Episode 586: Reward sum = 1.56, Last reward = 0.0, Steps = 17
# Episode 587: Reward sum = 3.04, Last reward = 0.0, Steps = 14
# Episode 588: Reward sum = 1.07, Last reward = 0.0, Steps = 16
# Episode 589: Reward sum = 0.85, Last reward = 0.0, Steps = 16
# Episode 590: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 591: Reward sum = 2.00, Last reward = 0.0, Steps = 17
# Episode 592: Reward sum = 1.96, Last reward = 0.0, Steps = 18
# Episode 593: Reward sum = 1.69, Last reward = 0.0, Steps = 18
# Episode 594: Reward sum = 2.08, Last reward = 0.0, Steps = 17
# Episode 595: Reward sum = 2.28, Last reward = 0.0, Steps = 16
# Episode 596: Reward sum = 2.44, Last reward = 0.0, Steps = 15
# Episode 597: Reward sum = -4.29, Last reward = -5.0, Steps = 16
# Episode 598: Reward sum = 2.29, Last reward = 0.0, Steps = 17
# Episode 599: Reward sum = 2.90, Last reward = 0.0, Steps = 16
# Episode 600: Reward sum = 2.84, Last reward = 0.0, Steps = 20
# Episode 601: Reward sum = 1.95, Last reward = 0.0, Steps = 15
# Episode 602: Reward sum = -28.57, Last reward = -30.0, Steps = 18
# Episode 603: Reward sum = 1.82, Last reward = 0.0, Steps = 17
# Episode 604: Reward sum = 1.64, Last reward = 0.0, Steps = 15
# Episode 605: Reward sum = -25.37, Last reward = -26.0, Steps = 16
# Episode 606: Reward sum = 17.01, Last reward = 15.0, Steps = 16
# Episode 607: Reward sum = 1.87, Last reward = 0.0, Steps = 18
# Episode 608: Reward sum = 2.00, Last reward = 0.0, Steps = 15
# Episode 609: Reward sum = 1.54, Last reward = 0.0, Steps = 17
# Episode 610: Reward sum = 2.67, Last reward = 0.0, Steps = 15
# Episode 611: Reward sum = 1.61, Last reward = 0.0, Steps = 18
# Episode 612: Reward sum = 13.06, Last reward = 10.0, Steps = 17
# Episode 613: Reward sum = 91.53, Last reward = 90.0, Steps = 18
# Episode 614: Reward sum = 2.84, Last reward = 0.0, Steps = 17
# Episode 615: Reward sum = -28.63, Last reward = -30.0, Steps = 17
# Episode 616: Reward sum = 1.94, Last reward = 0.0, Steps = 18
# Episode 617: Reward sum = 0.86, Last reward = 0.0, Steps = 15
# Episode 618: Reward sum = 1.34, Last reward = 0.0, Steps = 17
# Episode 619: Reward sum = 1.51, Last reward = 0.0, Steps = 16
# Episode 620: Reward sum = -14.90, Last reward = -17.0, Steps = 16
# Episode 621: Reward sum = 100.05, Last reward = 99.0, Steps = 18
# Episode 622: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 623: Reward sum = 2.66, Last reward = 0.0, Steps = 16
# Episode 624: Reward sum = 3.01, Last reward = 0.0, Steps = 15
# Episode 625: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 626: Reward sum = 1.93, Last reward = 0.0, Steps = 16
# Episode 627: Reward sum = 0.63, Last reward = 0.0, Steps = 17
# Episode 628: Reward sum = 2.42, Last reward = 0.0, Steps = 15
# Episode 629: Reward sum = 62.06, Last reward = 60.0, Steps = 18
# Episode 630: Reward sum = 2.04, Last reward = 0.0, Steps = 18
# Episode 631: Reward sum = 2.36, Last reward = 0.0, Steps = 16
# Episode 632: Reward sum = 1.86, Last reward = 0.0, Steps = 16
# Episode 633: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 634: Reward sum = 1.93, Last reward = 0.0, Steps = 15
# Episode 635: Reward sum = -25.72, Last reward = -27.0, Steps = 18
# Episode 636: Reward sum = 2.38, Last reward = 0.0, Steps = 17
# Episode 637: Reward sum = 1.23, Last reward = 0.0, Steps = 18
# Episode 638: Reward sum = 0.28, Last reward = 0.0, Steps = 15
# Episode 639: Reward sum = 2.58, Last reward = 0.0, Steps = 17
# Episode 640: Reward sum = 1.50, Last reward = 0.0, Steps = 16
# Episode 641: Reward sum = 2.50, Last reward = 0.0, Steps = 14
# Episode 642: Reward sum = 1.02, Last reward = 0.0, Steps = 15
# Episode 643: Reward sum = -3.35, Last reward = -5.0, Steps = 11
# Episode 644: Reward sum = 1.69, Last reward = 0.0, Steps = 14
# Episode 645: Reward sum = 2.42, Last reward = 0.0, Steps = 16
# Episode 646: Reward sum = 2.31, Last reward = 0.0, Steps = 15
# Episode 647: Reward sum = 0.45, Last reward = 0.0, Steps = 15
# Episode 648: Reward sum = 94.84, Last reward = 93.0, Steps = 18
# Episode 649: Reward sum = 1.40, Last reward = 0.0, Steps = 16
# Episode 650: Reward sum = 1.55, Last reward = 0.0, Steps = 16
# Episode 651: Reward sum = 0.89, Last reward = 0.0, Steps = 15
# Episode 652: Reward sum = 1.25, Last reward = 0.0, Steps = 16
# Episode 653: Reward sum = 2.68, Last reward = 0.0, Steps = 17
# Episode 654: Reward sum = -27.31, Last reward = -30.0, Steps = 18
# Episode 655: Reward sum = 2.03, Last reward = 0.0, Steps = 14
# Episode 656: Reward sum = 2.95, Last reward = 0.0, Steps = 16
# Episode 657: Reward sum = 0.56, Last reward = 0.0, Steps = 16
# Episode 658: Reward sum = 2.00, Last reward = 0.0, Steps = 18
# Episode 659: Reward sum = 1.39, Last reward = 0.0, Steps = 18
# Episode 660: Reward sum = 2.08, Last reward = 0.0, Steps = 17
# Episode 661: Reward sum = 2.28, Last reward = 0.0, Steps = 17
# Episode 662: Reward sum = 2.84, Last reward = 0.0, Steps = 16
# Episode 663: Reward sum = 1.96, Last reward = 0.0, Steps = 18
# Episode 664: Reward sum = 2.79, Last reward = 0.0, Steps = 16
# Episode 665: Reward sum = 2.34, Last reward = 0.0, Steps = 16
# Episode 666: Reward sum = 1.57, Last reward = 0.0, Steps = 17
# Episode 667: Reward sum = -12.60, Last reward = -14.0, Steps = 15
# Episode 668: Reward sum = -23.04, Last reward = -24.0, Steps = 17
# Episode 669: Reward sum = 1.44, Last reward = 0.0, Steps = 17
# Episode 670: Reward sum = 90.98, Last reward = 90.0, Steps = 15
# Episode 671: Reward sum = 1.81, Last reward = 0.0, Steps = 16
# Episode 672: Reward sum = 2.65, Last reward = 0.0, Steps = 17
# Episode 673: Reward sum = 1.69, Last reward = 0.0, Steps = 15
# Episode 674: Reward sum = 3.05, Last reward = 0.0, Steps = 16
# Episode 675: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 676: Reward sum = 1.19, Last reward = 0.0, Steps = 15
# Episode 677: Reward sum = 38.35, Last reward = 36.0, Steps = 15
# Episode 678: Reward sum = 1.07, Last reward = 0.0, Steps = 16
# Episode 679: Reward sum = 1.66, Last reward = 0.0, Steps = 18
# Episode 680: Reward sum = 1.56, Last reward = 0.0, Steps = 17
# Episode 681: Reward sum = 2.45, Last reward = 0.0, Steps = 15
# Episode 682: Reward sum = 1.62, Last reward = 0.0, Steps = 15
# Episode 683: Reward sum = 2.82, Last reward = 0.0, Steps = 16
# Episode 684: Reward sum = 1.92, Last reward = 0.0, Steps = 16
# Episode 685: Reward sum = 2.99, Last reward = 0.0, Steps = 14
# Episode 686: Reward sum = 2.29, Last reward = 0.0, Steps = 14
# Episode 687: Reward sum = 3.34, Last reward = 0.0, Steps = 16
# Episode 688: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 689: Reward sum = 3.40, Last reward = 0.0, Steps = 16
# Episode 690: Reward sum = 2.95, Last reward = 0.0, Steps = 17
# Episode 691: Reward sum = 0.98, Last reward = 0.0, Steps = 17
# Episode 692: Reward sum = 1.84, Last reward = 0.0, Steps = 16
# Episode 693: Reward sum = 3.00, Last reward = 0.0, Steps = 17
# Episode 694: Reward sum = 2.10, Last reward = 0.0, Steps = 17
# Episode 695: Reward sum = 1.46, Last reward = 0.0, Steps = 18
# Episode 696: Reward sum = 1.69, Last reward = 0.0, Steps = 16
# Episode 697: Reward sum = 0.89, Last reward = 0.0, Steps = 17
# Episode 698: Reward sum = 91.32, Last reward = 90.0, Steps = 16
# Episode 699: Reward sum = 1.58, Last reward = 0.0, Steps = 16
# Episode 700: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 701: Reward sum = 31.10, Last reward = 30.0, Steps = 16
# Episode 702: Reward sum = 0.90, Last reward = 0.0, Steps = 17
# Episode 703: Reward sum = -4.54, Last reward = -5.0, Steps = 17
# Episode 704: Reward sum = 1.33, Last reward = 0.0, Steps = 17
# Episode 705: Reward sum = 0.76, Last reward = 0.0, Steps = 16
# Episode 706: Reward sum = 0.99, Last reward = 0.0, Steps = 15
# Episode 707: Reward sum = 91.08, Last reward = 90.0, Steps = 16
# Episode 708: Reward sum = 16.74, Last reward = 15.0, Steps = 17
# Episode 709: Reward sum = 2.47, Last reward = 0.0, Steps = 15
# Episode 710: Reward sum = 61.68, Last reward = 60.0, Steps = 19
# Episode 711: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 712: Reward sum = 2.21, Last reward = 0.0, Steps = 18
# Episode 713: Reward sum = 2.32, Last reward = 0.0, Steps = 16
# Episode 714: Reward sum = 2.64, Last reward = 0.0, Steps = 14
# Episode 715: Reward sum = 2.60, Last reward = 0.0, Steps = 16
# Episode 716: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 717: Reward sum = 1.43, Last reward = 0.0, Steps = 17
# Episode 718: Reward sum = 1.99, Last reward = 0.0, Steps = 17
# Episode 719: Reward sum = 2.09, Last reward = 0.0, Steps = 14
# Episode 720: Reward sum = -5.36, Last reward = -8.0, Steps = 17
# Episode 721: Reward sum = 1.78, Last reward = 0.0, Steps = 15
# Episode 722: Reward sum = 3.05, Last reward = 0.0, Steps = 17
# Episode 723: Reward sum = 1.88, Last reward = 0.0, Steps = 16
# Episode 724: Reward sum = 1.64, Last reward = 0.0, Steps = 16
# Episode 725: Reward sum = 3.45, Last reward = 0.0, Steps = 16
# Episode 726: Reward sum = 3.02, Last reward = 0.0, Steps = 15
# Episode 727: Reward sum = 2.09, Last reward = 0.0, Steps = 17
# Episode 728: Reward sum = 20.79, Last reward = 18.0, Steps = 16
# Episode 729: Reward sum = 61.13, Last reward = 60.0, Steps = 19
# Episode 730: Reward sum = 3.37, Last reward = 0.0, Steps = 17
# Episode 731: Reward sum = 93.85, Last reward = 93.0, Steps = 17
# Episode 732: Reward sum = 1.91, Last reward = 0.0, Steps = 17
# Episode 733: Reward sum = -12.85, Last reward = -14.0, Steps = 17
# Episode 734: Reward sum = 3.12, Last reward = 0.0, Steps = 16
# Episode 735: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 736: Reward sum = 1.47, Last reward = 0.0, Steps = 16
# Episode 737: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 738: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 739: Reward sum = 1.63, Last reward = 0.0, Steps = 15
# Episode 740: Reward sum = 0.98, Last reward = 0.0, Steps = 16
# Episode 741: Reward sum = -36.64, Last reward = -39.0, Steps = 17
# Episode 742: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 743: Reward sum = 2.40, Last reward = 0.0, Steps = 15
# Episode 744: Reward sum = 2.61, Last reward = 0.0, Steps = 17
# Episode 745: Reward sum = 2.87, Last reward = 0.0, Steps = 17
# Episode 746: Reward sum = 1.67, Last reward = 0.0, Steps = 17
# Episode 747: Reward sum = 1.11, Last reward = 0.0, Steps = 16
# Episode 748: Reward sum = 2.51, Last reward = 0.0, Steps = 15
# Episode 749: Reward sum = 16.83, Last reward = 15.0, Steps = 17
# Episode 750: Reward sum = 1.24, Last reward = 0.0, Steps = 15
# Episode 751: Reward sum = 2.43, Last reward = 0.0, Steps = 16
# Episode 752: Reward sum = -5.00, Last reward = -5.0, Steps = 1
# Episode 753: Reward sum = 2.67, Last reward = 0.0, Steps = 15
# Episode 754: Reward sum = -11.78, Last reward = -14.0, Steps = 17
# Episode 755: Reward sum = 1.25, Last reward = 0.0, Steps = 17
# Episode 756: Reward sum = -26.75, Last reward = -30.0, Steps = 17
# Episode 757: Reward sum = 1.38, Last reward = 0.0, Steps = 17
# Episode 758: Reward sum = -1.91, Last reward = -5.0, Steps = 15
# Episode 759: Reward sum = -3.60, Last reward = -5.0, Steps = 16
# Episode 760: Reward sum = 1.49, Last reward = 0.0, Steps = 15
# Episode 761: Reward sum = 64.85, Last reward = 63.0, Steps = 17
# Episode 762: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 763: Reward sum = 1.84, Last reward = 0.0, Steps = 15
# Episode 764: Reward sum = 1.15, Last reward = 0.0, Steps = 16
# Episode 765: Reward sum = 19.92, Last reward = 18.0, Steps = 15
# Episode 766: Reward sum = 2.09, Last reward = 0.0, Steps = 16
# Episode 767: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 768: Reward sum = 1.39, Last reward = 0.0, Steps = 16
# ...
# Episode 1486: Reward sum = 1.47, Last reward = 0.0, Steps = 15
# Episode 1487: Reward sum = 61.28, Last reward = 60.0, Steps = 18
# Episode 1488: Reward sum = -0.50, Last reward = -2.0, Steps = 15
# Episode 1489: Reward sum = 3.07, Last reward = 0.0, Steps = 17
# Episode 1490: Reward sum = 63.96, Last reward = 63.0, Steps = 16
# Episode 1491: Reward sum = 2.10, Last reward = 0.0, Steps = 16
# Episode 1492: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 1493: Reward sum = 1.31, Last reward = 0.0, Steps = 16
# Episode 1494: Reward sum = 2.95, Last reward = 0.0, Steps = 14
# Episode 1495: Reward sum = 2.16, Last reward = 0.0, Steps = 15
# Episode 1496: Reward sum = 2.62, Last reward = 0.0, Steps = 16
# Episode 1497: Reward sum = 2.17, Last reward = 0.0, Steps = 17
# Episode 1498: Reward sum = -28.91, Last reward = -30.0, Steps = 15
# Episode 1499: Reward sum = 2.58, Last reward = 0.0, Steps = 17
# Episode 1500: Reward sum = -40.95, Last reward = -42.0, Steps = 15
# Episode 1501: Reward sum = 0.91, Last reward = 0.0, Steps = 15
# Episode 1502: Reward sum = 1.57, Last reward = 0.0, Steps = 15
# Episode 1503: Reward sum = 2.39, Last reward = 0.0, Steps = 15
# Episode 1504: Reward sum = 3.55, Last reward = 0.0, Steps = 16
# Episode 1505: Reward sum = 2.53, Last reward = 0.0, Steps = 17
# Episode 1506: Reward sum = 1.50, Last reward = 0.0, Steps = 16
# Episode 1507: Reward sum = 1.76, Last reward = 0.0, Steps = 17
# Episode 1508: Reward sum = 0.97, Last reward = 0.0, Steps = 15
# Episode 1509: Reward sum = 2.66, Last reward = 0.0, Steps = 14
# Episode 1510: Reward sum = 2.34, Last reward = 0.0, Steps = 14
# Episode 1511: Reward sum = 1.35, Last reward = 0.0, Steps = 15
# Episode 1512: Reward sum = 1.98, Last reward = 0.0, Steps = 16
# Episode 1513: Reward sum = 91.80, Last reward = 90.0, Steps = 18
# Episode 1514: Reward sum = 1.62, Last reward = 0.0, Steps = 15
# Episode 1515: Reward sum = 1.39, Last reward = 0.0, Steps = 17
# Episode 1516: Reward sum = -26.14, Last reward = -27.0, Steps = 16
# Episode 1517: Reward sum = 2.73, Last reward = 0.0, Steps = 15
# Episode 1518: Reward sum = 2.48, Last reward = 0.0, Steps = 17
# Episode 1519: Reward sum = 1.08, Last reward = 0.0, Steps = 16
# Episode 1520: Reward sum = 2.70, Last reward = 0.0, Steps = 16
# Episode 1521: Reward sum = 1.91, Last reward = 0.0, Steps = 16
# Episode 1522: Reward sum = 1.78, Last reward = 0.0, Steps = 16
# Episode 1523: Reward sum = 3.00, Last reward = 0.0, Steps = 16
# Episode 1524: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 1525: Reward sum = 1.86, Last reward = 0.0, Steps = 14
# Episode 1526: Reward sum = -27.94, Last reward = -30.0, Steps = 17
# Episode 1527: Reward sum = 62.51, Last reward = 60.0, Steps = 16
# Episode 1528: Reward sum = 2.33, Last reward = 0.0, Steps = 17
# Episode 1529: Reward sum = 19.64, Last reward = 18.0, Steps = 17
# Episode 1530: Reward sum = 1.83, Last reward = 0.0, Steps = 16
# Episode 1531: Reward sum = 3.68, Last reward = 0.0, Steps = 17
# Episode 1532: Reward sum = 1.43, Last reward = 0.0, Steps = 16
# Episode 1533: Reward sum = 1.19, Last reward = 0.0, Steps = 18
# Episode 1534: Reward sum = 2.53, Last reward = 0.0, Steps = 15
# Episode 1535: Reward sum = 2.13, Last reward = 0.0, Steps = 16
# Episode 1536: Reward sum = -3.63, Last reward = -5.0, Steps = 9
# Episode 1537: Reward sum = 2.82, Last reward = 0.0, Steps = 17
# Episode 1538: Reward sum = -6.08, Last reward = -8.0, Steps = 16
# Episode 1539: Reward sum = 2.95, Last reward = 0.0, Steps = 16
# Episode 1540: Reward sum = -29.45, Last reward = -30.0, Steps = 16
# Episode 1541: Reward sum = 1.81, Last reward = 0.0, Steps = 15
# Episode 1542: Reward sum = 3.00, Last reward = 0.0, Steps = 16
# Episode 1543: Reward sum = 3.23, Last reward = 0.0, Steps = 14
# Episode 1544: Reward sum = 2.41, Last reward = 0.0, Steps = 17
# Episode 1545: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 1546: Reward sum = 90.73, Last reward = 90.0, Steps = 18
# Episode 1547: Reward sum = 3.20, Last reward = 0.0, Steps = 16
# Episode 1548: Reward sum = 1.48, Last reward = 0.0, Steps = 17
# Episode 1549: Reward sum = 2.34, Last reward = 0.0, Steps = 16
# Episode 1550: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 1551: Reward sum = 1.82, Last reward = 0.0, Steps = 15
# Episode 1552: Reward sum = 2.20, Last reward = 0.0, Steps = 15
# Episode 1553: Reward sum = 17.06, Last reward = 15.0, Steps = 16
# Episode 1554: Reward sum = 1.60, Last reward = 0.0, Steps = 15
# Episode 1555: Reward sum = 2.32, Last reward = 0.0, Steps = 15
# Episode 1556: Reward sum = -28.79, Last reward = -30.0, Steps = 17
# Episode 1557: Reward sum = 1.22, Last reward = 0.0, Steps = 17
# Episode 1558: Reward sum = 1.92, Last reward = 0.0, Steps = 16
# Episode 1559: Reward sum = 1.50, Last reward = 0.0, Steps = 15
# Episode 1560: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 1561: Reward sum = 20.02, Last reward = 18.0, Steps = 17
# Episode 1562: Reward sum = 91.37, Last reward = 90.0, Steps = 14
# Episode 1563: Reward sum = 2.57, Last reward = 0.0, Steps = 15
# Episode 1564: Reward sum = 1.61, Last reward = 0.0, Steps = 16
# Episode 1565: Reward sum = 17.95, Last reward = 16.0, Steps = 18
# Episode 1566: Reward sum = 20.20, Last reward = 18.0, Steps = 17
# Episode 1567: Reward sum = 2.16, Last reward = 0.0, Steps = 17
# Episode 1568: Reward sum = 2.07, Last reward = 0.0, Steps = 15
# Episode 1569: Reward sum = 1.52, Last reward = 0.0, Steps = 17
# Episode 1570: Reward sum = 2.33, Last reward = 0.0, Steps = 15
# Episode 1571: Reward sum = 0.96, Last reward = 0.0, Steps = 17
# Episode 1572: Reward sum = 2.40, Last reward = 0.0, Steps = 16
# Episode 1573: Reward sum = 2.36, Last reward = 0.0, Steps = 15
# Episode 1574: Reward sum = 3.15, Last reward = 0.0, Steps = 17
# Episode 1575: Reward sum = 2.70, Last reward = 0.0, Steps = 17
# Episode 1576: Reward sum = 2.47, Last reward = 0.0, Steps = 17
# Episode 1577: Reward sum = 1.50, Last reward = 0.0, Steps = 15
# Episode 1578: Reward sum = 1.57, Last reward = 0.0, Steps = 17
# Episode 1579: Reward sum = 2.70, Last reward = 0.0, Steps = 16
# Episode 1580: Reward sum = -1.46, Last reward = -5.0, Steps = 14
# Episode 1581: Reward sum = 1.75, Last reward = 0.0, Steps = 16
# Episode 1582: Reward sum = 3.13, Last reward = 0.0, Steps = 16
# Episode 1583: Reward sum = -2.34, Last reward = -5.0, Steps = 16
# Episode 1584: Reward sum = 24.52, Last reward = 22.0, Steps = 15
# Episode 1585: Reward sum = 2.89, Last reward = 0.0, Steps = 15
# Episode 1586: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 1587: Reward sum = 91.01, Last reward = 90.0, Steps = 17
# Episode 1588: Reward sum = 1.83, Last reward = 0.0, Steps = 15
# Episode 1589: Reward sum = 2.41, Last reward = 0.0, Steps = 15
# Episode 1590: Reward sum = 2.45, Last reward = 0.0, Steps = 16
# Episode 1591: Reward sum = 20.35, Last reward = 18.0, Steps = 16
# Episode 1592: Reward sum = 1.06, Last reward = 0.0, Steps = 16
# Episode 1593: Reward sum = 1.51, Last reward = 0.0, Steps = 16
# Episode 1594: Reward sum = -35.78, Last reward = -39.0, Steps = 15
# Episode 1595: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 1596: Reward sum = 0.94, Last reward = 0.0, Steps = 17
# Episode 1597: Reward sum = 19.78, Last reward = 18.0, Steps = 15
# Episode 1598: Reward sum = 61.66, Last reward = 60.0, Steps = 19
# Episode 1599: Reward sum = 1.87, Last reward = 0.0, Steps = 15
# Episode 1600: Reward sum = 1.04, Last reward = 0.0, Steps = 16
# Episode 1601: Reward sum = -29.23, Last reward = -30.0, Steps = 17
# Episode 1602: Reward sum = 3.11, Last reward = 0.0, Steps = 18
# Episode 1603: Reward sum = 1.98, Last reward = 0.0, Steps = 17
# Episode 1604: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 1605: Reward sum = 1.75, Last reward = 0.0, Steps = 16
# Episode 1606: Reward sum = 1.78, Last reward = 0.0, Steps = 15
# Episode 1607: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 1608: Reward sum = 17.96, Last reward = 15.0, Steps = 17
# Episode 1609: Reward sum = 0.88, Last reward = 0.0, Steps = 16
# Episode 1610: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 1611: Reward sum = 1.56, Last reward = 0.0, Steps = 14
# Episode 1612: Reward sum = 1.66, Last reward = 0.0, Steps = 17
# Episode 1613: Reward sum = -14.18, Last reward = -17.0, Steps = 15
# Episode 1614: Reward sum = 100.00, Last reward = 90.0, Steps = 17
# Episode 1615: Reward sum = 2.24, Last reward = 0.0, Steps = 14
# Episode 1616: Reward sum = 1.89, Last reward = 0.0, Steps = 15
# Episode 1617: Reward sum = 1.44, Last reward = 0.0, Steps = 17
# Episode 1618: Reward sum = 2.16, Last reward = 0.0, Steps = 16
# Episode 1619: Reward sum = -2.83, Last reward = -5.0, Steps = 16
# Episode 1620: Reward sum = -18.66, Last reward = -20.0, Steps = 16
# Episode 1621: Reward sum = 1.60, Last reward = 0.0, Steps = 16
# Episode 1622: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 1623: Reward sum = 2.34, Last reward = 0.0, Steps = 17
# Episode 1624: Reward sum = 2.36, Last reward = 0.0, Steps = 17
# Episode 1625: Reward sum = 1.25, Last reward = 0.0, Steps = 16
# Episode 1626: Reward sum = 92.37, Last reward = 90.0, Steps = 16
# Episode 1627: Reward sum = 2.00, Last reward = 0.0, Steps = 17
# Episode 1628: Reward sum = 2.70, Last reward = 0.0, Steps = 15
# Episode 1629: Reward sum = -4.23, Last reward = -5.0, Steps = 5
# Episode 1630: Reward sum = 20.97, Last reward = 18.0, Steps = 15
# Episode 1631: Reward sum = 1.79, Last reward = 0.0, Steps = 16
# Episode 1632: Reward sum = 2.08, Last reward = 0.0, Steps = 15
# Episode 1633: Reward sum = 1.32, Last reward = 0.0, Steps = 16
# Episode 1634: Reward sum = 65.25, Last reward = 63.0, Steps = 20
# Episode 1635: Reward sum = 2.90, Last reward = 0.0, Steps = 16
# Episode 1636: Reward sum = 0.82, Last reward = 0.0, Steps = 15
# Episode 1637: Reward sum = 2.69, Last reward = 0.0, Steps = 15
# Episode 1638: Reward sum = 1.34, Last reward = 0.0, Steps = 15
# Episode 1639: Reward sum = 1.74, Last reward = 0.0, Steps = 15
# Episode 1640: Reward sum = 0.60, Last reward = 0.0, Steps = 16
# Episode 1641: Reward sum = 0.80, Last reward = 0.0, Steps = 16
# Episode 1642: Reward sum = 1.43, Last reward = 0.0, Steps = 15
# Episode 1643: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 1644: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 1645: Reward sum = 2.17, Last reward = 0.0, Steps = 17
# Episode 1646: Reward sum = 1.59, Last reward = 0.0, Steps = 15
# Episode 1647: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 1648: Reward sum = 2.11, Last reward = 0.0, Steps = 16
# Episode 1649: Reward sum = 2.71, Last reward = 0.0, Steps = 17
# Episode 1650: Reward sum = 2.67, Last reward = 0.0, Steps = 16
# Episode 1651: Reward sum = -12.75, Last reward = -14.0, Steps = 17
# Episode 1652: Reward sum = -29.80, Last reward = -33.0, Steps = 19
# Episode 1653: Reward sum = 3.14, Last reward = 0.0, Steps = 15
# Episode 1654: Reward sum = 1.92, Last reward = 0.0, Steps = 15
# Episode 1655: Reward sum = 1.10, Last reward = 0.0, Steps = 17
# Episode 1656: Reward sum = 2.50, Last reward = 0.0, Steps = 18
# Episode 1657: Reward sum = 2.94, Last reward = 0.0, Steps = 17
# Episode 1658: Reward sum = 16.36, Last reward = 15.0, Steps = 16
# Episode 1659: Reward sum = 3.63, Last reward = 0.0, Steps = 17
# Episode 1660: Reward sum = 1.16, Last reward = 0.0, Steps = 16
# Episode 1661: Reward sum = 1.41, Last reward = 0.0, Steps = 15
# Episode 1662: Reward sum = 0.59, Last reward = -2.0, Steps = 14
# Episode 1663: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 1664: Reward sum = 3.55, Last reward = 0.0, Steps = 16
# Episode 1665: Reward sum = 2.46, Last reward = 0.0, Steps = 17
# Episode 1666: Reward sum = 3.06, Last reward = 0.0, Steps = 18
# Episode 1667: Reward sum = 2.31, Last reward = 0.0, Steps = 16
# Episode 1668: Reward sum = 0.89, Last reward = 0.0, Steps = 15
# Episode 1669: Reward sum = 1.66, Last reward = 0.0, Steps = 16
# Episode 1670: Reward sum = 1.24, Last reward = 0.0, Steps = 18
# Episode 1671: Reward sum = 1.07, Last reward = 0.0, Steps = 17
# Episode 1672: Reward sum = 3.40, Last reward = 0.0, Steps = 16
# Episode 1673: Reward sum = 92.01, Last reward = 90.0, Steps = 17
# Episode 1674: Reward sum = 2.80, Last reward = 0.0, Steps = 15
# Episode 1675: Reward sum = 2.04, Last reward = 0.0, Steps = 17
# Episode 1676: Reward sum = 2.45, Last reward = 0.0, Steps = 15
# Episode 1677: Reward sum = 16.28, Last reward = 15.0, Steps = 7
# Episode 1678: Reward sum = 90.65, Last reward = 90.0, Steps = 17
# Episode 1679: Reward sum = 2.92, Last reward = 0.0, Steps = 15
# Episode 1680: Reward sum = -3.73, Last reward = -5.0, Steps = 16
# Episode 1681: Reward sum = 2.97, Last reward = 0.0, Steps = 15
# Episode 1682: Reward sum = 2.31, Last reward = 0.0, Steps = 18
# Episode 1683: Reward sum = 1.17, Last reward = 0.0, Steps = 15
# Episode 1684: Reward sum = 2.05, Last reward = 0.0, Steps = 15
# Episode 1685: Reward sum = 1.88, Last reward = 0.0, Steps = 16
# Episode 1686: Reward sum = 3.21, Last reward = 0.0, Steps = 15
# Episode 1687: Reward sum = 19.29, Last reward = 18.0, Steps = 16
# Episode 1688: Reward sum = 2.22, Last reward = 0.0, Steps = 15
# Episode 1689: Reward sum = 1.92, Last reward = 0.0, Steps = 16
# Episode 1690: Reward sum = 2.38, Last reward = 0.0, Steps = 17
# Episode 1691: Reward sum = 1.70, Last reward = 0.0, Steps = 17
# Episode 1692: Reward sum = 2.84, Last reward = 0.0, Steps = 17
# Episode 1693: Reward sum = -4.16, Last reward = -5.0, Steps = 16
# Episode 1694: Reward sum = 0.82, Last reward = 0.0, Steps = 15
# Episode 1695: Reward sum = 1.55, Last reward = 0.0, Steps = 16
# Episode 1696: Reward sum = 93.86, Last reward = 93.0, Steps = 15
# Episode 1697: Reward sum = 1.56, Last reward = 0.0, Steps = 16
# Episode 1698: Reward sum = -31.36, Last reward = -33.0, Steps = 14
# Episode 1699: Reward sum = -2.20, Last reward = -5.0, Steps = 14
# Episode 1700: Reward sum = 16.43, Last reward = 15.0, Steps = 17
# Episode 1701: Reward sum = 1.88, Last reward = 0.0, Steps = 17
# Episode 1702: Reward sum = 1.36, Last reward = 0.0, Steps = 17
# Episode 1703: Reward sum = 2.02, Last reward = 0.0, Steps = 19
# Episode 1704: Reward sum = 2.17, Last reward = 0.0, Steps = 16
# Episode 1705: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 1706: Reward sum = 4.03, Last reward = 0.0, Steps = 15
# Episode 1707: Reward sum = 1.30, Last reward = 0.0, Steps = 17
# Episode 1708: Reward sum = 2.32, Last reward = 0.0, Steps = 17
# Episode 1709: Reward sum = 2.57, Last reward = 0.0, Steps = 15
# Episode 1710: Reward sum = 3.05, Last reward = 0.0, Steps = 16
# Episode 1711: Reward sum = 1.79, Last reward = 0.0, Steps = 15
# Episode 1712: Reward sum = 4.20, Last reward = 0.0, Steps = 16
# Episode 1713: Reward sum = 2.21, Last reward = 0.0, Steps = 17
# /tmp/ipykernel_59706/489440595.py:81: RuntimeWarning: invalid value encountered in divide
#   action_probs /= np.sum(action_probs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 7
#       5 logger = Logger()
#       6 agent = ActorCritic(env, policy, value_network, logger)
# ----> 7 agent.train(2000)
#
# Cell In[86], line 151, in ActorCritic.train(self, episodes, save_freq)
#     149 def train(self, episodes=1, save_freq=20):
#     150     for episode in range(episodes):
# --> 151         episode_reward, last_reward, steps = self.run_episode()
#     152         self.training_rewards_per_episode_sum.append(episode_reward)
#     153         self.training_rewards_per_episode_last_one.append(last_reward)
#
# Cell In[86], line 133, in ActorCritic.run_episode(self, log_transition)
#     131 last_reward = 0
#     132 while not done:
# --> 133     action = self.sample_action(state)
#     134     next_state, reward, done, truncated, _ = self.env.step(action)
#     135     next_state = self.process_state(next_state)
#
# Cell In[86], line 82, in ActorCritic.sample_action(self, state)
#      80 action_probs[(state[:27]==0)] = 0.0
#      81 action_probs /= np.sum(action_probs)
# ---> 82 action = np.random.choice(len(action_probs), p=action_probs)
#      83 return action
#
# File numpy/random/mtrand.pyx:994, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN

# %%
plot_rewards(logger.log_dir, agent.training_rewards_per_episode_last_one, title="Training Rewards", save_fig=True)

# %%
agent_eval = ActorCritic(env, policy, value_network, logger)
agent_eval.evaluate(400)
# Out:
# Episode 1: Reward sum = 2.09, Last reward = 0.0, Steps = 15
# Episode 2: Reward sum = 0.90, Last reward = 0.0, Steps = 15
# Episode 3: Reward sum = 2.83, Last reward = 0.0, Steps = 17
# Episode 4: Reward sum = 2.10, Last reward = 0.0, Steps = 15
# Episode 5: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 6: Reward sum = 2.48, Last reward = 0.0, Steps = 16
# Episode 7: Reward sum = 1.85, Last reward = 0.0, Steps = 17
# Episode 8: Reward sum = 64.22, Last reward = 63.0, Steps = 17
# Episode 9: Reward sum = 2.21, Last reward = 0.0, Steps = 17
# Episode 10: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 11: Reward sum = 1.42, Last reward = 0.0, Steps = 16
# Episode 12: Reward sum = 1.42, Last reward = 0.0, Steps = 17
# Episode 13: Reward sum = 1.15, Last reward = 0.0, Steps = 15
# Episode 14: Reward sum = 1.59, Last reward = 0.0, Steps = 15
# Episode 15: Reward sum = 1.72, Last reward = 0.0, Steps = 15
# Episode 16: Reward sum = 2.69, Last reward = 0.0, Steps = 18
# Episode 17: Reward sum = 2.55, Last reward = 0.0, Steps = 16
# Episode 18: Reward sum = 1.70, Last reward = 0.0, Steps = 16
# Episode 19: Reward sum = -28.09, Last reward = -30.0, Steps = 18
# Episode 20: Reward sum = 2.07, Last reward = 0.0, Steps = 16
# Episode 21: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 22: Reward sum = 1.70, Last reward = 0.0, Steps = 18
# Episode 23: Reward sum = 2.61, Last reward = 0.0, Steps = 16
# Episode 24: Reward sum = 2.80, Last reward = 0.0, Steps = 17
# Episode 25: Reward sum = 12.22, Last reward = 10.0, Steps = 18
# Episode 26: Reward sum = -16.89, Last reward = -20.0, Steps = 19
# Episode 27: Reward sum = 2.17, Last reward = 0.0, Steps = 17
# Episode 28: Reward sum = 2.54, Last reward = 0.0, Steps = 14
# Episode 29: Reward sum = 1.94, Last reward = 0.0, Steps = 14
# Episode 30: Reward sum = 2.82, Last reward = 0.0, Steps = 16
# Episode 31: Reward sum = 2.98, Last reward = 0.0, Steps = 15
# Episode 32: Reward sum = 1.42, Last reward = 0.0, Steps = 16
# Episode 33: Reward sum = 2.45, Last reward = 0.0, Steps = 17
# Episode 34: Reward sum = 1.51, Last reward = 0.0, Steps = 16
# Episode 35: Reward sum = 2.84, Last reward = 0.0, Steps = 16
# Episode 36: Reward sum = 62.39, Last reward = 60.0, Steps = 17
# Episode 37: Reward sum = 1.56, Last reward = 0.0, Steps = 15
# Episode 38: Reward sum = 1.46, Last reward = 0.0, Steps = 20
# Episode 39: Reward sum = 1.60, Last reward = 0.0, Steps = 16
# Episode 40: Reward sum = 1.58, Last reward = 0.0, Steps = 15
# Episode 41: Reward sum = -3.00, Last reward = -5.0, Steps = 16
# Episode 42: Reward sum = 2.71, Last reward = 0.0, Steps = 16
# Episode 43: Reward sum = 1.18, Last reward = 0.0, Steps = 15
# Episode 44: Reward sum = 2.52, Last reward = 0.0, Steps = 16
# Episode 45: Reward sum = 2.10, Last reward = 0.0, Steps = 17
# Episode 46: Reward sum = 1.20, Last reward = 0.0, Steps = 15
# Episode 47: Reward sum = 2.03, Last reward = 0.0, Steps = 15
# Episode 48: Reward sum = 1.62, Last reward = 0.0, Steps = 17
# Episode 49: Reward sum = 2.99, Last reward = 0.0, Steps = 17
# Episode 50: Reward sum = 1.57, Last reward = 0.0, Steps = 16
# Episode 51: Reward sum = 2.28, Last reward = 0.0, Steps = 16
# Episode 52: Reward sum = 1.54, Last reward = 0.0, Steps = 17
# Episode 53: Reward sum = 91.94, Last reward = 90.0, Steps = 18
# Episode 54: Reward sum = 2.34, Last reward = 0.0, Steps = 14
# Episode 55: Reward sum = 3.53, Last reward = 0.0, Steps = 15
# Episode 56: Reward sum = 1.01, Last reward = 0.0, Steps = 15
# Episode 57: Reward sum = 26.07, Last reward = 24.0, Steps = 17
# Episode 58: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 59: Reward sum = 35.56, Last reward = 33.0, Steps = 17
# Episode 60: Reward sum = 2.49, Last reward = 0.0, Steps = 18
# Episode 61: Reward sum = 1.51, Last reward = 0.0, Steps = 16
# Episode 62: Reward sum = 90.60, Last reward = 90.0, Steps = 17
# Episode 63: Reward sum = 2.56, Last reward = 0.0, Steps = 15
# Episode 64: Reward sum = -28.49, Last reward = -30.0, Steps = 16
# Episode 65: Reward sum = 2.75, Last reward = 0.0, Steps = 17
# Episode 66: Reward sum = 2.36, Last reward = 0.0, Steps = 17
# Episode 67: Reward sum = 2.19, Last reward = 0.0, Steps = 16
# Episode 68: Reward sum = -3.88, Last reward = -5.0, Steps = 7
# Episode 69: Reward sum = 3.49, Last reward = 0.0, Steps = 16
# Episode 70: Reward sum = 1.54, Last reward = 0.0, Steps = 15
# Episode 71: Reward sum = 2.11, Last reward = 0.0, Steps = 15
# Episode 72: Reward sum = 91.62, Last reward = 90.0, Steps = 16
# Episode 73: Reward sum = 64.94, Last reward = 63.0, Steps = 17
# Episode 74: Reward sum = 1.73, Last reward = 0.0, Steps = 18
# Episode 75: Reward sum = 2.69, Last reward = 0.0, Steps = 16
# Episode 76: Reward sum = 1.03, Last reward = 0.0, Steps = 17
# Episode 77: Reward sum = 0.73, Last reward = 0.0, Steps = 16
# Episode 78: Reward sum = 2.06, Last reward = 0.0, Steps = 17
# Episode 79: Reward sum = 3.16, Last reward = 0.0, Steps = 17
# Episode 80: Reward sum = 1.68, Last reward = 0.0, Steps = 17
# Episode 81: Reward sum = 1.42, Last reward = 0.0, Steps = 18
# Episode 82: Reward sum = 1.54, Last reward = 0.0, Steps = 16
# Episode 83: Reward sum = 4.85, Last reward = 0.0, Steps = 15
# Episode 84: Reward sum = 1.48, Last reward = 0.0, Steps = 16
# Episode 85: Reward sum = 2.23, Last reward = 0.0, Steps = 15
# Episode 86: Reward sum = 1.72, Last reward = 0.0, Steps = 15
# Episode 87: Reward sum = 1.75, Last reward = 0.0, Steps = 17
# Episode 88: Reward sum = 5.81, Last reward = 0.0, Steps = 17
# Episode 89: Reward sum = 1.28, Last reward = 0.0, Steps = 15
# Episode 90: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 91: Reward sum = 2.79, Last reward = 0.0, Steps = 16
# Episode 92: Reward sum = 1.77, Last reward = 0.0, Steps = 16
# Episode 93: Reward sum = 65.12, Last reward = 63.0, Steps = 16
# Episode 94: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 95: Reward sum = 2.69, Last reward = 0.0, Steps = 19
# Episode 96: Reward sum = 1.70, Last reward = 0.0, Steps = 16
# Episode 97: Reward sum = -28.21, Last reward = -30.0, Steps = 16
# Episode 98: Reward sum = 2.72, Last reward = 0.0, Steps = 15
# Episode 99: Reward sum = 1.64, Last reward = 0.0, Steps = 15
# Episode 100: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 101: Reward sum = 1.48, Last reward = 0.0, Steps = 17
# Episode 102: Reward sum = 1.63, Last reward = 0.0, Steps = 15
# Episode 103: Reward sum = 1.92, Last reward = 0.0, Steps = 15
# Episode 104: Reward sum = 1.59, Last reward = 0.0, Steps = 17
# Episode 105: Reward sum = 1.70, Last reward = 0.0, Steps = 16
# Episode 106: Reward sum = 90.73, Last reward = 90.0, Steps = 17
# Episode 107: Reward sum = 3.25, Last reward = 0.0, Steps = 16
# Episode 108: Reward sum = 2.67, Last reward = 0.0, Steps = 15
# Episode 109: Reward sum = 2.33, Last reward = 0.0, Steps = 16
# Episode 110: Reward sum = 1.56, Last reward = 0.0, Steps = 17
# Episode 111: Reward sum = 0.60, Last reward = 0.0, Steps = 16
# Episode 112: Reward sum = 3.51, Last reward = 0.0, Steps = 15
# Episode 113: Reward sum = 1.72, Last reward = 0.0, Steps = 15
# Episode 114: Reward sum = 2.81, Last reward = 0.0, Steps = 16
# Episode 115: Reward sum = 2.24, Last reward = 0.0, Steps = 14
# Episode 116: Reward sum = 1.64, Last reward = 0.0, Steps = 15
# Episode 117: Reward sum = 2.08, Last reward = 0.0, Steps = 18
# Episode 118: Reward sum = -1.65, Last reward = -5.0, Steps = 16
# Episode 119: Reward sum = 1.78, Last reward = 0.0, Steps = 14
# Episode 120: Reward sum = 1.87, Last reward = 0.0, Steps = 15
# Episode 121: Reward sum = 16.40, Last reward = 15.0, Steps = 15
# Episode 122: Reward sum = 1.96, Last reward = 0.0, Steps = 18
# Episode 123: Reward sum = 2.44, Last reward = 0.0, Steps = 16
# Episode 124: Reward sum = -27.89, Last reward = -30.0, Steps = 12
# Episode 125: Reward sum = 1.94, Last reward = 0.0, Steps = 15
# Episode 126: Reward sum = -16.33, Last reward = -20.0, Steps = 16
# Episode 127: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 128: Reward sum = 91.59, Last reward = 90.0, Steps = 17
# Episode 129: Reward sum = 92.52, Last reward = 90.0, Steps = 17
# Episode 130: Reward sum = -16.04, Last reward = -17.0, Steps = 16
# Episode 131: Reward sum = 95.49, Last reward = 93.0, Steps = 15
# Episode 132: Reward sum = 96.52, Last reward = 93.0, Steps = 18
# Episode 133: Reward sum = 1.81, Last reward = 0.0, Steps = 16
# Episode 134: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 135: Reward sum = 1.04, Last reward = 0.0, Steps = 17
# Episode 136: Reward sum = 100.35, Last reward = 99.0, Steps = 16
# Episode 137: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 138: Reward sum = 2.38, Last reward = 0.0, Steps = 16
# Episode 139: Reward sum = 95.08, Last reward = 93.0, Steps = 17
# Episode 140: Reward sum = 59.57, Last reward = 57.0, Steps = 21
# Episode 141: Reward sum = -0.48, Last reward = -2.0, Steps = 15
# Episode 142: Reward sum = -36.54, Last reward = -39.0, Steps = 18
# Episode 143: Reward sum = 90.94, Last reward = 90.0, Steps = 18
# Episode 144: Reward sum = 1.85, Last reward = 0.0, Steps = 16
# Episode 145: Reward sum = 1.58, Last reward = 0.0, Steps = 17
# Episode 146: Reward sum = 2.25, Last reward = 0.0, Steps = 16
# Episode 147: Reward sum = 1.80, Last reward = 0.0, Steps = 18
# Episode 148: Reward sum = 1.70, Last reward = 0.0, Steps = 16
# Episode 149: Reward sum = 1.64, Last reward = 0.0, Steps = 14
# Episode 150: Reward sum = 2.35, Last reward = 0.0, Steps = 16
# Episode 151: Reward sum = 1.87, Last reward = 0.0, Steps = 14
# Episode 152: Reward sum = 1.94, Last reward = 0.0, Steps = 17
# Episode 153: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 154: Reward sum = 1.79, Last reward = 0.0, Steps = 16
# Episode 155: Reward sum = 1.76, Last reward = 0.0, Steps = 16
# Episode 156: Reward sum = 95.23, Last reward = 93.0, Steps = 19
# Episode 157: Reward sum = 1.57, Last reward = 0.0, Steps = 17
# Episode 158: Reward sum = 2.99, Last reward = 0.0, Steps = 16
# Episode 159: Reward sum = 1.97, Last reward = 0.0, Steps = 15
# Episode 160: Reward sum = 1.89, Last reward = 0.0, Steps = 16
# Episode 161: Reward sum = 1.85, Last reward = 0.0, Steps = 17
# Episode 162: Reward sum = 3.06, Last reward = 0.0, Steps = 17
# Episode 163: Reward sum = 0.99, Last reward = 0.0, Steps = 16
# Episode 164: Reward sum = 3.78, Last reward = 0.0, Steps = 17
# Episode 165: Reward sum = 2.41, Last reward = 0.0, Steps = 15
# Episode 166: Reward sum = 1.84, Last reward = 0.0, Steps = 16
# Episode 167: Reward sum = 2.17, Last reward = 0.0, Steps = 15
# Episode 168: Reward sum = 1.43, Last reward = 0.0, Steps = 15
# Episode 169: Reward sum = 2.78, Last reward = 0.0, Steps = 18
# Episode 170: Reward sum = 2.94, Last reward = 0.0, Steps = 17
# Episode 171: Reward sum = 2.67, Last reward = 0.0, Steps = 16
# Episode 172: Reward sum = -28.42, Last reward = -30.0, Steps = 17
# Episode 173: Reward sum = 2.23, Last reward = 0.0, Steps = 17
# Episode 174: Reward sum = 2.22, Last reward = 0.0, Steps = 16
# Episode 175: Reward sum = 1.82, Last reward = 0.0, Steps = 15
# Episode 176: Reward sum = 2.67, Last reward = 0.0, Steps = 15
# Episode 177: Reward sum = -34.02, Last reward = -35.0, Steps = 14
# Episode 178: Reward sum = 2.30, Last reward = 0.0, Steps = 15
# Episode 179: Reward sum = 2.37, Last reward = 0.0, Steps = 15
# Episode 180: Reward sum = 1.34, Last reward = 0.0, Steps = 15
# Episode 181: Reward sum = 2.58, Last reward = 0.0, Steps = 17
# Episode 182: Reward sum = 0.95, Last reward = 0.0, Steps = 17
# Episode 183: Reward sum = -2.88, Last reward = -5.0, Steps = 16
# Episode 184: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 185: Reward sum = -29.69, Last reward = -30.0, Steps = 16
# Episode 186: Reward sum = 19.08, Last reward = 18.0, Steps = 16
# Episode 187: Reward sum = 1.22, Last reward = 0.0, Steps = 16
# Episode 188: Reward sum = 1.69, Last reward = 0.0, Steps = 16
# Episode 189: Reward sum = 2.01, Last reward = 0.0, Steps = 15
# Episode 190: Reward sum = 3.31, Last reward = 0.0, Steps = 17
# Episode 191: Reward sum = 91.96, Last reward = 90.0, Steps = 14
# Episode 192: Reward sum = 3.10, Last reward = 0.0, Steps = 16
# Episode 193: Reward sum = 4.05, Last reward = 0.0, Steps = 16
# Episode 194: Reward sum = 2.18, Last reward = 0.0, Steps = 16
# Episode 195: Reward sum = 1.69, Last reward = 0.0, Steps = 15
# Episode 196: Reward sum = 61.96, Last reward = 60.0, Steps = 18
# Episode 197: Reward sum = 0.78, Last reward = 0.0, Steps = 16
# Episode 198: Reward sum = 1.38, Last reward = 0.0, Steps = 17
# Episode 199: Reward sum = 2.81, Last reward = 0.0, Steps = 16
# Episode 200: Reward sum = -28.27, Last reward = -30.0, Steps = 17
# Episode 201: Reward sum = 0.73, Last reward = 0.0, Steps = 16
# Episode 202: Reward sum = -28.65, Last reward = -30.0, Steps = 16
# Episode 203: Reward sum = 2.22, Last reward = 0.0, Steps = 15
# Episode 204: Reward sum = 3.27, Last reward = 0.0, Steps = 15
# Episode 205: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 206: Reward sum = 1.46, Last reward = 0.0, Steps = 15
# Episode 207: Reward sum = 2.19, Last reward = 0.0, Steps = 14
# Episode 208: Reward sum = 1.88, Last reward = 0.0, Steps = 15
# Episode 209: Reward sum = 1.85, Last reward = 0.0, Steps = 16
# Episode 210: Reward sum = 0.71, Last reward = 0.0, Steps = 17
# Episode 211: Reward sum = -2.06, Last reward = -5.0, Steps = 15
# Episode 212: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 213: Reward sum = -28.00, Last reward = -30.0, Steps = 18
# Episode 214: Reward sum = 2.34, Last reward = 0.0, Steps = 15
# Episode 215: Reward sum = -6.64, Last reward = -8.0, Steps = 16
# Episode 216: Reward sum = 2.06, Last reward = 0.0, Steps = 16
# Episode 217: Reward sum = 62.21, Last reward = 60.0, Steps = 17
# Episode 218: Reward sum = 1.13, Last reward = 0.0, Steps = 16
# Episode 219: Reward sum = 2.32, Last reward = 0.0, Steps = 16
# Episode 220: Reward sum = 1.52, Last reward = 0.0, Steps = 16
# Episode 221: Reward sum = 4.75, Last reward = 0.0, Steps = 16
# Episode 222: Reward sum = 1.12, Last reward = 0.0, Steps = 15
# Episode 223: Reward sum = -3.03, Last reward = -5.0, Steps = 15
# Episode 224: Reward sum = 61.85, Last reward = 60.0, Steps = 14
# Episode 225: Reward sum = 83.40, Last reward = 81.0, Steps = 17
# Episode 226: Reward sum = 1.80, Last reward = 0.0, Steps = 18
# Episode 227: Reward sum = 2.94, Last reward = 0.0, Steps = 17
# Episode 228: Reward sum = 1.16, Last reward = 0.0, Steps = 17
# Episode 229: Reward sum = -29.05, Last reward = -30.0, Steps = 16
# Episode 230: Reward sum = -28.32, Last reward = -30.0, Steps = 7
# Episode 231: Reward sum = 2.15, Last reward = 0.0, Steps = 16
# Episode 232: Reward sum = 1.31, Last reward = 0.0, Steps = 15
# Episode 233: Reward sum = -6.74, Last reward = -8.0, Steps = 17
# Episode 234: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 235: Reward sum = 1.84, Last reward = 0.0, Steps = 17
# Episode 236: Reward sum = -48.52, Last reward = -50.0, Steps = 17
# Episode 237: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 238: Reward sum = 3.23, Last reward = 0.0, Steps = 16
# Episode 239: Reward sum = 2.72, Last reward = 0.0, Steps = 14
# Episode 240: Reward sum = -2.51, Last reward = -5.0, Steps = 17
# Episode 241: Reward sum = 47.01, Last reward = 45.0, Steps = 13
# Episode 242: Reward sum = -26.40, Last reward = -30.0, Steps = 19
# Episode 243: Reward sum = 0.85, Last reward = 0.0, Steps = 17
# Episode 244: Reward sum = 0.97, Last reward = -2.0, Steps = 16
# Episode 245: Reward sum = 2.57, Last reward = 0.0, Steps = 16
# Episode 246: Reward sum = 1.19, Last reward = 0.0, Steps = 16
# Episode 247: Reward sum = 1.93, Last reward = 0.0, Steps = 17
# Episode 248: Reward sum = 94.30, Last reward = 90.0, Steps = 18
# Episode 249: Reward sum = 2.29, Last reward = 0.0, Steps = 16
# Episode 250: Reward sum = -4.09, Last reward = -5.0, Steps = 8
# Episode 251: Reward sum = 107.32, Last reward = 105.0, Steps = 18
# Episode 252: Reward sum = 2.41, Last reward = 0.0, Steps = 16
# Episode 253: Reward sum = 1.79, Last reward = 0.0, Steps = 17
# Episode 254: Reward sum = 2.12, Last reward = 0.0, Steps = 15
# Episode 255: Reward sum = 3.16, Last reward = 0.0, Steps = 18
# Episode 256: Reward sum = 2.39, Last reward = 0.0, Steps = 16
# Episode 257: Reward sum = 1.46, Last reward = 0.0, Steps = 16
# Episode 258: Reward sum = 1.62, Last reward = -2.0, Steps = 15
# Episode 259: Reward sum = 1.97, Last reward = 0.0, Steps = 17
# Episode 260: Reward sum = 3.10, Last reward = 0.0, Steps = 16
# Episode 261: Reward sum = 0.95, Last reward = 0.0, Steps = 16
# Episode 262: Reward sum = 2.29, Last reward = 0.0, Steps = 15
# Episode 263: Reward sum = 2.20, Last reward = 0.0, Steps = 16
# Episode 264: Reward sum = 53.46, Last reward = 51.0, Steps = 16
# Episode 265: Reward sum = 1.48, Last reward = 0.0, Steps = 16
# Episode 266: Reward sum = -3.46, Last reward = -5.0, Steps = 18
# Episode 267: Reward sum = 2.41, Last reward = 0.0, Steps = 16
# Episode 268: Reward sum = 8.86, Last reward = 7.0, Steps = 18
# Episode 269: Reward sum = 23.17, Last reward = 15.0, Steps = 13
# Episode 270: Reward sum = 3.15, Last reward = 0.0, Steps = 16
# Episode 271: Reward sum = 2.37, Last reward = 0.0, Steps = 15
# Episode 272: Reward sum = 12.23, Last reward = 9.0, Steps = 14
# Episode 273: Reward sum = 1.57, Last reward = 0.0, Steps = 17
# Episode 274: Reward sum = 1.77, Last reward = 0.0, Steps = 15
# Episode 275: Reward sum = 2.76, Last reward = 0.0, Steps = 17
# Episode 276: Reward sum = 1.65, Last reward = 0.0, Steps = 17
# Episode 277: Reward sum = 2.34, Last reward = 0.0, Steps = 16
# Episode 278: Reward sum = 2.59, Last reward = 0.0, Steps = 17
# Episode 279: Reward sum = 1.80, Last reward = 0.0, Steps = 16
# Episode 280: Reward sum = 1.85, Last reward = 0.0, Steps = 17
# Episode 281: Reward sum = 2.84, Last reward = 0.0, Steps = 15
# Episode 282: Reward sum = 1.02, Last reward = 0.0, Steps = 16
# Episode 283: Reward sum = 2.17, Last reward = 0.0, Steps = 17
# Episode 284: Reward sum = 3.50, Last reward = 0.0, Steps = 16
# Episode 285: Reward sum = 3.45, Last reward = 0.0, Steps = 16
# Episode 286: Reward sum = 2.01, Last reward = 0.0, Steps = 15
# Episode 287: Reward sum = 2.16, Last reward = 0.0, Steps = 16
# Episode 288: Reward sum = 0.85, Last reward = 0.0, Steps = 17
# Episode 289: Reward sum = 1.88, Last reward = 0.0, Steps = 17
# Episode 290: Reward sum = 1.59, Last reward = 0.0, Steps = 14
# Episode 291: Reward sum = 1.40, Last reward = 0.0, Steps = 16
# Episode 292: Reward sum = 2.16, Last reward = 0.0, Steps = 17
# Episode 293: Reward sum = 2.13, Last reward = 0.0, Steps = 17
# Episode 294: Reward sum = 1.80, Last reward = 0.0, Steps = 16
# Episode 295: Reward sum = 2.27, Last reward = 0.0, Steps = 15
# Episode 296: Reward sum = 4.17, Last reward = 0.0, Steps = 15
# Episode 297: Reward sum = 0.98, Last reward = 0.0, Steps = 15
# Episode 298: Reward sum = 1.39, Last reward = 0.0, Steps = 17
# Episode 299: Reward sum = 2.85, Last reward = 0.0, Steps = 16
# Episode 300: Reward sum = 1.26, Last reward = 0.0, Steps = 15
# Episode 301: Reward sum = 2.30, Last reward = 0.0, Steps = 17
# Episode 302: Reward sum = 2.86, Last reward = 0.0, Steps = 15
# Episode 303: Reward sum = 2.48, Last reward = 0.0, Steps = 17
# Episode 304: Reward sum = 3.47, Last reward = 0.0, Steps = 15
# Episode 305: Reward sum = 1.26, Last reward = 0.0, Steps = 16
# Episode 306: Reward sum = 94.04, Last reward = 93.0, Steps = 18
# Episode 307: Reward sum = 3.19, Last reward = 0.0, Steps = 14
# Episode 308: Reward sum = 1.49, Last reward = 0.0, Steps = 14
# Episode 309: Reward sum = 21.11, Last reward = 18.0, Steps = 18
# Episode 310: Reward sum = 90.93, Last reward = 90.0, Steps = 17
# Episode 311: Reward sum = 26.19, Last reward = 24.0, Steps = 16
# Episode 312: Reward sum = 9.24, Last reward = 0.0, Steps = 16
# Episode 313: Reward sum = 1.40, Last reward = 0.0, Steps = 17
# Episode 314: Reward sum = 66.63, Last reward = 63.0, Steps = 17
# Episode 315: Reward sum = 1.52, Last reward = 0.0, Steps = 14
# Episode 316: Reward sum = 62.51, Last reward = 60.0, Steps = 17
# Episode 317: Reward sum = 2.80, Last reward = 0.0, Steps = 17
# Episode 318: Reward sum = 0.41, Last reward = 0.0, Steps = 16
# Episode 319: Reward sum = 2.58, Last reward = 0.0, Steps = 15
# Episode 320: Reward sum = 2.21, Last reward = 0.0, Steps = 14
# Episode 321: Reward sum = 1.05, Last reward = 0.0, Steps = 17
# Episode 322: Reward sum = 0.46, Last reward = 0.0, Steps = 15
# Episode 323: Reward sum = 1.81, Last reward = 0.0, Steps = 16
# Episode 324: Reward sum = 1.79, Last reward = 0.0, Steps = 15
# Episode 325: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 326: Reward sum = 3.04, Last reward = 0.0, Steps = 14
# Episode 327: Reward sum = 2.35, Last reward = 0.0, Steps = 17
# Episode 328: Reward sum = 2.87, Last reward = 0.0, Steps = 16
# Episode 329: Reward sum = 3.33, Last reward = 0.0, Steps = 18
# Episode 330: Reward sum = -23.39, Last reward = -27.0, Steps = 17
# Episode 331: Reward sum = 2.77, Last reward = 0.0, Steps = 18
# Episode 332: Reward sum = 1.79, Last reward = 0.0, Steps = 18
# Episode 333: Reward sum = 2.42, Last reward = 0.0, Steps = 15
# Episode 334: Reward sum = 16.87, Last reward = 15.0, Steps = 10
# Episode 335: Reward sum = -36.03, Last reward = -39.0, Steps = 18
# Episode 336: Reward sum = 1.83, Last reward = 0.0, Steps = 16
# Episode 337: Reward sum = 2.23, Last reward = 0.0, Steps = 19
# Episode 338: Reward sum = -27.44, Last reward = -30.0, Steps = 17
# Episode 339: Reward sum = 1.31, Last reward = 0.0, Steps = 16
# Episode 340: Reward sum = 2.50, Last reward = 0.0, Steps = 16
# Episode 341: Reward sum = 1.52, Last reward = 0.0, Steps = 15
# Episode 342: Reward sum = 1.15, Last reward = 0.0, Steps = 17
# Episode 343: Reward sum = 2.78, Last reward = 0.0, Steps = 16
# Episode 344: Reward sum = 11.97, Last reward = 10.0, Steps = 17
# Episode 345: Reward sum = -34.61, Last reward = -36.0, Steps = 17
# Episode 346: Reward sum = 2.00, Last reward = 0.0, Steps = 16
# Episode 347: Reward sum = -14.39, Last reward = -17.0, Steps = 16
# Episode 348: Reward sum = 26.38, Last reward = 24.0, Steps = 17
# Episode 349: Reward sum = 2.57, Last reward = 0.0, Steps = 16
# Episode 350: Reward sum = 2.53, Last reward = 0.0, Steps = 16
# Episode 351: Reward sum = 1.99, Last reward = 0.0, Steps = 16
# Episode 352: Reward sum = 2.91, Last reward = 0.0, Steps = 16
# Episode 353: Reward sum = 1.30, Last reward = 0.0, Steps = 16
# Episode 354: Reward sum = 2.37, Last reward = 0.0, Steps = 15
# Episode 355: Reward sum = 1.81, Last reward = 0.0, Steps = 15
# Episode 356: Reward sum = 1.41, Last reward = 0.0, Steps = 16
# Episode 357: Reward sum = 2.01, Last reward = 0.0, Steps = 17
# Episode 358: Reward sum = 100.49, Last reward = 99.0, Steps = 16
# Episode 359: Reward sum = 92.43, Last reward = 90.0, Steps = 18
# Episode 360: Reward sum = 1.61, Last reward = 0.0, Steps = 17
# Episode 361: Reward sum = -3.63, Last reward = -5.0, Steps = 12
# Episode 362: Reward sum = 16.29, Last reward = 15.0, Steps = 15
# Episode 363: Reward sum = 1.33, Last reward = 0.0, Steps = 15
# Episode 364: Reward sum = 1.06, Last reward = 0.0, Steps = 16
# Episode 365: Reward sum = 3.14, Last reward = 0.0, Steps = 15
# Episode 366: Reward sum = -16.36, Last reward = -17.0, Steps = 11
# Episode 367: Reward sum = 2.25, Last reward = 0.0, Steps = 17
# Episode 368: Reward sum = -4.34, Last reward = -5.0, Steps = 8
# Episode 369: Reward sum = 2.22, Last reward = 0.0, Steps = 15
# Episode 370: Reward sum = 2.90, Last reward = 0.0, Steps = 16
# Episode 371: Reward sum = 70.98, Last reward = 69.0, Steps = 16
# Episode 372: Reward sum = 1.74, Last reward = 0.0, Steps = 16
# Episode 373: Reward sum = 1.55, Last reward = 0.0, Steps = 15
# Episode 374: Reward sum = 15.75, Last reward = 15.0, Steps = 4
# Episode 375: Reward sum = 0.82, Last reward = 0.0, Steps = 16
# Episode 376: Reward sum = 1.51, Last reward = 0.0, Steps = 18
# Episode 377: Reward sum = 1.71, Last reward = 0.0, Steps = 18
# Episode 378: Reward sum = -27.28, Last reward = -30.0, Steps = 14
# Episode 379: Reward sum = 3.04, Last reward = 0.0, Steps = 16
# Episode 380: Reward sum = 95.58, Last reward = 93.0, Steps = 17
# Episode 381: Reward sum = 2.55, Last reward = 0.0, Steps = 16
# Episode 382: Reward sum = 2.07, Last reward = 0.0, Steps = 15
# Episode 383: Reward sum = 65.13, Last reward = 63.0, Steps = 16
# Episode 384: Reward sum = 3.05, Last reward = 0.0, Steps = 16
# Episode 385: Reward sum = 1.75, Last reward = 0.0, Steps = 15
# Episode 386: Reward sum = 0.70, Last reward = -2.0, Steps = 16
# Episode 387: Reward sum = 2.24, Last reward = 0.0, Steps = 15
# Episode 388: Reward sum = 2.27, Last reward = 0.0, Steps = 16
# Episode 389: Reward sum = 2.30, Last reward = 0.0, Steps = 16
# Episode 390: Reward sum = 2.28, Last reward = 0.0, Steps = 17
# Episode 391: Reward sum = -25.38, Last reward = -27.0, Steps = 16
# Episode 392: Reward sum = 2.61, Last reward = 0.0, Steps = 17
# Episode 393: Reward sum = 2.11, Last reward = 0.0, Steps = 16
# Episode 394: Reward sum = 91.09, Last reward = 90.0, Steps = 10
# Episode 395: Reward sum = 1.63, Last reward = 0.0, Steps = 17
# Episode 396: Reward sum = 2.57, Last reward = 0.0, Steps = 17
# Episode 397: Reward sum = 14.15, Last reward = 0.0, Steps = 17
# Episode 398: Reward sum = 2.09, Last reward = 0.0, Steps = 14
# Episode 399: Reward sum = 1.33, Last reward = 0.0, Steps = 17
# Episode 400: Reward sum = 16.43, Last reward = 15.0, Steps = 15

# %%
plot_rewards(logger.log_dir, agent_eval.eval_rewards_per_episode_last_one, title="Evaluation Rewards", save_fig=True)
